# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# Configure image format to be ‘svg’
# %config InlineBackend.figure_format = 'svg'

# allow visuals to render within notebook
# %matplotlib inline

# %%
# Make some room to see stuff (i.e. drop display limits on Pandas rows & cols - be careful w/ big df's!)

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # 1. Read in the "daily_per_complex" dataframe csvs previously generated

# %%
daily_per_complex_2019 = pd.read_csv('daily_per_complex_2019.csv')
print(daily_per_complex_2019.shape)
display(daily_per_complex_2019.head(2))
daily_per_complex_2019.tail(2)
# Out:
# (25567, 20)
#    COMPLEX_ID        DATE  NET_DAILY_STATION_ENTRIES        STATION_x  \
# 0           1  2019-05-01                      18999  DITMARS BL-31 S
# 1           1  2019-05-02                      19257  DITMARS BL-31 S
#
#          STATION_y               STOP_NAME LINE_NAME_x LINE_NAME_y DIVISION  \
# 0  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW      BMT
# 1  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW      BMT
#
#   BOROUGH  WEEKDAY     DESC  GTFS_LATITUDE  GTFS_LONGITUDE     LINE REMOTE  \
# 0       Q        1  REGULAR      40.775036      -73.912034  Astoria   R095
# 1       Q        1  REGULAR      40.775036      -73.912034  Astoria   R095
#
#   BOOTH       SCP                      ID  ZIPCODE
# 0  R515  00-00-00  R515 - R095 - 00-00-00    11101
# 1  R515  00-00-00  R515 - R095 - 00-00-00    11101
#        COMPLEX_ID        DATE  NET_DAILY_STATION_ENTRIES   STATION_x  \
# 25565          99  2019-06-29                       3587  LORIMER ST
# 25566          99  2019-06-30                       3284  LORIMER ST
#
#         STATION_y   STOP_NAME LINE_NAME_x LINE_NAME_y DIVISION BOROUGH  \
# 25565  LORIMER ST  Lorimer St          JM          JM      BMT      Bk
# 25566  LORIMER ST  Lorimer St          JM          JM      BMT      Bk
#
#        WEEKDAY     DESC  GTFS_LATITUDE  GTFS_LONGITUDE     LINE REMOTE BOOTH  \
# 25565        0  REGULAR      40.703869      -73.947408  Jamaica   R353  J005
# 25566        0  REGULAR      40.703869      -73.947408  Jamaica   R353  J005
#
#             SCP                      ID  ZIPCODE
# 25565  00-00-00  J005 - R353 - 00-00-00    11207
# 25566  00-00-00  J005 - R353 - 00-00-00    11207

# %%
daily_per_complex_2021 = pd.read_csv('daily_per_complex_2021.csv')
print(daily_per_complex_2021.shape)
display(daily_per_complex_2021.head(2))
daily_per_complex_2021.tail(2)
# Out:
# (25615, 20)
#    COMPLEX_ID        DATE  NET_DAILY_STATION_ENTRIES        STATION_x  \
# 0           1  2021-05-01                       3485  DITMARS BL-31 S
# 1           1  2021-05-02                       2378  DITMARS BL-31 S
#
#          STATION_y               STOP_NAME LINE_NAME_x LINE_NAME_y DIVISION  \
# 0  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW      BMT
# 1  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW      BMT
#
#   BOROUGH  WEEKDAY     DESC  GTFS_LATITUDE  GTFS_LONGITUDE     LINE REMOTE  \
# 0       Q        0  REGULAR      40.775036      -73.912034  Astoria   R095
# 21967  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 21968  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 21969  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 21970  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 21971  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 21972  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 21973  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 21974  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 21975  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 21976  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 21977  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 21978  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 21979  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 21980  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 21981  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 21982  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 21983  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 21984  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 21985  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 21986  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 21987  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 21988  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 21989  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 21990  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 21991  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 21992  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 21993  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 21994  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 21995  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 21996  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 21997  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 21998  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 21999  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 22000  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 22001  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 22002  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 22003  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 22004  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 22005  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 22006  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017
# 22007  Lexington Av   R045  R236  00-00-00  R236 - R045 - 00-00-00    10017

# %% [markdown]
# #### 1a) Find the Busiest N Complexes

# %%
# Adjustable value for the number of these we want to see

N = 50 # Number of overall median busiest to find
M = 5  # Number of median busiest per borough to find

# %%
median_busiest_2019 = daily_per_complex_2019 \
             .groupby(['COMPLEX_ID', 'STATION_x', 'BOROUGH']).first() \
             .reset_index().drop(columns='NET_DAILY_STATION_ENTRIES')
median_busiest_2019.shape
# Out:
# (421, 19)

# %%
median_busiest_2019 = daily_per_complex_2019 \
             .groupby(['COMPLEX_ID', 'STATION_x', 'BOROUGH'])['NET_DAILY_STATION_ENTRIES'].median()

# %%
median_busiest_2019.shape
# Out:
# (421,)

# %%
median_busiest_bronx_2019 = median_busiest_2019[median_busiest_2019['BOROUGH'] == 'Bx']
median_busiest_bronx_2019.reset_index(drop=True, inplace=True)

median_busiest_brooklyn_2019 = median_busiest_2019[median_busiest_2019['BOROUGH'] == 'Bk']
median_busiest_brooklyn_2019.reset_index(drop=True, inplace=True)

median_busiest_manhattan_2019 = median_busiest_2019[median_busiest_2019['BOROUGH'] == 'M']
median_busiest_manhattan_2019.reset_index(drop=True, inplace=True)

median_busiest_queens_2019 = median_busiest_2019[median_busiest_2019['BOROUGH'] == 'Q']
median_busiest_queens_2019.reset_index(drop=True, inplace=True)

# %%
daily_busiest_2019 = daily_per_complex_2019[daily_per_complex_2019['COMPLEX_ID'] \
                                           .isin(median_busiest_2019['COMPLEX_ID'].unique())]
daily_busiest_2019.reset_index(drop=True, inplace=True)
daily_busiest_2019.shape
# Out:
# (25567, 20)

# %%
daily_busiest_bronx_2019 = daily_per_complex_2019[daily_per_complex_2019['COMPLEX_ID'] \
                                           .isin(median_busiest_bronx_2019['COMPLEX_ID'].unique())]
daily_busiest_bronx_2019.reset_index(drop=True, inplace=True)
daily_busiest_bronx_2019.shape
# Out:
# (4148, 20)

# %%
daily_busiest_brooklyn_2019 = daily_per_complex_2019[daily_per_complex_2019['COMPLEX_ID'] \
                                           .isin(median_busiest_brooklyn_2019['COMPLEX_ID'].unique())]
daily_busiest_brooklyn_2019.reset_index(drop=True, inplace=True)
daily_busiest_brooklyn_2019.shape
# Out:
# (9448, 20)

# %%
daily_busiest_manhattan_2019 = daily_per_complex_2019[daily_per_complex_2019['COMPLEX_ID'] \
                                           .isin(median_busiest_manhattan_2019['COMPLEX_ID'].unique())]
daily_busiest_manhattan_2019.reset_index(drop=True, inplace=True)
daily_busiest_manhattan_2019.shape
# Out:
# (7253, 20)

# %%
daily_busiest_queens_2019 = daily_per_complex_2019[daily_per_complex_2019['COMPLEX_ID'] \
                                           .isin(median_busiest_queens_2019['COMPLEX_ID'].unique())]
daily_busiest_queens_2019.reset_index(drop=True, inplace=True)
daily_busiest_queens_2019.shape
# Out:
# (4718, 20)

# %% [markdown]
# #### Let's visualize the Top N overall

# %%
plt.figure(figsize=(8,7))

labels = []
for c, complex in enumerate(daily_busiest_2019['COMPLEX_ID'].unique()):
    df = daily_busiest_2019[daily_busiest_2019['COMPLEX_ID'] == complex]
    df.reset_index(drop=True, inplace=True)
    if df.loc[0, 'BOROUGH'] == 'M':
        linestyle = 'dotted'
    elif df.loc[0, 'BOROUGH'] == 'Bk':
        linestyle = 'dashdot'
    elif df.loc[0, 'BOROUGH'] == 'Q':
        linestyle = 'dashed'
    else:
        linestyle = 'solid'
    plt.plot(df['DATE'] , df['NET_DAILY_STATION_ENTRIES'], linestyle=linestyle)
    labels.append(df.loc[0,'STATION_x'] + ' (' + df.loc[0,'BOROUGH'] + ')')
    if c == N - 1:
        break

plt.title('Busiest ' + str(N) + ' Stations, May-June 2019: Mostly Manhattan (barely any Bronx)')
plt.xlabel('Date')
plt.ylabel('Number of Entries')
plt.xticks(df[pd.to_datetime(df['DATE']).dt.weekday == 0]['DATE'], rotation = 45)
plt.legend(labels = labels, loc=(1.04,0), fontsize=8)

del df

# %% [markdown]
# #### Obviously, the Top N overall is highly biased towards Manhattan; Let's try Top 5 per Borough

# %%
plt.figure(figsize=(8,7))

labels = []
for c, complex in enumerate(daily_busiest_bronx_2019['COMPLEX_ID'].unique()):
    df = daily_busiest_bronx_2019[daily_busiest_bronx_2019['COMPLEX_ID'] == complex]
    df.reset_index(drop=True, inplace=True)
    linestyle = 'solid'
    plt.plot(df['DATE'] , df['NET_DAILY_STATION_ENTRIES'], linestyle=linestyle)
    labels.append(df.loc[0,'STATION_x'] + ' (' + df.loc[0,'BOROUGH'] + ')')
    if c == M - 1:
        break
    
for c, complex in enumerate(daily_busiest_manhattan_2019['COMPLEX_ID'].unique()):
    df = daily_busiest_manhattan_2019[daily_busiest_manhattan_2019['COMPLEX_ID'] == complex]
    df.reset_index(drop=True, inplace=True)
    linestyle = 'dotted'
    plt.plot(df['DATE'] , df['NET_DAILY_STATION_ENTRIES'], linestyle=linestyle)
    labels.append(df.loc[0,'STATION_x'] + ' (' + df.loc[0,'BOROUGH'] + ')')
    if c == M - 1:
        break
    
for c, complex in enumerate(daily_busiest_queens_2019['COMPLEX_ID'].unique()):
    df = daily_busiest_queens_2019[daily_busiest_queens_2019['COMPLEX_ID'] == complex]
    df.reset_index(drop=True, inplace=True)
    linestyle = 'dashdot'
    plt.plot(df['DATE'] , df['NET_DAILY_STATION_ENTRIES'], linestyle=linestyle)
    labels.append(df.loc[0,'STATION_x'] + ' (' + df.loc[0,'BOROUGH'] + ')')
    if c == M - 1:
        break

for c, complex in enumerate(daily_busiest_brooklyn_2019['COMPLEX_ID'].unique()):
    df = daily_busiest_brooklyn_2019[daily_busiest_brooklyn_2019['COMPLEX_ID'] == complex]
    df.reset_index(drop=True, inplace=True)
    linestyle = 'dashed'
    plt.plot(df['DATE'] , df['NET_DAILY_STATION_ENTRIES'], linestyle=linestyle)
    labels.append(df.loc[0,'STATION_x'] + ' (' + df.loc[0,'BOROUGH'] + ')')
    if c == M - 1:
        break

plt.title('Busiest ' + str(M) + ' Stations per Borough, May-June 2019')
plt.xlabel('Date')
plt.ylabel('Number of Entries')
plt.xticks(df[pd.to_datetime(df['DATE']).dt.weekday == 0]['DATE'], rotation = 45)
plt.legend(labels = labels, loc=(1.04,0), fontsize=8)

del df

# %%
#######################################################
#######################################################
#######################################################
#######################################################
#######################################################
#######################################################
#######################################################
#######################################################
Old stuff below this line!!! (This is meant to CRASH if all cells accidentally run)
# Out:
#   File "/var/folders/16/my2sdbrn4hvfl3_91fx0wj9c0000gn/T/ipykernel_3401/3151893241.py", line 3
#     Old stuff below this line!!! (This is meant to CRASH if all cells accidentally run)
#         ^
# SyntaxError: invalid syntax

# %%
daily_entries_2019[daily_entries_2019['NET_ENTRIES'] == daily_entries_2019['NET_ENTRIES'].max()]
# Out:
#           C/A  UNIT       SCP     STATION LINENAME        DATE  ENTRIES  \
# 172144  PTH07  R550  00-01-08  CITY / BUS        1  2019-06-11      116
#
#         PREV_DAY_ENTRIES  NET_ENTRIES  WEEKDAY
# 172144            296450       296334        1

# %%
# Drop unnecessary columns

daily_entries_2019.drop(['C/A', 'UNIT', 'SCP', 'ENTRIES', 'PREV_DAY_ENTRIES'], axis=1, inplace=True)
daily_entries_2021.drop(['C/A', 'UNIT', 'SCP', 'ENTRIES', 'PREV_DAY_ENTRIES'], axis=1, inplace=True)

display(daily_entries_2019.head())
display(daily_entries_2021.head())
# Out:
#   STATION LINENAME        DATE  NET_ENTRIES  WEEKDAY
# 0   59 ST  NQR456W  2019-05-01         1555        1
# 1   59 ST  NQR456W  2019-05-02         1555        1
# 2   59 ST  NQR456W  2019-05-03         1576        1
# 3   59 ST  NQR456W  2019-05-04          822        0
# 4   59 ST  NQR456W  2019-05-05          635        0
#   STATION LINENAME        DATE  NET_ENTRIES  WEEKDAY
# 0   59 ST  NQR456W  2021-05-01          457        0
# 1   59 ST  NQR456W  2021-05-02          326        0
# 2   59 ST  NQR456W  2021-05-03          498        1
# 3   59 ST  NQR456W  2021-05-04          566        1
# 4   59 ST  NQR456W  2021-05-05          600        1

# %% [markdown]
# ### 2d) Reduce both dataframes down to intersecting set of stations

# %%
# Form a new column 'STATION_ID'

daily_entries_2019['STATION_ID'] =  daily_entries_2019['STATION'] + ' - ' + daily_entries_2019['LINENAME']
daily_entries_2021['STATION_ID'] =  daily_entries_2021['STATION'] + ' - ' + daily_entries_2021['LINENAME']

# %%
# Find unique STATION_IDs for both years

unique_stations_2019 = daily_entries_2019['STATION_ID'].unique()
unique_stations_2021 = daily_entries_2021['STATION_ID'].unique()

print(unique_stations_2019.shape[0])
print(unique_stations_2021.shape[0])
# Out:
# 478
# 478

# %%
np.setdiff1d(unique_stations_2019, unique_stations_2021)
# Out:
# array(['181 ST - 1'], dtype=object)

# %%
np.setdiff1d(unique_stations_2021, unique_stations_2019)
# Out:
# array(['ASTORIA BLVD - NQW'], dtype=object)

# %%
common_stations = np.intersect1d(unique_stations_2019, unique_stations_2021)
common_stations.shape[0]
# Out:
# 477

# %%
# Filter 2019 entries down to just the common stations

print(daily_entries_2019.shape)
daily_entries_2019 = daily_entries_2019[daily_entries_2019['STATION_ID'].isin(common_stations)]
print(daily_entries_2019.shape)
# Out:
# (295643, 6)
# (295338, 6)

# %%
# So the same for 2021

print(daily_entries_2021.shape)
daily_entries_2021 = daily_entries_2021[daily_entries_2021['STATION_ID'].isin(common_stations)]
print(daily_entries_2021.shape)
# Out:
# (304524, 6)
# (303670, 6)

# %%
daily_entries_2019 = \
         daily_entries_2019[['STATION_ID', 'STATION', 'LINENAME', 'DATE', 'NET_ENTRIES', 'WEEKDAY']]
daily_entries_2021 = \
         daily_entries_2021[['STATION_ID', 'STATION', 'LINENAME', 'DATE', 'NET_ENTRIES', 'WEEKDAY']]


display(daily_entries_2019.head())
display(daily_entries_2021.head())
# Out:
#         STATION_ID STATION LINENAME        DATE  NET_ENTRIES  WEEKDAY
# 0  59 ST - NQR456W   59 ST  NQR456W  2019-05-01         1555        1
# 1  59 ST - NQR456W   59 ST  NQR456W  2019-05-02         1555        1
# 2  59 ST - NQR456W   59 ST  NQR456W  2019-05-03         1576        1
# 3  59 ST - NQR456W   59 ST  NQR456W  2019-05-04          822        0
# 4  59 ST - NQR456W   59 ST  NQR456W  2019-05-05          635        0
#         STATION_ID STATION LINENAME        DATE  NET_ENTRIES  WEEKDAY
# 0  59 ST - NQR456W   59 ST  NQR456W  2021-05-01          457        0
# 1  59 ST - NQR456W   59 ST  NQR456W  2021-05-02          326        0
# 2  59 ST - NQR456W   59 ST  NQR456W  2021-05-03          498        1
# 3  59 ST - NQR456W   59 ST  NQR456W  2021-05-04          566        1
# 4  59 ST - NQR456W   59 ST  NQR456W  2021-05-05          600        1

# %% [markdown]
# ### 2e) Write daily_entries dataframes to file for future use (can avoid rerunning all of the above)

# %%
daily_entries_2019.to_csv('daily_entries_2019.csv', index=False)
daily_entries_2021.to_csv('daily_entries_2021.csv', index=False)

# %% [markdown]
# ## 3. Identify Standout Stations

# %% [markdown]
# ### 3a) Form Weekday Medians per Station

# %%
# Median should protect against skewing due to outlier days

# weekday_medians_2019 = 
daily_entries_2019[daily_entries_2019['WEEKDAY'] == 1].groupby('STATION_ID')['NET_ENTRIES'].median().sort_values(ascending=False).reset_index().head(10)
# Out:
#                      STATION_ID  NET_ENTRIES
# 0                   YORK ST - F       4625.0
# 1                 GRAND ST - BD       3077.0
# 2               MYRTLE AV - JMZ       3053.5
# 3              NOSTRAND AV - AC       2810.0
# 4                     96 ST - 6       2683.5
# 5     14 ST-UNION SQ - LNQR456W       2568.0
# 6  TIMES SQ-42 ST - 1237ACENQRS       2521.0
# 7                     7 AV - BQ       2450.0
# 8       JKSN HT-ROOSVLT - EFMR7       2437.5
# 9                    23 ST - FM       2436.0

# %%
daily_entries_2019.groupby('STATION_ID')['NET_ENTRIES'].median().sort_values(ascending=False).reset_index().head(10)
# Out:
#                      STATION_ID  NET_ENTRIES
# 0                   YORK ST - F       3708.0
# 147715  YORK ST - F  YORK ST        F  2019-06-26         3579        1
# 147716  YORK ST - F  YORK ST        F  2019-06-27         3805        1
# 147717  YORK ST - F  YORK ST        F  2019-06-28         3741        1
# 147718  YORK ST - F  YORK ST        F  2019-06-29         1897        0
# 147719  YORK ST - F  YORK ST        F  2019-06-30         1922        0

# %% [markdown]
# ## Bring in External Data

# %% [markdown]
# ### Start with mapping neighborhoods to zip codes

# %%
neighborhoods_zips = pd.read_csv('https://raw.githubusercontent.com/erikgregorywebb/nyc-housing/master/Data/nyc-zip-codes.csv',)

# Check for NaNs
display(neighborhoods_zips[neighborhoods_zips.isna().any(axis=1)])

display(neighborhoods_zips.head())

# Confirm all zips are of length 5
print(neighborhoods_zips['ZipCode'].unique())
# Out:
# Empty DataFrame
# Columns: [Borough, Neighborhood, ZipCode]
# Index: []
#   Borough            Neighborhood  ZipCode
# 0   Bronx           Central Bronx    10453
# 1   Bronx           Central Bronx    10457
# 2   Bronx           Central Bronx    10460
# 3   Bronx  Bronx Park and Fordham    10458
# 4   Bronx  Bronx Park and Fordham    10467
# [10453 10457 10460 10458 10467 10468 10451 10452 10456 10454 10455 10459
#  10474 10463 10471 10466 10469 10470 10475 10461 10462 10464 10465 10472
#  10473 11212 11213 11216 11233 11238 11209 11214 11228 11204 11218 11219
#  11230 11234 11236 11239 11223 11224 11229 11235 11201 11205 11215 11217
#  11231 11203 11210 11225 11226 11207 11208 11211 11222 11220 11232 11206
#  11221 11237 10026 10027 10030 10037 10039 10001 10011 10018 10019 10020
#  10036 10029 10035 10010 10016 10017 10022 10012 10013 10014 10004 10005
#  10006 10007 10038 10280 10002 10003 10009 10021 10028 10044 10065 10075
#  10128 10023 10024 10025 10031 10032 10033 10034 10040 11361 11362 11363
#  11364 11354 11355 11356 11357 11358 11359 11360 11365 11366 11367 11412
#  11423 11432 11433 11434 11435 11436 11101 11102 11103 11104 11105 11106
#  11374 11375 11379 11385 11691 11692 11693 11694 11695 11697 11004 11005
#  11411 11413 11422 11426 11427 11428 11429 11414 11415 11416 11417 11418
#  11419 11420 11421 11368 11369 11370 11372 11373 11377 11378 10302 10303
#  10310 10306 10307 10308 10309 10312 10301 10304 10305 10314]

# %% [markdown]
# ### Now Latitude & Longitude per Station

# %%
# Longitude comes first in this dataset: 'POINT(longitude, latitude)'

lat_long_stations = pd.read_csv('https://raw.githubusercontent.com/peterskim12/appsearch-subway-example/master/DOITT_SUBWAY_STATION_01_13SEPT2010.csv', 
                                 header=None)
lat_long_stations = lat_long_stations.iloc[:, 2:4]
lat_long_stations.columns = ['STATION', 'LONG_LAT']
lat_long_stations['LATITUDE'] = lat_long_stations['LONG_LAT'] \
                                  .apply(lambda x: float(x.replace('POINT (', '').replace(')', '').split()[1]))
lat_long_stations['LONGITUDE'] = lat_long_stations['LONG_LAT'] \
                                  .apply(lambda x: float(x.replace('POINT (', '').replace(')', '').split()[0]))
lat_long_stations.drop('LONG_LAT', axis=1, inplace=True)

lat_long_stations
# Out:
#                                 STATION   LATITUDE  LONGITUDE
# 446                        Franklin Ave  40.681380 -73.956848
# 447           Clinton - Washington Aves  40.683263 -73.965838
# 448                          Forest Ave  40.704412 -73.903075
# 449                            110th St  40.795020 -73.944250
# 450                             86th St  40.779492 -73.955589
# 451                             York St  40.699743 -73.986885
# 452                             High St  40.699337 -73.990531
# 453                       Lafayette Ave  40.686113 -73.973946
# 454                        President St  40.667884 -73.950589
# 455                            Woodlawn  40.886037 -73.878751
# 456                         Bleecker St  40.725915 -73.994659
# 457                            103rd St  40.790600 -73.947478
# 458                          Euclid Ave  40.675377 -73.872106
# 459                             88th St  40.679843 -73.851470
# 460                        Cortelyou Rd  40.640940 -73.963790
# 461                            116th St  40.798629 -73.941617
# 462                         Parkchester  40.833226 -73.860816
# 463                         Franklin St  40.719318 -74.006886
# 464                             80th St  40.679371 -73.858992
# 465                 5th Ave - Bryant Pk  40.753821 -73.981963
# 466                           Spring St  40.722301 -73.997141
# 467                            125th St  40.804138 -73.937594
# 468         Coney Island - Stillwell Av  40.577281 -73.981236
# 469              34th St - Hudson Yards  40.755446 -74.002197
# 470                             72nd St  40.768803 -73.958362
# 471                             86th St  40.777861 -73.951771
# 472                             96th St  40.784237 -73.947066

# %%
# Clean the STATION column (making it match the MTA data in form)

lat_long_stations['STATION'] = \
        lat_long_stations['STATION'].apply(lambda x: x.replace('1st', '1').replace('2nd', '2').replace('3rd', '3') \
                                   .replace('0th', '0').replace('1th', '1').replace('2th', '2').replace('3th', '3') \
                                   .replace('4th', '4').replace('5th', '5').replace('6th', '6').replace('7th', '7') \
                                   .replace('8th', '8').replace('9th', '9').upper())
lat_long_stations['STATION'].values
# Out:
# array(['ASTOR PL', 'CANAL ST', '50 ST', 'BERGEN ST', 'PENNSYLVANIA AVE',
#        '238 ST', 'CATHEDRAL PKWY (110 ST)', 'KINGSTON - THROOP AVES',
#        '65 ST', '36 ST', 'DELANCEY ST - ESSEX ST', 'VAN SICLEN AVE',
#        'NORWOOD AVE', '104-102 STS', 'DEKALB AVE', 'BEACH 105 ST',
#        'BEACH 90 ST', 'FREEMAN ST', 'INTERVALE AVE', '182-183 STS',
#        '174-175 STS', '167 ST', 'METS - WILLETS POINT', 'JUNCTION BLVD',
#        'FLUSHING - MAIN ST', 'BUHRE AVE', '3 AVE - 138 ST',
#        'CASTLE HILL AVE', 'BROOKLYN BRIDGE - CITY HALL', 'ZEREGA AVE',
#        'GRAND CENTRAL - 42 ST', '33 ST', '96 ST', '77 ST', 'CHAUNCEY ST',
#        'UNION ST', 'ELMHURST AVE', 'RALPH AVE', 'PELHAM PKWY',
#        'GUN HILL RD', 'NEREID AVE (238 ST)', 'FRANKLIN AVE', 'SIMPSON ST',
#        'BRONX PARK EAST', 'WINTHROP ST', 'VAN SICLEN AVE',
#        '149 ST - GRAND CONCOURSE', '161 ST - YANKEE STADIUM',
#        'LEXINGTON AVE - 59 ST', 'E 149 ST', 'MORRISON AV - SOUNDVIEW',
#        'WHITLOCK AVE', 'ST LAWRENCE AVE', 'WOODSIDE - 61 ST',
#        'FAR ROCKAWAY - MOTT AVE', '72 ST', '96 ST', '168 ST',
#        'KINGSBRIDGE RD', '42 ST - BRYANT PK', 'PROSPECT PARK', '55 ST',
#        'JAMAICA - VAN WYCK', 'KEW GARDENS - UNION TPKE',
#        'SUTPHIN BLVD - ARCHER AV', 'COURT SQ - 23 ST', '67 AVE',
#        'GRAND AVE - NEWTOWN', 'DITMAS AVE', 'CLASSON AVE', 'BROADWAY',
#        'LORIMER ST', 'SUTTER AVE', 'WILSON AVE', 'HALSEY ST',
#        'LORIMER ST', '8 AVE', '36 AVE', 'BROADWAY', 'TIMES SQ - 42 ST',
#        'GRAND CENTRAL - 42 ST', 'PARK PL', '111 ST',
#        'W 4 ST - WASHINGTON SQ (LOWER)', '51 ST', '86 ST', '233 ST',
#        '66 ST - LINCOLN CTR', 'HUNTS POINT AVE', 'CANAL ST',
#        'MIDDLETOWN RD', '23 ST', 'COURT SQ', '59 ST - COLUMBUS CIRCLE',
#        'HUNTERS POINT AVE', '23 ST', 'HOUSTON ST', '104 ST',
#        'BROAD CHANNEL', 'OCEAN PKWY', 'VERNON BLVD - JACKSON AVE',
#        '68 ST - HUNTER COLLEGE', 'QUEENSBORO PLZ', 'ROCKAWAY BLVD',
#        'UNION SQ - 14 ST', 'BEDFORD - NOSTRAND AVES',
#        '15 ST - PROSPECT PARK', '7 AVE', 'FT HAMILTON PKWY', 'CHURCH AVE',
#        'BEVERLY RD', 'CHURCH AVE', 'NEWKIRK AVE', 'PARKSIDE AVE',
#        'GRAND ARMY PLAZA', "ATLANTIC AV - BARCLAY'S CENTER",
#        'ROCKAWAY AVE', 'FULTON ST', 'CLINTON - WASHINGTON AVES', '7 AVE',
#        "ATLANTIC AV - BARCLAY'S CENTER", "ATLANTIC AV - BARCLAY'S CENTER",
#        'BOROUGH HALL', 'AQUEDUCT RACETRACK', 'MORRIS PARK', 'PELHAM PKWY',
#        'NOSTRAND AVE', 'NEVINS ST', 'EASTERN PKWY - BKLYN MUSEUM',
#        'BEVERLY RD', 'CHURCH AVE', 'NEWKIRK AVE',
#        'BROOKLYN COLLEGE - FLATBUSH AVE', 'STERLING ST',
#        'CROWN HTS - UTICA AVE', 'KINGSTON AVE', 'NASSAU AVE',
#        'GREENPOINT AVE', 'MARCY AVE', 'HEWES ST',
#        '138 ST - GRAND CONCOURSE', '5 AVE - 53 ST',
#        'LEXINGTON AVE - 53 ST', '28 ST', 'HERALD SQ - 34 ST', '1 AVE',
#        'TIMES SQ - 42 ST', 'METROPOLITAN AVE', 'GRAND ST', 'GRAHAM AVE',
#        'BEDFORD AVE', 'MONTROSE AVE', 'LONG ISLAND CITY - COURT SQ',
#        '21 ST', '39 AVE', '145 ST', '157 ST', '96 ST', '103 ST',
#        'CENTRAL PARK NORTH (110 ST)', '103 ST', '72 ST', '81 ST',
#        '75 AVE', '86 ST', 'CATHEDRAL PKWY (110 ST)',
#        '116 ST - COLUMBIA UNIVERSITY', '125 ST', '135 ST', '116 ST',
#        'TREMONT AVE', '137 ST - CITY COLLEGE', '145 ST', '176 ST',
#        'BURNSIDE AVE', '170 ST', '168 ST', '181 ST', '191 ST', '175 ST',
#        'BEACH 44 ST', 'BEACH 60 ST', 'BEACH 98 ST',
#        'ROCKAWAY PARK - BEACH 116 ST', 'BEACH 36 ST', 'BEACH 25 ST',
#        'PARSONS BLVD', '169 ST', '103 ST - CORONA PLAZA', '111 ST',
#        '63 DR - REGO PARK', 'GRANT AVE', '79 ST', 'ATLANTIC AVE',
#        'CHRISTOPHER ST - SHERIDAN SQ', 'OZONE PARK - LEFFERTS BLVD',
#        'TIMES SQ - 42 ST', 'W 8 ST - NY AQUARIUM', '28 ST', '28 ST',
#        'PELHAM BAY PARK', 'WESTCHESTER SQ - E TREMONT AVE', '18 ST',
#        'GRAND CENTRAL - 42 ST', 'BEACH 67 ST',
#        'W 4 ST - WASHINGTON SQ (UPPER)', '85 ST - FOREST PKY',
#        'WOODHAVEN BLVD', '111 ST', '121 ST', 'HALSEY ST',
#        'MYRTLE - WYCKOFF AVES', 'NEW LOTS AVE', 'VAN SICLEN AVE',
#        'CLEVELAND ST', 'LIVONIA AVE', 'JUNIUS ST', 'ROCKAWAY AVE',
#        'CANARSIE - ROCKAWAY PKWY', 'E 105 ST', 'SARATOGA AVE',
#        'SUTTER AVE - RUTLAND ROAD', 'NEW LOTS AVE', 'BROADWAY JUNCTION',
#        'ALABAMA AVE', 'SHEPHERD AVE', 'CRESCENT ST', 'CYPRESS HILLS',
#        '75 ST - ELDERT LN', '69 ST', '74 ST - BROADWAY',
#        'WOODHAVEN BLVD - QUEENS MALL', 'MYRTLE - WYCKOFF AVES',
#        'SENECA AVE', 'DEKALB AVE', '52 ST', '46 ST', 'NORTHERN BLVD',
#        '46 ST', '82 ST - JACKSON HTS', '90 ST - ELMHURST AV',
#        'HOWARD BEACH - JFK AIRPORT', 'AQUEDUCT - NORTH CONDUIT AV',
#        'BRIARWOOD - VAN WYCK BLVD', 'FOREST HILLS - 71 AV',
#        'SUTPHIN BLVD', 'JAMAICA CTR - PARSONS / ARCHER', '225 ST',
#        'ELDER AVE', 'LONGWOOD AVE', 'ASTORIA BLVD',
#        'ASTORIA - DITMARS BLVD', 'JACKSON AVE', 'PROSPECT AVE',
#        'CYPRESS AVE', '174 ST', 'ALLERTON AVE', "E 143 ST - ST MARY'S ST",
#        'KINGSBRIDGE RD', 'BEDFORD PARK BLVD - LEHMAN COLLEGE',
#        'HARLEM - 148 ST', 'MT EDEN AVE', 'FORDHAM RD', '170 ST',
#        'BEDFORD PARK BLVD', 'MARBLE HILL - 225 ST', '231 ST', '215 ST',
#        '207 ST', 'INWOOD - 207 ST', 'VAN CORTLANDT PARK - 242 ST',
#        'WEST FARMS SQ - E TREMONT AV', '219 ST', 'MOSHOLU PKWY',
#        'NORWOOD - 205 ST', 'BURKE AVE', 'BAYCHESTER AVE',
#        'EASTCHESTER - DYRE AVE', 'JAMAICA - 179 ST', 'WAKEFIELD - 241 ST',
#        'BOTANIC GARDEN', 'BUSHWICK - ABERDEEN', 'BROADWAY JUNCTION',
#        'GUN HILL RD', 'E 180 ST', 'DYCKMAN ST', '125 ST',
#        'FRANKLIN AVE - FULTON ST', '149 ST - GRAND CONCOURSE',
#        '3 AVE - 149 ST', '167 ST', 'BROOK AVE', '33 ST', '40 ST',
#        '145 ST', '155 ST', '161 ST - YANKEE STADIUM', 'UTICA AVE',
#        'STEINWAY ST', 'KOSCIUSZKO ST', 'GATES AVE', 'CENTRAL AVE',
#        'KNICKERBOCKER AVE', '30 AVE', 'JEFFERSON ST', 'MORGAN AVE',
#        'QUEENS PLZ', '18 AVE', '77 ST', 'BAY RIDGE AVE', '50 ST',
#        'FT HAMILTON PKWY', '25 AVE', 'BAY PKY', '20 AVE', '18 AVE',
#        'BAY RIDGE - 95 ST', '86 ST', '79 ST', '71 ST', '20 AVE', '18 AVE',
#        '62 ST', 'NEW UTRECHT AVE', 'AVE U', 'KINGS HWY', 'BRIGHTON BEACH',
#        'SHEEPSHEAD BAY', 'AVE U', 'KINGS HWY', 'AVE U', 'KINGS HWY',
#        'NEPTUNE AVE', 'AVE X', 'BAY 50 ST', 'GRAVESEND - 86 ST', 'AVE P',
#        'AVE N', 'BAY PKY', 'AVE M', 'BAY PKY', 'AVE I', 'AVE J', 'AVE H',
#        'NECK RD', '21 ST - QUEENSBRIDGE', '50 ST', '7 AVE',
#        '47-50 STS - ROCKEFELLER CTR', '57 ST', 'LEXINGTON AVE - 63 ST',
#        'ROOSEVELT ISLAND - MAIN ST', '59 ST - COLUMBUS CIRCLE', '49 ST',
#        '57 ST', '5 AVE - 59 ST', 'LEXINGTON AVE - 59 ST',
#        '34 ST - PENN STATION', 'TIMES SQ - 42 ST', 'FULTON ST',
#        'CHAMBERS ST', '42 ST - PORT AUTHORITY BUS TERM',
#        'MYRTLE-WILLOUGHBY AVES', 'FLUSHING AVE', '23 ST',
#        'HERALD SQ - 34 ST', 'HOYT - SCHERMERHORN STS',
#        'JAY ST - METROTECH', 'EAST BROADWAY', 'DELANCEY ST - ESSEX ST',
#        'LOWER EAST SIDE - 2 AVE', 'FLUSHING AVE', 'MYRTLE AVE',
#        '4 AV - 9 ST', 'SMITH - 9 STS', 'BERGEN ST', 'JAY ST - METROTECH',
#        'COURT ST', 'UNION SQ - 14 ST', '23 ST', 'PROSPECT AVE',
#        '4 AV - 9 ST', '3 AVE', 'UNION SQ - 14 ST', 'LIBERTY AVE',
#        'BROADWAY JUNCTION', '59 ST', '45 ST', '36 ST', '9 AVE', '53 ST',
#        'FT HAMILTON PKWY', '25 ST', 'CARROLL ST', 'SPRING ST', '181 ST',
#        '190 ST', '116 ST', '125 ST', 'PRINCE ST', '8 ST - NYU',
#        'FULTON ST', 'PARK PL', 'CHAMBERS ST', 'HOYT ST', 'BOROUGH HALL',
#        '183 ST', 'FORDHAM RD', 'WORLD TRADE CENTER',
#        'CANAL ST - HOLLAND TUNNEL', '155 ST', '163 ST - AMSTERDAM AV',
#        'FULTON ST', 'CHAMBERS ST', 'CANAL ST', 'CITY HALL', 'CANAL ST',
#        'SOUTH FERRY', 'BOWLING GREEN', 'WALL ST', 'WHITEHALL ST',
#        'RECTOR ST', 'FRESH POND RD', 'MIDDLE VILLAGE - METROPOLITAN AVE',
#        'RECTOR ST', 'CORTLANDT ST', 'FULTON ST', 'BROAD ST',
#        'CORTLANDT ST', 'WALL ST', 'DYCKMAN ST', 'GRAND ST',
#        'BROADWAY - LAFAYETTE ST', 'BOWERY', 'CANAL ST', '23 ST',
#        '34 ST - PENN STATION', 'JACKSON HTS - ROOSEVELT AV', '14 ST',
#        '135 ST', '14 ST', '6 AVE', '8 AVE', '14 ST', 'NOSTRAND AVE',
#        'CLARK ST', 'FRANKLIN AVE', 'CLINTON - WASHINGTON AVES',
#        'FOREST AVE', '110 ST', '86 ST', 'YORK ST', 'HIGH ST',
#        'LAFAYETTE AVE', 'PRESIDENT ST', 'WOODLAWN', 'BLEECKER ST',
#        '103 ST', 'EUCLID AVE', '88 ST', 'CORTELYOU RD', '116 ST',
#        'PARKCHESTER', 'FRANKLIN ST', '80 ST', '5 AVE - BRYANT PK',
#        'SPRING ST', '125 ST', 'CONEY ISLAND - STILLWELL AV',
#        '34 ST - HUDSON YARDS', '72 ST', '86 ST', '96 ST'], dtype=object)

# %%
common_stations = np.intersect1d(lat_long_stations['STATION'].values, daily_entries_2019['STATION'].unique())
print(common_stations.shape)
common_stations
# Out:
# (106,)
# array(['110 ST', '121 ST', '157 ST', '169 ST', '174 ST', '174-175 STS',
#        '175 ST', '176 ST', '18 ST', '182-183 STS', '183 ST', '190 ST',
#        '191 ST', '207 ST', '21 ST', '215 ST', '219 ST', '225 ST',
#        '231 ST', '233 ST', '238 ST', '25 ST', '33 ST', '45 ST', '46 ST',
#        '49 ST', '51 ST', '52 ST', '53 ST', '55 ST', '57 ST', '65 ST',
#        '69 ST', '71 ST', '80 ST', '88 ST', 'ASTOR PL', 'BAY 50 ST',
#        'BEACH 105 ST', 'BEACH 25 ST', 'BEACH 36 ST', 'BEACH 44 ST',
#        'BEACH 60 ST', 'BEACH 67 ST', 'BEACH 90 ST', 'BEACH 98 ST',
#        'BEVERLY RD', 'BLEECKER ST', 'BOTANIC GARDEN', 'BOWERY',
#        'BOWLING GREEN', 'BRIGHTON BEACH', 'BROAD CHANNEL', 'BROAD ST',
#        'BRONX PARK EAST', 'CARROLL ST', 'CHAUNCEY ST', 'CITY HALL',
#        'CLARK ST', 'CLEVELAND ST', 'CORTELYOU RD', 'CORTLANDT ST',
#        'CRESCENT ST', 'CYPRESS HILLS', 'E 149 ST', 'E 180 ST',
#        'EAST BROADWAY', 'FOREST AVE', 'FRANKLIN ST', 'FREEMAN ST',
#        'FRESH POND RD', 'HEWES ST', 'HIGH ST', 'HOUSTON ST', 'HOYT ST',
#        'JEFFERSON ST', 'JUNCTION BLVD', 'JUNIUS ST', 'KOSCIUSZKO ST',
#        'MIDDLETOWN RD', 'MORRIS PARK', 'MOSHOLU PKWY', 'NECK RD',
#        'NEVINS ST', 'NORTHERN BLVD', 'OCEAN PKWY', 'PARKCHESTER',
#        'PARSONS BLVD', 'PELHAM BAY PARK', 'PRESIDENT ST', 'PRINCE ST',
#        'PROSPECT PARK', 'QUEENSBORO PLZ', 'ROCKAWAY BLVD', 'SENECA AVE',
#        'SHEEPSHEAD BAY', 'SIMPSON ST', 'SOUTH FERRY', 'STEINWAY ST',
#        'STERLING ST', 'SUTPHIN BLVD', 'UNION ST', 'VAN SICLEN AVE',
#        'WINTHROP ST', 'WOODLAWN', 'YORK ST'], dtype=object)

# %%
# We have easily found 106 stations from the Lat & Long data that overlap w/ the MTA data;
# Let's just focus on these 106 stations for now

print(daily_entries_2019.shape)
daily_entries_2019 = daily_entries_2019[daily_entries_2019['STATION'].isin(common_stations)]
print(daily_entries_2019.shape)
# Out:
# (180921, 5)
# (49541, 5)

# %%
print(daily_entries_2021.shape)
daily_entries_2021 = daily_entries_2021[daily_entries_2021['STATION'].isin(common_stations)]
print(daily_entries_2021.shape)
# Out:
# (186066, 5)
# (49867, 5)

# %% [markdown]
# ### Get ZIPCODEs associated with Lat/Longs

# %%
# Filter down to the common stations

print(lat_long_stations.shape)
lat_long_stations = lat_long_stations[lat_long_stations['STATION'].isin(common_stations)]
print(lat_long_stations.shape)
# Out:
# (473, 3)
# (113, 3)

# %%
# Looks like we have too many stations (should only be 109); Check for duplicates

lat_long_stations.groupby('STATION')['STATION'].count().sort_values(ascending=False).head(10)
# Out:
# STATION
# VAN SICLEN AVE    3
# 57 ST             2
# 46 ST             2
# CORTLANDT ST      2
# 33 ST             2
# BEVERLY RD        2
# FREEMAN ST        1
# KOSCIUSZKO ST     1
# JUNIUS ST         1
# JUNCTION BLVD     1
# Name: STATION, dtype: int64

# %%
display(lat_long_stations[lat_long_stations['STATION'] == 'VAN SICLEN AVE'])
display(lat_long_stations[lat_long_stations['STATION'] == '57 ST'])
display(lat_long_stations[lat_long_stations['STATION'] == '46 ST'])
display(lat_long_stations[lat_long_stations['STATION'] == 'CORTLANDT ST'])
display(lat_long_stations[lat_long_stations['STATION'] == '33 ST'])
display(lat_long_stations[lat_long_stations['STATION'] == 'BEVERLY RD'])
# Out:
#             STATION   LATITUDE  LONGITUDE
# 11   VAN SICLEN AVE  40.678028 -73.891658
# 45   VAN SICLEN AVE  40.665518 -73.889405
# 213  VAN SICLEN AVE  40.672710 -73.890358
#     STATION   LATITUDE  LONGITUDE
# 349   57 ST  40.764085 -73.977368
# 354   57 ST  40.764566 -73.980730
#     STATION   LATITUDE  LONGITUDE
# 236   46 ST  40.756317 -73.913522
# 238   46 ST  40.743132 -73.918435
#           STATION   LATITUDE  LONGITUDE
# 425  CORTLANDT ST  40.711835 -74.012188
# 428  CORTLANDT ST  40.710513 -74.011132
#     STATION   LATITUDE  LONGITUDE
# 31    33 ST  40.746081 -73.982076
# 292   33 ST  40.744587 -73.930997
#         STATION   LATITUDE  LONGITUDE
# 110  BEVERLY RD  40.643905 -73.964358
# 129  BEVERLY RD  40.645124 -73.948848

# %%
# These duplicates have conflicting geocoordinates, so let's just drop these 6 stations from everything

common_stations = np.setdiff1d(common_stations, 
                               ['VAN SICLEN AVE', '57 ST', '46 ST', 'CORTLANDT ST', '33 ST', 'BEVERLY RD'])
common_stations.shape
# Out:
# (100,)

# %%
# Reducing down to the now 100 common stations between entries data and lat/long data

print(daily_entries_2019.shape)
daily_entries_2019 = daily_entries_2019[daily_entries_2019['STATION'].isin(common_stations)]
print(daily_entries_2019.shape)
# Out:
# (49541, 5)
# (43506, 5)

# %%
print(daily_entries_2021.shape)
daily_entries_2021 = daily_entries_2021[daily_entries_2021['STATION'].isin(common_stations)]
print(daily_entries_2021.shape)
# Out:
# (49867, 5)
# (43828, 5)

# %%
# Remove duplicates from lat_long_stations

lat_long_stations = lat_long_stations[lat_long_stations['STATION'].isin(common_stations)]

# Check: should be no duplicates now
lat_long_stations.groupby('STATION')['STATION'].count().sort_values(ascending=False).head()
# Out:
# STATION
# 110 ST           1
# FRANKLIN ST      1
# KOSCIUSZKO ST    1
# JUNIUS ST        1
# JUNCTION BLVD    1
# Name: STATION, dtype: int64

# %%
stations_to_neighborhood = lat_long_stations.groupby('STATION')[['LATITUDE', 'LONGITUDE']].first().reset_index()
stations_to_neighborhood
# Out:
#             STATION   LATITUDE  LONGITUDE
# 0            110 ST  40.795020 -73.944250
# 1            121 ST  40.700482 -73.828349
# 2            157 ST  40.834041 -73.944890
# 3            169 ST  40.710518 -73.793474
# 4            174 ST  40.837196 -73.887694
# 5       174-175 STS  40.845900 -73.910136
# 6            175 ST  40.847391 -73.939704
# 7            176 ST  40.848480 -73.911794
# 8             18 ST  40.741040 -73.997871
# 9       182-183 STS  40.856093 -73.900741
# 10           183 ST  40.858407 -73.903879
# 11           190 ST  40.859022 -73.934180
# 12           191 ST  40.855225 -73.929412
# 13           207 ST  40.864614 -73.918819
# 14            21 ST  40.744129 -73.949600
# 15           215 ST  40.869444 -73.915279
# 16           219 ST  40.883888 -73.862510
# 17           225 ST  40.888028 -73.860215
# 18           231 ST  40.878856 -73.904834
# 19           233 ST  40.893143 -73.857362
# 20           238 ST  40.884667 -73.900870
# 21            25 ST  40.660397 -73.998091
# 22            45 ST  40.648939 -74.010006
# 23            49 ST  40.759802 -73.984210
# 24            51 ST  40.757107 -73.971920
# 25            52 ST  40.744149 -73.912549
# 26            53 ST  40.645069 -74.014034
# 27            55 ST  40.631479 -73.995349
# 28            65 ST  40.749720 -73.898788
# 29            69 ST  40.746325 -73.896403
# 30            71 ST  40.619259 -73.998841
# 31            80 ST  40.679371 -73.858992
# 32            88 ST  40.679843 -73.851470
# 33         ASTOR PL  40.730054 -73.991070
# 34        BAY 50 ST  40.588841 -73.983765
# 35     BEACH 105 ST  40.583268 -73.827581
# 36      BEACH 25 ST  40.600066 -73.761353
# 37      BEACH 36 ST  40.595398 -73.768175
# 38      BEACH 44 ST  40.592943 -73.776013
# 39      BEACH 60 ST  40.592374 -73.788522
# 40      BEACH 67 ST  40.590927 -73.796924
# 41      BEACH 90 ST  40.588092 -73.813651
# 42      BEACH 98 ST  40.585386 -73.820521
# 43      BLEECKER ST  40.725915 -73.994659
# 44   BOTANIC GARDEN  40.670343 -73.959245
# 45           BOWERY  40.720247 -73.993807
# 46    BOWLING GREEN  40.704914 -74.014008
# 47   BRIGHTON BEACH  40.577710 -73.961354
# 48    BROAD CHANNEL  40.608402 -73.815833
# 49         BROAD ST  40.706476 -74.011056
# 50  BRONX PARK EAST  40.848769 -73.868356
# 51       CARROLL ST  40.680273 -73.994947
# 52      CHAUNCEY ST  40.682851 -73.910384
# 53        CITY HALL  40.713272 -74.006986
# 54         CLARK ST  40.697466 -73.993086
# 55     CLEVELAND ST  40.679778 -73.885194
# 56     CORTELYOU RD  40.640940 -73.963790
# 57      CRESCENT ST  40.683153 -73.873929
# 58    CYPRESS HILLS  40.689616 -73.873322
# 59         E 149 ST  40.812118 -73.904098
# 60         E 180 ST  40.841863 -73.873346
# 61    EAST BROADWAY  40.713855 -73.990177
# 62       FOREST AVE  40.704412 -73.903075
# 63      FRANKLIN ST  40.719318 -74.006886
# 64       FREEMAN ST  40.829987 -73.891752
# 65    FRESH POND RD  40.706226 -73.895898
# 66         HEWES ST  40.706890 -73.953488
# 67          HIGH ST  40.699337 -73.990531
# 68       HOUSTON ST  40.728251 -74.005367
# 69          HOYT ST  40.690544 -73.985064
# 70     JEFFERSON ST  40.706607 -73.922913
# 71    JUNCTION BLVD  40.749145 -73.869527
# 72        JUNIUS ST  40.663589 -73.902449
# 73    KOSCIUSZKO ST  40.693172 -73.928509
# 74    MIDDLETOWN RD  40.843863 -73.836322
# 75      MORRIS PARK  40.854364 -73.860495
# 76     MOSHOLU PKWY  40.879750 -73.884655
# 77          NECK RD  40.595322 -73.955078
# 78        NEVINS ST  40.688311 -73.980407
# 79    NORTHERN BLVD  40.752825 -73.906065
# 80       OCEAN PKWY  40.576312 -73.968501
# 81      PARKCHESTER  40.833226 -73.860816
# 82     PARSONS BLVD  40.707572 -73.803289
# 83  PELHAM BAY PARK  40.852462 -73.828121
# 84     PRESIDENT ST  40.667884 -73.950589
# 85        PRINCE ST  40.724329 -73.997702
# 86    PROSPECT PARK  40.661633 -73.962031
# 87   QUEENSBORO PLZ  40.750636 -73.940164
# 88    ROCKAWAY BLVD  40.680429 -73.843853
# 89       SENECA AVE  40.702919 -73.907582
# 90   SHEEPSHEAD BAY  40.586548 -73.954058
# 91       SIMPSON ST  40.823977 -73.893066
# 92      SOUTH FERRY  40.701731 -74.013169
# 93      STEINWAY ST  40.756987 -73.920526
# 94      STERLING ST  40.662773 -73.950729
# 95     SUTPHIN BLVD  40.705418 -73.810833
# 96         UNION ST  40.677316 -73.983110
# 97      WINTHROP ST  40.656659 -73.950079
# 98         WOODLAWN  40.886037 -73.878751
# 99          YORK ST  40.699743 -73.986885

# %%
# This implementation is based on the info posted here:
#  https://stackoverflow.com/questions/66144427/how-do-i-get-zipcodes-from-longitude-and-latitude-on-python

geo = geopy.Nominatim(user_agent="check_1")

stations_to_neighborhood['ZIPCODE'] = stations_to_neighborhood \
                                       .apply(lambda x: geo.reverse('{}, {}'
                                                .format(x['LATITUDE'],
                                                        x['LONGITUDE'])) \
                                                .raw['address']['postcode'], axis=1)

# geo.reverse("{}, {}".format(40.641362, -74.017881)).raw['address']['neighbourhood']
stations_to_neighborhood
# Out:
#             STATION   LATITUDE  LONGITUDE     ZIPCODE
# 0            110 ST  40.795020 -73.944250       10029
# 1            121 ST  40.700482 -73.828349       11418
# 2            157 ST  40.834041 -73.944890       10032
# 3            169 ST  40.710518 -73.793474       11427
# 4            174 ST  40.837196 -73.887694       10460
# 5       174-175 STS  40.845900 -73.910136       10453
# 6            175 ST  40.847391 -73.939704       10033
# 7            176 ST  40.848480 -73.911794       10468
# 8             18 ST  40.741040 -73.997871       10001
# 9       182-183 STS  40.856093 -73.900741  10457-2919
# 10           183 ST  40.858407 -73.903879       10453
# 11           190 ST  40.859022 -73.934180       10040
# 12           191 ST  40.855225 -73.929412       10040
# 13           207 ST  40.864614 -73.918819       10034
# 14            21 ST  40.744129 -73.949600       11109
# 15           215 ST  40.869444 -73.915279       10034
# 16           219 ST  40.883888 -73.862510       10469
# 17           225 ST  40.888028 -73.860215       10466
# 18           231 ST  40.878856 -73.904834       10463
# 19           233 ST  40.893143 -73.857362       10470
# 20           238 ST  40.884667 -73.900870       10463
# 21            25 ST  40.660397 -73.998091       11232
# 22            45 ST  40.648939 -74.010006       11220
# 23            49 ST  40.759802 -73.984210       10036
# 24            51 ST  40.757107 -73.971920       10037
# 25            52 ST  40.744149 -73.912549       11377
# 26            53 ST  40.645069 -74.014034       11220
# 27            55 ST  40.631479 -73.995349       11228
# 28            65 ST  40.749720 -73.898788       11377
# 29            69 ST  40.746325 -73.896403       11377
# 30            71 ST  40.619259 -73.998841       11204
# 31            80 ST  40.679371 -73.858992       11419
# 32            88 ST  40.679843 -73.851470       11419
# 33         ASTOR PL  40.730054 -73.991070       10003
# 34        BAY 50 ST  40.588841 -73.983765       11224
# 35     BEACH 105 ST  40.583268 -73.827581       11694
# 36      BEACH 25 ST  40.600066 -73.761353       11691
# 37      BEACH 36 ST  40.595398 -73.768175       11691
# 38      BEACH 44 ST  40.592943 -73.776013       11692
# 39      BEACH 60 ST  40.592374 -73.788522       11692
# 40      BEACH 67 ST  40.590927 -73.796924       11692
# 41      BEACH 90 ST  40.588092 -73.813651       11693
# 42      BEACH 98 ST  40.585386 -73.820521       11693
# 43      BLEECKER ST  40.725915 -73.994659       10012
# 44   BOTANIC GARDEN  40.670343 -73.959245       11213
# 45           BOWERY  40.720247 -73.993807       10002
# 46    BOWLING GREEN  40.704914 -74.014008       10003
# 47   BRIGHTON BEACH  40.577710 -73.961354       11235
# 48    BROAD CHANNEL  40.608402 -73.815833       11693
# 49         BROAD ST  40.706476 -74.011056       10004
# 50  BRONX PARK EAST  40.848769 -73.868356       10462
# 51       CARROLL ST  40.680273 -73.994947       11231
# 52      CHAUNCEY ST  40.682851 -73.910384       11233
# 53        CITY HALL  40.713272 -74.006986       10003
# 54         CLARK ST  40.697466 -73.993086  11201-1832
# 55     CLEVELAND ST  40.679778 -73.885194       11208
# 56     CORTELYOU RD  40.640940 -73.963790       11226
# 57      CRESCENT ST  40.683153 -73.873929       11208
# 58    CYPRESS HILLS  40.689616 -73.873322       11208
# 59         E 149 ST  40.812118 -73.904098       10458
# 60         E 180 ST  40.841863 -73.873346       10460
# 61    EAST BROADWAY  40.713855 -73.990177       10002
# 62       FOREST AVE  40.704412 -73.903075       11385
# 63      FRANKLIN ST  40.719318 -74.006886       10013
# 64       FREEMAN ST  40.829987 -73.891752       10459
# 65    FRESH POND RD  40.706226 -73.895898       11385
# 66         HEWES ST  40.706890 -73.953488       11211
# 67          HIGH ST  40.699337 -73.990531  11201-1832
# 68       HOUSTON ST  40.728251 -74.005367       10014
# 69          HOYT ST  40.690544 -73.985064       11207
# 70     JEFFERSON ST  40.706607 -73.922913       11237
# 71    JUNCTION BLVD  40.749145 -73.869527       11368
# 72        JUNIUS ST  40.663589 -73.902449       11207
# 73    KOSCIUSZKO ST  40.693172 -73.928509       11207
# 74    MIDDLETOWN RD  40.843863 -73.836322       10461
# 75      MORRIS PARK  40.854364 -73.860495       10462
# 76     MOSHOLU PKWY  40.879750 -73.884655       10467
# 77          NECK RD  40.595322 -73.955078       11229
# 78        NEVINS ST  40.688311 -73.980407       11227
# 79    NORTHERN BLVD  40.752825 -73.906065       11373
# 80       OCEAN PKWY  40.576312 -73.968501       11235
# 81      PARKCHESTER  40.833226 -73.860816       10472
# 82     PARSONS BLVD  40.707572 -73.803289       11427
# 83  PELHAM BAY PARK  40.852462 -73.828121       10461
# 84     PRESIDENT ST  40.667884 -73.950589       11213
# 85        PRINCE ST  40.724329 -73.997702       10003
# 86    PROSPECT PARK  40.661633 -73.962031       11225
# 87   QUEENSBORO PLZ  40.750636 -73.940164       11101
# 88    ROCKAWAY BLVD  40.680429 -73.843853       11419
# 89       SENECA AVE  40.702919 -73.907582       11385
# 90   SHEEPSHEAD BAY  40.586548 -73.954058       11235
# 91       SIMPSON ST  40.823977 -73.893066       10459
# 92      SOUTH FERRY  40.701731 -74.013169       10004
# 93      STEINWAY ST  40.756987 -73.920526       11101
# 94      STERLING ST  40.662773 -73.950729       11203
# 95     SUTPHIN BLVD  40.705418 -73.810833       11427
# 96         UNION ST  40.677316 -73.983110       11217
# 97      WINTHROP ST  40.656659 -73.950079       11203
# 98         WOODLAWN  40.886037 -73.878751       10468
# 99          YORK ST  40.699743 -73.986885       11201

# %%
stations_to_neighborhood.drop(['LATITUDE', 'LONGITUDE'], axis=1, inplace=True)
stations_to_neighborhood.head()
# Out:
#   STATION ZIPCODE
# 0  110 ST   10029
# 1  121 ST   11418
# 2  157 ST   10032
# 3  169 ST   11427
# 4  174 ST   10460

# %%
# Need to reduce the zip codes with -xxxx extension down to just first 5 digits

stations_to_neighborhood['ZIPCODE'] = stations_to_neighborhood['ZIPCODE'].apply(lambda x: x[:5])
stations_to_neighborhood['ZIPCODE'].values
# Out:
# array(['10029', '11418', '10032', '11427', '10460', '10453', '10033',
#        '10468', '10001', '10457', '10453', '10040', '10040', '10034',
#        '11109', '10034', '10469', '10466', '10463', '10470', '10463',
#        '11232', '11220', '10036', '10037', '11377', '11220', '11228',
#        '11377', '11377', '11204', '11419', '11419', '10003', '11224',
#        '11694', '11691', '11691', '11692', '11692', '11692', '11693',
#        '11693', '10012', '11213', '10002', '10003', '11235', '11693',
#        '10004', '10462', '11231', '11233', '10003', '11201', '11208',
#        '11226', '11208', '11208', '10458', '10460', '10002', '11385',
#        '10013', '10459', '11385', '11211', '11201', '10014', '11207',
#        '11237', '11368', '11207', '11207', '10461', '10462', '10467',
#        '11229', '11227', '11373', '11235', '10472', '11427', '10461',
#        '11213', '10003', '11225', '11101', '11419', '11385', '11235',
#        '10459', '10004', '11101', '11203', '11427', '11217', '11203',
#        '10468', '11201'], dtype=object)

# %% [markdown]
# ### Merge the MTA data for the stations above with the ZIPCODE data

# %%
daily_entries_2019 = daily_entries_2019.merge(right=stations_to_neighborhood, how='left', on='STATION')

# Check for NaNs
display(daily_entries_2019[daily_entries_2019.isna().any(axis=1)])

display(daily_entries_2019.head())
display(daily_entries_2019.tail())
# Out:
# Empty DataFrame
# Columns: [STATION, LINENAME, DATE, NET_ENTRIES, WEEKDAY, ZIPCODE]
# Index: []
#   STATION LINENAME        DATE  NET_ENTRIES  WEEKDAY ZIPCODE
# 0   49 ST     NQRW  05/01/2019          796        1   10036
# 1   49 ST     NQRW  05/02/2019          806        1   10036
# 2   49 ST     NQRW  05/03/2019          762        1   10036
# 3   49 ST     NQRW  05/04/2019          460        0   10036
# 4   49 ST     NQRW  05/05/2019          373        0   10036
#            STATION LINENAME        DATE  NET_ENTRIES  WEEKDAY ZIPCODE
# 43501  MORRIS PARK        5  06/26/2019         1320        1   10462
# 43502  MORRIS PARK        5  06/27/2019         1280        1   10462
# 43503  MORRIS PARK        5  06/28/2019         1253        1   10462
# 43504  MORRIS PARK        5  06/29/2019          416        0   10462
# 43505  MORRIS PARK        5  06/30/2019          380        0   10462

# %%
daily_entries_2021 = daily_entries_2021.merge(right=stations_to_neighborhood, how='left', on='STATION')

# Check for NaNs
display(daily_entries_2021[daily_entries_2021.isna().any(axis=1)])

display(daily_entries_2021.head())
display(daily_entries_2021.tail())
# Out:
# Empty DataFrame
# Columns: [STATION, LINENAME, DATE, NET_ENTRIES, WEEKDAY, ZIPCODE]
# Index: []
#   STATION LINENAME        DATE  NET_ENTRIES  WEEKDAY ZIPCODE
# 0   49 ST     NQRW  05/01/2021           99        0   10036
# 1   49 ST     NQRW  05/02/2021           66        0   10036
# 2   49 ST     NQRW  05/03/2021          124        1   10036
# 3   49 ST     NQRW  05/04/2021          131        1   10036
# 4   49 ST     NQRW  05/05/2021          122        1   10036
#            STATION LINENAME        DATE  NET_ENTRIES  WEEKDAY ZIPCODE
# 43823  MORRIS PARK        5  06/26/2021          146        0   10462
# 43824  MORRIS PARK        5  06/27/2021          104        0   10462
# 43825  MORRIS PARK        5  06/28/2021          436        1   10462
# 43826  MORRIS PARK        5  06/29/2021          415        1   10462
# 43827  MORRIS PARK        5  06/30/2021          464        1   10462

# %% [markdown]
# ### Now Merge with the Neighborhoods and Boroughs

# %%
neighborhoods_zips['ZipCode'].values
# Out:
# array([10453, 10457, 10460, 10458, 10467, 10468, 10451, 10452, 10456,
#        10454, 10455, 10459, 10474, 10463, 10471, 10466, 10469, 10470,
#        10475, 10461, 10462, 10464, 10465, 10472, 10473, 11212, 11213,
#        11216, 11233, 11238, 11209, 11214, 11228, 11204, 11218, 11219,
#        11230, 11234, 11236, 11239, 11223, 11224, 11229, 11235, 11201,
#        11205, 11215, 11217, 11231, 11203, 11210, 11225, 11226, 11207,
#        11208, 11211, 11222, 11220, 11232, 11206, 11221, 11237, 10026,
#        10027, 10030, 10037, 10039, 10001, 10011, 10018, 10019, 10020,
#        10036, 10029, 10035, 10010, 10016, 10017, 10022, 10012, 10013,
#        10014, 10004, 10005, 10006, 10007, 10038, 10280, 10002, 10003,
#        10009, 10021, 10028, 10044, 10065, 10075, 10128, 10023, 10024,
#        10025, 10031, 10032, 10033, 10034, 10040, 11361, 11362, 11363,
#        11364, 11354, 11355, 11356, 11357, 11358, 11359, 11360, 11365,
#        11366, 11367, 11412, 11423, 11432, 11433, 11434, 11435, 11436,
#        11101, 11102, 11103, 11104, 11105, 11106, 11374, 11375, 11379,
#        11385, 11691, 11692, 11693, 11694, 11695, 11697, 11004, 11005,
#        11411, 11413, 11422, 11426, 11427, 11428, 11429, 11414, 11415,
#        11416, 11417, 11418, 11419, 11420, 11421, 11368, 11369, 11370,
#        11372, 11373, 11377, 11378, 10302, 10303, 10310, 10306, 10307,
#        10308, 10309, 10312, 10301, 10304, 10305, 10314])

# %%
# Need to make these zip codes strings (they're integers)

neighborhoods_zips['ZipCode'] = neighborhoods_zips['ZipCode'].astype('str')
neighborhoods_zips.columns = ['BOROUGH', 'NEIGHBORHOOD', 'ZIPCODE']

# %%
np.setdiff1d(neighborhoods_zips['ZIPCODE'].unique(), daily_entries_2019['ZIPCODE'].unique())
# Out:
# array(['10005', '10006', '10007', '10009', '10010', '10011', '10016',
#        '10017', '10018', '10019', '10020', '10021', '10022', '10023',
#        '10024', '10025', '10026', '10027', '10028', '10030', '10031',
#        '10035', '10038', '10039', '10044', '10065', '10075', '10128',
#        '10280', '10301', '10302', '10303', '10304', '10305', '10306',
#        '10307', '10308', '10309', '10310', '10312', '10314', '10451',
#        '10452', '10454', '10455', '10456', '10464', '10465', '10471',
#        '10473', '10474', '10475', '11004', '11005', '11102', '11103',
#        '11104', '11105', '11106', '11205', '11206', '11209', '11210',
#        '11212', '11214', '11215', '11216', '11218', '11219', '11221',
#        '11222', '11223', '11230', '11234', '11236', '11238', '11239',
#        '11354', '11355', '11356', '11357', '11358', '11359', '11360',
#        '11361', '11362', '11363', '11364', '11365', '11366', '11367',
#        '11369', '11370', '11372', '11374', '11375', '11378', '11379',
#        '11411', '11412', '11413', '11414', '11415', '11416', '11417',
#        '11420', '11421', '11422', '11423', '11426', '11428', '11429',
#        '11432', '11433', '11434', '11435', '11436', '11695', '11697'],
#       dtype=object)

# %%
np.setdiff1d(daily_entries_2019['ZIPCODE'].unique(),neighborhoods_zips['ZIPCODE'].unique())
# Out:
# array(['11109', '11227'], dtype=object)

# %%
np.setdiff1d(daily_entries_2019['ZIPCODE'].unique(), daily_entries_2021['ZIPCODE'].unique())
# Out:
# array([], dtype=object)

# %%
# Looks like we have some ZIPCODE discrepancies between neighborhoods_zips and daily_entries_20xx;
#  Let's whittle down to a common set off ZIPCODEs

common_zipcodes = np.intersect1d(daily_entries_2019['ZIPCODE'].unique(),neighborhoods_zips['ZIPCODE'].unique())
common_zipcodes.shape
# Out:
# (59,)

# %%
print(neighborhoods_zips.shape)
neighborhoods_zips = neighborhoods_zips[neighborhoods_zips['ZIPCODE'].isin(common_zipcodes)]
print(neighborhoods_zips.shape)
# Out:
# (178, 3)
# (59, 3)

# %%
print(daily_entries_2019.shape)
daily_entries_2019 = daily_entries_2019[daily_entries_2019['ZIPCODE'].isin(common_zipcodes)]
print(daily_entries_2019.shape)
# Out:
# (43506, 6)
# (42713, 6)

# %%
print(daily_entries_2021.shape)
daily_entries_2021 = daily_entries_2021[daily_entries_2021['ZIPCODE'].isin(common_zipcodes)]
print(daily_entries_2021.shape)
# Out:
# (43828, 6)
# (43035, 6)

# %%
daily_entries_2019 = daily_entries_2019.merge(right=neighborhoods_zips, how='inner', on='ZIPCODE')

# Check for NaNs
display(daily_entries_2019[daily_entries_2019.isna().any(axis=1)])

display(daily_entries_2019.head())
display(daily_entries_2019.tail())
# Out:
# Empty DataFrame
# Columns: [STATION, LINENAME, DATE, NET_ENTRIES, WEEKDAY, ZIPCODE, BOROUGH, NEIGHBORHOOD]
# Index: []
#   STATION LINENAME        DATE  NET_ENTRIES  WEEKDAY ZIPCODE    BOROUGH  \
# 0   49 ST     NQRW  05/01/2019          796        1   10036  Manhattan
# 1   49 ST     NQRW  05/02/2019          806        1   10036  Manhattan
# 2   49 ST     NQRW  05/03/2019          762        1   10036  Manhattan
# 3   49 ST     NQRW  05/04/2019          460        0   10036  Manhattan
# 4   49 ST     NQRW  05/05/2019          373        0   10036  Manhattan
#
#           NEIGHBORHOOD
# 0  Chelsea and Clinton
# 1  Chelsea and Clinton
# 2  Chelsea and Clinton
# 3  Chelsea and Clinton
# 4  Chelsea and Clinton
#            STATION LINENAME        DATE  NET_ENTRIES  WEEKDAY ZIPCODE  \
# 42708  WINTHROP ST       25  06/26/2019            0        1   11203
# 42709  WINTHROP ST       25  06/27/2019            0        1   11203
# 42710  WINTHROP ST       25  06/28/2019            0        1   11203
# 42711  WINTHROP ST       25  06/29/2019          492        0   11203
# 42712  WINTHROP ST       25  06/30/2019          194        0   11203
#
#         BOROUGH NEIGHBORHOOD
# 42708  Brooklyn     Flatbush
# 42709  Brooklyn     Flatbush
# 42710  Brooklyn     Flatbush
# 42711  Brooklyn     Flatbush
# 42712  Brooklyn     Flatbush

# %%
daily_entries_2021 = daily_entries_2021.merge(right=neighborhoods_zips, how='inner', on='ZIPCODE')

# Check for NaNs
display(daily_entries_2021[daily_entries_2021.isna().any(axis=1)])

display(daily_entries_2021.head())
display(daily_entries_2021.tail())
# Out:
# Empty DataFrame
# Columns: [STATION, LINENAME, DATE, NET_ENTRIES, WEEKDAY, ZIPCODE, BOROUGH, NEIGHBORHOOD]
# Index: []
#   STATION LINENAME        DATE  NET_ENTRIES  WEEKDAY ZIPCODE    BOROUGH  \
# 0   49 ST     NQRW  05/01/2021           99        0   10036  Manhattan
# 1   49 ST     NQRW  05/02/2021           66        0   10036  Manhattan
# 2   49 ST     NQRW  05/03/2021          124        1   10036  Manhattan
# 3   49 ST     NQRW  05/04/2021          131        1   10036  Manhattan
# 4   49 ST     NQRW  05/05/2021          122        1   10036  Manhattan
#
#           NEIGHBORHOOD
# 0  Chelsea and Clinton
# 1  Chelsea and Clinton
# 2  Chelsea and Clinton
# 3  Chelsea and Clinton
# 4  Chelsea and Clinton
#            STATION LINENAME        DATE  NET_ENTRIES  WEEKDAY ZIPCODE  \
# 43030  WINTHROP ST       25  06/26/2021          457        0   11203
# 43031  WINTHROP ST       25  06/27/2021          105        0   11203
# 43032  WINTHROP ST       25  06/28/2021          213        1   11203
# 43033  WINTHROP ST       25  06/29/2021          233        1   11203
# 43034  WINTHROP ST       25  06/30/2021          199        1   11203
#
#         BOROUGH NEIGHBORHOOD
# 43030  Brooklyn     Flatbush
# 43031  Brooklyn     Flatbush
# 43032  Brooklyn     Flatbush
# 43033  Brooklyn     Flatbush
# 43034  Brooklyn     Flatbush

# %%
# Here's how many stations survived all the way through the data to this point:

daily_entries_2019['STATION'].unique().shape[0]
# Out:
# 98

# %% [markdown]
# ### Now import US Census Data (Median Income) and Merge with existing dataset

# %% [markdown]
# #### Start with ZIPCODE-level data

# %%
median_income_zipcodes = pd.read_csv('median_income_zipcode.csv', 
                                      usecols=['ZIPCODE', 'All Households', 'Families'])
median_income_zipcodes.columns = ['ZIPCODE', 'MEDIAN_INCOME_ALL_ZIP', 'MEDIAN_INCOME_FAMILIES_ZIP']
median_income_zipcodes['ZIPCODE'] = median_income_zipcodes['ZIPCODE'].str.replace('Zip Code ', '')
median_income_zipcodes.head()
# Out:
#   ZIPCODE  MEDIAN_INCOME_ALL_ZIP  MEDIAN_INCOME_FAMILIES_ZIP
# 0   10001                  92840                      122776
# 1   10002                  36982                       40045
# 2   10003                 118161                      183787
# 3   10004                 190223                      205202
# 4   10005                 189702                      241094

# %%
daily_entries_2019 = daily_entries_2019.merge(right=median_income_zipcodes, how='left', on='ZIPCODE')

# Check for NaNs
display(daily_entries_2019[daily_entries_2019.isna().any(axis=1)])

display(daily_entries_2019.head())
# Out:
# Empty DataFrame
# Columns: [STATION, LINENAME, DATE, NET_ENTRIES, WEEKDAY, ZIPCODE, BOROUGH, NEIGHBORHOOD, MEDIAN_INCOME_ALL_ZIP, MEDIAN_INCOME_FAMILIES_ZIP]
# Index: []
#   STATION LINENAME        DATE  NET_ENTRIES  WEEKDAY ZIPCODE    BOROUGH  \
# 0   49 ST     NQRW  05/01/2019          796        1   10036  Manhattan
# 1   49 ST     NQRW  05/02/2019          806        1   10036  Manhattan
# 2   49 ST     NQRW  05/03/2019          762        1   10036  Manhattan
# 3   49 ST     NQRW  05/04/2019          460        0   10036  Manhattan
# 4   49 ST     NQRW  05/05/2019          373        0   10036  Manhattan
#
#           NEIGHBORHOOD  MEDIAN_INCOME_ALL_ZIP  MEDIAN_INCOME_FAMILIES_ZIP
# 0  Chelsea and Clinton                  95301                      112342
# 1  Chelsea and Clinton                  95301                      112342
# 2  Chelsea and Clinton                  95301                      112342
# 3  Chelsea and Clinton                  95301                      112342
# 4  Chelsea and Clinton                  95301                      112342

# %%
daily_entries_2021 = daily_entries_2021.merge(right=median_income_zipcodes, how='left', on='ZIPCODE')

# Check for NaNs
display(daily_entries_2021[daily_entries_2021.isna().any(axis=1)])

display(daily_entries_2021.head())
# Out:
# Empty DataFrame
# Columns: [STATION, LINENAME, DATE, NET_ENTRIES, WEEKDAY, ZIPCODE, BOROUGH, NEIGHBORHOOD, MEDIAN_INCOME_ALL_ZIP, MEDIAN_INCOME_FAMILIES_ZIP]
# Index: []
#   STATION LINENAME        DATE  NET_ENTRIES  WEEKDAY ZIPCODE    BOROUGH  \
# 0   49 ST     NQRW  05/01/2021           99        0   10036  Manhattan
# 1   49 ST     NQRW  05/02/2021           66        0   10036  Manhattan
# 2   49 ST     NQRW  05/03/2021          124        1   10036  Manhattan
# 3   49 ST     NQRW  05/04/2021          131        1   10036  Manhattan
# 4   49 ST     NQRW  05/05/2021          122        1   10036  Manhattan
#
#           NEIGHBORHOOD  MEDIAN_INCOME_ALL_ZIP  MEDIAN_INCOME_FAMILIES_ZIP
# 0  Chelsea and Clinton                  95301                      112342
# 1  Chelsea and Clinton                  95301                      112342
# 2  Chelsea and Clinton                  95301                      112342
# 3  Chelsea and Clinton                  95301                      112342
# 4  Chelsea and Clinton                  95301                      112342

# %% [markdown]
# #### Do the same with BOROUGH-level data

# %%
median_income_boroughs = pd.read_csv('median_income_borough.csv', 
                                      usecols=['BOROUGH', 'All Households', 'Families'])
median_income_boroughs.columns = ['BOROUGH', 'MEDIAN_INCOME_ALL_BOR', 'MEDIAN_INCOME_FAMILIES_BOR']
median_income_boroughs.head()
# Out:
#          BOROUGH  MEDIAN_INCOME_ALL_BOR  MEDIAN_INCOME_FAMILIES_BOR
# 0          Bronx                  41432                       50835
# 1       Brooklyn                  66937                       74422
# 2      Manhattan                  93651                      126690
# 3         Queens                  73696                       82534
# 4  Staten Island                  89821                      105438

# %%
daily_entries_2019 = daily_entries_2019.merge(right=median_income_boroughs, how='left', on='BOROUGH')

# Check for NaNs
display(daily_entries_2019[daily_entries_2019.isna().any(axis=1)])

display(daily_entries_2019.head())
# Out:
# Empty DataFrame
# Columns: [STATION, LINENAME, DATE, NET_ENTRIES, WEEKDAY, ZIPCODE, BOROUGH, NEIGHBORHOOD, MEDIAN_INCOME_ALL_ZIP, MEDIAN_INCOME_FAMILIES_ZIP, MEDIAN_INCOME_ALL_BOR, MEDIAN_INCOME_FAMILIES_BOR]
# Index: []
#   STATION LINENAME        DATE  NET_ENTRIES  WEEKDAY ZIPCODE    BOROUGH  \
# 0   49 ST     NQRW  05/01/2019          796        1   10036  Manhattan
# 1   49 ST     NQRW  05/02/2019          806        1   10036  Manhattan
# 2   49 ST     NQRW  05/03/2019          762        1   10036  Manhattan
# 3   49 ST     NQRW  05/04/2019          460        0   10036  Manhattan
# 4   49 ST     NQRW  05/05/2019          373        0   10036  Manhattan
#
#           NEIGHBORHOOD  MEDIAN_INCOME_ALL_ZIP  MEDIAN_INCOME_FAMILIES_ZIP  \
# 0  Chelsea and Clinton                  95301                      112342
# 1  Chelsea and Clinton                  95301                      112342
# 2  Chelsea and Clinton                  95301                      112342
# 3  Chelsea and Clinton                  95301                      112342
# 4  Chelsea and Clinton                  95301                      112342
#
#    MEDIAN_INCOME_ALL_BOR  MEDIAN_INCOME_FAMILIES_BOR
# 0                  93651                      126690
# 1                  93651                      126690
# 2                  93651                      126690
# 3                  93651                      126690
# 4                  93651                      126690

# %%
daily_entries_2021 = daily_entries_2021.merge(right=median_income_boroughs, how='left', on='BOROUGH')

# Check for NaNs
display(daily_entries_2021[daily_entries_2021.isna().any(axis=1)])

display(daily_entries_2021.head())
# Out:
# Empty DataFrame
# Columns: [STATION, LINENAME, DATE, NET_ENTRIES, WEEKDAY, ZIPCODE, BOROUGH, NEIGHBORHOOD, MEDIAN_INCOME_ALL_ZIP, MEDIAN_INCOME_FAMILIES_ZIP, MEDIAN_INCOME_ALL_BOR, MEDIAN_INCOME_FAMILIES_BOR]
# Index: []
#   STATION LINENAME        DATE  NET_ENTRIES  WEEKDAY ZIPCODE    BOROUGH  \
# 0   49 ST     NQRW  05/01/2021           99        0   10036  Manhattan
# 1   49 ST     NQRW  05/02/2021           66        0   10036  Manhattan
# 2   49 ST     NQRW  05/03/2021          124        1   10036  Manhattan
# 3   49 ST     NQRW  05/04/2021          131        1   10036  Manhattan
# 4   49 ST     NQRW  05/05/2021          122        1   10036  Manhattan
#
#           NEIGHBORHOOD  MEDIAN_INCOME_ALL_ZIP  MEDIAN_INCOME_FAMILIES_ZIP  \
# 0  Chelsea and Clinton                  95301                      112342
# 1  Chelsea and Clinton                  95301                      112342
# 2  Chelsea and Clinton                  95301                      112342
# 3  Chelsea and Clinton                  95301                      112342
# 4  Chelsea and Clinton                  95301                      112342
#
#    MEDIAN_INCOME_ALL_BOR  MEDIAN_INCOME_FAMILIES_BOR
# 0                  93651                      126690
# 1                  93651                      126690
# 2                  93651                      126690
# 3                  93651                      126690
# 4                  93651                      126690

# %%
# One last thing: Make ZIPCODE an integer (will help w/ analyis below)

daily_entries_2019['ZIPCODE'] = daily_entries_2019['ZIPCODE'].astype('int')
daily_entries_2021['ZIPCODE'] = daily_entries_2021['ZIPCODE'].astype('int')

# %% [markdown]
# # Now Let's Visualize Something!

# %% [markdown]
# # Start with finding the busiest stations (on average) in the 2019 data

# %%
# Criterion: Median NET_ENTRIES (as opposed to Mean)

busiest_2019 = daily_entries_2019.groupby(['STATION', 'LINENAME', 'BOROUGH']) \
                                           .median().sort_values(by='NET_ENTRIES', ascending=False) \
                                           .reset_index()

busiest_2019
# Out:
#             STATION LINENAME    BOROUGH  NET_ENTRIES  WEEKDAY  ZIPCODE  \
# 81                     82534.0
# 82                    126690.0
# 83                     50835.0
# 84                     82534.0
# 85                     82534.0
# 86                     82534.0
# 87                     50835.0
# 88                     82534.0
# 89                    126690.0
# 90                     82534.0
# 91                     74422.0
# 92                     82534.0
# 93                     82534.0
# 94                     82534.0
# 95                     50835.0
# 96                     82534.0
# 97                     50835.0

# %%
# How many stations to consider per borough? Let's make it a parameter

stations_per_borough = 1

# %%
# 2019 data (sets the baseline stations to compare against 2021)

boroughs = daily_entries_2019['BOROUGH'].unique()
busiest_2019_top_stations = pd.DataFrame(columns=busiest_2019.columns)

for borough in boroughs:
    busiest_2019_top_stations = pd.concat([busiest_2019_top_stations, 
                                           busiest_2019[busiest_2019['BOROUGH'] == borough]
                                           .head(stations_per_borough)], 
                                           axis=0)
    
busiest_2019_top_stations.reset_index(drop=True, inplace=True)
busiest_2019_top_stations
# Out:
#           STATION LINENAME    BOROUGH  NET_ENTRIES  WEEKDAY  ZIPCODE  \
# 0          191 ST        1  Manhattan       1628.0      1.0  10040.0
# 1         YORK ST        F   Brooklyn       3708.0      1.0  11201.0
# 2  QUEENSBORO PLZ     7NQW     Queens       2311.0      1.0  11101.0
# 3     182-183 STS       BD      Bronx       1424.0      1.0  10457.0
#
#    MEDIAN_INCOME_ALL_ZIP  MEDIAN_INCOME_FAMILIES_ZIP  MEDIAN_INCOME_ALL_BOR  \
# 0                49677.0                     56530.0                93651.0
# 1               129248.0                    176004.0                66937.0
# 2                75581.0                     82636.0                73696.0
# 3                29767.0                     38096.0                41432.0
#
#    MEDIAN_INCOME_FAMILIES_BOR
# 0                    126690.0
# 1                     74422.0
# 2                     82534.0
# 3                     50835.0

# %%
# Need to get this down to the same subset, in the same STATION order as busiest_2019_top_stations
#   NOTE: The slick reindexing trick came from here:
#   https://stackoverflow.com/questions/45576800/how-to-sort-dataframe-based-on-a-column-in-another-dataframe-in-pandas

compare_2021 = daily_entries_2021.groupby(['STATION', 'LINENAME', 'BOROUGH']) \
                                           .median().reset_index()
compare_2021 = compare_2021.set_index('STATION')
compare_2021 = compare_2021.reindex(index=busiest_2019_top_stations['STATION'])
compare_2021 = compare_2021.reset_index()
compare_2021
# Out:
#           STATION LINENAME    BOROUGH  NET_ENTRIES  WEEKDAY  ZIPCODE  \
# 0          191 ST        1  Manhattan        917.5      1.0  10040.0
# 1         YORK ST        F   Brooklyn       1135.0      1.0  11201.0
# 2  QUEENSBORO PLZ     7NQW     Queens        649.0      1.0  11101.0
# 3     182-183 STS       BD      Bronx        619.0      1.0  10457.0
#
#    MEDIAN_INCOME_ALL_ZIP  MEDIAN_INCOME_FAMILIES_ZIP  MEDIAN_INCOME_ALL_BOR  \
# 0                49677.0                     56530.0                93651.0
# 1               129248.0                    176004.0                66937.0
# 2                75581.0                     82636.0                73696.0
# 3                29767.0                     38096.0                41432.0
#
#    MEDIAN_INCOME_FAMILIES_BOR
# 0                    126690.0
# 1                     74422.0
# 2                     82534.0
# 3                     50835.0

# %%
# Add a YEAR column to both so we can compare them in plots

busiest_2019_top_stations['YEAR'] = 2019
compare_2021['YEAR'] = 2021

# %%
busiest_top_stations_compare = pd.concat([busiest_2019_top_stations, compare_2021], axis=0)
busiest_top_stations_compare.reset_index(drop=True, inplace=True)
busiest_top_stations_compare['ZIPCODE'] = busiest_top_stations_compare['ZIPCODE'].astype('int')
busiest_top_stations_compare
# Out:
#           STATION LINENAME    BOROUGH  NET_ENTRIES  WEEKDAY  ZIPCODE  \
# 0          191 ST        1  Manhattan       1628.0      1.0    10040
# 1         YORK ST        F   Brooklyn       3708.0      1.0    11201
# 2  QUEENSBORO PLZ     7NQW     Queens       2311.0      1.0    11101
# 3     182-183 STS       BD      Bronx       1424.0      1.0    10457
# 4          191 ST        1  Manhattan        917.5      1.0    10040
# 5         YORK ST        F   Brooklyn       1135.0      1.0    11201
# 6  QUEENSBORO PLZ     7NQW     Queens        649.0      1.0    11101
# 7     182-183 STS       BD      Bronx        619.0      1.0    10457
#
#    MEDIAN_INCOME_ALL_ZIP  MEDIAN_INCOME_FAMILIES_ZIP  MEDIAN_INCOME_ALL_BOR  \
# 0                49677.0                     56530.0                93651.0
# 1               129248.0                    176004.0                66937.0
# 2                75581.0                     82636.0                73696.0
# 3                29767.0                     38096.0                41432.0
# 4                49677.0                     56530.0                93651.0
# 5               129248.0                    176004.0                66937.0
# 6                75581.0                     82636.0                73696.0
# 7                29767.0                     38096.0                41432.0
#
#    MEDIAN_INCOME_FAMILIES_BOR  YEAR
# 0                    126690.0  2019
# 1                     74422.0  2019
# 2                     82534.0  2019
# 3                     50835.0  2019
# 4                    126690.0  2021
# 5                     74422.0  2021
# 6                     82534.0  2021
# 7                     50835.0  2021

# %%
sns.set_style("darkgrid")
sns.catplot(x='ZIPCODE', y='NET_ENTRIES', hue='YEAR', data=busiest_top_stations_compare, kind='bar', ci=None)
plt.title('Median Daily Riders, Busiest Station (Zip Code) \nper Borough, May & June, 2019 vs. 2021', 
          fontdict={'weight': 'bold', 'fontsize': 14})
plt.xlabel("Zip Code", fontdict={'weight': 'bold', 'size': 12})
plt.ylabel("Median Daily Station Entries", fontdict={'weight': 'bold', 'size': 12});

# %%
# Create dataframe of relative % differences in ridership comparing the selected stations from 2019 to 2021

busiest_top_stations_relative = busiest_2019_top_stations.groupby('BOROUGH').sum().reset_index()
busiest_top_stations_relative['NET_ENTRIES'] = \
                    np.abs((busiest_2019_top_stations.groupby('BOROUGH').sum()['NET_ENTRIES'] -
                         compare_2021.groupby('BOROUGH').sum()['NET_ENTRIES']).values)
busiest_top_stations_relative['ZIPCODE'] = busiest_top_stations_relative['ZIPCODE'].astype('int')
busiest_top_stations_relative
# Out:
#      BOROUGH  NET_ENTRIES  WEEKDAY  ZIPCODE  MEDIAN_INCOME_ALL_ZIP  \
# 0      Bronx        805.0      1.0    10457                29767.0
# 1   Brooklyn       2573.0      1.0    11201               129248.0
# 2  Manhattan        710.5      1.0    10040                49677.0
# 3     Queens       1662.0      1.0    11101                75581.0
#
#    MEDIAN_INCOME_FAMILIES_ZIP  MEDIAN_INCOME_ALL_BOR  \
# 0                     38096.0                41432.0
# 1                    176004.0                66937.0
# 2                     56530.0                93651.0
# 3                     82636.0                73696.0
#
#    MEDIAN_INCOME_FAMILIES_BOR  YEAR
# 0                     50835.0  2019
# 1                     74422.0  2019
# 2                    126690.0  2019
# 3                     82534.0  2019

# %%
plt.figure(figsize=(5,5))
plt.pie(x=busiest_top_stations_relative['NET_ENTRIES'], 
        labels=busiest_top_stations_relative['ZIPCODE'],
        explode = [0.02]*4,
        autopct="-%.1f%%",
        textprops={'fontsize': 14, 'fontweight': 'bold'})
plt.title('Relative % Change in Ridership Between Busiest Four Stations \n(Zip Codes - One per Borough), May & June, 2019 vs. 2021',
          fontdict={'weight': 'bold', 'size': 14});

# %%
sns.set_style("darkgrid")
g = sns.catplot(x='ZIPCODE', y='MEDIAN_INCOME_ALL_ZIP', 
            data=busiest_top_stations_compare, kind='bar', 
            palette=['green', 'blue', 'red', 'orange'], ci=None)
plt.title('Median Income in Zip Code, Busiest Station \nper Borough, May & June, 2019 vs. 2021', 
          fontdict={'weight': 'bold', 'size': 14})
plt.xlabel("Zip Code", fontdict={'weight': 'bold', 'size': 12})
plt.ylabel("Median Income ($)", fontdict={'weight': 'bold', 'size': 12});

# %%
# Create dataframe of absolute % differences in ridership per selected station from 2019 to 2021

busiest_top_stations_absolute = busiest_2019_top_stations.groupby('BOROUGH').sum().reset_index()
busiest_top_stations_absolute['NET_ENTRIES'] = -100* \
           ((busiest_2019_top_stations.groupby('BOROUGH').sum()['NET_ENTRIES'] -
             compare_2021.groupby('BOROUGH').sum()['NET_ENTRIES']) / 
             busiest_2019_top_stations.groupby('BOROUGH').sum()['NET_ENTRIES']).values
busiest_top_stations_absolute['ZIPCODE'] = busiest_top_stations_absolute['ZIPCODE'].astype('int')
busiest_top_stations_absolute
# Out:
#      BOROUGH  NET_ENTRIES  WEEKDAY  ZIPCODE  MEDIAN_INCOME_ALL_ZIP  \
# 0      Bronx   -56.530899      1.0    10457                29767.0
# 1   Brooklyn   -69.390507      1.0    11201               129248.0
# 2  Manhattan   -43.642506      1.0    10040                49677.0
# 3     Queens   -71.916919      1.0    11101                75581.0
#
#    MEDIAN_INCOME_FAMILIES_ZIP  MEDIAN_INCOME_ALL_BOR  \
# 0                     38096.0                41432.0
# 1                    176004.0                66937.0
# 2                     56530.0                93651.0
# 3                     82636.0                73696.0
#
#    MEDIAN_INCOME_FAMILIES_BOR  YEAR
# 0                     50835.0  2019
# 1                     74422.0  2019
# 2                    126690.0  2019
# 3                     82534.0  2019

# %%
sns.set_style("darkgrid")
g = sns.catplot(x='ZIPCODE', y='NET_ENTRIES', 
            data=busiest_top_stations_absolute, kind='bar', 
            palette=['green', 'blue', 'red', 'orange'], ci=None)
plt.title('Absolute % Change in Ridership per Station (Zip Code) \nfor Each Borough, May & June, 2019 vs. 2021', 
          fontdict={'weight': 'bold', 'size': 14})
plt.xlabel("Zip Code", fontdict={'weight': 'bold', 'size': 12})
plt.ylabel("% Change in Ridership (2019 to 2021)", fontdict={'weight': 'bold', 'size': 12});
