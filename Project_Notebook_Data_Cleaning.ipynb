# %%
import pandas as pd
import numpy as np

from sqlalchemy import create_engine

import geopy

import matplotlib.pyplot as plt
import seaborn as sns

# Configure image format to be ‘svg’
# %config InlineBackend.figure_format = 'svg'

# allow visuals to render within notebook
# %matplotlib inline

# %%
# Make some room to see stuff (i.e. drop display limits on Pandas rows & cols - be careful w/ big df's!)

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # 1. Import MTA Data From SQLite Database

# %%
engine = create_engine('sqlite:///../_PROJECT/mta_data.db')

engine.table_names()
# Out:
# /var/folders/16/my2sdbrn4hvfl3_91fx0wj9c0000gn/T/ipykernel_22642/152434287.py:3: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ['mta_data']

# %%
# Check for any NULL values

pd.read_sql('''
            SELECT *
            FROM mta_data
            WHERE unit IS NULL 
               OR scp IS NULL
               OR station IS NULL
               OR linename IS NULL
               OR date IS NULL
               OR time IS NULL
               OR desc IS NULL
               OR entries IS NULL
               OR exits IS NULL;
            ''', con=engine)
# Out:
# Empty DataFrame
# Columns: [C/A, UNIT, SCP, STATION, LINENAME, DIVISION, DATE, TIME, DESC, ENTRIES, EXITS]
# Index: []

# %%
# Bring in just the data for May-June 2019 (order by ascending 'DATE'; don't bother importing 'EXITS' col)

# df_2019 = pd.read_sql('''
#                       SELECT (STATION || ' - ' || LINENAME || ' - ' || DIVISION) AS STATION_ID,
#                          STATION AS STATION_NAME, [C/A], UNIT, SCP,  DATE, TIME, DESC, ENTRIES
#                       FROM mta_data
#                       WHERE DATE = '04/30/2019' OR DATE LIKE '05%19' OR DATE LIKE '06%19'
#                       ORDER BY DATE ASC;
#                       ''', con=engine)

df_2019 = pd.read_sql('''
                      SELECT *
                      FROM mta_data
                      WHERE DATE = '04/30/2019' OR DATE LIKE '05%19' OR DATE LIKE '06%19'
                      ORDER BY DATE ASC;
                      ''', con=engine)

# %%
# Add a 'DATETIME' column (and drop 'DATE' & 'TIME' - can get either of these from 'DATETIME' if needed)

df_2019['DATETIME'] = pd.to_datetime(df_2019['DATE'] + ' ' + df_2019['TIME'])

# Make 'DATE' column a proper date format
df_2019['DATE'] = df_2019['DATETIME'].dt.date

df_2019.drop(columns=['TIME', 'EXITS'], inplace=True)

# %%
print(df_2019.shape)
display(df_2019.head())
display(df_2019.tail())
# Out:
# (3639340, 10)
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE     DESC  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  2019-04-30  REGULAR
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  2019-04-30  REGULAR
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  2019-04-30  REGULAR
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  2019-04-30  REGULAR
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  2019-04-30  REGULAR
#
#    ENTRIES            DATETIME
# 0  7038242 2019-04-30 00:00:00
# 1  7038261 2019-04-30 04:00:00
# 2  7038308 2019-04-30 08:00:00
# 3  7038474 2019-04-30 12:00:00
# 4  7038775 2019-04-30 16:00:00
#            C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 3639335  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  2019-06-30
# 3639336  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  2019-06-30
# 3639337  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  2019-06-30
# 3639338  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  2019-06-30
# 3639339  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  2019-06-30
#
#             DESC  ENTRIES            DATETIME
# 3639335  REGULAR     5554 2019-06-30 05:00:00
# 3639336  REGULAR     5554 2019-06-30 09:00:00
# 3639337  REGULAR     5554 2019-06-30 13:00:00
# 3639338  REGULAR     5554 2019-06-30 17:00:00
# 3639339  REGULAR     5554 2019-06-30 21:00:00

# %%
# Bring in just the data for May-June 2021 (order by ascending 'DATE'; don't bother importing 'EXITS' col)

# df_2021 = pd.read_sql('''
#                       SELECT (STATION || ' - ' || LINENAME || ' - ' || DIVISION) AS STATION_ID,
#                          STATION AS STATION_NAME, [C/A], UNIT, SCP,  DATE, TIME, DESC, ENTRIES
#                       FROM mta_data
#                       WHERE DATE = '04/30/2021' OR DATE LIKE '05%21' OR DATE LIKE '06%21'
#                       ORDER BY DATE ASC;
#                       ''', con=engine)

df_2021 = pd.read_sql('''
                      SELECT *
                      FROM mta_data
                      WHERE DATE = '04/30/2021' OR DATE LIKE '05%21' OR DATE LIKE '06%21'
                      ORDER BY DATE ASC;
                      ''', con=engine)

# %%
# Add a 'DATETIME' column (and drop 'DATE' & 'TIME' - can get either of these from 'DATETIME' if needed)

df_2021['DATETIME'] = pd.to_datetime(df_2021['DATE'] + ' ' + df_2021['TIME'])

# Make 'DATE' column a proper date format
df_2021['DATE'] = df_2021['DATETIME'].dt.date

df_2021.drop(columns=['TIME', 'EXITS'], inplace=True)

# %%
print(df_2021.shape)
display(df_2021.head())
display(df_2021.tail())
# Out:
# (3706606, 10)
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE     DESC  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  2021-04-30  REGULAR
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  2021-04-30  REGULAR
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  2021-04-30  REGULAR
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  2021-04-30  REGULAR
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  2021-04-30  REGULAR
#
#    ENTRIES            DATETIME
# 0  7564048 2021-04-30 00:00:00
# 1  7564059 2021-04-30 04:00:00
# 2  7564073 2021-04-30 08:00:00
# 3  7564118 2021-04-30 12:00:00
# 4  7564286 2021-04-30 16:00:00
#            C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 3706601  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  2021-06-30
# 3706602  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  2021-06-30
# 3706603  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  2021-06-30
# 3706604  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  2021-06-30
# 3706605  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  2021-06-30
#
#             DESC  ENTRIES            DATETIME
# 3706601  REGULAR     5554 2021-06-30 05:00:00
# 3706602  REGULAR     5554 2021-06-30 09:00:00
# 3706603  REGULAR     5554 2021-06-30 13:00:00
# 3706604  REGULAR     5554 2021-06-30 17:00:00
# 3706605  REGULAR     5554 2021-06-30 21:00:00

# %% [markdown]
# # 2. Basic Cleaning

# %% [markdown]
# ### 2a) Check for Duplicates
# #### A single turnstile somwhere in the system is uniquely identified by C/A (Booth) + UNIT (Station) + SCP (Turnstile)
# #### Add a new column 'ID' that creates a unique identifier for grouping on these three

# %%
df_2019['ID'] = df_2019['C/A'] + ' - ' + df_2019['UNIT'] + ' - ' + df_2019['SCP']
df_2019.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE     DESC  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  2019-04-30  REGULAR
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  2019-04-30  REGULAR
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  2019-04-30  REGULAR
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  2019-04-30  REGULAR
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  2019-04-30  REGULAR
#
#    ENTRIES            DATETIME                      ID
# 0  7038242 2019-04-30 00:00:00  A002 - R051 - 02-00-00
# 1  7038261 2019-04-30 04:00:00  A002 - R051 - 02-00-00
# 2  7038308 2019-04-30 08:00:00  A002 - R051 - 02-00-00
# 3  7038474 2019-04-30 12:00:00  A002 - R051 - 02-00-00
# 4  7038775 2019-04-30 16:00:00  A002 - R051 - 02-00-00

# %%
df_2021['ID'] = df_2021['C/A'] + ' - ' + df_2021['UNIT'] + ' - ' + df_2021['SCP']
df_2021.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE     DESC  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  2021-04-30  REGULAR
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  2021-04-30  REGULAR
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  2021-04-30  REGULAR
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  2021-04-30  REGULAR
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  2021-04-30  REGULAR
#
#    ENTRIES            DATETIME                      ID
# 0  7564048 2021-04-30 00:00:00  A002 - R051 - 02-00-00
# 1  7564059 2021-04-30 04:00:00  A002 - R051 - 02-00-00
# 2  7564073 2021-04-30 08:00:00  A002 - R051 - 02-00-00
# 3  7564118 2021-04-30 12:00:00  A002 - R051 - 02-00-00
# 4  7564286 2021-04-30 16:00:00  A002 - R051 - 02-00-00

# %% [markdown]
# #### Now check for duplicates (Start with df_2019):

# %%
check = df_2019.groupby(['ID', 'DATETIME'])['ENTRIES'] \
                        .count().sort_values(ascending=False)
check.reset_index().head()
# Out:
#                        ID            DATETIME  ENTRIES
# 0  R249 - R179 - 01-05-00 2019-06-27 00:00:00        4
# 1  N045 - R187 - 01-06-00 2019-06-02 17:00:00        4
# 2  R174 - R034 - 00-00-03 2019-06-08 00:00:00        4
# 3  N045 - R187 - 01-00-00 2019-06-02 17:00:00        4
# 4  R174 - R034 - 00-00-02 2019-06-08 00:00:00        4

# %%
for i in range(0, 6):
    display(df_2019[(df_2019['ID'] == check.reset_index().iloc[i, 0:1].values[0]) & 
                    (df_2019['DATETIME'] == check.reset_index().iloc[i, 1:2].values[0])])
# Out:
#           C/A  UNIT       SCP STATION LINENAME DIVISION        DATE  \
# 3427686  R249  R179  01-05-00   86 ST      456      IRT  2019-06-27
# 3427687  R249  R179  01-05-00   86 ST      456      IRT  2019-06-27
# 3457150  R249  R179  01-05-00   86 ST      456      IRT  2019-06-27
# 3457151  R249  R179  01-05-00   86 ST      456      IRT  2019-06-27
#
#                DESC  ENTRIES   DATETIME                      ID
# 3427686     REGULAR        6 2019-06-27  R249 - R179 - 01-05-00
# 3427687  RECOVR AUD       11 2019-06-27  R249 - R179 - 01-05-00
# 3457150     REGULAR        6 2019-06-27  R249 - R179 - 01-05-00
# 3457151  RECOVR AUD       11 2019-06-27  R249 - R179 - 01-05-00
#           C/A  UNIT       SCP       STATION LINENAME DIVISION        DATE  \
# 1940800  N045  R187  01-06-00  81 ST-MUSEUM       BC      IND  2019-06-02
# 1940801  N045  R187  01-06-00  81 ST-MUSEUM       BC      IND  2019-06-02
# 1969768  N045  R187  01-06-00  81 ST-MUSEUM       BC      IND  2019-06-02
# 1969769  N045  R187  01-06-00  81 ST-MUSEUM       BC      IND  2019-06-02
#
#                DESC  ENTRIES            DATETIME                      ID
# 1940800     REGULAR  2254050 2019-06-02 17:00:00  N045 - R187 - 01-06-00
# 1940801  RECOVR AUD  2254049 2019-06-02 17:00:00  N045 - R187 - 01-06-00
# 1969768     REGULAR  2254050 2019-06-02 17:00:00  N045 - R187 - 01-06-00
# 1969769  RECOVR AUD  2254049 2019-06-02 17:00:00  N045 - R187 - 01-06-00
#           C/A  UNIT       SCP STATION LINENAME DIVISION        DATE  \
# 2306436  R174  R034  00-00-03  125 ST        1      IRT  2019-06-08
# 2306437  R174  R034  00-00-03  125 ST        1      IRT  2019-06-08
# 2335466  R174  R034  00-00-03  125 ST        1      IRT  2019-06-08
# 2335467  R174  R034  00-00-03  125 ST        1      IRT  2019-06-08
#
#                DESC  ENTRIES   DATETIME                      ID
# 2306436     REGULAR  3828801 2019-06-08  R174 - R034 - 00-00-03
# 2306437  RECOVR AUD  3828804 2019-06-08  R174 - R034 - 00-00-03
# 2335466     REGULAR  3828801 2019-06-08  R174 - R034 - 00-00-03
# 2335467  RECOVR AUD  3828804 2019-06-08  R174 - R034 - 00-00-03
#           C/A  UNIT       SCP       STATION LINENAME DIVISION        DATE  \
# 1940782  N045  R187  01-00-00  81 ST-MUSEUM       BC      IND  2019-06-02
# 1940783  N045  R187  01-00-00  81 ST-MUSEUM       BC      IND  2019-06-02
# 1969750  N045  R187  01-00-00  81 ST-MUSEUM       BC      IND  2019-06-02
# 1969751  N045  R187  01-00-00  81 ST-MUSEUM       BC      IND  2019-06-02
#
#                DESC  ENTRIES            DATETIME                      ID
# 1940782     REGULAR  5254570 2019-06-02 17:00:00  N045 - R187 - 01-00-00
# 1940783  RECOVR AUD  5254568 2019-06-02 17:00:00  N045 - R187 - 01-00-00
# 1969750     REGULAR  5254570 2019-06-02 17:00:00  N045 - R187 - 01-00-00
# 1969751  RECOVR AUD  5254568 2019-06-02 17:00:00  N045 - R187 - 01-00-00
#           C/A  UNIT       SCP STATION LINENAME DIVISION        DATE  \
# 2306430  R174  R034  00-00-02  125 ST        1      IRT  2019-06-08
# 2306431  R174  R034  00-00-02  125 ST        1      IRT  2019-06-08
# 2335460  R174  R034  00-00-02  125 ST        1      IRT  2019-06-08
# 2335461  R174  R034  00-00-02  125 ST        1      IRT  2019-06-08
#
#                DESC  ENTRIES   DATETIME                      ID
# 2306430     REGULAR  6091547 2019-06-08  R174 - R034 - 00-00-02
# 2306431  RECOVR AUD  6091548 2019-06-08  R174 - R034 - 00-00-02
# 2335460     REGULAR  6091547 2019-06-08  R174 - R034 - 00-00-02
# 2335461  RECOVR AUD  6091548 2019-06-08  R174 - R034 - 00-00-02
#           C/A  UNIT       SCP       STATION LINENAME DIVISION        DATE  \
# 2467844  N045  R187  01-06-00  81 ST-MUSEUM       BC      IND  2019-06-11
# 2467845  N045  R187  01-06-00  81 ST-MUSEUM       BC      IND  2019-06-11
# 2496957  N045  R187  01-06-00  81 ST-MUSEUM       BC      IND  2019-06-11
# 2496958  N045  R187  01-06-00  81 ST-MUSEUM       BC      IND  2019-06-11
#
#                DESC  ENTRIES            DATETIME                      ID
# 2467844     REGULAR  2258033 2019-06-11 21:00:00  N045 - R187 - 01-06-00
# 2467845  RECOVR AUD  2258031 2019-06-11 21:00:00  N045 - R187 - 01-06-00
# 2496957     REGULAR  2258033 2019-06-11 21:00:00  N045 - R187 - 01-06-00
# 2496958  RECOVR AUD  2258031 2019-06-11 21:00:00  N045 - R187 - 01-06-00

# %% [markdown]
# #### Looks like accidental data duplication and some RECOV AUDs virtually identical to REGULARs; will just drop all the duplicates

# %%
print(df_2019.shape)

df_2019 = df_2019.sort_values(by=['ID', 'DATETIME'], 
                              ascending=False) \
                             .drop_duplicates(subset=['ID', 'DATETIME'])

df_2019.reset_index(drop=True, inplace=True)
print(df_2019.shape)
# Out:
# (3639340, 11)
# (1819646, 11)

# %%
# Re-check for duplicates

check = df_2019.groupby(['ID', 'DATETIME'])['ENTRIES'] \
                        .count().sort_values(ascending=False)
check.reset_index().head()
# Out:
#                        ID            DATETIME  ENTRIES
# 0  A002 - R051 - 02-00-00 2019-04-30 00:00:00        1
# 1  R142 - R293 - 01-00-01 2019-05-12 18:00:00        1
# 2  R142 - R293 - 01-00-01 2019-05-14 06:00:00        1
# 3  R142 - R293 - 01-00-01 2019-05-14 02:00:00        1
# 4  R142 - R293 - 01-00-01 2019-05-13 22:00:00        1

# %% [markdown]
# #### Now deal with duplicates in df_2021:

# %%
check = df_2021.groupby(['ID', 'DATETIME'])['ENTRIES'] \
                         .count().sort_values(ascending=False)
check.reset_index().head()
# Out:
#                        ID            DATETIME  ENTRIES
# 0  B024 - R211 - 00-05-00 2021-05-02 12:00:00        4
# 1  B024 - R211 - 00-05-00 2021-05-05 12:00:00        4
# 2  N329 - R201 - 00-03-02 2021-05-08 05:00:00        4
# 3  N329 - R201 - 00-03-02 2021-05-08 01:00:00        4
# 4  N335 - R158 - 01-00-03 2021-06-20 18:30:00        4

# %%
for i in range(0, 6):
    display(df_2021[(df_2021['ID'] == check.reset_index().iloc[i, 0:1].values[0]) & 
                    (df_2021['DATETIME'] == check.reset_index().iloc[i, 1:2].values[0])])
# Out:
#          C/A  UNIT       SCP    STATION LINENAME DIVISION        DATE  \
# 121785  B024  R211  00-05-00  KINGS HWY       BQ      BMT  2021-05-02
# 121786  B024  R211  00-05-00  KINGS HWY       BQ      BMT  2021-05-02
# 151574  B024  R211  00-05-00  KINGS HWY       BQ      BMT  2021-05-02
# 151575  B024  R211  00-05-00  KINGS HWY       BQ      BMT  2021-05-02
#
#               DESC  ENTRIES            DATETIME                      ID
# 121785     REGULAR   262152 2021-05-02 12:00:00  B024 - R211 - 00-05-00
# 121786  RECOVR AUD       13 2021-05-02 12:00:00  B024 - R211 - 00-05-00
# 151574     REGULAR   262152 2021-05-02 12:00:00  B024 - R211 - 00-05-00
# 151575  RECOVR AUD       13 2021-05-02 12:00:00  B024 - R211 - 00-05-00
#          C/A  UNIT       SCP    STATION LINENAME DIVISION        DATE  \
# 301051  B024  R211  00-05-00  KINGS HWY       BQ      BMT  2021-05-05
# 301052  B024  R211  00-05-00  KINGS HWY       BQ      BMT  2021-05-05
# 330870  B024  R211  00-05-00  KINGS HWY       BQ      BMT  2021-05-05
# 330871  B024  R211  00-05-00  KINGS HWY       BQ      BMT  2021-05-05
#
#               DESC  ENTRIES            DATETIME                      ID
# 301051     REGULAR   262152 2021-05-05 12:00:00  B024 - R211 - 00-05-00
# 301052  RECOVR AUD       21 2021-05-05 12:00:00  B024 - R211 - 00-05-00
# 330870     REGULAR   262152 2021-05-05 12:00:00  B024 - R211 - 00-05-00
# 330871  RECOVR AUD       21 2021-05-05 12:00:00  B024 - R211 - 00-05-00
#          C/A  UNIT       SCP         STATION LINENAME DIVISION        DATE  \
# 490387  N329  R201  00-03-02  WOODHAVEN BLVD       MR      IND  2021-05-08
# 490388  N329  R201  00-03-02  WOODHAVEN BLVD       MR      IND  2021-05-08
# 520213  N329  R201  00-03-02  WOODHAVEN BLVD       MR      IND  2021-05-08
# 520214  N329  R201  00-03-02  WOODHAVEN BLVD       MR      IND  2021-05-08
#
#               DESC   ENTRIES            DATETIME                      ID
# 490387     REGULAR   4825280 2021-05-08 05:00:00  N329 - R201 - 00-03-02
# 490388  RECOVR AUD  12538860 2021-05-08 05:00:00  N329 - R201 - 00-03-02
# 520213     REGULAR   4825280 2021-05-08 05:00:00  N329 - R201 - 00-03-02
# 520214  RECOVR AUD  12538860 2021-05-08 05:00:00  N329 - R201 - 00-03-02
#          C/A  UNIT       SCP         STATION LINENAME DIVISION        DATE  \
# 490385  N329  R201  00-03-02  WOODHAVEN BLVD       MR      IND  2021-05-08
# 490386  N329  R201  00-03-02  WOODHAVEN BLVD       MR      IND  2021-05-08
# 520211  N329  R201  00-03-02  WOODHAVEN BLVD       MR      IND  2021-05-08
# 520212  N329  R201  00-03-02  WOODHAVEN BLVD       MR      IND  2021-05-08
#
#               DESC   ENTRIES            DATETIME                      ID
# 490385     REGULAR   4825276 2021-05-08 01:00:00  N329 - R201 - 00-03-02
# 490386  RECOVR AUD  12538859 2021-05-08 01:00:00  N329 - R201 - 00-03-02
# 520211     REGULAR   4825276 2021-05-08 01:00:00  N329 - R201 - 00-03-02
# 520212  RECOVR AUD  12538859 2021-05-08 01:00:00  N329 - R201 - 00-03-02
#           C/A  UNIT       SCP      STATION LINENAME DIVISION        DATE  \
# 3061698  N335  R158  01-00-03  KEW GARDENS       EF      IND  2021-06-20
# 3061699  N335  R158  01-00-03  KEW GARDENS       EF      IND  2021-06-20
# 3091640  N335  R158  01-00-03  KEW GARDENS       EF      IND  2021-06-20
# 3091641  N335  R158  01-00-03  KEW GARDENS       EF      IND  2021-06-20
#
#                DESC  ENTRIES            DATETIME                      ID
# 3061698     REGULAR  5201958 2021-06-20 18:30:00  N335 - R158 - 01-00-03
# 3061699  RECOVR AUD  5201960 2021-06-20 18:30:00  N335 - R158 - 01-00-03
# 3091640     REGULAR  5201958 2021-06-20 18:30:00  N335 - R158 - 01-00-03
# 3091641  RECOVR AUD  5201960 2021-06-20 18:30:00  N335 - R158 - 01-00-03
#          C/A  UNIT       SCP    STATION LINENAME DIVISION        DATE  \
# 181380  B024  R211  00-05-00  KINGS HWY       BQ      BMT  2021-05-03
# 181381  B024  R211  00-05-00  KINGS HWY       BQ      BMT  2021-05-03
# 211194  B024  R211  00-05-00  KINGS HWY       BQ      BMT  2021-05-03
# 211195  B024  R211  00-05-00  KINGS HWY       BQ      BMT  2021-05-03
#
#               DESC  ENTRIES            DATETIME                      ID
# 181380     REGULAR   262152 2021-05-03 20:00:00  B024 - R211 - 00-05-00
# 181381  RECOVR AUD       16 2021-05-03 20:00:00  B024 - R211 - 00-05-00
# 211194     REGULAR   262152 2021-05-03 20:00:00  B024 - R211 - 00-05-00
# 211195  RECOVR AUD       16 2021-05-03 20:00:00  B024 - R211 - 00-05-00

# %% [markdown]
# #### Looks like a similar situation as with df_2019; some RECOVR AUDs look like trivial tests of some sort; will just drop the duplicates

# %%
print(df_2021.shape)

df_2021 = df_2021.sort_values(by=['ID', 'DATETIME'], 
                              ascending=False) \
                             .drop_duplicates(subset=['ID', 'DATETIME'])

df_2021.reset_index(drop=True, inplace=True)
print(df_2021.shape)
# Out:
# (3706606, 11)
# (1853257, 11)

# %%
# Re-check for duplicates

check = df_2021.groupby(['ID', 'DATETIME'])['ENTRIES'] \
                         .count().sort_values(ascending=False)
check.reset_index().head()
# Out:
#                        ID            DATETIME  ENTRIES
# 0  A002 - R051 - 02-00-00 2021-04-30 00:00:00        1
# 1  R138 - R293 - 00-03-04 2021-05-08 22:00:00        1
# 2  R138 - R293 - 00-03-04 2021-05-13 06:00:00        1
# 3  R138 - R293 - 00-03-04 2021-05-13 02:00:00        1
# 4  R138 - R293 - 00-03-04 2021-05-12 22:00:00        1

# %% [markdown]
# ### 2b) Find common set of Stations in 2019 and 2021 datasets (Station roughly equates to the 'UNIT' column)

# %%
print(df_2019['UNIT'].unique().shape)
print(df_2021['UNIT'].unique().shape)

print(np.setdiff1d(df_2019['UNIT'].unique(), df_2021['UNIT'].unique()))
print(np.setdiff1d(df_2021['UNIT'].unique(), df_2019['UNIT'].unique()))
# Out:
# (469,)
# (469,)
# ['R260']
# ['R094']

# %% [markdown]
# #### Each year's data has one station not present in the other - will find the common set between the two years

# %%
common_units = np.intersect1d(df_2019['UNIT'].unique(), df_2021['UNIT'].unique())
common_units.shape
# Out:
# (468,)

# %% [markdown]
# #### Now limit both year's datasets down to these common stations (UNITs)

# %%
print(df_2019.shape)
df_2019 = df_2019[df_2019['UNIT'].isin(common_units)]
df_2019.reset_index(drop=True, inplace=True)
print(df_2019.shape)
# Out:
# (1819646, 11)
# (1817754, 11)

# %%
print(df_2021.shape)
df_2021 = df_2021[df_2021['UNIT'].isin(common_units)]
df_2021.reset_index(drop=True, inplace=True)
print(df_2021.shape)
# Out:
# (1853257, 11)
# (1848056, 11)

# %% [markdown]
# ### 2c) Find NET_DAILY_ENTRIES per unique turnstile ('ID')

# %% [markdown]
# #### Assumption 1: Some turnstiles count backwards, accounting for the negatives; just take absolute value of everything
# #### Assumption 2: Even considering rush hr., >180 entries/hr ON AVERAGE over the full day (24 hours) is unlikely, so daily entries count > 24*180 = 4320 is probably due to counter rollover or other asynchronous counter reset -> just set these values to 0

# %%
daily_per_turnstile_2019 = df_2019.groupby(['ID', 'DATE']).first().reset_index().drop(columns='ENTRIES')

daily_per_turnstile_2019['NET_DAILY_ENTRIES'] = np.abs(df_2019.groupby(['ID', 'DATE'])['ENTRIES'].first() - 
                                                       df_2019.groupby(['ID', 'DATE'])['ENTRIES'].last()) \
                                                        .values

daily_per_turnstile_2019['NET_DAILY_ENTRIES'] = daily_per_turnstile_2019['NET_DAILY_ENTRIES'] \
                                                        .apply(lambda x: 0 if x > 180*24 else x)

daily_per_turnstile_2019.head()
# Out:
#                        ID        DATE   C/A  UNIT       SCP STATION LINENAME  \
# 0  A002 - R051 - 02-00-00  2019-04-30  A002  R051  02-00-00   59 ST  NQR456W
# 1  A002 - R051 - 02-00-00  2019-05-01  A002  R051  02-00-00   59 ST  NQR456W
# 2  A002 - R051 - 02-00-00  2019-05-02  A002  R051  02-00-00   59 ST  NQR456W
# 3  A002 - R051 - 02-00-00  2019-05-03  A002  R051  02-00-00   59 ST  NQR456W
# 4  A002 - R051 - 02-00-00  2019-05-04  A002  R051  02-00-00   59 ST  NQR456W
#
#   DIVISION     DESC            DATETIME  NET_DAILY_ENTRIES
# 0      BMT  REGULAR 2019-04-30 20:00:00               1278
# 1      BMT  REGULAR 2019-05-01 20:00:00               1346
# 2      BMT  REGULAR 2019-05-02 20:00:00               1327
# 3      BMT  REGULAR 2019-05-03 20:00:00               1326
# 4      BMT  REGULAR 2019-05-04 20:00:00                560

# %%
# This looks reasonable:

daily_per_turnstile_2019['NET_DAILY_ENTRIES'].describe()
# Out:
# count    300165.000000
# mean        915.348638
# std         851.082939
# min           0.000000
# 25%         222.000000
# 50%         704.000000
# 75%        1394.000000
# max        4320.000000
# Name: NET_DAILY_ENTRIES, dtype: float64

# %% [markdown]
# #### Repeat this whole process for df_2021

# %%
daily_per_turnstile_2021 = df_2021.groupby(['ID', 'DATE']).first().reset_index().drop(columns='ENTRIES')

daily_per_turnstile_2021['NET_DAILY_ENTRIES'] = np.abs(df_2021.groupby(['ID', 'DATE'])['ENTRIES'].first() - 
                                                       df_2021.groupby(['ID', 'DATE'])['ENTRIES'].last()) \
                                                        .values

daily_per_turnstile_2021['NET_DAILY_ENTRIES'] = daily_per_turnstile_2021['NET_DAILY_ENTRIES'] \
                                                        .apply(lambda x: 0 if x > 180*24 else x)

daily_per_turnstile_2021.head()
# Out:
#                        ID        DATE   C/A  UNIT       SCP STATION LINENAME  \
# 0  A002 - R051 - 02-00-00  2021-04-30  A002  R051  02-00-00   59 ST  NQR456W
# 1  A002 - R051 - 02-00-00  2021-05-01  A002  R051  02-00-00   59 ST  NQR456W
# 2  A002 - R051 - 02-00-00  2021-05-02  A002  R051  02-00-00   59 ST  NQR456W
# 3  A002 - R051 - 02-00-00  2021-05-03  A002  R051  02-00-00   59 ST  NQR456W
# 4  A002 - R051 - 02-00-00  2021-05-04  A002  R051  02-00-00   59 ST  NQR456W
#
#   DIVISION     DESC            DATETIME  NET_DAILY_ENTRIES
# 0      BMT  REGULAR 2021-04-30 20:00:00                469
# 1      BMT  REGULAR 2021-05-01 20:00:00                361
# 2      BMT  REGULAR 2021-05-02 20:00:00                250
# 3      BMT  REGULAR 2021-05-03 20:00:00                472
# 4      BMT  REGULAR 2021-05-04 20:00:00                501

# %%
# This looks reasonable:

daily_per_turnstile_2021['NET_DAILY_ENTRIES'].describe()
# Out:
# count    308646.000000
# mean        320.566260
# std         327.177385
# min           0.000000
# 25%          73.000000
# 50%         233.000000
# 75%         466.000000
# max        3808.000000
# Name: NET_DAILY_ENTRIES, dtype: float64

# %% [markdown]
# #### While we're here, let's add a WEEKDAY column (1 for M-F, 0 for Sat or Sun)

# %%
# pd.Series.dt.weekday: 0 = Mon, 6 = Sun

daily_per_turnstile_2019['WEEKDAY'] = pd.to_datetime(daily_per_turnstile_2019['DATE']) \
                                                        .dt.weekday.apply(lambda x: 1 if x < 5 else 0)
display(daily_per_turnstile_2019.sample(10))
# Out:
#                              ID        DATE    C/A  UNIT       SCP  \
# 288295   R618 - R058 - 01-00-02  2019-05-28   R618  R058  01-00-02
# 286474   R610 - R057 - 00-05-00  2019-05-04   R610  R057  00-05-00
# 257451   R334 - R367 - 00-00-01  2019-06-09   R334  R367  00-00-01
# 285461   R609 - R056 - 01-00-02  2019-06-12   R609  R056  01-00-02
# 111627   N303 - R015 - 00-00-00  2019-06-16   N303  R015  00-00-00
# 186499  PTH22 - R540 - 00-05-02  2019-05-19  PTH22  R540  00-05-02
# 24166    B022 - R229 - 00-00-03  2019-05-14   B022  R229  00-00-03
# 213691   R176 - R169 - 00-00-03  2019-06-12   R176  R169  00-00-03
# 31377    C012 - R258 - 01-03-02  2019-06-07   C012  R258  01-03-02
# 219383   R202 - R042 - 00-00-03  2019-06-12   R202  R042  00-00-03
#
#                 STATION   LINENAME DIVISION     DESC            DATETIME  \
# 288295        BERGEN ST         23      IRT  REGULAR 2019-05-28 20:00:00
# 286474   ATL AV-BARCLAY  2345BDNQR      IRT  REGULAR 2019-05-04 20:00:00
# 257451           233 ST         25      IRT  REGULAR 2019-06-09 21:00:00
# 285461        NEVINS ST       2345      IRT  REGULAR 2019-06-12 20:00:00
# 111627       5 AV/53 ST         EM      IND  REGULAR 2019-06-16 22:00:00
# 186499     PATH NEW WTC          1      PTH  REGULAR 2019-05-19 23:03:38
# 24166          AVENUE M         BQ      BMT  REGULAR 2019-05-14 20:00:00
# 213691  137 ST CITY COL          1      IRT  REGULAR 2019-06-12 21:00:00
# 31377          4AV-9 ST     DFGMNR      BMT  REGULAR 2019-06-07 20:00:00
# 219383    BOWLING GREEN         45      IRT  REGULAR 2019-06-12 20:00:00
#
#         NET_DAILY_ENTRIES  WEEKDAY
# 288295                308        1
# 286474                  1        0
# 257451                766        0
# 285461               1755        1
# 111627                524        0
# 186499                  0        0
# 24166                1092        1
# 213691               2578        1
# 31377                 877        1
# 219383               2146        1

# %%
daily_per_turnstile_2021['WEEKDAY'] = pd.to_datetime(daily_per_turnstile_2021['DATE']) \
                                                        .dt.weekday.apply(lambda x: 1 if x < 5 else 0)
display(daily_per_turnstile_2021.sample(10))
# Out:
#                              ID        DATE    C/A  UNIT       SCP  \
# 30172    C008 - R099 - 00-00-01  2021-05-06   C008  R099  00-00-01
# 25793    B023 - R211 - 01-06-01  2021-05-22   B023  R211  01-06-01
# 171966  N702A - R572 - 01-00-00  2021-05-02  N702A  R572  01-00-00
# 202060   R124 - R290 - 03-00-01  2021-05-20   R124  R290  03-00-01
# 296838   R621 - R060 - 00-00-01  2021-05-30   R621  R060  00-00-01
# 152047   N513 - R163 - 04-00-02  2021-05-14   N513  R163  04-00-02
# 258554   R306 - R207 - 00-00-04  2021-06-20   R306  R207  00-00-04
# 201915   R123 - R290 - 00-00-01  2021-06-30   R123  R290  00-00-01
# 65123    K022 - R402 - 00-03-01  2021-06-11   K022  R402  00-03-01
# 35477    C023 - R213 - 00-00-01  2021-06-10   C023  R213  00-00-01
#
#                 STATION LINENAME DIVISION     DESC            DATETIME  \
# 30172         DEKALB AV    BDNQR      BMT  REGULAR 2021-05-06 20:00:00
# 25793         KINGS HWY       BQ      BMT  REGULAR 2021-05-22 20:00:00
# 171966      96 ST-2 AVE        Q      IND  REGULAR 2021-05-02 21:00:00
# 202060       HOUSTON ST        1      IRT  REGULAR 2021-05-20 21:00:00
# 296838  EASTN PKWY-MUSM       23      IRT  REGULAR 2021-05-30 20:00:00
# 152047            14 ST   FLM123      IND  REGULAR 2021-05-14 20:00:00
# 258554           135 ST       23      IRT  REGULAR 2021-06-20 20:00:00
# 201915       HOUSTON ST        1      IRT  REGULAR 2021-06-30 21:00:00
# 65123        SENECA AVE        M      BMT  REGULAR 2021-06-11 21:00:00
# 35477      BAY RIDGE AV        R      BMT  REGULAR 2021-06-10 20:00:00
#
#         NET_DAILY_ENTRIES  WEEKDAY
# 30172                 374        1
# 25793                 358        0
# 171966                252        0
# 202060                112        1
# 296838                159        0
# 152047                181        1
# 258554                535        0
# 201915                389        1
# 65123                 431        1
# 35477                 303        1

# %% [markdown]
# #### Drop the April 30th Data

# %%
print(daily_per_turnstile_2019.shape)
daily_per_turnstile_2019 = daily_per_turnstile_2019[ \
                                pd.to_datetime(daily_per_turnstile_2019['DATE']) != pd.to_datetime('2019-04-30')]
daily_per_turnstile_2019.reset_index(drop=True, inplace=True)
print(daily_per_turnstile_2019.shape)
display(daily_per_turnstile_2019.head())
display(daily_per_turnstile_2019.tail())
# Out:
# (300165, 12)
# (295338, 12)
#                        ID        DATE   C/A  UNIT       SCP STATION LINENAME  \
# 0  A002 - R051 - 02-00-00  2019-05-01  A002  R051  02-00-00   59 ST  NQR456W
# 1  A002 - R051 - 02-00-00  2019-05-02  A002  R051  02-00-00   59 ST  NQR456W
# 2  A002 - R051 - 02-00-00  2019-05-03  A002  R051  02-00-00   59 ST  NQR456W
# 3  A002 - R051 - 02-00-00  2019-05-04  A002  R051  02-00-00   59 ST  NQR456W
# 4  A002 - R051 - 02-00-00  2019-05-05  A002  R051  02-00-00   59 ST  NQR456W
#
#   DIVISION     DESC            DATETIME  NET_DAILY_ENTRIES  WEEKDAY
# 0      BMT  REGULAR 2019-05-01 20:00:00               1346        1
# 1      BMT  REGULAR 2019-05-02 20:00:00               1327        1
# 2      BMT  REGULAR 2019-05-03 20:00:00               1326        1
# 3      BMT  REGULAR 2019-05-04 20:00:00                560        0
# 4      BMT  REGULAR 2019-05-05 20:00:00                449        0
#                              ID        DATE    C/A  UNIT       SCP  \
# 295333  TRAM2 - R469 - 00-05-01  2019-06-26  TRAM2  R469  00-05-01
# 295334  TRAM2 - R469 - 00-05-01  2019-06-27  TRAM2  R469  00-05-01
# 295335  TRAM2 - R469 - 00-05-01  2019-06-28  TRAM2  R469  00-05-01
# 295336  TRAM2 - R469 - 00-05-01  2019-06-29  TRAM2  R469  00-05-01
# 295337  TRAM2 - R469 - 00-05-01  2019-06-30  TRAM2  R469  00-05-01
#
#               STATION LINENAME DIVISION     DESC            DATETIME  \
# 295333  RIT-ROOSEVELT        R      RIT  REGULAR 2019-06-26 21:00:00
# 295334  RIT-ROOSEVELT        R      RIT  REGULAR 2019-06-27 21:00:00
# 295335  RIT-ROOSEVELT        R      RIT  REGULAR 2019-06-28 21:00:00
# 295336  RIT-ROOSEVELT        R      RIT  REGULAR 2019-06-29 21:00:00
# 295337  RIT-ROOSEVELT        R      RIT  REGULAR 2019-06-30 21:00:00
#
#         NET_DAILY_ENTRIES  WEEKDAY
# 295333                  0        1
# 295334                  0        1
# 295335                  0        1
# 295336                  0        0
# 295337                  0        0

# %%
# Drop the 4/30/2021 rows

print(daily_per_turnstile_2021.shape)
daily_per_turnstile_2021 = daily_per_turnstile_2021[ \
                                pd.to_datetime(daily_per_turnstile_2021['DATE']) != pd.to_datetime('2021-04-30')]
daily_per_turnstile_2019.reset_index(drop=True, inplace=True)
print(daily_per_turnstile_2021.shape)
display(daily_per_turnstile_2021.head())
display(daily_per_turnstile_2021.tail())
# Out:
# (308646, 12)
# (303670, 12)
#                        ID        DATE   C/A  UNIT       SCP STATION LINENAME  \
# 1  A002 - R051 - 02-00-00  2021-05-01  A002  R051  02-00-00   59 ST  NQR456W
# 2  A002 - R051 - 02-00-00  2021-05-02  A002  R051  02-00-00   59 ST  NQR456W
# 3  A002 - R051 - 02-00-00  2021-05-03  A002  R051  02-00-00   59 ST  NQR456W
# 4  A002 - R051 - 02-00-00  2021-05-04  A002  R051  02-00-00   59 ST  NQR456W
# 5  A002 - R051 - 02-00-00  2021-05-05  A002  R051  02-00-00   59 ST  NQR456W
#
#   DIVISION     DESC            DATETIME  NET_DAILY_ENTRIES  WEEKDAY
# 1      BMT  REGULAR 2021-05-01 20:00:00                361        0
# 2      BMT  REGULAR 2021-05-02 20:00:00                250        0
# 3      BMT  REGULAR 2021-05-03 20:00:00                472        1
# 4      BMT  REGULAR 2021-05-04 20:00:00                501        1
# 5      BMT  REGULAR 2021-05-05 20:00:00                522        1
#                              ID        DATE    C/A  UNIT       SCP  \
# 308641  TRAM2 - R469 - 00-05-01  2021-06-26  TRAM2  R469  00-05-01
# 308642  TRAM2 - R469 - 00-05-01  2021-06-27  TRAM2  R469  00-05-01
# 308643  TRAM2 - R469 - 00-05-01  2021-06-28  TRAM2  R469  00-05-01
# 308644  TRAM2 - R469 - 00-05-01  2021-06-29  TRAM2  R469  00-05-01
# 308645  TRAM2 - R469 - 00-05-01  2021-06-30  TRAM2  R469  00-05-01
#
#               STATION LINENAME DIVISION     DESC            DATETIME  \
# 308641  RIT-ROOSEVELT        R      RIT  REGULAR 2021-06-26 21:00:00
# 308642  RIT-ROOSEVELT        R      RIT  REGULAR 2021-06-27 21:00:00
# 308643  RIT-ROOSEVELT        R      RIT  REGULAR 2021-06-28 21:00:00
# 308644  RIT-ROOSEVELT        R      RIT  REGULAR 2021-06-29 21:00:00
# 308645  RIT-ROOSEVELT        R      RIT  REGULAR 2021-06-30 21:00:00
#
#         NET_DAILY_ENTRIES  WEEKDAY
# 308641                  0        0
# 308642                  0        0
# 308643                  0        1
# 308644                  0        1
# 308645                  0        1

# %% [markdown]
# ### 2e) Figure out which turnstiles all belong to the same station and sum up station-level NET_DAILY_ENTRIES

# %% [markdown]
# #### While UNIT ("Remote Unit") generally denotes a station, certain stations actually have several UNITs associated with them; the term "Complex" describes the physical location where a Remote Unit resides.

# %% [markdown]
# Import MTA Complex List Dataset (based on MTA-provided data & augmented slightly by Chris Whong); found at the following link:

# %% [markdown]
# https://qri.cloud/nyc-transit-data/remote_complex_lookup

# %%
# NOTE: The 'remote' column in this dataset refers to the same entity as 'UNIT' in the turnstile data
#         (the full name is technically 'Remote Unit'); Also, 'booth' below refers to the same entity
#         as 'C/A' in the turnstile data

complex_list = pd.read_csv('nyc_transit_data_remote_complex_lookup.csv')

# Drop the division='SRT' rows (these are Staten Island Railway stations; not under consideration here);
#   Also drop 'LIB' and 'BEE' divisions (they are not included in the MTA Turnstile data)
complex_list = complex_list[~complex_list['division'].isin(['SRT', 'LIB', 'BEE'])].reset_index(drop=True)

print(complex_list.shape)
complex_list
# Out:
# (770, 6)
#     remote  booth  complex_id             station    line_name division
# 0     R001   A060       635.0        WHITEHALL ST           R1      BMT
# 1     R001   A058       635.0        WHITEHALL ST           R1      BMT
# 2     R001  R101S       635.0         SOUTH FERRY           R1      IRT
# 3     R002   A077       628.0           FULTON ST     ACJZ2345      BMT
# 4     R002   A081       628.0           FULTON ST     ACJZ2345      BMT
# 5     R002   A082       628.0           FULTON ST     ACJZ2345      BMT
# 6     R003   J025        86.0       CYPRESS HILLS            J      BMT
# 7     R004   J028        85.0        ELDERTS LANE           JZ      BMT
# 8     R005   J030        84.0      FOREST PARKWAY            J      BMT
# 9     R006   J031        83.0      WOODHAVEN BLVD           JZ      BMT
# 10    R006   J032        83.0      WOODHAVEN BLVD           JZ      BMT
# 11    R007   J034        82.0              104 ST           JZ      BMT
# 12    R008   J035        81.0              111 ST            J      BMT
# 13    R009   J037        80.0              121 ST           JZ      BMT
# 14    R010  N062A       611.0     42 ST-PA BUS TE  ACENQRS1237      IND
# 15    R010   N060       611.0     42 ST-PA BUS TE  ACENQRS1237      IND
# 16    R011  N063A       611.0     42 ST-PA BUS TE  ACENQRS1237      IND
# 17    R011   N062       611.0     42 ST-PA BUS TE  ACENQRS1237      IND
# 18    R011   N063       611.0     42 ST-PA BUS TE  ACENQRS1237      IND
# 19    R012   N067       164.0      34 ST-PENN STA          ACE      IND
# 20    R012   N065       164.0      34 ST-PENN STA          ACE      IND
# 21    R012   N068       164.0      34 ST-PENN STA          ACE      IND
# 22    R012   N070       164.0      34 ST-PENN STA          ACE      IND
# 23    R012   N072       164.0      34 ST-PENN STA          ACE      IND
# 24    R013   N071       164.0      34 ST-PENN STA          ACE      IND
# 25    R013   N069       164.0      34 ST-PENN STA          ACE      IND
# 26    R013   N073       164.0      34 ST-PENN STA          ACE      IND
# 27    R014   N095       628.0           FULTON ST     ACJZ2345      IND
# 28    R014   R205       628.0           FULTON ST     ACJZ2345      IRT
# 29    R014   R206       628.0           FULTON ST     2345ACJZ      IRT
# 30    R014   R208       628.0           FULTON ST     2345ACJZ      IRT
# 31    R014  R205A       628.0           FULTON ST     2345ACJZ      IRT
# 32    R015   N303       276.0         5 AVE-53 ST           EM      IND
# 33    R015   N304       276.0         5 AVE-53 ST           EM      IND
# 34    R016  N305A       613.0     LEXINGTON-53 ST          EM6      IND
# 35    R017   N306       613.0     LEXINGTON-53 ST          EM6      IND
# 36    R017   N305       613.0     LEXINGTON-53 ST          EM6      IND
# 37    R018   N324       616.0       ROOSEVELT AVE        EFMR7      IND
# 38    R018   N323       616.0       ROOSEVELT AVE        EFMR7      IND
# 39    R018   R525       616.0      74 ST-BROADWAY        EFMR7      IRT
# 40    R019   N343       254.0      JAMAICA-179 ST            F      IND
# 41    R019   N342       254.0      JAMAICA-179 ST            F      IND
# 42    R020   N500       225.0       47-50 ST-ROCK         BDFM      IND
# 43    R020   N501       225.0       47-50 ST-ROCK         BDFM      IND
# 44    R020  N501A       225.0       47-50 ST-ROCK         BDFM      IND
# 45    R021   N503       609.0     42 ST-BRYANT PK        BDFM7      IND
# 46    R021   N502       609.0     42 ST-BRYANT PK        BDFM7      IND
# 47    R021   N504       609.0     42 ST-BRYANT PK        BDFM7      IND
# 48    R022   N506       607.0     34 ST-HERALD SQ      BDFMNQR      IND
# 49    R022   A022       607.0     34 ST-HERALD SQ      BDFMNQR      BMT
# 50    R022   N505       607.0     34 ST-HERALD SQ      BDFMNQR      IND
# 51    R023   N507       607.0     34 ST-HERALD SQ      BDFMNQR      IND
# 52    R023   A025       607.0     34 ST-HERALD SQ      BDFMNQR      BMT
# 53    R024   N605       279.0        SUTPHIN BLVD          EJZ      IND
# 54    R025   N606       278.0      JAMAICA CENTER          EJZ      IND
# 55    R025   N607       278.0      JAMAICA CENTER          EJZ      IND
# 56    R027   R111       333.0             WALL ST           23      IRT
# 57    R027   R110       333.0             WALL ST           23      IRT
# 58    R027   R112       333.0             WALL ST           23      IRT
# 59    R027  R112A       333.0             WALL ST           23      IRT
# 60    R028  R113A       628.0           FULTON ST     2345ACJZ      IRT
# 61    R028   R113       628.0           FULTON ST     2345ACJZ      IRT
# 62    R028   R114       628.0           FULTON ST     2345ACJZ      IRT
# 63    R029   R115       624.0          PARK PLACE        23ACE      IRT
# 64    R029   N094       624.0     WORLD TRADE CTR        23ACE      IND
# 65    R029   N091       624.0         CHAMBERS ST        ACE23      IND
# 66    R029   N092       624.0         CHAMBERS ST        ACE23      IND
# 67    R030   R116       327.0         CHAMBERS ST          123      IRT
# 68    R031   R141       318.0      34 ST-PENN STA          123      IRT
# 69    R031   R135       318.0      34 ST-PENN STA          123      IRT
# 70    R031   R137       318.0      34 ST-PENN STA          123      IRT
# 71    R031   R139       318.0      34 ST-PENN STA          123      IRT
# 72    R032   R145       611.0      42 ST-TIMES SQ  1237ACENQRS      IRT
# 73    R032   A021       611.0      42 ST-TIMES SQ  1237ACENQRS      BMT
# 74    R032   R143       611.0      42 ST-TIMES SQ  ACENQRS1237      IRT
# 75    R032   R146       611.0      42 ST-TIMES SQ  1237ACENQRS      IRT
# 76    R033   R151       611.0      42 ST-TIMES SQ  1237ACENQRS      IRT
# 77    R033   R148       611.0      42 ST-TIMES SQ  1237ACENQRS      IRT
# 78    R033   R150       611.0      42 ST-TIMES SQ  1237ACENQRS      IRT
# 79    R033   R153       611.0      42 ST-TIMES SQ  1237ACENQRS      IRT
# 80    R033   R147       611.0      42 ST-TIMES SQ  1237ACENQRS      IRT
# 81    R034   R174       306.0              125 ST            1      IRT
# 82    R035   R182       605.0     168 ST-BROADWAY          1AC      IRT
# 83    R035   N012       605.0     168 ST-BROADWAY          1AC      IND
# 84    R035   N013       605.0     168 ST-BROADWAY          AC1      IND
# 85    R036   R186       299.0          DYCKMAN ST            1      IRT
# 86    R037   R188       298.0              207 ST            1      IRT
# 87    R038   R190       297.0              215 ST            1      IRT
# 88    R039   R192       296.0     MARBLE HILL-225            1      IRT
# 89    R040   R194       295.0              231 ST            1      IRT
# 90    R041   R201       414.0       BOWLING GREEN           45      IRT
# 91    R041  R200A       414.0       BOWLING GREEN           45      IRT
# 92    R042   R202       414.0       BOWLING GREEN           45      IRT
# 93    R043   R203       413.0             WALL ST           45      IRT
# 94    R043  R203A       413.0             WALL ST           45      IRT
# 95    R043   R204       413.0             WALL ST           45      IRT
# 96    R043  R204A       413.0             WALL ST           45      IRT
# 97    R044   R210       622.0     BROOKLYN BRIDGE        456JZ      IRT
# 98    R044   A069       622.0         CHAMBERS ST        456JZ      BMT
# 99    R044   A071       622.0         CHAMBERS ST        JZ456      BMT
# 100   R044  R210A       622.0     BROOKLYN BRIDGE        JZ456      IRT
# 101   R045   R236       610.0     42 ST-GRD CNTRL        4567S      IRT
# 102   R045   R233       610.0     42 ST-GRD CNTRL        4567S      IRT
# 103   R046   R238       610.0     42 ST-GRD CNTRL        4567S      IRT
# 104   R046   R237       610.0     42 ST-GRD CNTRL        4567S      IRT
# 105   R046  R238A       610.0     42 ST-GRD CNTRL        4567S      IRT
# 106   R047   R240       610.0     42 ST-GRD CNTRL        4567S      IRT
# 107   R047  R237B       610.0     42 ST-GRD CNTRL        4567S      IRT
# 108   R048  R241A       610.0     42 ST-GRD CNTRL        4567S      IRT
# 109   R049   R243       612.0               51 ST            6      IRT
# 110   R049   R242       612.0               51 ST            6      IRT
# 111   R049  R242A       612.0               51 ST            6      IRT
# 112   R050   R244       613.0               59 ST       456NQR      IRT
# 113   R050  R244A       613.0               59 ST       456NQR      IRT
# 114   R050   A004       613.0       LEXINGTON AVE       456NQR      BMT
# 115   R051   R245       613.0               59 ST       456NQR      IRT
# 116   R051  R245A       613.0               59 ST       456NQR      IRT
# 117   R051   A002       613.0       LEXINGTON AVE       456NQR      BMT
# 118   R052   R294       378.0       WOODLAWN ROAD            4      IRT
# 119   R053   R311       434.0        149 ST-3 AVE           25      IRT
# 120   R053   R310       434.0        149 ST-3 AVE           25      IRT
# 121   R054   R501       609.0     5 AVE-BRYANT PK        7BDFM      IRT
# 122   R054   R500       609.0     5 AVE-BRYANT PK        7BDFM      IRT
# 123   R055   R533       447.0             MAIN ST            7      IRT
# 124   R055   R534       447.0             MAIN ST            7      IRT
# 125   R056   R608       337.0           NEVINS ST         2345      IRT
# 126   R056   R609       337.0           NEVINS ST         2345      IRT
# 127   R057   R610       617.0        ATLANTIC AVE    2345BDNQR      IRT
# 128   R057   B001       617.0        ATLANTIC AVE    2345BDNQR      BMT
# 129   R057   B002       617.0        ATLANTIC AVE    BDNQR2345      BMT
# 130   R057   C009       617.0          PACIFIC ST    BDNQR2345      BMT
# 131   R058   R617       339.0           BERGEN ST           23      IRT
# 132   R058   R618       339.0           BERGEN ST           23      IRT
# 133   R059   R619       340.0     GRAND ARMY PLAZ           23      IRT
# 134   R060   R621       341.0        EASTERN PKWY           23      IRT
# 135   R061   R623       343.0        NOSTRAND AVE            3      IRT
# 136   R062   R626       345.0     CROWN HTS-UTICA           34      IRT
# 137   R062   R625       345.0     CROWN HTS-UTICA           34      IRT
# 138   R063   R627       346.0          SUTTER AVE            3      IRT
# 139   R064   R628       347.0        SARATOGA AVE            3      IRT
# 140   R065   R629       348.0        ROCKAWAY AVE            3      IRT
# 141   R066   R630       349.0           JUNIUS ST            3      IRT
# 142   R067   R632       350.0     PENNSYLVANIA AV            3      IRT
# 143   R068   R633       351.0      VAN SICLEN AVE            3      IRT
# 144   R069   R634       352.0        NEW LOTS AVE            3      IRT
# 145   R072   R550       471.0      34 ST - 11 AVE            7      IRT
# 146   R072   R551       471.0      34 ST - 11 AVE            7      IRT
# 147   R076  MCC07         NaN     2 BDWY CUST SRV           45      IRT
# 148   R079   A006         8.0         5 AVE-59 ST          NQR      BMT
# 149   R079   A007         8.0         5 AVE-59 ST          NQR      BMT
# 150   R080   A010         9.0         57 ST-7 AVE          NQR      BMT
# 151   R080   A011         9.0         57 ST-7 AVE          NQR      BMT
# 152   R081   A015         8.0         49 ST-7 AVE          NQR      BMT
# 153   R081   A013        10.0         49 ST-7 AVE          NQR      BMT
# 154   R081   A014         8.0         49 ST-7 AVE          NQR      BMT
# 155   R081   A016         8.0         49 ST-7 AVE          NQR      BMT
# 156   R082   A029        13.0      28 ST-BROADWAY           NR      BMT
# 157   R082   A027        13.0      28 ST-BROADWAY           NR      BMT
# 158   R083   A031        14.0         23 ST-5 AVE           NR      BMT
# 159   R083   A030        14.0         23 ST-5 AVE           NR      BMT
# 160   R084   R158       614.0      59 ST-COLUMBUS        1ABCD      IRT
# 161   R084   N049       614.0      59 ST-COLUMBUS        1ABCD      IND
# 162   R084   N051       614.0      59 ST-COLUMBUS        ABCD1      IND
# 163   R085   A038        16.0      8 ST-B'WAY NYU           NR      BMT
# 164   R085   A039        16.0      8 ST-B'WAY NYU           NR      BMT
# 165   R086   A041        17.0     PRINCE ST-B'WAY           NR      BMT
# 166   R086   A042        17.0     PRINCE ST-B'WAY           NR      BMT
# 167   R087   A047       623.0     MURRAY ST-B'WAY            R      BMT
# 168   R088   A050       624.0        CORTLANDT ST            R      BMT
# 169   R088   A052       624.0        CORTLANDT ST            R      BMT
# 170   R088   A051       624.0        CORTLANDT ST            R      BMT
# 171   R088   A053       624.0        CORTLANDT ST            R      BMT
# 172   R089   C003       636.0     JAY ST-METROTEC            R      BMT
# 173   R089   C004       636.0     JAY ST-METROTEC            R      BMT
# 174   R090   R510         6.0        BEEBE-39 AVE           NQ      BMT
# 175   R091   R511         5.0     WASHINGTON-36 A           NQ      BMT
# 176   R092   R512         4.0      BROADWAY-31 ST           NQ      BMT
# 177   R093   R513         3.0        GRAND-30 AVE           NQ      BMT
# 178   R094   R514         2.0     HOYT ST-ASTORIA           NQ      BMT
# 179   R095   R515         1.0     DITMARS BL-31 S           NQ      BMT
# 180   R096   R526       453.0     82 ST-JACKSON H            7      IRT
# 181   R097   R528       451.0       JUNCTION BLVD            7      IRT
# 182   R098   B016        44.0          CHURCH AVE           BQ      BMT
# 183   R098   B015        44.0          CHURCH AVE           BQ      BMT
# 184   R099   C008        26.0          DEKALB AVE        BDNQR      BMT
# 185   R100   K026       108.0     METROPOLITAN AV            M      BMT
# 186   R101   N020       151.0              145 ST         ABCD      IND
# 187   R101   N019       151.0              145 ST         ABCD      IND
# 188   R102   N026       153.0              125 ST         ACBD      IND
# 189   R102   N025       153.0              125 ST         ACBD      IND
# 190   R103   N124       621.0        BROADWAY-ENY        ACJLZ      IND
# 191   R104   N207       218.0              167 ST           BD      IND
# 192   R104   N206       218.0              167 ST           BD      IND
# 193   R105   R127       601.0               14 ST       123FLM      IRT
# 194   R105   R128       601.0               14 ST       123FLM      IRT
# 195   R106   R418       365.0     CASTLE HILL AVE            6      IRT
# 196   R107   R420       363.0      WESTCHESTER SQ            6      IRT
# 197   R108   R602       620.0     BOROUGH HALL/CT        2345R      IRT
# 198   R108   C001       620.0     BOROUGH HALL/CT        2345R      BMT
# 199   R108  R601A       620.0     BOROUGH HALL/CT        R2345      IRT
# 200   R108   R604       620.0     BOROUGH HALL/CT        2345R      IRT
# 201   R109   R639       356.0          CHURCH AVE           25      IRT
# 202   R110   R645       359.0        FLATBUSH AVE           25      IRT
# 203   R110   R646       359.0        FLATBUSH AVE           25      IRT
# 204   R110   R647       359.0        FLATBUSH AVE           25      IRT
# 205   R111   N076       165.0               23 ST           CE      IND
# 206   R111   N075       165.0               23 ST           CE      IND
# 207   R111   N077       165.0               23 ST           CE      IND
# 208   R112   N217       213.0        FORDHAM ROAD           BD      IND
# 209   R112   N218       213.0        FORDHAM ROAD           BD      IND
# 210   R113   N301       277.0         7 AVE-53 ST          BDE      IND
# 211   R113   N300       277.0         7 AVE-53 ST          BDE      IND
# 212   R114  N339A       256.0        PARSONS BLVD            F      IND
# 213   R114   N339       256.0        PARSONS BLVD            F      IND
# 214   R115   N340       255.0              169 ST            F      IND
# 215   R115  N340A       255.0              169 ST            F      IND
# 216   R116   R154       316.0               50 ST            1      IRT
# 217   R116   R155       316.0               50 ST            1      IRT
# 218   R117   R197       293.0              242 ST            1      IRT
# 219   R118   A066       623.0            CANAL ST       JNQRZ6      BMT
# 220   R119   R289       382.0        FORDHAM ROAD            4      IRT
# 221   R120   R415       368.0        MORRISON AVE            6      IRT
# 222   R121   R509       461.0      QUEENSBORO PLZ          7NQ      IRT
# 223   R122   R527       452.0      90 ST-ELMHURST            7      IRT
# 224   R123   R622       627.0        FRANKLIN AVE        2345S      IRT
# 225   R124   R624       344.0        KINGSTON AVE            3      IRT
# 226   R125   A083       107.0            BROAD ST           JZ      BMT
# 227   R125   A084       107.0            BROAD ST           JZ      BMT
# 228   R125   A085       107.0            BROAD ST           JZ      BMT
# 229   R126   N010       147.0              175 ST            A      IND
# 230   R126   N011       147.0              175 ST            A      IND
# 231   R127   N103       636.0     JAY ST-METROTEC          ACF      IND
# 232   R127   N102       636.0     JAY ST-METROTEC          ACF      IND
# 233   R128  N338B       257.0        SUTPHIN BLVD            F      IND
# 234   R128   N338       257.0        SUTPHIN BLVD            F      IND
# 235   R129   N532       236.0           BERGEN ST           FG      IND
# 236   R129   N531       236.0           BERGEN ST           FG      IND
# 237   R129   N533       236.0           BERGEN ST           FG      IND
# 238   R130   N557       250.0       KINGS HIGHWAY            F      IND
# 239   R130   N558       250.0       KINGS HIGHWAY            F      IND
# 240   R131   R227       405.0               23 ST            6      IRT
# 241   R131  R227A       405.0               23 ST            6      IRT
# 242   R131   R226       405.0               23 ST            6      IRT
# 243   R131  R226A       405.0               23 ST            6      IRT
# 244   R132   R258       392.0              125 ST          456      IRT
# 245   R133   R293       379.0     MOSHOLU PARKWAY            4      IRT
# 246   R134   R507       463.0      HUNTERS PT AVE            7      IRT
# 247   R135   R643       358.0         NEWKIRK AVE           25      IRT
# 248   R135   R644       358.0         NEWKIRK AVE           25      IRT
# 249   R136   B027        54.0      SHEEPSHEAD BAY           BQ      BMT
# 250   R136   B028        54.0      SHEEPSHEAD BAY           BQ      BMT
# 251   R137   H026       630.0          MYRTLE AVE           LM      BMT
# 252   R137   H027       630.0          MYRTLE AVE           LM      BMT
# 253   R138   N080       167.0      W 4 ST-WASH SQ      ABCDEFM      IND
# 254   R138   N083       167.0      W 4 ST-WASH SQ      ABCDEFM      IND
# 255   R139   N089       169.0            CANAL ST          ACE      IND
# 256   R139   N090       169.0            CANAL ST          ACE      IND
# 257   R140  N309A       273.0        QUEENS PLAZA          EMR      IND
# 258   R140   N310       273.0        QUEENS PLAZA          EMR      IND
# 259   R141  N333A       261.0     FOREST HILLS-71         EFMR      IND
# 260   R141   N333       261.0     FOREST HILLS-71         EFMR      IND
# 261   R141  N333B       261.0     FOREST HILLS-71         EFMR      IND
# 262   R142   A061       625.0            ESSEX ST         FJMZ      BMT
# 263   R142   N525       625.0         DELANCEY ST         FJMZ      IND
# 264   R142   N526       625.0         DELANCEY ST         FJMZ      IND
# 265   R143   R228       404.0               28 ST            6      IRT
# 266   R143   R229       404.0               28 ST            6      IRT
# 267   R143   R230       404.0               28 ST            6      IRT
# 268   R144   R251       396.0               96 ST            6      IRT
# 269   R145   R336       416.0       WAKEFIELD-241            2      IRT
# 270   R146   R412       371.0     HUNTS POINT AVE            6      IRT
# 271   R147   R523       456.0      61 ST/WOODSIDE            7      IRT
# 272   R148   B014        43.0        PARKSIDE AVE           BQ      BMT
# 273   R149   B019        47.0         NEWKIRK AVE           BQ      BMT
# 274   R150   B025        52.0               AVE U           BQ      BMT
# 275   R151   G001        58.0       STILLWELL AVE         DFNQ      BMT
# 276   R151   G009        58.0       STILLWELL AVE         DFNQ      BMT
# 277   R152   H041       138.0        ROCKAWAY PKY            L      BMT
# 278   R153   N120       181.0           UTICA AVE           AC      IND
# 279   R153  N120A       181.0           UTICA AVE           AC      IND
# 280   R154   N213       215.0         TREMONT AVE           BD      IND
# 281   R154   N214       215.0         TREMONT AVE           BD      IND
# 282   R155   N221       212.0      KINGSBRIDGE RD           BD      IND
# 283   R155   N220       212.0      KINGSBRIDGE RD           BD      IND
# 284   R156   N222       211.0     BEDFORD PARK BL           BD      IND
# 285   R156   N223       211.0     BEDFORD PARK BL           BD      IND
# 286   R157   N224       210.0      NORWOOD-205 ST            D      IND
# 287   R157   N225       210.0      NORWOOD-205 ST            D      IND
# 288   R158   N336       259.0     UNION TPK-KEW G           EF      IND
# 289   R158   N335       259.0     UNION TPK-KEW G           EF      IND
# 290   R159   R173       307.0     116 ST-COLUMBIA            1      IRT
# 291   R160   R219       407.0         ASTOR PLACE            6      IRT
# 292   R160   R220       407.0         ASTOR PLACE            6      IRT
# 293   R161   R290       381.0      KINGSBRIDGE RD            4      IRT
# 294   R162   R414       369.0           ELDER AVE            6      IRT
# 295   R163   N512       601.0         14 ST-6 AVE       FLM123      IND
# 296   R163   H003       601.0               6 AVE       FLM123      BMT
# 297   R163   N510       601.0         14 ST-6 AVE       FLM123      IND
# 298   R163   N511       601.0         14 ST-6 AVE       FLM123      IND
# 299   R163   N513       601.0         14 ST-6 AVE       FLM123      IND
# 300   R164  R160A       314.0       66 ST-LINCOLN            1      IRT
# 301   R164   R159       314.0       66 ST-LINCOLN            1      IRT
# 302   R164   R160       314.0       66 ST-LINCOLN            1      IRT
# 303   R166   R162       312.0               79 ST            1      IRT
# 304   R166   R163       312.0               79 ST            1      IRT
# 305   R167   R164       311.0               86 ST            1      IRT
# 306   R167   R165       311.0               86 ST            1      IRT
# 307   R167   R166       311.0               86 ST            1      IRT
# 308   R168  R168A       310.0               96 ST          123      IRT
# 309   R168   R168       310.0               96 ST          123      IRT
# 310   R169   R176       305.0     137 ST-CITY COL            1      IRT
# 311   R169   R175       305.0     137 ST-CITY COL            1      IRT
# 312   R170   A035       602.0      14 ST-UNION SQ      LNQR456      BMT
# 313   R170   R221       602.0      14 ST-UNION SQ      LNQR456      IRT
# 314   R170   A033       602.0      14 ST-UNION SQ      456LNQR      BMT
# 315   R170   A034       602.0      14 ST-UNION SQ      LNQR456      BMT
# 316   R170   A036       602.0      14 ST-UNION SQ      LNQR456      BMT
# 317   R170   A037       602.0      14 ST-UNION SQ      LNRQ456      BMT
# 318   R171   B004        41.0               7 AVE           BQ      BMT
# 319   R172   B029        55.0      BRIGHTON BEACH           BQ      BMT
# 320   R172   B031        55.0      BRIGHTON BEACH           BQ      BMT
# 321   R173  N002A       143.0       INWOOD-207 ST            A      IND
# 322   R173   N001       143.0       INWOOD-207 ST            A      IND
# 323   R174  N007A       146.0              181 ST            A      IND
# 324   R174   N009       146.0              181 ST            A      IND
# 325   R175   H001       618.0               8 AVE         ACEL      BMT
# 326   R175   N078       618.0               14 ST         ACEL      IND
# 327   R176   R231       403.0               33 ST            6      IRT
# 328   R176  R231A       403.0               33 ST            6      IRT
# 329   R176   R232       403.0               33 ST            6      IRT
# 330   R176  R232A       403.0               33 ST            6      IRT
# 331   R177   R246       399.0     68ST-HUNTER COL            6      IRT
# 332   R178   R248       398.0               77 ST            6      IRT
# 333   R178   R247       398.0               77 ST            6      IRT
# 334   R179   R250       397.0               86 ST          456      IRT
# 335   R179   R249       397.0               86 ST          456      IRT
# 336   R180   R252       395.0              103 ST            6      IRT
# 337   R181   R253       394.0              110 ST            6      IRT
# 338   R181   R254       394.0              110 ST            6      IRT
# 339   R182   R256       393.0              116 ST            6      IRT
# 340   R182   R257       393.0              116 ST            6      IRT
# 341   R183   R291       380.0     BEDFORD PARK BL            4      IRT
# 342   R184   B018        46.0      CORTELYOU ROAD           BQ      BMT
# 343   R185   N003       144.0      DYCKMAN-200 ST            A      IND
# 344   R186   N043       158.0               86 ST           BC      IND
# 345   R186   N042       158.0               86 ST           BC      IND
# 346   R187   N044       159.0        81 ST-MUSEUM           BC      IND
# 347   R187   N045       159.0        81 ST-MUSEUM           BC      IND
# 348   R188   N057       162.0               50 ST           CE      IND
# 349   R188   N056       162.0               50 ST           CE      IND
# 350   R189   R125       323.0      CHRISTOPHER ST            1      IRT
# 351   R189   R126       323.0      CHRISTOPHER ST            1      IRT
# 352   R190   R131       320.0               23 ST            1      IRT
# 353   R190   R132       320.0               23 ST            1      IRT
# 354   R191   R170       309.0              103 ST            1      IRT
# 355   R192   R172       308.0     110 ST-CATHEDRL            1      IRT
# 356   R192   R171       308.0     110 ST-CATHEDRL            1      IRT
# 357   R193   R180       303.0              157 ST            1      IRT
# 358   R193   R179       303.0              157 ST            1      IRT
# 359   R194  R217A       619.0         BLEECKER ST          6DF      IRT
# 360   R195   N203       604.0       161 ST-YANKEE          BD4      IND
# 361   R195   N204       604.0       161 ST-YANKEE          BD4      IND
# 362   R195   N205       604.0       161 ST-YANKEE          BD4      IND
# 363   R195   R262       604.0       161 ST-YANKEE          BD4      IRT
# 364   R195  R262A       604.0       161 ST-YANKEE          4BD      IRT
# 365   R195  R262B       604.0       161 ST-YANKEE          4BD      IRT
# 366   R196   B012        42.0       PROSPECT PARK          BQS      BMT
# 367   R196   B013        42.0       PROSPECT PARK          BQS      BMT
# 368   R197   C018        32.0               36 ST          DNR      BMT
# 369   R198   N116       179.0        NOSTRAND AVE           AC      IND
# 370   R198   N117       179.0        NOSTRAND AVE           AC      IND
# 371   R199   N119       180.0     KINGSTON-THROOP            C      IND
# 372   R199   N118       180.0     KINGSTON-THROOP            C      IND
# 373   R200   N128       188.0          EUCLID AVE           AC      IND
# 374   R201   N329       264.0      WOODHAVEN BLVD           MR      IND
# 375   R201  N329A       264.0      WOODHAVEN BLVD           MR      IND
# 376   R202  N330B       263.0     63 DR-REGO PARK           MR      IND
# 377   R202  N330C       263.0     63 DR-REGO PARK           MR      IND
# 378   R203   N509       228.0         23 ST-6 AVE           FM      IND
# 379   R204   N546       243.0          CHURCH AVE           FG      IND
# 380   R204   N545       243.0          CHURCH AVE           FG      IND
# 381   R205   R260       439.0      149 ST-GR CONC          245      IRT
# 382   R205   R261       603.0      149 ST-GR CONC          245      IRT
# 383   R206   R304       439.0              125 ST           23      IRT
# 384   R206   R305       439.0              125 ST           23      IRT
# 385   R207   R306       438.0              135 ST           23      IRT
# 386   R207   R307       438.0              135 ST           23      IRT
# 387   R208   R529       450.0       103 ST-CORONA            7      IRT
# 388   R209   R636       354.0         STERLING ST           25      IRT
# 389   R210   R641       357.0        BEVERLY ROAD           25      IRT
# 390   R211   B024        51.0       KINGS HIGHWAY           BQ      BMT
# 391   R211   B023        51.0       KINGS HIGHWAY           BQ      BMT
# 392   R211  B024A        51.0       KINGS HIGHWAY           BQ      BMT
# 393   R212   C021        35.0               59 ST           NR      BMT
# 394   R212   C022        35.0               59 ST           NR      BMT
# 395   R213   C023        36.0       BAY RIDGE AVE            R      BMT
# 396   R214   C024        37.0               77 ST            R      BMT
# 397   R215   C025        38.0               86 ST            R      BMT
# 398   R215   C026        38.0               86 ST            R      BMT
# 399   R216   C027        39.0     BAY RIDGE-95 ST            R      BMT
# 400   R216   C028        39.0     BAY RIDGE-95 ST            R      BMT
# 401   R217   N108       175.0       HOYT/SCHERMER          ACG      IND
# 402   R218  N325A       266.0        ELMHURST AVE           MR      IND
# 403   R219   N331       262.0              67 AVE           MR      IND
# 404   R219   N332       262.0              67 AVE           MR      IND
# 405   R220   N535       237.0          CARROLL ST           FG      IND
# 406   R220   N534       237.0          CARROLL ST           FG      IND
# 407   R221   R283       388.0              167 ST            4      IRT
# 408   R222   R417       366.0     E 177 ST-PARKCH            6      IRT
# 409   R223   R519       458.0      46 ST-BLISS ST            7      IRT
# 410   R223   R520       458.0      46 ST-BLISS ST            7      IRT
# 411   R224   R600       334.0            CLARK ST           23      IRT
# 412   R225   R606       336.0             HOYT ST           23      IRT
# 413   R226   R728       444.0       GUN HILL ROAD            5      IRT
# 414   R227   A055        22.0           RECTOR ST            R      BMT
# 415   R227   A054        22.0           RECTOR ST            R      BMT
# 416   R228   B021        49.0               AVE J           BQ      BMT
# 417   R229   B022        50.0               AVE M           BQ      BMT
# 418   R230   B026        53.0           NECK ROAD           BQ      BMT
# 419   R231   C010        28.0            UNION ST            R      BMT
# 420   R231   C011        28.0            UNION ST            R      BMT
# 421   R232   C019        33.0               45 ST            R      BMT
# 422   R233   C020        34.0               53 ST            R      BMT
# 423   R234   E004        61.0               50 ST            D      BMT
# 424   R235   H009       120.0         BEDFORD AVE            L      BMT
# 425   R236   H023       127.0          DEKALB AVE            L      BMT
# 426   R237   N215       214.0          182-183 ST           BD      IND
# 427   R238   N315       271.0         STEINWAY ST           MR      IND
# 428   R238   N314       271.0         STEINWAY ST           MR      IND
# 429   R239   N405       283.0      GREENPOINT AVE            G      IND
# 430   R239   N403       283.0      GREENPOINT AVE            G      IND
# 431   R240   N520       231.0            GRAND ST           BD      IND
# 432   R241   N542       241.0      15 ST-PROSPECT           FG      IND
# 433   R241   N541       241.0      15 ST-PROSPECT           FG      IND
# 434   R242   N549       245.0              18 AVE            F      IND
# 435   R242   N550       245.0              18 AVE            F      IND
# 436   R243   R284       387.0              170 ST            4      IRT
# 437   R244   R287       384.0        BURNSIDE AVE            4      IRT
# 438   R245   R416       367.0     ST LAWRENCE AVE            6      IRT
# 439   R246   C014        30.0        PROSPECT AVE            R      BMT
# 440   R247   E005        62.0               55 ST            D      BMT
# 441   R248   H007       119.0               1 AVE            L      BMT
# 442   R248   H008       119.0               1 AVE            L      BMT
# 443   R249   H014       122.0          GRAHAM AVE            L      BMT
# 444   R249   H013       122.0          GRAHAM AVE            L      BMT
# 445   R250   H016       123.0            GRAND ST            L      BMT
# 446   R250   H015       123.0            GRAND ST            L      BMT
# 447   R251   N040       157.0               96 ST           BC      IND
# 448   R251   N039       157.0               96 ST           BC      IND
# 449   R252   N100       173.0             HIGH ST           AC      IND
# 450   R252   N101       173.0             HIGH ST           AC      IND
# 451   R253   N210       216.0          174-175 ST           BD      IND
# 452   R253   N212       216.0          174-175 ST           BD      IND
# 453   R254   N327       265.0     GRAND AV-NEWTON           MR      IND
# 454   R255   N337       258.0       VAN WYCK BLVD           EF      IND
# 455   R256  N408A       284.0           NASSAU AV            G      IND
# 456   R257   N529       234.0       EAST BROADWAY            F      IND
# 457   R257   N528       234.0       EAST BROADWAY            F      IND
# 458   R258   N537       608.0               4 AVE       DFGMNR      IND
# 459   R258   C012       608.0                9 ST       DFGMNR      BMT
# 460   R259   N602       222.0        ROOSEVELT IS            F      IND
# 461   R260   R183       301.0              181 ST            1      IRT
# 462   R261   R518       459.0     40 ST-LOWERY ST            7      IRT
# 463   R262   B017        45.0       BEVERLEY ROAD           BQ      BMT
# 464   R263   B020        48.0               AVE H           BQ      BMT
# 465   R264   B032        56.0       OCEAN PARKWAY            Q      BMT
# 466   R264   B034        56.0       OCEAN PARKWAY            Q      BMT
# 467   R265   H017       124.0        MONTROSE AVE            L      BMT
# 468   R266   H028       129.0           HALSEY ST            L      BMT
# 469   R266   H030       129.0           HALSEY ST            L      BMT
# 470   R267   N316       270.0               46 ST           MR      IND
# 471   R267  N316A       270.0               46 ST           MR      IND
# 472   R267   N317       270.0               46 ST           MR      IND
# 473   R268   N409       629.0     METROPOLITAN AV           GL      IND
# 474   R268   H012       629.0          LORIMER ST           GL      BMT
# 475   R269   N417       289.0     BEDFORD/NOSTRAN            G      IND
# 476   R269   N418       289.0     BEDFORD/NOSTRAN            G      IND
# 477   R270   N536       238.0          SMITH-9 ST           FG      IND
# 478   R271   N561       252.0               AVE X            F      IND
# 479   R272   R133       319.0               28 ST            1      IRT
# 480   R272   R134       319.0               28 ST            1      IRT
# 481   R273   R178       304.0              145 ST            1      IRT
# 482   R273   R177       304.0              145 ST            1      IRT
# 483   R274   R185       300.0              191 ST            1      IRT
# 484   R275   R288       383.0              183 ST            4      IRT
# 485   R276   R504       464.0      VERNON/JACKSON            7      IRT
# 486   R276   R503       464.0      VERNON/JACKSON            7      IRT
# 487   R276   R506       464.0      VERNON/JACKSON            7      IRT
# 488   R277   R635       353.0        PRESIDENT ST           25      IRT
# 489   R278   C016        31.0               25 ST            R      BMT
# 490   R279   H022       126.0        JEFFERSON ST            L      BMT
# 491   R280  N006A       145.0              190 ST            A      IND
# 492   R281   N046       160.0               72 ST           BC      IND
# 493   R282   N086       168.0           SPRING ST           CE      IND
# 494   R282   N087       168.0           SPRING ST           CE      IND
# 495   R283   N110       176.0       LAFAYETTE AVE            C      IND
# 496   R284   N111       177.0     CLINTON-WASH AV            C      IND
# 497   R284  N112A       177.0     CLINTON-WASH AV            C      IND
# 498   R285   N196       209.0        FAR ROCKAWAY            A      IND
# 499   R286   N415       288.0     MYRTLE-WILLOUGH            G      IND
# 500   R286   N416       288.0     MYRTLE-WILLOUGH            G      IND
# 501   R287   N419       290.0         CLASSON AVE            G      IND
# 502   R288  N539A       240.0     7 AV-PARK SLOPE           FG      IND
# 503   R289   N543       242.0     FT HAMILTON PKY           FG      IND
# 504   R289   N544       242.0     FT HAMILTON PKY           FG      IND
# 505   R290   R123       324.0          HOUSTON ST            1      IRT
# 506   R290   R121       324.0          HOUSTON ST            1      IRT
# 507   R290   R122       324.0          HOUSTON ST            1      IRT
# 508   R290   R124       324.0          HOUSTON ST            1      IRT
# 509   R291   R516       460.0     33 ST/RAWSON ST            7      IRT
# 510   R291   R517       460.0     33 ST/RAWSON ST            7      IRT
# 511   R292   R729       443.0      BAYCHESTER AVE            5      IRT
# 512   R293   R138       164.0      34 ST-PENN STA       123ACE      IRT
# 513   R293   R142       164.0      34 ST-PENN STA       123ACE      IRT
# 514   R294   H019       125.0          MORGAN AVE            L      BMT
# 515   R295   H032       130.0          WILSON AVE            L      BMT
# 516   R296  N016A       149.0     163 ST-AMSTERDM            C      IND
# 517   R297   N113       627.0        FRANKLIN AVE          ACS      IND
# 518   R297   N114       627.0        FRANKLIN AVE          ACS      IND
# 519   R298   N318       269.0       NORTHERN BLVD           MR      IND
# 520   R298   N319       269.0       NORTHERN BLVD           MR      IND
# 521   R299   N412       286.0            BROADWAY            G      IND
# 522   R300   N523       232.0               2 AVE            F      IND
# 523   R300   N521       232.0               2 AVE            F      IND
# 524   R301   N530       235.0             YORK ST            F      IND
# 525   R302   N600       224.0               57 ST            F      IND
# 526   R303   N603       221.0               21 ST            F      IND
# 527   R304   R103       329.0           RECTOR ST            1      IRT
# 528   R304   R102       329.0           RECTOR ST            1      IRT
# 529   R305   R107       328.0        CORTLANDT ST            1      IRT
# 530   R305   R106       328.0        CORTLANDT ST            1      IRT
# 531   R305   R108       328.0        CORTLANDT ST            1      IRT
# 532   R305   R109       328.0        CORTLANDT ST            1      IRT
# 533   R306   R196       294.0              238 ST            1      IRT
# 534   R307   R259       391.0      138 ST-GR CONC           45      IRT
# 535   R308   R285       386.0         MT EDEN AVE            4      IRT
# 536   R309   R286       385.0              176 ST            4      IRT
# 537   R310   R530       449.0              111 ST            7      IRT
# 538   R311   A064       103.0              BOWERY           JZ      BMT
# 539   R312   G011        57.0     W 8 ST-AQUARIUM           FQ      BMT
# 540   R312   G015        57.0     W 8 ST-AQUARIUM           FQ      BMT
# 541   R313   H033       131.0        BUSHWICK AVE            L      BMT
# 542   R314   N037       156.0              103 ST           BC      IND
# 543   R315   N202       220.0              155 ST           BD      IND
# 544   R316   N414       287.0        FLUSHING AVE            G      IND
# 545   R316  N414A       287.0        FLUSHING AVE            G      IND
# 546   R317  N420B       291.0     CLINTON-WASH AV            G      IND
# 547   R318   N422       292.0           FULTON ST            G      IND
# 548   R319   N601       223.0       LEXINGTON AVE            F      IND
# 549   R320   R119       325.0            CANAL ST            1      IRT
# 550   R320   R120       325.0            CANAL ST            1      IRT
# 551   R321   R129       321.0               18 ST            1      IRT
# 552   R321   R130       321.0               18 ST            1      IRT
# 553   R322   R215       409.0           SPRING ST            6      IRT
# 554   R322   R216       409.0           SPRING ST            6      IRT
# 555   R323   R301       441.0          110 ST-CPN           23      IRT
# 556   R324   R303       440.0              116 ST           23      IRT
# 557   R324   R302       440.0              116 ST           23      IRT
# 558   R325   R413       370.0        WHITLOCK AVE            6      IRT
# 559   R326   R419       364.0          ZEREGA AVE            6      IRT
# 560   R327   R521       457.0       52 ST-LINCOLN            7      IRT
# 561   R328   R532       448.0     METS-WILLETS PT            7      IRT
# 562   R328  R532G       448.0     METS-WILLETS PT            7      IRT
# 563   R328  R532H       448.0     METS-WILLETS PT            7      IRT
# 564   R329   R726       446.0         MORRIS PARK            5      IRT
# 565   R330   H005       118.0               3 AVE            L      BMT
# 566   R330   H006       118.0               3 AVE            L      BMT
# 567   R331   N017       150.0              155 ST            C      IND
# 568   R332   N024       152.0              135 ST           BC      IND
# 569   R332   N023       152.0              135 ST           BC      IND
# 570   R332   N022       152.0              135 ST           BC      IND
# 571   R333   N030       154.0              116 ST           BC      IND
# 572   R333   N029       154.0              116 ST           BC      IND
# 573   R334   N035       155.0     CATHEDRL-110 ST           BC      IND
# 574   R334   N034       155.0     CATHEDRL-110 ST           BC      IND
# 575   R335   N191       204.0         BEACH 67 ST            A      IND
# 576   R336   N192       205.0         BEACH 60 ST            A      IND
# 577   R337   N193       206.0         BEACH 44 ST            A      IND
# 578   R338   N194       207.0         BEACH 36 ST            A      IND
# 579   R339   N312       272.0               36 ST           MR      IND
# 580   R339   N311       272.0               36 ST           MR      IND
# 581   R340   N322       268.0               65 ST           MR      IND
# 582   R341  N334B       260.0              75 AVE           EF      IND
# 583   R342   N604       280.0     JAMAICA-VAN WYC            E      IND
# 584   R343   R117       326.0         FRANKLIN ST            1      IRT
# 585   R343   R118       326.0         FRANKLIN ST            1      IRT
# 586   R344   R308       437.0              145 ST            3      IRT
# 587   R345   R309       436.0        148 ST-LENOX            3      IRT
# 588   R346   R508       606.0            COURT SQ            7      IRT
# 589   R347   R524       455.0      69 ST-FISK AVE            7      IRT
# 590   R348   H035       133.0        ATLANTIC AVE            L      BMT
# 591   R349   H037       134.0          SUTTER AVE            L      BMT
# 592   R350   H038       135.0         LIVONIA AVE            L      BMT
# 593   R352   J003       100.0            HEWES ST           JM      BMT
# 594   R353   J005        99.0          LORIMER ST           JM      BMT
# 595   R354   N137       193.0       OXFORD-104 ST            A      IND
# 596   R355   N139       194.0       GREENWOOD-111            A      IND
# 597   R355   N138       194.0       GREENWOOD-111            A      IND
# 598   R356   N141       195.0       LEFFERTS BLVD            A      IND
# 599   R357   N181       197.0     AQUEDUCT-N CNDT            A      IND
# 600   R358   N195       208.0         BEACH 25 ST            A      IND
# 601   R359   N307       606.0      COURT SQ-23 ST          EMG      IND
# 602   R359   N400       606.0            COURT SQ          EMG      IND
# 603   R359  N400A       606.0            COURT SQ          EMG      IND
# 604   R360   N401       282.0     VAN ALSTON-21ST            G      IND
# 605   R361   R328       424.0      PELHAM PARKWAY           25      IRT
# 606   R361   R327       424.0      PELHAM PARKWAY           25      IRT
# 607   R362   R329       423.0        ALLERTON AVE           25      IRT
# 608   R363   R330       422.0           BURKE AVE           25      IRT
# 609   R364   R331       421.0       GUN HILL ROAD           25      IRT
# 610   R365   R332       420.0              219 ST           25      IRT
# 611   R366   R333       419.0              225 ST           25      IRT
# 612   R367   R334       418.0              233 ST           25      IRT
# 613   R368   E001        59.0               9 AVE            D      BMT
# 614   R369   E003        60.0     FT HAMILTON PKY            D      BMT
# 615   R370   E009        64.0               71 ST            D      BMT
# 616   R371   E011        65.0               79 ST            D      BMT
# 617   R372   E012        66.0              18 AVE            D      BMT
# 618   R373   E013        67.0              20 AVE            D      BMT
# 619   R374   E014        68.0         BAY PARKWAY            D      BMT
# 620   R375   H039       136.0        NEW LOTS AVE            L      BMT
# 621   R376   H040       137.0         EAST 105 ST            L      BMT
# 622   R377   J007        98.0        FLUSHING AVE           JM      BMT
# 623   R378   J009        97.0          MYRTLE AVE          JMZ      BMT
# 624   R379   J012        96.0       KOSCIUSZKO ST            J      BMT
# 625   R380   J013        95.0           GATES AVE           JZ      BMT
# 626   R381   J016        94.0           HALSEY ST            J      BMT
# 627   R382   N129       189.0           GRANT AVE            A      IND
# 628   R383   N131       190.0        HUDSON-80 ST            A      IND
# 629   R383   N130       190.0        HUDSON-80 ST            A      IND
# 630   R384   N133       191.0          BOYD-88 ST            A      IND
# 631   R385   N134       192.0       ROCKAWAY BLVD            A      IND
# 632   R385   N135       192.0       ROCKAWAY BLVD            A      IND
# 633   R386   R322       428.0              174 ST           25      IRT
# 634   R386   R321       428.0              174 ST           25      IRT
# 635   R387   R323       427.0       E TREMONT AVE           25      IRT
# 636   R387  R323A       427.0       E TREMONT AVE           25      IRT
# 637   R388   R325       426.0            E 180 ST           25      IRT
# 638   R389   R326       425.0     BRONX PARK EAST           25      IRT
# 639   R390   D002        71.0               8 AVE            N      BMT
# 640   R391   D003        72.0     FT HAMILTON PKY            N      BMT
# 641   R391   D004        72.0     FT HAMILTON PKY            N      BMT
# 642   R392   D008        74.0              18 AVE            N      BMT
# 643   R393   D009        75.0              20 AVE            N      BMT
# 644   R394   D010        76.0      BAY PKY-22 AVE            N      BMT
# 645   R394   D011        76.0      BAY PKY-22 AVE            N      BMT
# 646   R395   D012        77.0       KINGS HIGHWAY            N      BMT
# 647   R396   D015        78.0               AVE U            N      BMT
# 648   R397   D016        79.0               86 ST            N      BMT
# 649   R398   D005       615.0     NEW UTRECHT AVE           ND      BMT
# 650   R398   D006       615.0     NEW UTRECHT AVE           ND      BMT
# 651   R399   E015        69.0              25 AVE            D      BMT
# 652   R400   E016        70.0           BAY 50 ST            D      BMT
# 653   R401   K017       114.0         CENTRAL AVE            M      BMT
# 654   R402   K022       111.0          SENECA AVE            M      BMT
# 655   R403   K024       110.0          FOREST AVE            M      BMT
# 656   R404   K025       109.0     FRESH POND ROAD            M      BMT
# 657   R405   R312       433.0         JACKSON AVE           25      IRT
# 658   R406   R314       432.0        PROSPECT AVE           25      IRT
# 659   R406   R315       432.0        PROSPECT AVE           25      IRT
# 660   R407   R316       431.0       INTERVALE-163           25      IRT
# 661   R408   R318       430.0          SIMPSON ST           25      IRT
# 662   R408   R317       430.0          SIMPSON ST           25      IRT
# 663   R409   R320       429.0          FREEMAN ST           25      IRT
# 664   R409   R319       429.0          FREEMAN ST           25      IRT
# 665   R410   X001         NaN     NYC & CO - 7 AV            1      IRT
# 666   R411   B009       141.0          PARK PLACE            S      BMT
# 667   R412   B010       626.0      BOTANIC GARDEN        S2345      BMT
# 668   R413   K019       113.0       KNICKERBOCKER            M      BMT
# 669   R414   N182       198.0      HOWARD BCH-JFK            A      IND
# 670   R414  N182A       198.0      HOWARD BCH-JFK            A      IND
# 671   R415   N183       199.0       BROAD CHANNEL           AS      IND
# 672   R416   N184       200.0         BEACH 90 ST           AS      IND
# 673   R417   N185       201.0         BEACH 98 ST           AS      IND
# 674   R418   N186       202.0        BEACH 105 ST           AS      IND
# 675   R419   N187       203.0     ROCKAWAY PK 116           AS      IND
# 676   R420   N548       244.0          DITMAS AVE            F      IND
# 677   R420   N547       244.0          DITMAS AVE            F      IND
# 678   R421   N551       246.0               AVE I            F      IND
# 679   R422   N553       247.0      22 AVE-BAY PKY            F      IND
# 680   R423   N555       248.0               AVE N            F      IND
# 681   R423   N554       248.0               AVE N            F      IND
# 682   R424   N556       249.0               AVE P            F      IND
# 683   R425   N559       251.0               AVE U            F      IND
# 684   R426   N562       253.0         NEPTUNE AVE            F      IND
# 685   R427   R421       362.0     MIDDLETOWN ROAD            6      IRT
# 686   R428   R422       361.0           BUHRE AVE            6      IRT
# 687   R429   R423       360.0     PELHAM BAY PARK            6      IRT
# 688   R430   R727       445.0      PELHAM PARKWAY            5      IRT
# 689   R431   R730       442.0            DYRE AVE            5      IRT
# 690   R432   J017        93.0         CHAUNCEY ST           JZ      BMT
# 691   R433   J020        91.0         ALABAMA AVE            J      BMT
# 692   R434   J021        90.0      VAN SICLEN AVE           JZ      BMT
# 693   R435   J022        89.0        CLEVELAND ST            J      BMT
# 694   R436   J023        88.0         NORWOOD AVE           JZ      BMT
# 695   R437   J024        87.0         CRESCENT ST           JZ      BMT
# 696   R438  N121B       182.0           RALPH AVE            C      IND
# 697   R439   N122       183.0        ROCKAWAY AVE            C      IND
# 698   R439  N123B       183.0        ROCKAWAY AVE            C      IND
# 699   R440   N125       185.0         LIBERTY AVE            C      IND
# 700   R441   N126       186.0      VAN SICLEN AVE            C      IND
# 701   R442   N127       187.0        SHEPHERD AVE            C      IND
# 702   R443   N209       217.0              170 ST           BD      IND
# 703   R443   N208       217.0              170 ST           BD      IND
# 704   R444   R335       417.0          NEREID AVE           25      IRT
# 705   R445   R401       377.0        138 ST-3 AVE            6      IRT
# 706   R446   R402       376.0           BROOK AVE            6      IRT
# 707   R446   R403       376.0           BROOK AVE            6      IRT
# 708   R447   R404       375.0         CYPRESS AVE            6      IRT
# 709   R447   R405       375.0         CYPRESS AVE            6      IRT
# 710   R448   R406       374.0            E 143 ST            6      IRT
# 711   R448   R407       374.0            E 143 ST            6      IRT
# 712   R449   R408       373.0            E 149 ST            6      IRT
# 713   R449   R409       373.0            E 149 ST            6      IRT
# 714   R450   R410       372.0        LONGWOOD AVE            6      IRT
# 715   R450   R411       372.0        LONGWOOD AVE            6      IRT
# 716   R451   R637       355.0         WINTHROP ST           25      IRT
# 717   R452  R161B       313.0               72 ST          123      IRT
# 718   R452  R161A       313.0               72 ST          123      IRT
# 719   R453   N508       228.0         23 ST-6 AVE           FM      IND
# 720   R454   C015        30.0        PROSPECT AVE            R      BMT
# 721   R455   C017        31.0               25 ST            R      BMT
# 722   R456   R605       336.0             HOYT ST           23      IRT
# 723   R457   MCB1         NaN     METROCARD BUS 1           23      BMT
# 724   R458   MCB2         NaN     METROCARD BUS 2           23      BMT
# 725   R459   OB01         NaN       ORCHARD BEACH            6      IND
# 726   R460   J002       101.0           MARCY AVE          JMZ      BMT
# 727   R460   J001       101.0           MARCY AVE          JMZ      BMT
# 728   R461   N519       619.0      BROADWAY/LAFAY        BDFQ6      IND
# 729   R461  N519A       619.0      BROADWAY/LAFAY        BDFQ6      IND
# 730   R462   A043       623.0            CANAL ST       JNQRZ6      BMT
# 731   R462   A044       623.0            CANAL ST       JNQRZ6      BMT
# 732   R463   A046       623.0            CANAL ST       JNQRZ6      BMT
# 733   R463   R214       623.0            CANAL ST       JNQRZ6      IRT
# 734   R464  N181A       196.0      AQUEDUCT TRACK            A      IND
# 735   R465   MCV1         NaN     METROCARD VAN-1            1      BMT
# 736   R466   MCV2         NaN     METROCARD VAN-2            1      BMT
# 737   R467   MCV3         NaN     METROCARD VAN-3            1      BMT
# 738   R468  TRAM1         NaN       RIT-MANHATTAN            R      RIT
# 739   R469  TRAM2         NaN       RIT-ROOSEVELT            R      RIT
# 740   R535  JFK01       198.0      JFK HOWARD BCH            A      IND
# 741   R535  JFK02       198.0      JFK HOWARD BCH            A      IND
# 742   R536  JFK03       278.0     JFK JAMAICA CT1            E      IND
# 743   R537  JFK04       278.0     JFK JAMAICA CT2            E      IND
# 744   R538  LGA01         NaN     LGA AIRPORT CTB            7      IRT
# 745   R540  PTH08         NaN            PATH WTC            1      PTH
# 746   R540  PTH21         NaN          PATH WTC 2            1      PTH
# 747   R541  PTH13         NaN           THIRTY ST            1      PTH
# 748   R541  PTH17         NaN     THIRTY THIRD ST            1      PTH
# 749   R542  PTH12         NaN     TWENTY THIRD ST            1      PTH
# 750   R543  PTH05         NaN      EXCHANGE PLACE            1      PTH
# 751   R544  PTH02         NaN            HARRISON            1      PTH
# 752   R545  PTH11         NaN         14TH STREET            1      PTH
# 753   R546  PTH06         NaN     PAVONIA/NEWPORT            1      PTH
# 754   R547  PTH10         NaN          9TH STREET            1      PTH
# 755   R548  PTH09         NaN      CHRISTOPHER ST            1      PTH
# 756   R549  PTH01         NaN     NEWARK HW BMEBE            1      PTH
# 757   R549  PTH18         NaN        NEWARK BM BW            1      PTH
# 758   R549  PTH19         NaN            NEWARK C            1      PTH
# 759   R549  PTH20         NaN        NEWARK HM HE            1      PTH
# 760   R550  PTH07         NaN          CITY / BUS            1      PTH
# 761   R550  PTH16         NaN          LACKAWANNA            1      PTH
# 762   R551  PTH04         NaN        GROVE STREET            1      PTH
# 763   R552  PTH03         NaN      JOURNAL SQUARE            1      PTH
# 764   R570   N700       477.0  72 ST - SECOND AVE            Q      IND
# 765   R570  N700A       477.0  72 ST - SECOND AVE            Q      IND
# 766   R571   N701       476.0  86 ST - SECOND AVE            Q      IND
# 767   R571  N701A       476.0  86 ST - SECOND AVE            Q      IND
# 768   R572   N702       475.0  96 ST - SECOND AVE            Q      IND
# 769   R572  N702A       475.0  96 ST - SECOND AVE            Q      IND

# %%
complex_list['division'].unique()
# Out:
# array(['BMT', 'IRT', 'IND', 'RIT', 'PTH'], dtype=object)

# %% [markdown]
# While we're at it, let's drop 'SRT' division from the daily_per_turnstile data (not interested in Staten Island)

# %%
print(daily_per_turnstile_2019.shape)
daily_per_turnstile_2019 = daily_per_turnstile_2019[daily_per_turnstile_2019['DIVISION'] != 'SRT']
daily_per_turnstile_2019.reset_index(drop=True, inplace=True)
print(daily_per_turnstile_2019.shape)
# Out:
# (295338, 12)
# (293325, 12)

# %%
daily_per_turnstile_2019['DIVISION'].unique()
# Out:
# array(['BMT', 'IND', 'PTH', 'IRT', 'RIT'], dtype=object)

# %%
print(daily_per_turnstile_2021.shape)
daily_per_turnstile_2021 = daily_per_turnstile_2021[daily_per_turnstile_2021['DIVISION'] != 'SRT']
daily_per_turnstile_2021.reset_index(drop=True, inplace=True)
print(daily_per_turnstile_2021.shape)
# Out:
# (303670, 12)
# (301718, 12)

# %%
daily_per_turnstile_2021['DIVISION'].unique()
# Out:
# array(['BMT', 'IND', 'PTH', 'IRT', 'RIT'], dtype=object)

# %% [markdown]
# Now import the dataset that maps complex_id to physical location of each "Complex" (MTA-provided data but again slightly modified by Chris Whong). Can be found at the following link:

# %% [markdown]
# https://qri.cloud/nyc-transit-data/turnstiles_station_list

# %%
station_locations = pd.read_csv('nyc_transit_turnstiles_station_list.csv')

# Drop the division='SIR' rows (these are Staten Island Railway stations; not under consideration here)
station_locations = station_locations[station_locations['division'] != 'SIR'].reset_index(drop=True)

print(station_locations.shape)
station_locations
# Out:
# (490, 14)
#      ogc_fid  station_id complex_id gtfs_stop_id division  \
# 0          1         1.0          1          R01      BMT
# 1          2         2.0          2          R03      BMT
# 2          3         3.0          3          R04      BMT
# 3          4         4.0          4          R05      BMT
# 4          5         5.0          5          R06      BMT
# 5          6         6.0          6          R08      BMT
# 6          7         7.0        613          R11      BMT
# 7          8         8.0          8          R13      BMT
# 8          9         9.0          9          R14      BMT
# 9         10        10.0         10          R15      BMT
# 10        11        11.0        611          R16      BMT
# 11        12        12.0        607          R17      BMT
# 12        13        13.0         13          R18      BMT
# 13        14        14.0         14          R19      BMT
# 14        15        15.0        602          R20      BMT
# 15        16        16.0         16          R21      BMT
# 16        17        17.0         17          R22      BMT
# 17        18        18.0        623          R23      BMT
# 18        19        19.0        623          Q01      BMT
# 19        20        20.0         20          R24      BMT
# 20        21        21.0        624          R25      BMT
# 21        22        22.0         22          R26      BMT
# 22        23        23.0        635          R27      BMT
# 23        24        24.0        620          R28      BMT
# 24        25        25.0        636          R29      BMT
# 25        26        26.0         26          R30      BMT
# 26        27        27.0        617          R31      BMT
# 27        28        28.0         28          R32      BMT
# 28        29        29.0        608          R33      BMT
# 29        30        30.0         30          R34      BMT
# 30        31        31.0         31          R35      BMT
# 31        32        32.0         32          R36      BMT
# 32        33        33.0         33          R39      BMT
# 33        34        34.0         34          R40      BMT
# 34        35        35.0         35          R41      BMT
# 35        36        36.0         36          R42      BMT
# 36        37        37.0         37          R43      BMT
# 37        38        38.0         38          R44      BMT
# 38        39        39.0         39          R45      BMT
# 39        40        40.0        617          D24      BMT
# 40        41        41.0         41          D25      BMT
# 41        42        42.0         42          D26      BMT
# 42        43        43.0         43          D27      BMT
# 43        44        44.0         44          D28      BMT
# 44        45        45.0         45          D29      BMT
# 45        46        46.0         46          D30      BMT
# 46        47        47.0         47          D31      BMT
# 47        48        48.0         48          D32      BMT
# 48        49        49.0         49          D33      BMT
# 49        50        50.0         50          D34      BMT
# 50        51        51.0         51          D35      BMT
# 51        52        52.0         52          D37      BMT
# 52        53        53.0         53          D38      BMT
# 53        54        54.0         54          D39      BMT
# 54        55        55.0         55          D40      BMT
# 55        56        56.0         56          D41      BMT
# 56        57        57.0         57          D42      BMT
# 57        58        58.0         58          D43      BMT
# 58        59        59.0         59          B12      BMT
# 59        60        60.0         60          B13      BMT
# 60        61        61.0         61          B14      BMT
# 61        62        62.0         62          B15      BMT
# 62        63        63.0        615          B16      BMT
# 63        64        64.0         64          B17      BMT
# 64        65        65.0         65          B18      BMT
# 65        66        66.0         66          B19      BMT
# 66        67        67.0         67          B20      BMT
# 67        68        68.0         68          B21      BMT
# 68        69        69.0         69          B22      BMT
# 69        70        70.0         70          B23      BMT
# 70        71        71.0         71          N02      BMT
# 71        72        72.0         72          N03      BMT
# 72        73        73.0        615          N04      BMT
# 73        74        74.0         74          N05      BMT
# 74        75        75.0         75          N06      BMT
# 75        76        76.0         76          N07      BMT
# 76        77        77.0         77          N08      BMT
# 77        78        78.0         78          N09      BMT
# 78        79        79.0         79          N10      BMT
# 79        80        80.0         80          J12      BMT
# 80        81        81.0         81          J13      BMT
# 81        82        82.0         82          J14      BMT
# 82        83        83.0         83          J15      BMT
# 83        84        84.0         84          J16      BMT
# 84        85        85.0         85          J17      BMT
# 85        86        86.0         86          J19      BMT
# 86        87        87.0         87          J20      BMT
# 87        88        88.0         88          J21      BMT
# 88        89        89.0         89          J22      BMT
# 89        90        90.0         90          J23      BMT
# 90        91        91.0         91          J24      BMT
# 91        92        92.0        621          J27      BMT
# 92        93        93.0         93          J28      BMT
# 93        94        94.0         94          J29      BMT
# 94        95        95.0         95          J30      BMT
# 95        96        96.0         96          J31      BMT
# 96        97        97.0         97          M11      BMT
# 97        98        98.0         98          M12      BMT
# 98        99        99.0         99          M13      BMT
# 99       100       100.0        100          M14      BMT
# 100      101       101.0        101          M16      BMT
# 101      102       102.0        625          M18      BMT
# 102      103       103.0        103          M19      BMT
# 103      104       104.0        623          M20      BMT
# 104      105       105.0        622          M21      BMT
# 105      106       106.0        628          M22      BMT
# 106      107       107.0        107          M23      BMT
# 107      108       108.0        108          M01      BMT
# 108      109       109.0        109          M04      BMT
# 109      110       110.0        110          M05      BMT
# 110      111       111.0        111          M06      BMT
# 111      112       112.0        630          M08      BMT
# 112      113       113.0        113          M09      BMT
# 113      114       114.0        114          M10      BMT
# 114      115       115.0        618          L01      BMT
# 115      116       116.0        601          L02      BMT
# 116      117       117.0        602          L03      BMT
# 117      118       118.0        118          L05      BMT
# 118      119       119.0        119          L06      BMT
# 119      120       120.0        120          L08      BMT
# 120      121       121.0        629          L10      BMT
# 121      122       122.0        122          L11      BMT
# 122      123       123.0        123          L12      BMT
# 123      124       124.0        124          L13      BMT
# 124      125       125.0        125          L14      BMT
# 125      126       126.0        126          L15      BMT
# 126      127       127.0        127          L16      BMT
# 127      128       128.0        630          L17      BMT
# 128      129       129.0        129          L19      BMT
# 129      130       130.0        130          L20      BMT
# 130      131       131.0        131          L21      BMT
# 131      132       132.0        621          L22      BMT
# 132      133       133.0        133          L24      BMT
# 133      134       134.0        134          L25      BMT
# 134      135       135.0        135          L26      BMT
# 135      136       136.0        136          L27      BMT
# 136      137       137.0        137          L28      BMT
# 137      138       138.0        138          L29      BMT
# 138      139       139.0        627          S01      BMT
# 139      140       141.0        141          S03      BMT
# 140      141       142.0        626          S04      BMT
# 141      142       143.0        143          A02      IND
# 142      143       144.0        144          A03      IND
# 143      144       145.0        145          A05      IND
# 144      145       146.0        146          A06      IND
# 145      146       147.0        147          A07      IND
# 146      147       148.0        605          A09      IND
# 147      148       149.0        149          A10      IND
# 148      149       150.0        150          A11      IND
# 149      150       151.0        151          A12      IND
# 150      151       151.0        151          D13      IND
# 151      152       152.0        152          A14      IND
# 152      153       153.0        153          A15      IND
# 153      154       154.0        154          A16      IND
# 154      155       155.0        155          A17      IND
# 155      156       156.0        156          A18      IND
# 156      157       157.0        157          A19      IND
# 157      158       158.0        158          A20      IND
# 158      159       159.0        159          A21      IND
# 159      160       160.0        160          A22      IND
# 160      161       161.0        614          A24      IND
# 161      162       162.0        162          A25      IND
# 162      163       163.0        611          A27      IND
# 163      164       164.0        164          A28      IND
# 164      165       165.0        165          A30      IND
# 165      166       166.0        618          A31      IND
# 166      167       167.0        167          A32      IND
# 167      168       167.0        167          D20      IND
# 168      169       168.0        168          A33      IND
# 169      170       169.0        169          A34      IND
# 170      171       170.0        624          A36      IND
# 171      172       171.0        624          E01      IND
# 172      173       172.0        628          A38      IND
# 173      174       173.0        173          A40      IND
# 174      175       174.0        636          A41      IND
# 175      176       175.0        175          A42      IND
# 176      177       176.0        176          A43      IND
# 177      178       177.0        177          A44      IND
# 178      179       178.0        627          A45      IND
# 179      180       179.0        179          A46      IND
# 180      181       180.0        180          A47      IND
# 181      182       181.0        181          A48      IND
# 182      183       182.0        182          A49      IND
# 183      184       183.0        183          A50      IND
# 184      185       184.0        621          A51      IND
# 185      186       185.0        185          A52      IND
# 186      187       186.0        186          A53      IND
# 187      188       187.0        187          A54      IND
# 188      189       188.0        188          A55      IND
# 189      190       189.0        189          A57      IND
# 190      191       190.0        190          A59      IND
# 191      192       191.0        191          A60      IND
# 192      193       192.0        192          A61      IND
# 193      194       193.0        193          A63      IND
# 194      195       194.0        194          A64      IND
# 195      196       195.0        195          A65      IND
# 196      197       196.0        196          H01      IND
# 197      198       197.0        197          H02      IND
# 198      199       198.0        198          H03      IND
# 199      200       199.0        199          H04      IND
# 200      201       200.0        200          H12      IND
# 201      202       201.0        201          H13      IND
# 202      203       202.0        202          H14      IND
# 203      204       203.0        203          H15      IND
# 204      205       204.0        204          H06      IND
# 205      206       205.0        205          H07      IND
# 206      207       206.0        206          H08      IND
# 207      208       207.0        207          H09      IND
# 208      209       208.0        208          H10      IND
# 209      210       209.0        209          H11      IND
# 210      211       210.0        210          D01      IND
# 211      212       211.0        211          D03      IND
# 212      213       212.0        212          D04      IND
# 213      214       213.0        213          D05      IND
# 214      215       214.0        214          D06      IND
# 215      216       215.0        215          D07      IND
# 216      217       216.0        216          D08      IND
# 217      218       217.0        217          D09      IND
# 218      219       218.0        218          D10      IND
# 219      220       219.0        604          D11      IND
# 220      221       220.0        220          D12      IND
# 221      222       221.0        221          B04      IND
# 222      223       222.0        222          B06      IND
# 223      224       223.0        223          B08      IND
# 224      225       224.0        224          B10      IND
# 225      226       225.0        225          D15      IND
# 226      227       226.0        609          D16      IND
# 227      228       227.0        607          D17      IND
# 228      229       228.0        228          D18      IND
# 229      230       229.0        601          D19      IND
# 230      231       230.0        619          D21      IND
# 231      232       231.0        231          D22      IND
# 232      233       232.0        232          F14      IND
# 233      234       233.0        625          F15      IND
# 234      235       234.0        234          F16      IND
# 235      236       235.0        235          F18      IND
# 236      237       236.0        236          F20      IND
# 237      238       237.0        237          F21      IND
# 238      239       238.0        238          F22      IND
# 239      240       239.0        608          F23      IND
# 240      241       240.0        240          F24      IND
# 241      242       241.0        241          F25      IND
# 242      243       242.0        242          F26      IND
# 243      244       243.0        243          F27      IND
# 244      245       244.0        244          F29      IND
# 245      246       245.0        245          F30      IND
# 246      247       246.0        246          F31      IND
# 247      248       247.0        247          F32      IND
# 248      249       248.0        248          F33      IND
# 249      250       249.0        249          F34      IND
# 250      251       250.0        250          F35      IND
# 251      252       251.0        251          F36      IND
# 252      253       252.0        252          F38      IND
# 253      254       253.0        253          F39      IND
# 254      255       254.0        254          F01      IND
# 255      256       255.0        255          F02      IND
# 256      257       256.0        256          F03      IND
# 257      258       257.0        257          F04      IND
# 258      259       258.0        258          F05      IND
# 259      260       259.0        259          F06      IND
# 260      261       260.0        260          F07      IND
# 261      262       261.0        261          G08      IND
# 262      263       262.0        262          G09      IND
# 263      264       263.0        263          G10      IND
# 264      265       264.0        264          G11      IND
# 265      266       265.0        265          G12      IND
# 266      267       266.0        266          G13      IND
# 267      268       267.0        616          G14      IND
# 268      269       268.0        268          G15      IND
# 269      270       269.0        269          G16      IND
# 270      271       270.0        270          G18      IND
# 271      272       271.0        271          G19      IND
# 272      273       272.0        272          G20      IND
# 273      274       273.0        273          G21      IND
# 274      275       274.0        606          F09      IND
# 275      276       275.0        612          F11      IND
# 276      277       276.0        276          F12      IND
# 277      278       277.0        277          D14      IND
# 278      279       278.0        278          G05      IND
# 279      280       279.0        279          G06      IND
# 280      281       280.0        280          G07      IND
# 281      282       281.0        606          G22      IND
# 282      283       282.0        282          G24      IND
# 283      284       283.0        283          G26      IND
# 284      285       284.0        284          G28      IND
# 285      286       285.0        629          G29      IND
# 286      287       286.0        286          G30      IND
# 287      288       287.0        287          G31      IND
# 288      289       288.0        288          G32      IND
# 289      290       289.0        289          G33      IND
# 290      291       290.0        290          G34      IND
# 291      292       291.0        291          G35      IND
# 292      293       292.0        292          G36      IND
# 293      294       293.0        293          101      IRT
# 294      295       294.0        294          103      IRT
# 295      296       295.0        295          104      IRT
# 296      297       296.0        296          106      IRT
# 297      298       297.0        297          107      IRT
# 298      299       298.0        298          108      IRT
# 299      300       299.0        299          109      IRT
# 300      301       300.0        300          110      IRT
# 301      302       301.0        301          111      IRT
# 302      303       302.0        605          112      IRT
# 303      304       303.0        303          113      IRT
# 304      305       304.0        304          114      IRT
# 305      306       305.0        305          115      IRT
# 306      307       306.0        306          116      IRT
# 307      308       307.0        307          117      IRT
# 308      309       308.0        308          118      IRT
# 309      310       309.0        309          119      IRT
# 310      311       310.0        310          120      IRT
# 311      312       311.0        311          121      IRT
# 312      313       312.0        312          122      IRT
# 313      314       313.0        313          123      IRT
# 314      315       314.0        314          124      IRT
# 315      316       315.0        614          125      IRT
# 316      317       316.0        316          126      IRT
# 317      318       317.0        611          127      IRT
# 318      319       318.0        318          128      IRT
# 319      320       319.0        319          129      IRT
# 320      321       320.0        320          130      IRT
# 321      322       321.0        321          131      IRT
# 322      323       322.0        601          132      IRT
# 323      324       323.0        323          133      IRT
# 324      325       324.0        324          134      IRT
# 325      326       325.0        325          135      IRT
# 326      327       326.0        326          136      IRT
# 327      328       327.0        327          137      IRT
# 328      329       328.0        328          138      IRT
# 329      330       329.0        329          139      IRT
# 330      331       330.0        635          142      IRT
# 331      332       331.0        624          228      IRT
# 332      333       332.0        628          229      IRT
# 333      334       333.0        333          230      IRT
# 334      335       334.0        334          231      IRT
# 335      336       335.0        620          232      IRT
# 336      337       336.0        336          233      IRT
# 337      338       337.0        337          234      IRT
# 338      339       338.0        617          235      IRT
# 339      340       339.0        339          236      IRT
# 340      341       340.0        340          237      IRT
# 341      342       341.0        341          238      IRT
# 342      343       342.0        626          239      IRT
# 343      344       343.0        343          248      IRT
# 344      345       344.0        344          249      IRT
# 345      346       345.0        345          250      IRT
# 346      347       346.0        346          251      IRT
# 347      348       347.0        347          252      IRT
# 348      349       348.0        348          253      IRT
# 349      350       349.0        349          254      IRT
# 350      351       350.0        350          255      IRT
# 351      352       351.0        351          256      IRT
# 352      353       352.0        352          257      IRT
# 353      354       353.0        353          241      IRT
# 354      355       354.0        354          242      IRT
# 355      356       355.0        355          243      IRT
# 356      357       356.0        356          244      IRT
# 357      358       357.0        357          245      IRT
# 358      359       358.0        358          246      IRT
# 359      360       359.0        359          247      IRT
# 360      361       360.0        360          601      IRT
# 361      362       361.0        361          602      IRT
# 362      363       362.0        362          603      IRT
# 363      364       363.0        363          604      IRT
# 364      365       364.0        364          606      IRT
# 365      366       365.0        365          607      IRT
# 366      367       366.0        366          608      IRT
# 367      368       367.0        367          609      IRT
# 368      369       368.0        368          610      IRT
# 369      370       369.0        369          611      IRT
# 370      371       370.0        370          612      IRT
# 371      372       371.0        371          613      IRT
# 372      373       372.0        372          614      IRT
# 373      374       373.0        373          615      IRT
# 374      375       374.0        374          616      IRT
# 375      376       375.0        375          617      IRT
# 376      377       376.0        376          618      IRT
# 377      378       377.0        377          619      IRT
# 378      379       378.0        378          401      IRT
# 379      380       379.0        379          402      IRT
# 380      381       380.0        380          405      IRT
# 381      382       381.0        381          406      IRT
# 382      383       382.0        382          407      IRT
# 383      384       383.0        383          408      IRT
# 384      385       384.0        384          409      IRT
# 385      386       385.0        385          410      IRT
# 386      387       386.0        386          411      IRT
# 387      388       387.0        387          412      IRT
# 388      389       388.0        388          413      IRT
# 389      390       389.0        604          414      IRT
# 390      391       390.0        603          415      IRT
# 391      392       391.0        391          416      IRT
# 392      393       392.0        392          621      IRT
# 393      394       393.0        393          622      IRT
# 394      395       394.0        394          623      IRT
# 395      396       395.0        395          624      IRT
# 396      397       396.0        396          625      IRT
# 397      398       397.0        397          626      IRT
# 398      399       398.0        398          627      IRT
# 399      400       399.0        399          628      IRT
# 400      401       400.0        613          629      IRT
# 401      402       401.0        612          630      IRT
# 402      403       402.0        610          631      IRT
# 403      404       403.0        403          632      IRT
# 404      405       404.0        404          633      IRT
# 405      406       405.0        405          634      IRT
# 406      407       406.0        602          635      IRT
# 407      408       407.0        407          636      IRT
# 408      409       408.0        619          637      IRT
# 409      410       409.0        409          638      IRT
# 410      411       410.0        623          639      IRT
# 411      412       411.0        622          640      IRT
# 412      413       412.0        628          418      IRT
# 413      414       413.0        413          419      IRT
# 414      415       414.0        414          420      IRT
# 415      416       415.0        620          423      IRT
# 416      417       416.0        416          201      IRT
# 417      418       417.0        417          204      IRT
# 418      419       418.0        418          205      IRT
# 419      420       419.0        419          206      IRT
# 420      421       420.0        420          207      IRT
# 421      422       421.0        421          208      IRT
# 422      423       422.0        422          209      IRT
# 423      424       423.0        423          210      IRT
# 424      425       424.0        424          211      IRT
# 425      426       425.0        425          212      IRT
# 426      427       426.0        426          213      IRT
# 427      428       427.0        427          214      IRT
# 428      429       428.0        428          215      IRT
# 429      430       429.0        429          216      IRT
# 430      431       430.0        430          217      IRT
# 431      432       431.0        431          218      IRT
# 432      433       432.0        432          219      IRT
# 433      434       433.0        433          220      IRT
# 434      435       434.0        434          221      IRT
# 435      436       435.0        603          222      IRT
# 436      437       436.0        436          301      IRT
# 437      438       437.0        437          302      IRT
# 438      439       438.0        438          224      IRT
# 439      440       439.0        439          225      IRT
# 440      441       440.0        440          226      IRT
# 441      442       441.0        441          227      IRT
# 442      443       442.0        442          501      IRT
# 443      444       443.0        443          502      IRT
# 444      445       444.0        444          503      IRT
# 445      446       445.0        445          504      IRT
# 446      447       446.0        446          505      IRT
# 447      448       447.0        447          701      IRT
# 448      449       448.0        448          702      IRT
# 449      450       449.0        449          705      IRT
# 450      451       450.0        450          706      IRT
# 451      452       451.0        451          707      IRT
# 452      453       452.0        452          708      IRT
# 453      454       453.0        453          709      IRT
# 454      455       454.0        616          710      IRT
# 455      456       455.0        455          711      IRT
# 456      457       456.0        456          712      IRT
# 457      458       457.0        457          713      IRT
# 458      459       458.0        458          714      IRT
# 459      460       459.0        459          715      IRT
# 460      461       460.0        460          716      IRT
# 461      462       461.0        461          718      IRT
# 462      463       461.0        461          R09      BMT
# 463      464       462.0        606          719      IRT
# 464      465       463.0        463          720      IRT
# 465      466       464.0        464          721      IRT
# 466      467       465.0        610          723      IRT
# 467      468       466.0        609          724      IRT
# 468      469       467.0        611          725      IRT
# 469      470       468.0        611          902      IRT
# 470      471       469.0        610          901      IRT
# 471      472       471.0        471          726      IRT
# 472      473       475.0        475          Q05      IND
# 473      474       476.0        476          Q04      IND
# 474      475       477.0        477          Q03      IND
# 475      497         NaN       R468          NaN      RIT
# 476      498         NaN       R469          NaN      RIT
# 477      499         NaN       R540          NaN      PTH
# 478      500         NaN       R541          NaN      PTH
# 479      501         NaN       R542          NaN      PTH
# 480      502         NaN       R543          NaN      PTH
# 481      503         NaN       R544          NaN      PTH
# 482      504         NaN       R545          NaN      PTH
# 483      505         NaN       R546          NaN      PTH
# 484      506         NaN       R547          NaN      PTH
# 485      507         NaN       R548          NaN      PTH
# 486      508         NaN       R549          NaN      PTH
# 487      509         NaN       R550          NaN      PTH
# 488      510         NaN       R551          NaN      PTH
# 489      511         NaN       R552          NaN      PTH
#
#                                          line  \
# 0                                     Astoria
# 1                                     Astoria
# 2                                     Astoria
# 3                                     Astoria
# 4                                     Astoria
# 5                                     Astoria
# 6                                     Astoria
# 7                                     Astoria
# 8                         Broadway - Brighton
# 9                         Broadway - Brighton
# 10                        Broadway - Brighton
# 11                        Broadway - Brighton
# 12                        Broadway - Brighton
# 13                        Broadway - Brighton
# 14                        Broadway - Brighton
# 15                        Broadway - Brighton
# 16                        Broadway - Brighton
# 17                                   Broadway
# 18                           Manhattan Bridge
# 19                                   Broadway
# 20                                   Broadway
# 21                                   Broadway
# 22                                   Broadway
# 23                                   Broadway
# 24                                   Broadway
# 25                        Broadway - Brighton
# 26                                     4th Av
# 27                                     4th Av
# 28                                     4th Av
# 29                                     4th Av
# 30                                     4th Av
# 31                                     4th Av
# 32                                     4th Av
# 33                                     4th Av
# 34                                     4th Av
# 35                                     4th Av
# 36                                     4th Av
# 37                                     4th Av
# 38                                     4th Av
# 39                        Broadway - Brighton
# 40                        Broadway - Brighton
# 41                        Broadway - Brighton
# 42                        Broadway - Brighton
# 43                        Broadway - Brighton
# 44                        Broadway - Brighton
# 45                        Broadway - Brighton
# 46                        Broadway - Brighton
# 47                        Broadway - Brighton
# 48                        Broadway - Brighton
# 49                        Broadway - Brighton
# 50                        Broadway - Brighton
# 51                        Broadway - Brighton
# 52                        Broadway - Brighton
# 53                        Broadway - Brighton
# 54                        Broadway - Brighton
# 55                        Broadway - Brighton
# 56                        Broadway - Brighton
# 57   Sea Beach / West End / Culver / Brighton
# 58                                   West End
# 59                                   West End
# 60                                   West End
# 61                                   West End
# 62                                   West End
# 63                                   West End
# 64                                   West End
# 65                                   West End
# 66                                   West End
# 67                                   West End
# 68                                   West End
# 69                                   West End
# 70                                  Sea Beach
# 71                                  Sea Beach
# 72                                  Sea Beach
# 73                                  Sea Beach
# 74                                  Sea Beach
# 75                                  Sea Beach
# 76                                  Sea Beach
# 77                                  Sea Beach
# 78                                  Sea Beach
# 79                                    Jamaica
# 80                                    Jamaica
# 81                                    Jamaica
# 82                                    Jamaica
# 83                                    Jamaica
# 84                                    Jamaica
# 85                                    Jamaica
# 86                                    Jamaica
# 87                                    Jamaica
# 88                                    Jamaica
# 89                                    Jamaica
# 90                                    Jamaica
# 91                                    Jamaica
# 92                                    Jamaica
# 93                                    Jamaica
# 94                                    Jamaica
# 95                                    Jamaica
# 96                                    Jamaica
# 97                                    Jamaica
# 98                                    Jamaica
# 99                                    Jamaica
# 100                                   Jamaica
# 101                                   Jamaica
# 102                                   Jamaica
# 103                                   Jamaica
# 104                                   Jamaica
# 105                                   Jamaica
# 106                                   Jamaica
# 107                                 Myrtle Av
# 108                                 Myrtle Av
# 109                                 Myrtle Av
# 110                                 Myrtle Av
# 111                                 Myrtle Av
# 112                                 Myrtle Av
# 113                                 Myrtle Av
# 114                                  Canarsie
# 115                                  Canarsie
# 116                                  Canarsie
# 117                                  Canarsie
# 118                                  Canarsie
# 119                                  Canarsie
# 120                                  Canarsie
# 121                                  Canarsie
# 122                                  Canarsie
# 123                                  Canarsie
# 124                                  Canarsie
# 125                                  Canarsie
# 126                                  Canarsie
# 127                                  Canarsie
# 128                                  Canarsie
# 129                                  Canarsie
# 130                                  Canarsie
# 131                                  Canarsie
# 132                                  Canarsie
# 133                                  Canarsie
# 134                                  Canarsie
# 135                                  Canarsie
# 136                                  Canarsie
# 137                                  Canarsie
# 138                          Franklin Shuttle
# 139                          Franklin Shuttle
# 140                          Franklin Shuttle
# 141                        8th Av - Fulton St
# 142                        8th Av - Fulton St
# 143                        8th Av - Fulton St
# 144                        8th Av - Fulton St
# 145                        8th Av - Fulton St
# 146                        8th Av - Fulton St
# 147                        8th Av - Fulton St
# 148                        8th Av - Fulton St
# 149                        8th Av - Fulton St
# 150                                 Concourse
# 151                        8th Av - Fulton St
# 152                        8th Av - Fulton St
# 153                        8th Av - Fulton St
# 154                        8th Av - Fulton St
# 155                        8th Av - Fulton St
# 156                        8th Av - Fulton St
# 157                        8th Av - Fulton St
# 158                        8th Av - Fulton St
# 159                        8th Av - Fulton St
# 160                        8th Av - Fulton St
# 161                        8th Av - Fulton St
# 162                        8th Av - Fulton St
# 163                        8th Av - Fulton St
# 164                        8th Av - Fulton St
# 165                        8th Av - Fulton St
# 166                        8th Av - Fulton St
# 167                           6th Av - Culver
# 168                        8th Av - Fulton St
# 169                        8th Av - Fulton St
# 170                        8th Av - Fulton St
# 171                        8th Av - Fulton St
# 172                        8th Av - Fulton St
# 173                        8th Av - Fulton St
# 174                        8th Av - Fulton St
# 175                        8th Av - Fulton St
# 176                        8th Av - Fulton St
# 177                        8th Av - Fulton St
# 178                        8th Av - Fulton St
# 179                        8th Av - Fulton St
# 180                        8th Av - Fulton St
# 181                        8th Av - Fulton St
# 182                        8th Av - Fulton St
# 183                        8th Av - Fulton St
# 184                        8th Av - Fulton St
# 185                        8th Av - Fulton St
# 186                        8th Av - Fulton St
# 187                        8th Av - Fulton St
# 188                        8th Av - Fulton St
# 189                                Liberty Av
# 190                                Liberty Av
# 191                                Liberty Av
# 192                                Liberty Av
# 193                                Liberty Av
# 194                                Liberty Av
# 195                                Liberty Av
# 196                                  Rockaway
# 197                                  Rockaway
# 198                                  Rockaway
# 199                                  Rockaway
# 200                                  Rockaway
# 201                                  Rockaway
# 202                                  Rockaway
# 203                                  Rockaway
# 204                                  Rockaway
# 205                                  Rockaway
# 206                                  Rockaway
# 207                                  Rockaway
# 208                                  Rockaway
# 209                                  Rockaway
# 210                                 Concourse
# 211                                 Concourse
# 212                                 Concourse
# 213                                 Concourse
# 214                                 Concourse
# 215                                 Concourse
# 216                                 Concourse
# 217                                 Concourse
# 218                                 Concourse
# 219                                 Concourse
# 220                                 Concourse
# 221                                   63rd St
# 222                                   63rd St
# 223                                   63rd St
# 224                           6th Av - Culver
# 225                           6th Av - Culver
# 226                           6th Av - Culver
# 227                           6th Av - Culver
# 228                           6th Av - Culver
# 229                           6th Av - Culver
# 230                           6th Av - Culver
# 231                           6th Av - Culver
# 232                           6th Av - Culver
# 233                           6th Av - Culver
# 234                           6th Av - Culver
# 235                           6th Av - Culver
# 236                           6th Av - Culver
# 237                           6th Av - Culver
# 238                           6th Av - Culver
# 239                           6th Av - Culver
# 240                           6th Av - Culver
# 241                           6th Av - Culver
# 242                           6th Av - Culver
# 243                           6th Av - Culver
# 244                           6th Av - Culver
# 245                           6th Av - Culver
# 246                           6th Av - Culver
# 247                           6th Av - Culver
# 248                           6th Av - Culver
# 249                           6th Av - Culver
# 250                           6th Av - Culver
# 251                           6th Av - Culver
# 252                           6th Av - Culver
# 253                           6th Av - Culver
# 254                               Queens Blvd
# 255                               Queens Blvd
# 256                               Queens Blvd
# 257                               Queens Blvd
# 258                               Queens Blvd
# 259                               Queens Blvd
# 260                               Queens Blvd
# 261                               Queens Blvd
# 262                               Queens Blvd
# 263                               Queens Blvd
# 264                               Queens Blvd
# 265                               Queens Blvd
# 266                               Queens Blvd
# 267                               Queens Blvd
# 268                               Queens Blvd
# 269                               Queens Blvd
# 270                               Queens Blvd
# 271                               Queens Blvd
# 272                               Queens Blvd
# 273                               Queens Blvd
# 274                               Queens Blvd
# 275                               Queens Blvd
# 276                               Queens Blvd
# 277                               Queens Blvd
# 278                           Queens - Archer
# 279                           Queens - Archer
# 280                           Queens - Archer
# 281                                 Crosstown
# 282                                 Crosstown
# 283                                 Crosstown
# 284                                 Crosstown
# 285                                 Crosstown
# 286                                 Crosstown
# 287                                 Crosstown
# 288                                 Crosstown
# 289                                 Crosstown
# 290                                 Crosstown
# 291                                 Crosstown
# 292                                 Crosstown
# 293                            Broadway - 7Av
# 294                            Broadway - 7Av
# 295                            Broadway - 7Av
# 296                            Broadway - 7Av
# 297                            Broadway - 7Av
# 298                            Broadway - 7Av
# 299                            Broadway - 7Av
# 300                            Broadway - 7Av
# 301                            Broadway - 7Av
# 302                            Broadway - 7Av
# 303                            Broadway - 7Av
# 304                            Broadway - 7Av
# 305                            Broadway - 7Av
# 306                            Broadway - 7Av
# 307                            Broadway - 7Av
# 308                            Broadway - 7Av
# 309                            Broadway - 7Av
# 310                            Broadway - 7Av
# 311                            Broadway - 7Av
# 312                            Broadway - 7Av
# 313                            Broadway - 7Av
# 314                            Broadway - 7Av
# 315                            Broadway - 7Av
# 316                            Broadway - 7Av
# 317                            Broadway - 7Av
# 318                            Broadway - 7Av
# 319                            Broadway - 7Av
# 320                            Broadway - 7Av
# 321                            Broadway - 7Av
# 322                            Broadway - 7Av
# 323                            Broadway - 7Av
# 324                            Broadway - 7Av
# 325                            Broadway - 7Av
# 326                            Broadway - 7Av
# 327                            Broadway - 7Av
# 328                            Broadway - 7Av
# 329                            Broadway - 7Av
# 330                            Broadway - 7Av
# 331                                  Clark St
# 332                                  Clark St
# 333                                  Clark St
# 334                                  Clark St
# 335                                  Clark St
# 336                               Eastern Pky
# 337                               Eastern Pky
# 338                               Eastern Pky
# 339                               Eastern Pky
# 340                               Eastern Pky
# 341                               Eastern Pky
# 342                               Eastern Pky
# 343                               Eastern Pky
# 344                               Eastern Pky
# 345                               Eastern Pky
# 346                               Eastern Pky
# 347                               Eastern Pky
# 348                               Eastern Pky
# 349                               Eastern Pky
# 350                               Eastern Pky
# 351                               Eastern Pky
# 352                               Eastern Pky
# 353                                  Nostrand
# 354                                  Nostrand
# 355                                  Nostrand
# 356                                  Nostrand
# 357                                  Nostrand
# 358                                  Nostrand
# 359                                  Nostrand
# 360                                    Pelham
# 361                                    Pelham
# 362                                    Pelham
# 363                                    Pelham
# 364                                    Pelham
# 365                                    Pelham
# 366                                    Pelham
# ...
# 183                                     Euclid Av
# 184                 Euclid - Lefferts - Rockaways
# 185                                     Euclid Av
# 186                                     Euclid Av
# 187                                     Euclid Av
# 188                          Lefferts - Rockaways
# 189                          Lefferts - Rockaways
# 190                          Lefferts - Rockaways
# 191                          Lefferts - Rockaways
# 192                          Lefferts - Rockaways
# 193                                 Lefferts Blvd
# 194                                 Lefferts Blvd
# 195                                           NaN
# 196                                     Rockaways
# 197                                     Rockaways
# 198                                     Rockaways
# 199                                     Rockaways
# 200                                 Rockaway Park
# 201                                 Rockaway Park
# 202                                 Rockaway Park
# 203                                           NaN
# 204                                  Far Rockaway
# 205                                  Far Rockaway
# 206                                  Far Rockaway
# 207                                  Far Rockaway
# 208                                  Far Rockaway
# 209                                           NaN
# 210                                     Manhattan
# 211                                     Manhattan
# 212                                     Manhattan
# 213                                     Manhattan
# 214                                     Manhattan
# 215                                     Manhattan
# 216                                     Manhattan
# 217                                     Manhattan
# 218                                     Manhattan
# 219                                     Manhattan
# 220                           Downtown & Brooklyn
# 221                                     Manhattan
# 222                                     Manhattan
# 223                           Downtown & Brooklyn
# 224                           Downtown & Brooklyn
# 225                           Downtown & Brooklyn
# 226                           Downtown & Brooklyn
# 227                           Downtown & Brooklyn
# 228                           Downtown & Brooklyn
# 229                           Downtown & Brooklyn
# 230                           Downtown & Brooklyn
# 231                                      Brooklyn
# 232                           Downtown & Brooklyn
# 233                           Downtown & Brooklyn
# 234                                      Brooklyn
# 235                                  Coney Island
# 236                      Church Av - Coney Island
# 237                      Church Av - Coney Island
# 238                      Church Av - Coney Island
# 239                      Church Av - Coney Island
# 240                      Church Av - Coney Island
# 241                      Church Av - Coney Island
# 242                      Church Av - Coney Island
# 243                                  Coney Island
# 244                                  Coney Island
# 245                                  Coney Island
# 246                                  Coney Island
# 247                                  Coney Island
# 248                                  Coney Island
# 249                                  Coney Island
# 250                                  Coney Island
# 251                                  Coney Island
# 252                                  Coney Island
# 253                                  Stillwell Av
# 254                                     Manhattan
# 255                                     Manhattan
# 256                                     Manhattan
# 257                                     Manhattan
# 258                                     Manhattan
# 259                                     Manhattan
# 260                                     Manhattan
# 261                                     Manhattan
# 262                                     Manhattan
# 263                                     Manhattan
# 264                                     Manhattan
# 265                                     Manhattan
# 266                                     Manhattan
# 267                                     Manhattan
# 268                                     Manhattan
# 269                                     Manhattan
# 270                                     Manhattan
# 271                                     Manhattan
# 272                                     Manhattan
# 273                                     Manhattan
# 274                                     Manhattan
# 275                           Downtown & Brooklyn
# 276                           Downtown & Brooklyn
# 277                           Downtown & Brooklyn
# 278                                     Manhattan
# 279                                     Manhattan
# 280                                     Manhattan
# 281                                      Brooklyn
# 282                                      Brooklyn
# 283                                     Church Av
# 284                                     Church Av
# 285                                     Church Av
# 286                                     Church Av
# 287                                     Church Av
# 288                                     Church Av
# 289                                     Church Av
# 290                                     Church Av
# 291                                     Church Av
# 292                                     Church Av
# 293                                     Manhattan
# 294                                     Manhattan
# 295                                     Manhattan
# 296                                      Downtown
# 297                                      Downtown
# 298                                      Downtown
# 299                                      Downtown
# 300                                      Downtown
# 301                                      Downtown
# 302                                      Downtown
# 303                                      Downtown
# 304                                      Downtown
# 305                                      Downtown
# 306                                      Downtown
# 307                                      Downtown
# 308                                      Downtown
# 309                                      Downtown
# 310                           Downtown & Brooklyn
# 311                                      Downtown
# 312                                      Downtown
# 313                           Downtown & Brooklyn
# 314                                      Downtown
# 315                                      Downtown
# 316                                      Downtown
# 317                           Downtown & Brooklyn
# 318                           Downtown & Brooklyn
# 319                                      Downtown
# 320                                      Downtown
# 321                                      Downtown
# 322                           Downtown & Brooklyn
# 323                                      Downtown
# 324                                      Downtown
# 325                                      Downtown
# 326                                      Downtown
# 327                           Downtown & Brooklyn
# 328                                      Downtown
# 329                                      Downtown
# 330                                           NaN
# 331                           Downtown & Brooklyn
# 332                           Downtown & Brooklyn
# 333                                      Brooklyn
# 334                           Flatbush - New Lots
# 335                           Flatbush - New Lots
# 336                           Flatbush - New Lots
# 337                   Flatbush - Utica - New Lots
# 338                           Flatbush - New Lots
# 339                           Flatbush - New Lots
# 340                           Flatbush - New Lots
# 341                           Flatbush - New Lots
# 342                   Flatbush - Utica - New Lots
# 343                                      New Lots
# 344                                      New Lots
# 345                                      New Lots
# 346                                      New Lots
# 347                                      New Lots
# 348                                      New Lots
# 349                                      New Lots
# 350                                      New Lots
# 351                                      New Lots
# 352                                           NaN
# 353                                      Flatbush
# 354                                      Flatbush
# 355                                      Flatbush
# 356                                      Flatbush
# 357                                      Flatbush
# 358                                      Flatbush
# 359                                           NaN
# 360                                     Manhattan
# 361                                     Manhattan
# 362                                     Manhattan
# 363                                     Manhattan
# 364                                     Manhattan
# 365                                     Manhattan
# 366                                     Manhattan
# 367                                     Manhattan
# 368                                     Manhattan
# 369                                     Manhattan
# 370                                     Manhattan
# 371                                     Manhattan
# 372                                     Manhattan
# 373                                     Manhattan
# 374                                     Manhattan
# 375                                     Manhattan
# 376                                     Manhattan
# 377                                     Manhattan
# 378                                     Manhattan
# 379                                     Manhattan
# 380                                     Manhattan
# 381                                     Manhattan
# 382                                     Manhattan
# 383                                     Manhattan
# 384                                     Manhattan
# 385                                     Manhattan
# 386                                     Manhattan
# 387                                     Manhattan
# 388                                     Manhattan
# 389                                     Manhattan
# 390                                     Manhattan
# 391                                     Manhattan
# 392                           Downtown & Brooklyn
# 393                                      Downtown
# 394                                      Downtown
# 395                                      Downtown
# 396                                      Downtown
# 397                           Downtown & Brooklyn
# 398                                      Downtown
# 399                                      Downtown
# 400                           Downtown & Brooklyn
# 401                                      Downtown
# 402                           Downtown & Brooklyn
# 403                                      Downtown
# 404                                      Downtown
# 405                                      Downtown
# 406                           Downtown & Brooklyn
# 407                                      Downtown
# 408                                      Downtown
# 409                                      Downtown
# 410                                      Downtown
# 411                           Downtown & Brooklyn
# 412                           Downtown & Brooklyn
# 413                           Downtown & Brooklyn
# 414                                      Brooklyn
# 415                              Flatbush - Utica
# 416                                     Manhattan
# 417                                     Manhattan
# 418                                     Manhattan
# 419                                     Manhattan
# 420                                     Manhattan
# 421                                     Manhattan
# 422                                     Manhattan
# 423                                     Manhattan
# 424                                     Manhattan
# 425                                     Manhattan
# 426                                     Manhattan
# 427                                     Manhattan
# 428                                     Manhattan
# 429                                     Manhattan
# 430                                     Manhattan
# 431                                     Manhattan
# 432                                     Manhattan
# 433                                     Manhattan
# 434                                     Manhattan
# 435                                     Manhattan
# 436                           Downtown & Brooklyn
# 437                           Downtown & Brooklyn
# 438                           Downtown & Brooklyn
# 439                           Downtown & Brooklyn
# 440                           Downtown & Brooklyn
# 441                           Downtown & Brooklyn
# 442                                     Manhattan
# 443                                     Manhattan
# 444                                     Manhattan
# 445                                     Manhattan
# 446                                     Manhattan
# 447                                     Manhattan
# 448                                     Manhattan
# 449                                     Manhattan
# 450                                     Manhattan
# 451                                     Manhattan
# 452                                     Manhattan
# 453                                     Manhattan
# 454                                     Manhattan
# 455                                     Manhattan
# 456                                     Manhattan
# 457                                     Manhattan
# 458                                     Manhattan
# 459                                     Manhattan
# 460                                     Manhattan
# 461                                     Manhattan
# 462                                     Manhattan
# 463                                     Manhattan
# 464                                     Manhattan
# 465                                     Manhattan
# 466                          34 St - Hudson Yards
# 467                          34 St - Hudson Yards
# 468                          34 St - Hudson Yards
# 469                                 Grand Central
# 470                                           NaN
# 471                                           NaN
# 472                           Downtown & Brooklyn
# 473                           Downtown & Brooklyn
# 474                           Downtown & Brooklyn
# 475                                           NaN
# 476                                           NaN
# 477                                           NaN
# 478                                           NaN
# 479                                           NaN
# 480                                           NaN
# 481                                           NaN
# 482                                           NaN
# 483                                           NaN
# 484                                           NaN
# 485                                           NaN
# 486                                           NaN
# 487                                           NaN
# 488                                           NaN
# 489                                           NaN

# %%
# Let's drop some unnecessary columns from station_locations

station_locations = station_locations[['complex_id', 'division', 'line', 'stop_name', 
                                       'borough', 'gtfs_latitude', 'gtfs_longitude']]
station_locations.head()
# Out:
#   complex_id division     line               stop_name borough  gtfs_latitude  \
# 0          1      BMT  Astoria  Astoria - Ditmars Blvd       Q      40.775036
# 1          2      BMT  Astoria            Astoria Blvd       Q      40.770258
# 2          3      BMT  Astoria                   30 Av       Q      40.766779
# 3          4      BMT  Astoria                Broadway       Q      40.761820
# 4          5      BMT  Astoria                   36 Av       Q      40.756804
#
#    gtfs_longitude
# 0      -73.912034
# 1      -73.917843
# 2      -73.921479
# 3      -73.925508
# 4      -73.929575

# %% [markdown]
# #### Now merge complex_list with station_locations

# %%
station_locations['complex_id'].dtype
# Out:
# dtype('O')

# %%
# Need to convert 'complex_id' in complex_list to same format

print(complex_list['complex_id'].dtype)

complex_list['complex_id'] = complex_list['complex_id'].apply(lambda x: str(x).replace('.0','')).astype('str')
print(complex_list['complex_id'].dtype)
# Out:
# float64
# object

# %%
print(complex_list.shape)
complex_locations = complex_list.merge(right=station_locations, 
                                       how='inner', 
                                       on=['complex_id', 'division'])
# Out:
# (770, 6)

# %%
print(complex_locations.shape)

# Check for NaNs
print(complex_locations[complex_locations.isna().any(axis=1)].shape)

complex_locations.sample(10)
# Out:
# (809, 11)
# (0, 11)
#     remote booth complex_id          station    line_name division  \
# 454   R205  R261        603   149 ST-GR CONC          245      IRT
# 108   R035  N012        605  168 ST-BROADWAY          1AC      IND
# 558   R276  R504        464   VERNON/JACKSON            7      IRT
# 97    R033  R150        611   42 ST-TIMES SQ  1237ACENQRS      IRT
# 516   R249  H014        122       GRAHAM AVE            L      BMT
# 512   R454  C015         30     PROSPECT AVE            R      BMT
# 344   R154  N213        215      TREMONT AVE           BD      IND
# 273   R113  N300        277      7 AVE-53 ST          BDE      IND
# 438   R198  N116        179     NOSTRAND AVE           AC      IND
# 136   R046  R237        610  42 ST-GRD CNTRL        4567S      IRT
#
#                    line                 stop_name borough  gtfs_latitude  \
# 454           Jerome Av  149 St - Grand Concourse      Bx      40.818375
# 108  8th Av - Fulton St                    168 St       M      40.840719
# 558            Flushing  Vernon Blvd - Jackson Av       Q      40.742626
# 97             Flushing          Times Sq - 42 St       M      40.755477
# 516            Canarsie                 Graham Av      Bk      40.714565
# 512              4th Av               Prospect Av      Bk      40.665414
# 344           Concourse                Tremont Av      Bx      40.850410
# 273         Queens Blvd                      7 Av       M      40.762862
# 438  8th Av - Fulton St               Nostrand Av      Bk      40.680438
# 136            Flushing     Grand Central - 42 St       M      40.751431
#
#      gtfs_longitude
# 454      -73.927351
# 108      -73.939561
# 558      -73.953581
# 97       -73.987691
# 516      -73.944053
# 512      -73.992872
# 344      -73.905227
# 273      -73.981637
# 438      -73.950426
# 136      -73.976041

# %% [markdown]
# #### Now we can merge complex_locations with the daily_per_turnstile datasets for 2019 & 2021

# %%
complex_locations.columns = [col.upper() for col in complex_locations.columns]
complex_locations.head()
# Out:
#   REMOTE  BOOTH COMPLEX_ID       STATION LINE_NAME DIVISION            LINE  \
# 0   R001   A060        635  WHITEHALL ST        R1      BMT        Broadway
# 1   R001   A058        635  WHITEHALL ST        R1      BMT        Broadway
# 2   R001  R101S        635   SOUTH FERRY        R1      IRT  Broadway - 7Av
# 3   R002   A077        628     FULTON ST  ACJZ2345      BMT         Jamaica
# 4   R002   A081        628     FULTON ST  ACJZ2345      BMT         Jamaica
#
#       STOP_NAME BOROUGH  GTFS_LATITUDE  GTFS_LONGITUDE
# 0  Whitehall St       M      40.703087      -74.012994
# 1  Whitehall St       M      40.703087      -74.012994
# 2   South Ferry       M      40.702068      -74.013664
# 3     Fulton St       M      40.710374      -74.007582
# 4     Fulton St       M      40.710374      -74.007582

# %%
# Drop unnecessary column
daily_per_turnstile_2019.drop(columns=['DATETIME'], inplace=True)

# Get consistent column names between the two dataframes to be merged

daily_per_turnstile_2019.columns = ['ID', 'DATE', 'BOOTH', 'REMOTE', 'SCP', 'STATION', 
                                    'LINE_NAME', 'DIVISION', 'DESC', 'NET_DAILY_ENTRIES', 'WEEKDAY']
daily_per_turnstile_2019.head()
# Out:
#                        ID        DATE BOOTH REMOTE       SCP STATION  \
# 0  A002 - R051 - 02-00-00  2019-05-01  A002   R051  02-00-00   59 ST
# 1  A002 - R051 - 02-00-00  2019-05-02  A002   R051  02-00-00   59 ST
# 2  A002 - R051 - 02-00-00  2019-05-03  A002   R051  02-00-00   59 ST
# 3  A002 - R051 - 02-00-00  2019-05-04  A002   R051  02-00-00   59 ST
# 4  A002 - R051 - 02-00-00  2019-05-05  A002   R051  02-00-00   59 ST
#
#   LINE_NAME DIVISION     DESC  NET_DAILY_ENTRIES  WEEKDAY
# 0   NQR456W      BMT  REGULAR               1346        1
# 1   NQR456W      BMT  REGULAR               1327        1
# 2   NQR456W      BMT  REGULAR               1326        1
# 3   NQR456W      BMT  REGULAR                560        0
# 4   NQR456W      BMT  REGULAR                449        0

# %%
daily_per_turnstile_loc_2019 = complex_locations.merge(right=daily_per_turnstile_2019, 
                                                       how='inner',
                                                       on=['BOOTH', 'REMOTE', 'DIVISION'])

# %%
# Didn't even lose 3000 rows here - pretty good!

print(daily_per_turnstile_2019.shape)
daily_per_turnstile_loc_2019.shape
# Out:
# (293325, 11)
# (290643, 19)

# %%
# Check for NaNs

daily_per_turnstile_loc_2019[daily_per_turnstile_loc_2019.isna().any(axis=1)].shape[0]
# Out:
# 0

# %%
# STATION_x and STATION_y seem to match up well! (LINE_NAME_x and LINE_NAME_y, too!)

daily_per_turnstile_loc_2019.sample(n=20)
# Out:
#        REMOTE  BOOTH COMPLEX_ID        STATION_x LINE_NAME_x DIVISION  \
# 11440    R014   R208        628        FULTON ST    2345ACJZ      IRT
# 139829   R141   N333        261  FOREST HILLS-71        EFMR      IND
# 76055    R057   C009        617       PACIFIC ST   BDNQR2345      BMT
# 17455    R018   R525        616   74 ST-BROADWAY       EFMR7      IRT
# 134024   R137   H027        630       MYRTLE AVE          LM      BMT
# 151237   R158   N335        259  UNION TPK-KEW G          EF      IND
# 231991   R305   R106        328     CORTLANDT ST           1      IRT
# 159179   R170   A035        602   14 ST-UNION SQ     LNQR456      BMT
# 63340    R047   R240        610  42 ST-GRD CNTRL       4567S      IRT
# 17402    R018   R525        616   74 ST-BROADWAY       EFMR7      IRT
# 146653   R151   G009         58    STILLWELL AVE        DFNQ      BMT
# 183648   R453   N508        228      23 ST-6 AVE          FM      IND
# 183664   R453   N508        228      23 ST-6 AVE          FM      IND
# 204615   R245   R416        367  ST LAWRENCE AVE           6      IRT
# 100498   R088   A053        624     CORTLANDT ST           R      BMT
# 272962   R535  JFK02        198   JFK HOWARD BCH           A      IND
# 143706   R146   R412        371  HUNTS POINT AVE           6      IRT
# 84419    R081   A016          8      49 ST-7 AVE         NQR      BMT
# 21865    R021   N502        609  42 ST-BRYANT PK       BDFM7      IND
# 160861   R170   A034        602   14 ST-UNION SQ     LNQR456      BMT
#
#                                             LINE                    STOP_NAME  \
# 11440                                   Clark St                    Fulton St
# 139829                               Queens Blvd         Forest Hills - 71 Av
# 76055                                     4th Av   Atlantic Av - Barclays Ctr
# 17455                                   Flushing             74 St - Broadway
# 134024                                  Canarsie         Myrtle - Wyckoff Avs
# 151237                               Queens Blvd     Kew Gardens - Union Tpke
# 231991                            Broadway - 7Av                WTC Cortlandt
# 159179                       Broadway - Brighton             14 St - Union Sq
# 63340                                   Flushing        Grand Central - 42 St
# 17402                                   Flushing             74 St - Broadway
# 146653  Sea Beach / West End / Culver / Brighton  Coney Island - Stillwell Av
# 183648                           6th Av - Culver                        23 St
# 183664                           6th Av - Culver                        23 St
# 204615                                    Pelham               St Lawrence Av
# 100498                                  Broadway                 Cortlandt St
# 272962                                  Rockaway   Howard Beach - JFK Airport
# 143706                                    Pelham               Hunts Point Av
# 84419                                    Astoria                   5 Av/59 St
# 21865                            6th Av - Culver            42 St - Bryant Pk
# 160861                       Broadway - Brighton             14 St - Union Sq
#
#        BOROUGH  GTFS_LATITUDE  GTFS_LONGITUDE                       ID  \
# 11440        M      40.709416      -74.006571   R208 - R014 - 03-01-02
# 139829       Q      40.721691      -73.844521   N333 - R141 - 01-00-02
# 76055       Bk      40.683666      -73.978810   C009 - R057 - 03-03-02
# 17455        Q      40.746848      -73.891394   R525 - R018 - 02-00-02
# 134024      Bk      40.699814      -73.911586   H027 - R137 - 01-06-00
# 151237       Q      40.714441      -73.831008   N335 - R158 - 01-00-01
# 231991       M      40.711835      -74.012188   R106 - R305 - 01-00-01
# 159179       M      40.735736      -73.990568   A035 - R170 - 00-00-03
# 63340        M      40.751431      -73.976041   R240 - R047 - 00-03-00
# 17402        Q      40.746848      -73.891394   R525 - R018 - 02-00-01
# 146653      Bk      40.577422      -73.981233   G009 - R151 - 02-00-03
# 183648       M      40.742878      -73.992821   N508 - R453 - 00-00-03
# 183664       M      40.742878      -73.992821   N508 - R453 - 00-00-04
# 204615      Bx      40.831509      -73.867618   R416 - R245 - 00-05-00
# 100498       M      40.710668      -74.011029   A053 - R088 - 03-05-01
# 272962       Q      40.660476      -73.830301  JFK02 - R535 - 01-00-02
# 143706      Bx      40.820948      -73.890549   R412 - R146 - 00-00-02
# 84419        M      40.764811      -73.973347   A016 - R081 - 03-00-00
# 21865        M      40.754222      -73.984569   N502 - R021 - 01-00-03
# 160861       M      40.735736      -73.990568   A034 - R170 - 03-03-01
#
#               DATE       SCP        STATION_y LINE_NAME_y     DESC  \
# 11440   2019-05-08  03-01-02        FULTON ST    2345ACJZ  REGULAR
# 139829  2019-05-18  01-00-02  FOREST HILLS 71        EFMR  REGULAR
# 76055   2019-05-31  03-03-02   ATL AV-BARCLAY   BDNQR2345  REGULAR
# 17455   2019-06-14  02-00-02   74 ST-BROADWAY       7EFMR  REGULAR
# 134024  2019-05-08  01-06-00   MYRTLE-WYCKOFF          LM  REGULAR
# 151237  2019-05-06  01-00-01      KEW GARDENS          EF  REGULAR
# 231991  2019-06-07  01-00-01    WTC-CORTLANDT           1  REGULAR
# 159179  2019-05-18  00-00-03   14 ST-UNION SQ    LNQR456W  REGULAR
# 63340   2019-06-14  00-03-00  GRD CNTRL-42 ST       4567S  REGULAR
# 17402   2019-06-22  02-00-01   74 ST-BROADWAY       7EFMR  REGULAR
# 146653  2019-06-03  02-00-03  CONEY IS-STILLW        DFNQ  REGULAR
# 183648  2019-06-25  00-00-03            23 ST          FM  REGULAR
# 183664  2019-05-21  00-00-04            23 ST          FM  REGULAR
# 204615  2019-06-03  00-05-00   ST LAWRENCE AV           6  REGULAR
# 100498  2019-05-15  03-05-01     CORTLANDT ST         RNW  REGULAR
# 272962  2019-06-06  01-00-02   HOWARD BCH JFK           A  REGULAR
# 143706  2019-06-21  00-00-02   HUNTS POINT AV           6  REGULAR
# 84419   2019-06-07  03-00-00            49 ST        NQRW  REGULAR
# 21865   2019-05-22  01-00-03  42 ST-BRYANT PK       BDFM7  REGULAR
# 160861  2019-06-22  03-03-01   14 ST-UNION SQ    LNQR456W  REGULAR
#
#         NET_DAILY_ENTRIES  WEEKDAY
# 11440                 441        1
# 139829                235        0
# 76055                1532        1
# 17455                1566        1
# 134024               2074        1
# 151237               1682        1
# 231991                  0        1
# 159179                881        0
# 63340                2211        1
# 17402                 662        0
# 146653                856        1
# 183648               2214        1
# 183664               1842        1
# 204615                  0        1
# 100498                  0        1
# 272962                605        1
# 143706               1561        1
# 84419                1104        1
# 21865                2385        1
# 160861               2164        0

# %% [markdown]
# #### Reorder the columns for more readability (might be useful not to drop any for future troubleshooting)

# %%
daily_per_turnstile_loc_2019 = daily_per_turnstile_loc_2019[['STATION_x', 'STATION_y', 'STOP_NAME', 
                                                             'LINE_NAME_x', 'LINE_NAME_y', 'DIVISION', 
                                                             'BOROUGH', 'DATE', 'NET_DAILY_ENTRIES', 'WEEKDAY', 
                                                             'DESC', 'GTFS_LATITUDE', 'GTFS_LONGITUDE', 'LINE', 
                                                             'REMOTE', 'BOOTH', 'SCP', 'COMPLEX_ID', 'ID']]
print(daily_per_turnstile_loc_2019.shape)
daily_per_turnstile_loc_2019.head()
# Out:
# (290643, 19)
#       STATION_x        STATION_y     STOP_NAME LINE_NAME_x LINE_NAME_y  \
# 0  WHITEHALL ST  WHITEHALL S-FRY  Whitehall St          R1         R1W
# 1  WHITEHALL ST  WHITEHALL S-FRY  Whitehall St          R1         R1W
# 2  WHITEHALL ST  WHITEHALL S-FRY  Whitehall St          R1         R1W
# 3  WHITEHALL ST  WHITEHALL S-FRY  Whitehall St          R1         R1W
# 4  WHITEHALL ST  WHITEHALL S-FRY  Whitehall St          R1         R1W
#
#   DIVISION BOROUGH        DATE  NET_DAILY_ENTRIES  WEEKDAY     DESC  \
# 0      BMT       M  2019-05-01               2604        1  REGULAR
# 1      BMT       M  2019-05-02               2676        1  REGULAR
# 2      BMT       M  2019-05-03               2768        1  REGULAR
# 3      BMT       M  2019-05-04               1717        0  REGULAR
# 4      BMT       M  2019-05-05               1184        0  REGULAR
#
#    GTFS_LATITUDE  GTFS_LONGITUDE      LINE REMOTE BOOTH       SCP COMPLEX_ID  \
# 0      40.703087      -74.012994  Broadway   R001  A060  00-00-00        635
# 1      40.703087      -74.012994  Broadway   R001  A060  00-00-00        635
# 2      40.703087      -74.012994  Broadway   R001  A060  00-00-00        635
# 3      40.703087      -74.012994  Broadway   R001  A060  00-00-00        635
# 4      40.703087      -74.012994  Broadway   R001  A060  00-00-00        635
#
#                        ID
# 0  A060 - R001 - 00-00-00
# 1  A060 - R001 - 00-00-00
# 2  A060 - R001 - 00-00-00
# 3  A060 - R001 - 00-00-00
# 4  A060 - R001 - 00-00-00

# %% [markdown]
# ##### Repeat all of the above steps for the 2021 data

# %%
# Drop unnecessary column
daily_per_turnstile_2021.drop(columns=['DATETIME'], inplace=True)

# Get consistent column names between the two dataframes to be merged

daily_per_turnstile_2021.columns = ['ID', 'DATE', 'BOOTH', 'REMOTE', 'SCP', 'STATION', 
                                    'LINE_NAME', 'DIVISION', 'DESC', 'NET_DAILY_ENTRIES', 'WEEKDAY']
daily_per_turnstile_2021.head()
# Out:
#                        ID        DATE BOOTH REMOTE       SCP STATION  \
# 0  A002 - R051 - 02-00-00  2021-05-01  A002   R051  02-00-00   59 ST
# 1  A002 - R051 - 02-00-00  2021-05-02  A002   R051  02-00-00   59 ST
# 2  A002 - R051 - 02-00-00  2021-05-03  A002   R051  02-00-00   59 ST
# 3  A002 - R051 - 02-00-00  2021-05-04  A002   R051  02-00-00   59 ST
# 4  A002 - R051 - 02-00-00  2021-05-05  A002   R051  02-00-00   59 ST
#
#   LINE_NAME DIVISION     DESC  NET_DAILY_ENTRIES  WEEKDAY
# 0   NQR456W      BMT  REGULAR                361        0
# 1   NQR456W      BMT  REGULAR                250        0
# 2   NQR456W      BMT  REGULAR                472        1
# 3   NQR456W      BMT  REGULAR                501        1
# 4   NQR456W      BMT  REGULAR                522        1

# %%
daily_per_turnstile_loc_2021 = complex_locations.merge(right=daily_per_turnstile_2021, 
                                                       how='inner',
                                                       on=['BOOTH', 'REMOTE', 'DIVISION'])

# %%
# Again, only lost ~3500 rows here - pretty good!

print(daily_per_turnstile_2021.shape)
daily_per_turnstile_loc_2021.shape
# Out:
# (301718, 11)
# (298140, 19)

# %%
# Check for NaNs

daily_per_turnstile_loc_2021[daily_per_turnstile_loc_2021.isna().any(axis=1)].shape[0]
# Out:
# 0

# %%
# Again, STATION_x and STATION_y seem to match up well! (LINE_NAME_x and LINE_NAME_y, too!)

daily_per_turnstile_loc_2021.sample(n=20)
# Out:
#        REMOTE  BOOTH COMPLEX_ID        STATION_x  LINE_NAME_x DIVISION  \
# 266621   R377   J007         98     FLUSHING AVE           JM      BMT
# 226567   R282   N087        168        SPRING ST           CE      IND
# 23254    R022   N506        607  34 ST-HERALD SQ      BDFMNQR      IND
# 156375   R162   R414        369        ELDER AVE            6      IRT
# 51153    R043  R204A        413          WALL ST           45      IRT
# 180429   R193   R180        303           157 ST            1      IRT
# 81195    R064   R628        347     SARATOGA AVE            3      IRT
# 41883    R033   R151        611   42 ST-TIMES SQ  1237ACENQRS      IRT
# 37670    R031   R139        318   34 ST-PENN STA          123      IRT
# 54835    R045   R236        610  42 ST-GRD CNTRL        4567S      IRT
# 9713     R014   N095        628        FULTON ST     ACJZ2345      IND
# 182923   R195  R262A        604    161 ST-YANKEE          4BD      IRT
# 236088   R304   R102        329        RECTOR ST            1      IRT
# 153491   R157   N225        210   NORWOOD-205 ST            D      IND
# 96170    R462   A043        623         CANAL ST       JNQRZ6      BMT
# 185191   R199   N119        180  KINGSTON-THROOP            C      IND
# 212553   R253   N212        216       174-175 ST           BD      IND
# 228388   R286   N415        288  MYRTLE-WILLOUGH            G      IND
# 116827   R109   R639        356       CHURCH AVE           25      IRT
# 270384   R389   R326        425  BRONX PARK EAST           25      IRT
#
#                            LINE                STOP_NAME BOROUGH  \
# 266621                  Jamaica              Flushing Av      Bk
# 226567       8th Av - Fulton St                Spring St       M
# 23254           6th Av - Culver        34 St - Herald Sq       M
# 156375                   Pelham                 Elder Av      Bx
# 51153              Lexington Av                  Wall St       M
# 180429           Broadway - 7Av                   157 St       M
# 81195               Eastern Pky              Saratoga Av      Bk
# 41883       Lexington - Shuttle         Times Sq - 42 St       M
# 37670            Broadway - 7Av     34 St - Penn Station       M
# 54835       Lexington - Shuttle    Grand Central - 42 St       M
# 9713         8th Av - Fulton St                Fulton St       M
# 182923                Jerome Av  161 St - Yankee Stadium      Bx
# 236088           Broadway - 7Av                Rector St       M
# 153491                Concourse         Norwood - 205 St      Bx
# 96170                  Broadway                 Canal St       M
# 185191       8th Av - Fulton St    Kingston - Throop Avs      Bk
# 212553                Concourse              174-175 Sts      Bx
# 228388                Crosstown  Myrtle - Willoughby Avs      Bk
# 116827                 Nostrand                Church Av      Bk
# 270384  Lenox - White Plains Rd          Bronx Park East      Bx
#
#         GTFS_LATITUDE  GTFS_LONGITUDE                       ID        DATE  \
# 266621      40.700260      -73.941126   J007 - R377 - 00-05-00  2021-05-28
# 226567      40.726227      -74.003739   N087 - R282 - 01-06-00  2021-05-14
# 23254       40.749719      -73.987823   N506 - R022 - 00-05-00  2021-06-02
# 156375      40.828584      -73.879159   R414 - R162 - 00-03-01  2021-06-25
# 51153       40.707557      -74.011862  R204A - R043 - 03-05-01  2021-05-09
# 180429      40.834041      -73.944890   R180 - R193 - 00-00-03  2021-05-17
# 81195       40.661453      -73.916327   R628 - R064 - 00-00-00  2021-05-26
# 41883       40.755983      -73.986229   R151 - R033 - 00-00-01  2021-06-16
# 37670       40.750373      -73.991057   R139 - R031 - 04-00-03  2021-06-12
# 54835       40.752769      -73.979189   R236 - R045 - 00-00-02  2021-06-10
# 9713        40.710197      -74.007691   N095 - R014 - 00-03-03  2021-06-03
# 182923      40.827994      -73.925831  R262A - R195 - 04-00-02  2021-05-11
# 236088      40.707513      -74.013783   R102 - R304 - 01-03-00  2021-05-24
# 153491      40.874811      -73.878855   N225 - R157 - 01-00-02  2021-06-08
# 96170       40.719527      -74.001775   A043 - R462 - 00-03-02  2021-05-12
# 185191      40.679921      -73.940858   N119 - R199 - 00-00-01  2021-05-22
# 212553      40.845900      -73.910136   N212 - R253 - 01-00-01  2021-06-01
# 228388      40.694568      -73.949046   N415 - R286 - 00-00-00  2021-05-05
# 116827      40.650843      -73.949575   R639 - R109 - 00-05-02  2021-06-16
# 270384      40.848828      -73.868457   R326 - R389 - 00-00-01  2021-05-09
#
#              SCP        STATION_y   LINE_NAME_y     DESC  NET_DAILY_ENTRIES  \
# 266621  00-05-00      FLUSHING AV            JM  REGULAR                  0
# 226567  01-06-00        SPRING ST            CE  REGULAR                509
# 23254   00-05-00  34 ST-HERALD SQ      BDFMNQRW  REGULAR                340
# 156375  00-03-01         ELDER AV             6  REGULAR               1003
# 51153   03-05-01          WALL ST            45  REGULAR                  0
# 180429  00-00-03           157 ST             1  REGULAR                237
# 81195   00-00-00      SARATOGA AV             3  REGULAR                526
# 41883   00-00-01   TIMES SQ-42 ST  1237ACENQRSW  REGULAR               1086
# 37670   04-00-03   34 ST-PENN STA           123  REGULAR                299
# 54835   00-00-02  GRD CNTRL-42 ST         4567S  REGULAR                190
# 9713    00-03-03        FULTON ST      ACJZ2345  REGULAR                636
# 182923  04-00-02  161/YANKEE STAD           4BD  REGULAR                  0
# 236088  01-03-00        RECTOR ST             1  REGULAR                 73
# 153491  01-00-02   NORWOOD 205 ST             D  REGULAR                394
# 96170   00-03-02         CANAL ST       JNQRZ6W  REGULAR                 96
# 185191  00-00-01  KINGSTON-THROOP             C  REGULAR                398
# 212553  01-00-01      174-175 STS            BD  REGULAR                103
# 228388  00-00-00  MYRTLE-WILLOUGH             G  REGULAR                500
# 116827  00-05-02        CHURCH AV            25  REGULAR                  0
# 270384  00-00-01  BRONX PARK EAST            25  REGULAR                 86
#
#         WEEKDAY
# 266621        1
# 226567        1
# 23254         1
# 156375        1
# 51153         0
# 180429        1
# 81195         1
# 41883         1
# 37670         0
# 54835         1
# 9713          1
# 182923        1
# 236088        1
# 153491        1
# 96170         1
# 185191        0
# 212553        1
# 228388        1
# 116827        1
# 270384        0

# %% [markdown]
# #### Reorder the columns for more readability (might be useful not to drop any for future troubleshooting)

# %%
daily_per_turnstile_loc_2021 = daily_per_turnstile_loc_2021[['STATION_x', 'STATION_y', 'STOP_NAME', 
                                                             'LINE_NAME_x', 'LINE_NAME_y', 'DIVISION', 
                                                             'BOROUGH', 'DATE', 'NET_DAILY_ENTRIES', 'WEEKDAY', 
                                                             'DESC', 'GTFS_LATITUDE', 'GTFS_LONGITUDE', 'LINE', 
                                                             'REMOTE', 'BOOTH', 'SCP', 'COMPLEX_ID', 'ID']]
print(daily_per_turnstile_loc_2021.shape)
daily_per_turnstile_loc_2021.head()
# Out:
# (298140, 19)
#       STATION_x        STATION_y     STOP_NAME LINE_NAME_x LINE_NAME_y  \
# 0  WHITEHALL ST  WHITEHALL S-FRY  Whitehall St          R1         R1W
# 1  WHITEHALL ST  WHITEHALL S-FRY  Whitehall St          R1         R1W
# 2  WHITEHALL ST  WHITEHALL S-FRY  Whitehall St          R1         R1W
# 3  WHITEHALL ST  WHITEHALL S-FRY  Whitehall St          R1         R1W
# 4  WHITEHALL ST  WHITEHALL S-FRY  Whitehall St          R1         R1W
#
#   DIVISION BOROUGH        DATE  NET_DAILY_ENTRIES  WEEKDAY     DESC  \
# 0      BMT       M  2021-05-01                692        0  REGULAR
# 1      BMT       M  2021-05-02                578        0  REGULAR
# 2      BMT       M  2021-05-03                895        1  REGULAR
# 3      BMT       M  2021-05-04                947        1  REGULAR
# 4      BMT       M  2021-05-05                905        1  REGULAR
#
#    GTFS_LATITUDE  GTFS_LONGITUDE      LINE REMOTE BOOTH       SCP COMPLEX_ID  \
# 0      40.703087      -74.012994  Broadway   R001  A060  00-00-00        635
# 1      40.703087      -74.012994  Broadway   R001  A060  00-00-00        635
# 2      40.703087      -74.012994  Broadway   R001  A060  00-00-00        635
# 3      40.703087      -74.012994  Broadway   R001  A060  00-00-00        635
# 4      40.703087      -74.012994  Broadway   R001  A060  00-00-00        635
#
#                        ID
# 0  A060 - R001 - 00-00-00
# 1  A060 - R001 - 00-00-00
# 2  A060 - R001 - 00-00-00
# 3  A060 - R001 - 00-00-00
# 4  A060 - R001 - 00-00-00

# %% [markdown]
# ### 2f) Now generate NET_DAILY_STATION_ENTRIES (i.e. aggregate from per-turnstile to per-station basis)

# %% [markdown]
# #### (Recall from previous section that 'COMPLEX_ID' is the unifying element that identifies all turnstiles residing "under one roof")

# %%
daily_per_station_2019 = daily_per_turnstile_loc_2019.groupby(['COMPLEX_ID', 'STATION_x', 'DIVISION',
                                                               'DATE'])['NET_DAILY_ENTRIES'] \
                                                     .sum().reset_index()

daily_per_station_2019.columns = ['COMPLEX_ID', 'STATION_x', 'DIVISION', 'DATE', 'NET_DAILY_STATION_ENTRIES']
print(daily_per_station_2019.shape)
display(daily_per_station_2019.head())
display(daily_per_station_2019.tail())
# Out:
# (27512, 5)
#   COMPLEX_ID        STATION_x DIVISION        DATE  NET_DAILY_STATION_ENTRIES
# 0          1  DITMARS BL-31 S      BMT  2019-05-01                      18999
# 1          1  DITMARS BL-31 S      BMT  2019-05-02                      19257
# 2          1  DITMARS BL-31 S      BMT  2019-05-03                      18661
# 3          1  DITMARS BL-31 S      BMT  2019-05-04                       9577
# 4          1  DITMARS BL-31 S      BMT  2019-05-05                       6630
#       COMPLEX_ID   STATION_x DIVISION        DATE  NET_DAILY_STATION_ENTRIES
# 27507         99  LORIMER ST      BMT  2019-06-26                       5117
# 27508         99  LORIMER ST      BMT  2019-06-27                       5155
# 27509         99  LORIMER ST      BMT  2019-06-28                       4908
# 27510         99  LORIMER ST      BMT  2019-06-29                       3587
# 27511         99  LORIMER ST      BMT  2019-06-30                       3284

# %% [markdown]
# #### Now merge in the other desired columns

# %%
daily_per_station_2019 = daily_per_station_2019.merge(right=daily_per_turnstile_loc_2019
                                                      .groupby(['COMPLEX_ID', 'STATION_x', 'DIVISION',
                                                                'DATE'])
                                                      .first().reset_index(),
                                                      how='inner',
                                                      on=['COMPLEX_ID', 'STATION_x', 'DIVISION', 'DATE']) \
                                                      .drop(columns='NET_DAILY_ENTRIES')

# %%
print(daily_per_station_2019.shape)
display(daily_per_station_2019.head(10))
display(daily_per_station_2019.tail(10))
# Out:
# (27512, 19)
#   COMPLEX_ID        STATION_x DIVISION        DATE  NET_DAILY_STATION_ENTRIES  \
# 0          1  DITMARS BL-31 S      BMT  2019-05-01                      18999
# 1          1  DITMARS BL-31 S      BMT  2019-05-02                      19257
# 2          1  DITMARS BL-31 S      BMT  2019-05-03                      18661
# 3          1  DITMARS BL-31 S      BMT  2019-05-04                       9577
# 4          1  DITMARS BL-31 S      BMT  2019-05-05                       6630
# 5          1  DITMARS BL-31 S      BMT  2019-05-06                      18272
# 6          1  DITMARS BL-31 S      BMT  2019-05-07                      19146
# 7          1  DITMARS BL-31 S      BMT  2019-05-08                      19359
# 8          1  DITMARS BL-31 S      BMT  2019-05-09                      19073
# 9          1  DITMARS BL-31 S      BMT  2019-05-10                      18527
#
#          STATION_y               STOP_NAME LINE_NAME_x LINE_NAME_y BOROUGH  \
# 0  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW       Q
# 1  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW       Q
# 2  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW       Q
# 3  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW       Q
# 4  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW       Q
# 5  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW       Q
# 6  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW       Q
# 7  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW       Q
# 8  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW       Q
# 9  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW       Q
#
#    WEEKDAY     DESC  GTFS_LATITUDE  GTFS_LONGITUDE     LINE REMOTE BOOTH  \
# 0        1  REGULAR      40.775036      -73.912034  Astoria   R095  R515
# 1        1  REGULAR      40.775036      -73.912034  Astoria   R095  R515
# 2        1  REGULAR      40.775036      -73.912034  Astoria   R095  R515
# 3        0  REGULAR      40.775036      -73.912034  Astoria   R095  R515
# 4        0  REGULAR      40.775036      -73.912034  Astoria   R095  R515
# 5        1  REGULAR      40.775036      -73.912034  Astoria   R095  R515
# 6        1  REGULAR      40.775036      -73.912034  Astoria   R095  R515
# 7        1  REGULAR      40.775036      -73.912034  Astoria   R095  R515
# 8        1  REGULAR      40.775036      -73.912034  Astoria   R095  R515
# 9        1  REGULAR      40.775036      -73.912034  Astoria   R095  R515
#
#         SCP                      ID
# 0  00-00-00  R515 - R095 - 00-00-00
# 1  00-00-00  R515 - R095 - 00-00-00
# 2  00-00-00  R515 - R095 - 00-00-00
# 3  00-00-00  R515 - R095 - 00-00-00
# 4  00-00-00  R515 - R095 - 00-00-00
# 5  00-00-00  R515 - R095 - 00-00-00
# 6  00-00-00  R515 - R095 - 00-00-00
# 7  00-00-00  R515 - R095 - 00-00-00
# 8  00-00-00  R515 - R095 - 00-00-00
# 9  00-00-00  R515 - R095 - 00-00-00
#       COMPLEX_ID   STATION_x DIVISION        DATE  NET_DAILY_STATION_ENTRIES  \
# 27502         99  LORIMER ST      BMT  2019-06-21                       5253
# 27503         99  LORIMER ST      BMT  2019-06-22                       4194
# 27504         99  LORIMER ST      BMT  2019-06-23                       3647
# 27505         99  LORIMER ST      BMT  2019-06-24                       5175
# 27506         99  LORIMER ST      BMT  2019-06-25                       5099
# 27507         99  LORIMER ST      BMT  2019-06-26                       5117
# 27508         99  LORIMER ST      BMT  2019-06-27                       5155
# 27509         99  LORIMER ST      BMT  2019-06-28                       4908
# 27510         99  LORIMER ST      BMT  2019-06-29                       3587
# 27511         99  LORIMER ST      BMT  2019-06-30                       3284
#
#         STATION_y   STOP_NAME LINE_NAME_x LINE_NAME_y BOROUGH  WEEKDAY  \
# 27502  LORIMER ST  Lorimer St          JM          JM      Bk        1
# 27503  LORIMER ST  Lorimer St          JM          JM      Bk        0
# 27504  LORIMER ST  Lorimer St          JM          JM      Bk        0
# 27505  LORIMER ST  Lorimer St          JM          JM      Bk        1
# 27506  LORIMER ST  Lorimer St          JM          JM      Bk        1
# 27507  LORIMER ST  Lorimer St          JM          JM      Bk        1
# 27508  LORIMER ST  Lorimer St          JM          JM      Bk        1
# 27509  LORIMER ST  Lorimer St          JM          JM      Bk        1
# 27510  LORIMER ST  Lorimer St          JM          JM      Bk        0
# 27511  LORIMER ST  Lorimer St          JM          JM      Bk        0
#
#              DESC  GTFS_LATITUDE  GTFS_LONGITUDE     LINE REMOTE BOOTH  \
# 27502     REGULAR      40.703869      -73.947408  Jamaica   R353  J005
# 27503  RECOVR AUD      40.703869      -73.947408  Jamaica   R353  J005
# 27504     REGULAR      40.703869      -73.947408  Jamaica   R353  J005
# 27505     REGULAR      40.703869      -73.947408  Jamaica   R353  J005
# 27506     REGULAR      40.703869      -73.947408  Jamaica   R353  J005
# 27507     REGULAR      40.703869      -73.947408  Jamaica   R353  J005
# 27508     REGULAR      40.703869      -73.947408  Jamaica   R353  J005
# 27509     REGULAR      40.703869      -73.947408  Jamaica   R353  J005
# 27510     REGULAR      40.703869      -73.947408  Jamaica   R353  J005
# 27511     REGULAR      40.703869      -73.947408  Jamaica   R353  J005
#
#             SCP                      ID
# 27502  00-00-00  J005 - R353 - 00-00-00
# 27503  00-00-00  J005 - R353 - 00-00-00
# 27504  00-00-00  J005 - R353 - 00-00-00
# 27505  00-00-00  J005 - R353 - 00-00-00
# 27506  00-00-00  J005 - R353 - 00-00-00
# 27507  00-00-00  J005 - R353 - 00-00-00
# 27508  00-00-00  J005 - R353 - 00-00-00
# 27509  00-00-00  J005 - R353 - 00-00-00
# 27510  00-00-00  J005 - R353 - 00-00-00
# 27511  00-00-00  J005 - R353 - 00-00-00

# %% [markdown]
# ##### Do the same for 2021 data

# %%
daily_per_station_2021 = daily_per_turnstile_loc_2021.groupby(['COMPLEX_ID', 'STATION_x', 'DIVISION',
                                                               'DATE'])['NET_DAILY_ENTRIES'] \
                                                     .sum().reset_index()

daily_per_station_2021.columns = ['COMPLEX_ID', 'STATION_x', 'DIVISION', 'DATE', 'NET_DAILY_STATION_ENTRIES']
print(daily_per_station_2021.shape)
display(daily_per_station_2021.head())
display(daily_per_station_2021.tail())
# Out:
# (27567, 5)
#   COMPLEX_ID        STATION_x DIVISION        DATE  NET_DAILY_STATION_ENTRIES
# 0          1  DITMARS BL-31 S      BMT  2021-05-01                       3485
# 1          1  DITMARS BL-31 S      BMT  2021-05-02                       2378
# 2          1  DITMARS BL-31 S      BMT  2021-05-03                       4990
# 3          1  DITMARS BL-31 S      BMT  2021-05-04                       5290
# 4          1  DITMARS BL-31 S      BMT  2021-05-05                       5196
#       COMPLEX_ID   STATION_x DIVISION        DATE  NET_DAILY_STATION_ENTRIES
# 27562         99  LORIMER ST      BMT  2021-06-26                       1132
# 27563         99  LORIMER ST      BMT  2021-06-27                        981
# 27564         99  LORIMER ST      BMT  2021-06-28                       1663
# 27565         99  LORIMER ST      BMT  2021-06-29                       1542
# 27566         99  LORIMER ST      BMT  2021-06-30                       1669

# %% [markdown]
# #### Now merge in the other desired columns

# %%
daily_per_station_2021 = daily_per_station_2021.merge(right=daily_per_turnstile_loc_2021
                                                      .groupby(['COMPLEX_ID', 'STATION_x', 'DIVISION',
                                                                'DATE'])
                                                      .first().reset_index(),
                                                      how='inner',
                                                      on=['COMPLEX_ID', 'STATION_x', 'DIVISION', 'DATE']) \
                                                      .drop(columns='NET_DAILY_ENTRIES')

# %%
print(daily_per_station_2021.shape)
display(daily_per_station_2021.head(10))
display(daily_per_station_2021.tail(10))
# Out:
# (27567, 19)
#   COMPLEX_ID        STATION_x DIVISION        DATE  NET_DAILY_STATION_ENTRIES  \
# 0          1  DITMARS BL-31 S      BMT  2021-05-01                       3485
# 1          1  DITMARS BL-31 S      BMT  2021-05-02                       2378
# 2          1  DITMARS BL-31 S      BMT  2021-05-03                       4990
# 3          1  DITMARS BL-31 S      BMT  2021-05-04                       5290
# 4          1  DITMARS BL-31 S      BMT  2021-05-05                       5196
# 5          1  DITMARS BL-31 S      BMT  2021-05-06                       5470
# 6          1  DITMARS BL-31 S      BMT  2021-05-07                       5448
# 7          1  DITMARS BL-31 S      BMT  2021-05-08                       3192
# 8          1  DITMARS BL-31 S      BMT  2021-05-09                       2362
# 9          1  DITMARS BL-31 S      BMT  2021-05-10                       4986
#
#          STATION_y               STOP_NAME LINE_NAME_x LINE_NAME_y BOROUGH  \
# 0  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW       Q
# 1  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW       Q
# 2  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW       Q
# 3  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW       Q
# 4  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW       Q
# 5  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW       Q
# 6  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW       Q
# 7  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW       Q
# 8  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW       Q
# 9  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW       Q
#
#    WEEKDAY     DESC  GTFS_LATITUDE  GTFS_LONGITUDE     LINE REMOTE BOOTH  \
# 0        0  REGULAR      40.775036      -73.912034  Astoria   R095  R515
# 1        0  REGULAR      40.775036      -73.912034  Astoria   R095  R515
# 2        1  REGULAR      40.775036      -73.912034  Astoria   R095  R515
# 3        1  REGULAR      40.775036      -73.912034  Astoria   R095  R515
# 4        1  REGULAR      40.775036      -73.912034  Astoria   R095  R515
# 5        1  REGULAR      40.775036      -73.912034  Astoria   R095  R515
# 6        1  REGULAR      40.775036      -73.912034  Astoria   R095  R515
# 7        0  REGULAR      40.775036      -73.912034  Astoria   R095  R515
# 8        0  REGULAR      40.775036      -73.912034  Astoria   R095  R515
# 9        1  REGULAR      40.775036      -73.912034  Astoria   R095  R515
#
#         SCP                      ID
# 0  00-00-00  R515 - R095 - 00-00-00
# 1  00-00-00  R515 - R095 - 00-00-00
# 2  00-00-00  R515 - R095 - 00-00-00
# 3  00-00-00  R515 - R095 - 00-00-00
# 4  00-00-00  R515 - R095 - 00-00-00
# 5  00-00-00  R515 - R095 - 00-00-00
# 6  00-00-00  R515 - R095 - 00-00-00
# 7  00-00-00  R515 - R095 - 00-00-00
# 8  00-00-00  R515 - R095 - 00-00-00
# 9  00-00-00  R515 - R095 - 00-00-00
#       COMPLEX_ID   STATION_x DIVISION        DATE  NET_DAILY_STATION_ENTRIES  \
# 27557         99  LORIMER ST      BMT  2021-06-21                       1711
# 27558         99  LORIMER ST      BMT  2021-06-22                       1705
# 27559         99  LORIMER ST      BMT  2021-06-23                       1909
# 27560         99  LORIMER ST      BMT  2021-06-24                       1836
# 27561         99  LORIMER ST      BMT  2021-06-25                       1868
# 27562         99  LORIMER ST      BMT  2021-06-26                       1132
# 27563         99  LORIMER ST      BMT  2021-06-27                        981
# 27564         99  LORIMER ST      BMT  2021-06-28                       1663
# 27565         99  LORIMER ST      BMT  2021-06-29                       1542
# 27566         99  LORIMER ST      BMT  2021-06-30                       1669
#
#         STATION_y   STOP_NAME LINE_NAME_x LINE_NAME_y BOROUGH  WEEKDAY  \
# 27557  LORIMER ST  Lorimer St          JM          JM      Bk        1
# 27558  LORIMER ST  Lorimer St          JM          JM      Bk        1
# 27559  LORIMER ST  Lorimer St          JM          JM      Bk        1
# 27560  LORIMER ST  Lorimer St          JM          JM      Bk        1
# 27561  LORIMER ST  Lorimer St          JM          JM      Bk        1
# 27562  LORIMER ST  Lorimer St          JM          JM      Bk        0
# 27563  LORIMER ST  Lorimer St          JM          JM      Bk        0
# 27564  LORIMER ST  Lorimer St          JM          JM      Bk        1
# 27565  LORIMER ST  Lorimer St          JM          JM      Bk        1
# 27566  LORIMER ST  Lorimer St          JM          JM      Bk        1
#
#           DESC  GTFS_LATITUDE  GTFS_LONGITUDE     LINE REMOTE BOOTH       SCP  \
# 27557  REGULAR      40.703869      -73.947408  Jamaica   R353  J005  00-00-00
# 27558  REGULAR      40.703869      -73.947408  Jamaica   R353  J005  00-00-00
# 27559  REGULAR      40.703869      -73.947408  Jamaica   R353  J005  00-00-00
# 27560  REGULAR      40.703869      -73.947408  Jamaica   R353  J005  00-00-00
# 27561  REGULAR      40.703869      -73.947408  Jamaica   R353  J005  00-00-00
# 27562  REGULAR      40.703869      -73.947408  Jamaica   R353  J005  00-00-00
# 27563  REGULAR      40.703869      -73.947408  Jamaica   R353  J005  00-00-00
# 27564  REGULAR      40.703869      -73.947408  Jamaica   R353  J005  00-00-00
# 27565  REGULAR      40.703869      -73.947408  Jamaica   R353  J005  00-00-00
# 27566  REGULAR      40.703869      -73.947408  Jamaica   R353  J005  00-00-00
#
#                            ID
# 27557  J005 - R353 - 00-00-00
# 27558  J005 - R353 - 00-00-00
# 27559  J005 - R353 - 00-00-00
# 27560  J005 - R353 - 00-00-00
# 27561  J005 - R353 - 00-00-00
# 27562  J005 - R353 - 00-00-00
# 27563  J005 - R353 - 00-00-00
# 27564  J005 - R353 - 00-00-00
# 27565  J005 - R353 - 00-00-00
# 27566  J005 - R353 - 00-00-00

# %% [markdown]
# #### Verify that we've still got a common set of stations between the two years

# %%
print(daily_per_station_2019['STATION_x'].unique().shape)
print(daily_per_station_2021['STATION_x'].unique().shape)
print(np.setdiff1d(daily_per_station_2019['STATION_x'].unique(), daily_per_station_2021['STATION_x'].unique()))
print(np.setdiff1d(daily_per_station_2021['STATION_x'].unique(), daily_per_station_2019['STATION_x'].unique()))
# Out:
# (360,)
# (360,)
# []
# []

# %% [markdown]
# ### 2g) Now add ZIPCODEs corresponding to the latitude/longitude information

# %%
# Just using WEEKDAY column as a placeholder during grouping; will drop immediately

locations = daily_per_station_2019.groupby(['COMPLEX_ID', 'STATION_x', 'DIVISION', 
                                            'GTFS_LATITUDE', 'GTFS_LONGITUDE']) \
                                  ['WEEKDAY'].first().reset_index()

locations.drop(columns='WEEKDAY', inplace=True)
print(locations.shape)
locations
# Out:
# (452, 5)
#     COMPLEX_ID           STATION_x DIVISION  GTFS_LATITUDE  GTFS_LONGITUDE
# 0            1     DITMARS BL-31 S      BMT      40.775036      -73.912034
# 1           10         49 ST-7 AVE      BMT      40.759901      -73.984139
# 2          100            HEWES ST      BMT      40.706870      -73.953431
# 3          101           MARCY AVE      BMT      40.708359      -73.957757
# 4          103              BOWERY      BMT      40.720280      -73.993915
# 5          107            BROAD ST      BMT      40.706476      -74.011056
# 6          108     METROPOLITAN AV      BMT      40.711396      -73.889601
# 7          109     FRESH POND ROAD      BMT      40.706186      -73.895877
# 8          110          FOREST AVE      BMT      40.704423      -73.903077
# 9          111          SENECA AVE      BMT      40.702762      -73.907740
# 10         113       KNICKERBOCKER      BMT      40.698664      -73.919711
# 11         114         CENTRAL AVE      BMT      40.697857      -73.927397
# 12         118               3 AVE      BMT      40.732849      -73.986122
# 13         119               1 AVE      BMT      40.730953      -73.981628
# 14         120         BEDFORD AVE      BMT      40.717304      -73.956872
# 15         122          GRAHAM AVE      BMT      40.714565      -73.944053
# 16         123            GRAND ST      BMT      40.711926      -73.940670
# 17         124        MONTROSE AVE      BMT      40.707739      -73.939850
# 18         125          MORGAN AVE      BMT      40.706152      -73.933147
# 19         126        JEFFERSON ST      BMT      40.706607      -73.922913
# 20         127          DEKALB AVE      BMT      40.703811      -73.918425
# 21         129           HALSEY ST      BMT      40.695602      -73.904084
# 22          13      28 ST-BROADWAY      BMT      40.745494      -73.988691
# 23         130          WILSON AVE      BMT      40.688764      -73.904046
# 24         131        BUSHWICK AVE      BMT      40.682829      -73.905249
# 25         133        ATLANTIC AVE      BMT      40.675345      -73.903097
# 26         134          SUTTER AVE      BMT      40.669367      -73.901975
# 27         135         LIVONIA AVE      BMT      40.664038      -73.900571
# 28         136        NEW LOTS AVE      BMT      40.658733      -73.899232
# 29         137         EAST 105 ST      BMT      40.650573      -73.899485
# 30         138        ROCKAWAY PKY      BMT      40.646654      -73.901850
# 31          14         23 ST-5 AVE      BMT      40.741303      -73.989344
# 32         141          PARK PLACE      BMT      40.674772      -73.957624
# 33         143       INWOOD-207 ST      IND      40.868072      -73.919899
# 34         144      DYCKMAN-200 ST      IND      40.865491      -73.927271
# 35         145              190 ST      IND      40.859022      -73.934180
# 36         146              181 ST      IND      40.851695      -73.937969
# 37         147              175 ST      IND      40.847391      -73.939704
# 38         149     163 ST-AMSTERDM      IND      40.836013      -73.939892
# 39         150              155 ST      IND      40.830518      -73.941514
# 40         151              145 ST      IND      40.824783      -73.944216
# 41         152              135 ST      IND      40.817894      -73.947649
# 42         153              125 ST      IND      40.811109      -73.952343
# 43         154              116 ST      IND      40.805085      -73.954882
# 44         155     CATHEDRL-110 ST      IND      40.800603      -73.958161
# 45         156              103 ST      IND      40.796092      -73.961454
# 46         157               96 ST      IND      40.791642      -73.964696
# 47         158               86 ST      IND      40.785868      -73.968916
# 48         159        81 ST-MUSEUM      IND      40.781433      -73.972143
# 49          16      8 ST-B'WAY NYU      BMT      40.730328      -73.992629
# 50         160               72 ST      IND      40.775594      -73.976410
# 51         162               50 ST      IND      40.762456      -73.985984
# 52         164      34 ST-PENN STA      IND      40.752287      -73.993391
# 53         165               23 ST      IND      40.745906      -73.998041
# 54         167      W 4 ST-WASH SQ      IND      40.732338      -74.000495
# 55         168           SPRING ST      IND      40.726227      -74.003739
# 56         169            CANAL ST      IND      40.720824      -74.005229
# 57          17     PRINCE ST-B'WAY      BMT      40.724329      -73.997702
# 58         173             HIGH ST      IND      40.699337      -73.990531
# 59         175       HOYT/SCHERMER      IND      40.688484      -73.985001
# 60         176       LAFAYETTE AVE      IND      40.686113      -73.973946
# 61         177     CLINTON-WASH AV      IND      40.683263      -73.965838
# 62         179        NOSTRAND AVE      IND      40.680438      -73.950426
# 63         180     KINGSTON-THROOP      IND      40.679921      -73.940858
# 64         181           UTICA AVE      IND      40.679364      -73.930729
# 65         182           RALPH AVE      IND      40.678822      -73.920786
# 66         183        ROCKAWAY AVE      IND      40.678340      -73.911946
# 67         185         LIBERTY AVE      IND      40.674542      -73.896548
# 68         186      VAN SICLEN AVE      IND      40.672710      -73.890358
# 69         187        SHEPHERD AVE      IND      40.674130      -73.880750
# 70         188          EUCLID AVE      IND      40.675377      -73.872106
# 71         189           GRANT AVE      IND      40.677044      -73.865050
# 72         190        HUDSON-80 ST      IND      40.679371      -73.858992
# 73         191          BOYD-88 ST      IND      40.679843      -73.851470
# 74         192       ROCKAWAY BLVD      IND      40.680429      -73.843853
# 75         193       OXFORD-104 ST      IND      40.681711      -73.837683
# 76         194       GREENWOOD-111      IND      40.684331      -73.832163
# 77         195       LEFFERTS BLVD      IND      40.685951      -73.825798
# 78         196      AQUEDUCT TRACK      IND      40.672097      -73.835919
# 79         197     AQUEDUCT-N CNDT      IND      40.668234      -73.834058
# 80         198      HOWARD BCH-JFK      IND      40.660476      -73.830301
# 81         198      JFK HOWARD BCH      IND      40.660476      -73.830301
# 82         199       BROAD CHANNEL      IND      40.608382      -73.815925
# 83         200         BEACH 90 ST      IND      40.588034      -73.813641
# 84         201         BEACH 98 ST      IND      40.585307      -73.820558
# 85         202        BEACH 105 ST      IND      40.583209      -73.827559
# 86         203     ROCKAWAY PK 116      IND      40.580903      -73.835592
# 87         204         BEACH 67 ST      IND      40.590927      -73.796924
# 88         205         BEACH 60 ST      IND      40.592374      -73.788522
# 89         206         BEACH 44 ST      IND      40.592943      -73.776013
# 90         207         BEACH 36 ST      IND      40.595398      -73.768175
# 91         208         BEACH 25 ST      IND      40.600066      -73.761353
# 92         209        FAR ROCKAWAY      IND      40.603995      -73.755405
# 93         210      NORWOOD-205 ST      IND      40.874811      -73.878855
# 94         211     BEDFORD PARK BL      IND      40.873244      -73.887138
# 95         212      KINGSBRIDGE RD      IND      40.866978      -73.893509
# 96         213        FORDHAM ROAD      IND      40.861296      -73.897749
# 97         214          182-183 ST      IND      40.856093      -73.900741
# 98         215         TREMONT AVE      IND      40.850410      -73.905227
# 99         216          174-175 ST      IND      40.845900      -73.910136
# 100        217              170 ST      IND      40.839306      -73.913400
# 101        218              167 ST      IND      40.833771      -73.918440
# 102         22           RECTOR ST      BMT      40.707220      -74.013342
# 103        220              155 ST      IND      40.830135      -73.938209
# 104        221               21 ST      IND      40.754203      -73.942836
# 105        222        ROOSEVELT IS      IND      40.759145      -73.953260
# 106        223       LEXINGTON AVE      IND      40.764629      -73.966113
# 107        224               57 ST      IND      40.763972      -73.977450
# 108        225       47-50 ST-ROCK      IND      40.758663      -73.981329
# 109        228         23 ST-6 AVE      IND      40.742878      -73.992821
# 110        231            GRAND ST      IND      40.718267      -73.993753
# 111        232               2 AVE      IND      40.723402      -73.989938
# 112        234       EAST BROADWAY      IND      40.713715      -73.990173
# 113        235             YORK ST      IND      40.701397      -73.986751
# 114        236           BERGEN ST      IND      40.686145      -73.990862
# 115        237          CARROLL ST      IND      40.680303      -73.995048
# 116        238          SMITH-9 ST      IND      40.673580      -73.995959
# 117        241      15 ST-PROSPECT      IND      40.660365      -73.979493
# 118        242     FT HAMILTON PKY      IND      40.650782      -73.975776
# 119        243          CHURCH AVE      IND      40.644041      -73.979678
# 120        244          DITMAS AVE      IND      40.636119      -73.978172
# 121        245              18 AVE      IND      40.629755      -73.976971
# 122        246               AVE I      IND      40.625322      -73.976127
# 123        247      22 AVE-BAY PKY      IND      40.620769      -73.975264
# 124        248               AVE N      IND      40.615140      -73.974197
# 125        249               AVE P      IND      40.608944      -73.973022
# 126        250       KINGS HIGHWAY      IND      40.603217      -73.972361
# 127        251               AVE U      IND      40.596063      -73.973357
# 128        252               AVE X      IND      40.589620      -73.974250
# 129        253         NEPTUNE AVE      IND      40.581011      -73.974574
# 130        254      JAMAICA-179 ST      IND      40.712646      -73.783817
# 131        255              169 ST      IND      40.710470      -73.793604
# 132        256        PARSONS BLVD      IND      40.707564      -73.803326
# 133        257        SUTPHIN BLVD      IND      40.705460      -73.810708
# 134        258       VAN WYCK BLVD      IND      40.709179      -73.820574
# 135        259     UNION TPK-KEW G      IND      40.714441      -73.831008
# 136         26          DEKALB AVE      BMT      40.690635      -73.981824
# 137        260              75 AVE      IND      40.718331      -73.837324
# 138        261     FOREST HILLS-71      IND      40.721691      -73.844521
# 139        262              67 AVE      IND      40.726523      -73.852719
# 140        263     63 DR-REGO PARK      IND      40.729846      -73.861604
# 141        264      WOODHAVEN BLVD      IND      40.733106      -73.869229
# 142        265     GRAND AV-NEWTON      IND      40.737015      -73.877223
# 143        266        ELMHURST AVE      IND      40.742454      -73.882017
# 144        268               65 ST      IND      40.749669      -73.898453
# 145        269       NORTHERN BLVD      IND      40.752885      -73.906006
# 146        270               46 ST      IND      40.756312      -73.913333
# 147        271         STEINWAY ST      IND      40.756879      -73.920740
# 148        272               36 ST      IND      40.752039      -73.928781
# 149        273        QUEENS PLAZA      IND      40.748973      -73.937243
# 150        276         5 AVE-53 ST      IND      40.760167      -73.975224
# 151        277         7 AVE-53 ST      IND      40.762862      -73.981637
# 152        278      JAMAICA CENTER      IND      40.702147      -73.801109
# 153        278     JFK JAMAICA CT1      IND      40.702147      -73.801109
# 154        279        SUTPHIN BLVD      IND      40.700486      -73.807969
# 155         28            UNION ST      BMT      40.677316      -73.983110
# 156        280     JAMAICA-VAN WYC      IND      40.702566      -73.816859
# 157        282     VAN ALSTON-21ST      IND      40.744065      -73.949724
# 158        283      GREENPOINT AVE      IND      40.731352      -73.954449
# 159        284           NASSAU AV      IND      40.724635      -73.951277
# 160        286            BROADWAY      IND      40.706092      -73.950308
# 161        287        FLUSHING AVE      IND      40.700377      -73.950234
# 162        288     MYRTLE-WILLOUGH      IND      40.694568      -73.949046
# 163        289     BEDFORD/NOSTRAN      IND      40.689627      -73.953522
# 164        290         CLASSON AVE      IND      40.688873      -73.960070
# 165        291     CLINTON-WASH AV      IND      40.688089      -73.966839
# 166        292           FULTON ST      IND      40.687119      -73.975375
# 167        293              242 ST      IRT      40.889248      -73.898583
# 168        294              238 ST      IRT      40.884667      -73.900870
# 169        295              231 ST      IRT      40.878856      -73.904834
# 170        296     MARBLE HILL-225      IRT      40.874561      -73.909831
# 171        297              215 ST      IRT      40.869444      -73.915279
# 172        298              207 ST      IRT      40.864621      -73.918822
# 173        299          DYCKMAN ST      IRT      40.860531      -73.925536
# 174          3        GRAND-30 AVE      BMT      40.766779      -73.921479
# 175         30        PROSPECT AVE      BMT      40.665414      -73.992872
# 176        300              191 ST      IRT      40.855225      -73.929412
# 177        303              157 ST      IRT      40.834041      -73.944890
# 178        304              145 ST      IRT      40.826551      -73.950360
# 179        305     137 ST-CITY COL      IRT      40.822008      -73.953676
# 180        306              125 ST      IRT      40.815581      -73.958372
# 181        307     116 ST-COLUMBIA      IRT      40.807722      -73.964110
# 182        308     110 ST-CATHEDRL      IRT      40.803967      -73.966847
# 183        309              103 ST      IRT      40.799446      -73.968379
# 184         31               25 ST      BMT      40.660397      -73.998091
# 185        310               96 ST      IRT      40.793919      -73.972323
# 186        311               86 ST      IRT      40.788644      -73.976218
# 187        312               79 ST      IRT      40.783934      -73.979917
# 188        313               72 ST      IRT      40.778453      -73.981970
# 189        314       66 ST-LINCOLN      IRT      40.773440      -73.982209
# 190        316               50 ST      IRT      40.761728      -73.983849
# 191        318      34 ST-PENN STA      IRT      40.750373      -73.991057
# 192        319               28 ST      IRT      40.747215      -73.993365
# 193         32               36 ST      BMT      40.655144      -74.003549
# 194        320               23 ST      IRT      40.744081      -73.995657
# 195        321               18 ST      IRT      40.741040      -73.997871
# 196        323      CHRISTOPHER ST      IRT      40.733422      -74.002906
# 197        324          HOUSTON ST      IRT      40.728251      -74.005367
# 198        325            CANAL ST      IRT      40.722854      -74.006277
# 199        326         FRANKLIN ST      IRT      40.719318      -74.006886
# 200        327         CHAMBERS ST      IRT      40.715478      -74.009266
# 201        328        CORTLANDT ST      IRT      40.711835      -74.012188
# 202        329           RECTOR ST      IRT      40.707513      -74.013783
# 203         33               45 ST      BMT      40.648939      -74.010006
# 204        333             WALL ST      IRT      40.706821      -74.009100
# 205        334            CLARK ST      IRT      40.697466      -73.993086
# 206        336             HOYT ST      IRT      40.690545      -73.985065
# 207        337           NEVINS ST      IRT      40.688246      -73.980492
# 208        339           BERGEN ST      IRT      40.680829      -73.975098
# 209         34               53 ST      BMT      40.645069      -74.014034
# 210        340     GRAND ARMY PLAZ      IRT      40.675235      -73.971046
# 211        341        EASTERN PKWY      IRT      40.671987      -73.964375
# 212        343        NOSTRAND AVE      IRT      40.669847      -73.950466
# 213        344        KINGSTON AVE      IRT      40.669399      -73.942161
# 214        345     CROWN HTS-UTICA      IRT      40.668897      -73.932942
# 215        346          SUTTER AVE      IRT      40.664717      -73.922610
# 216        347        SARATOGA AVE      IRT      40.661453      -73.916327
# 217        348        ROCKAWAY AVE      IRT      40.662549      -73.908946
# 218        349           JUNIUS ST      IRT      40.663515      -73.902447
# 219         35               59 ST      BMT      40.641362      -74.017881
# 220        350     PENNSYLVANIA AV      IRT      40.664635      -73.894895
# 221        351      VAN SICLEN AVE      IRT      40.665449      -73.889395
# 222        352        NEW LOTS AVE      IRT      40.666235      -73.884079
# 223        353        PRESIDENT ST      IRT      40.667883      -73.950683
# 224        354         STERLING ST      IRT      40.662742      -73.950850
# 225        355         WINTHROP ST      IRT      40.656652      -73.950200
# 226        356          CHURCH AVE      IRT      40.650843      -73.949575
# 227        357        BEVERLY ROAD      IRT      40.645098      -73.948959
# 228        358         NEWKIRK AVE      IRT      40.639967      -73.948411
# 229        359        FLATBUSH AVE      IRT      40.632836      -73.947642
# 230         36       BAY RIDGE AVE      BMT      40.634967      -74.023377
# 231        360     PELHAM BAY PARK      IRT      40.852462      -73.828121
# 232        361           BUHRE AVE      IRT      40.846810      -73.832569
# 233        362     MIDDLETOWN ROAD      IRT      40.843863      -73.836322
# 234        363      WESTCHESTER SQ      IRT      40.839892      -73.842952
# 235        364          ZEREGA AVE      IRT      40.836488      -73.847036
# 236        365     CASTLE HILL AVE      IRT      40.834255      -73.851222
# 237        366     E 177 ST-PARKCH      IRT      40.833226      -73.860816
# 238        367     ST LAWRENCE AVE      IRT      40.831509      -73.867618
# 239        368        MORRISON AVE      IRT      40.829521      -73.874516
# 240        369           ELDER AVE      IRT      40.828584      -73.879159
# 241         37               77 ST      BMT      40.629742      -74.025510
# 242        370        WHITLOCK AVE      IRT      40.826525      -73.886283
# 243        371     HUNTS POINT AVE      IRT      40.820948      -73.890549
# 244        372        LONGWOOD AVE      IRT      40.816104      -73.896435
# 245        373            E 149 ST      IRT      40.812118      -73.904098
# 246        374            E 143 ST      IRT      40.808719      -73.907657
# 247        375         CYPRESS AVE      IRT      40.805368      -73.914042
# 248        376           BROOK AVE      IRT      40.807566      -73.919240
# 249        377        138 ST-3 AVE      IRT      40.810476      -73.926138
# 250        378       WOODLAWN ROAD      IRT      40.886037      -73.878751
# 251        379     MOSHOLU PARKWAY      IRT      40.879750      -73.884655
# 252         38               86 ST      BMT      40.622687      -74.028398
# 253        380     BEDFORD PARK BL      IRT      40.873412      -73.890064
# 254        381      KINGSBRIDGE RD      IRT      40.867760      -73.897174
# 255        382        FORDHAM ROAD      IRT      40.862803      -73.901034
# 256        383              183 ST      IRT      40.858407      -73.903879
# 257        384        BURNSIDE AVE      IRT      40.853453      -73.907684
# 258        385              176 ST      IRT      40.848480      -73.911794
# 259        386         MT EDEN AVE      IRT      40.844434      -73.914685
# 260        387              170 ST      IRT      40.840075      -73.917791
# 261        388              167 ST      IRT      40.835537      -73.921400
# 262         39     BAY RIDGE-95 ST      BMT      40.616622      -74.030876
# 263        391      138 ST-GR CONC      IRT      40.813224      -73.929849
# 264        392              125 ST      IRT      40.804138      -73.937594
# 265        393              116 ST      IRT      40.798629      -73.941617
# 266        394              110 ST      IRT      40.795020      -73.944250
# 267        395              103 ST      IRT      40.790600      -73.947478
# 268        396               96 ST      IRT      40.785672      -73.951070
# 269        397               86 ST      IRT      40.779492      -73.955589
# 270        398               77 ST      IRT      40.773620      -73.959874
# 271        399     68ST-HUNTER COL      IRT      40.768141      -73.963870
# 272          4      BROADWAY-31 ST      BMT      40.761820      -73.925508
# 273        403               33 ST      IRT      40.746081      -73.982076
# 274        404               28 ST      IRT      40.743070      -73.984264
# 275        405               23 ST      IRT      40.739864      -73.986599
# 276        407         ASTOR PLACE      IRT      40.730054      -73.991070
# 277        409           SPRING ST      IRT      40.722301      -73.997141
# 278         41               7 AVE      BMT      40.677050      -73.972367
# 279        413             WALL ST      IRT      40.707557      -74.011862
# 280        414       BOWLING GREEN      IRT      40.704817      -74.014065
# 281        416       WAKEFIELD-241      IRT      40.903125      -73.850620
# 282        417          NEREID AVE      IRT      40.898379      -73.854376
# 283        418              233 ST      IRT      40.893193      -73.857473
# 284        419              225 ST      IRT      40.888022      -73.860341
# 285         42       PROSPECT PARK      BMT      40.661614      -73.962246
# 286        420              219 ST      IRT      40.883895      -73.862633
# 287        421       GUN HILL ROAD      IRT      40.877850      -73.866256
# 288        422           BURKE AVE      IRT      40.871356      -73.867164
# 289        423        ALLERTON AVE      IRT      40.865462      -73.867352
# 290        424      PELHAM PARKWAY      IRT      40.857192      -73.867615
# 291        425     BRONX PARK EAST      IRT      40.848828      -73.868457
# 292        426            E 180 ST      IRT      40.841894      -73.873488
# 293        427       E TREMONT AVE      IRT      40.840295      -73.880049
# 294        428              174 ST      IRT      40.837288      -73.887734
# 295        429          FREEMAN ST      IRT      40.829993      -73.891865
# 296         43        PARKSIDE AVE      BMT      40.655292      -73.961495
# 297        430          SIMPSON ST      IRT      40.824073      -73.893064
# 298        431       INTERVALE-163      IRT      40.822181      -73.896736
# 299        432        PROSPECT AVE      IRT      40.819585      -73.901770
# 300        433         JACKSON AVE      IRT      40.816490      -73.907807
# 301        434        149 ST-3 AVE      IRT      40.816109      -73.917757
# 302        436        148 ST-LENOX      IRT      40.823880      -73.936470
# 303        437              145 ST      IRT      40.820421      -73.936245
# 304        438              135 ST      IRT      40.814229      -73.940770
# 305        439              125 ST      IRT      40.807754      -73.945495
# 306        439      149 ST-GR CONC      IRT      40.807754      -73.945495
# 307         44          CHURCH AVE      BMT      40.650527      -73.962982
# 308        440              116 ST      IRT      40.802098      -73.949625
# 309        441          110 ST-CPN      IRT      40.799075      -73.951822
# 310        442            DYRE AVE      IRT      40.888300      -73.830834
# 311        443      BAYCHESTER AVE      IRT      40.878663      -73.838591
# 312        444       GUN HILL ROAD      IRT      40.869526      -73.846384
# 313        445      PELHAM PARKWAY      IRT      40.858985      -73.855359
# 314        446         MORRIS PARK      IRT      40.854364      -73.860495
# 315        447             MAIN ST      IRT      40.759600      -73.830030
# 316        448     METS-WILLETS PT      IRT      40.754622      -73.845625
# 317        449              111 ST      IRT      40.751730      -73.855334
# 318         45       BEVERLEY ROAD      BMT      40.644031      -73.964492
# 319        450       103 ST-CORONA      IRT      40.749865      -73.862700
# 320        451       JUNCTION BLVD      IRT      40.749145      -73.869527
# 321        452      90 ST-ELMHURST      IRT      40.748408      -73.876613
# 322        453     82 ST-JACKSON H      IRT      40.747659      -73.883697
# 323        455      69 ST-FISK AVE      IRT      40.746325      -73.896403
# 324        456      61 ST/WOODSIDE      IRT      40.745630      -73.902984
# 325        457       52 ST-LINCOLN      IRT      40.744149      -73.912549
# 326        458      46 ST-BLISS ST      IRT      40.743132      -73.918435
# 327        459     40 ST-LOWERY ST      IRT      40.743781      -73.924016
# 328         46      CORTELYOU ROAD      BMT      40.640927      -73.963891
# 329        460     33 ST/RAWSON ST      IRT      40.744587      -73.930997
# 330        461      QUEENSBORO PLZ      IRT      40.750582      -73.940202
# 331        463      HUNTERS PT AVE      IRT      40.742216      -73.948916
# 332        464      VERNON/JACKSON      IRT      40.742626      -73.953581
# 333         47         NEWKIRK AVE      BMT      40.635082      -73.962793
# 334        471      34 ST - 11 AVE      IRT      40.755882      -74.001910
# 335        475  96 ST - SECOND AVE      IND      40.784318      -73.947152
# 336        476  86 ST - SECOND AVE      IND      40.777891      -73.951787
# 337        477  72 ST - SECOND AVE      IND      40.768799      -73.958424
# 338         48               AVE H      BMT      40.629270      -73.961639
# 339         49               AVE J      BMT      40.625039      -73.960803
# 340          5     WASHINGTON-36 A      BMT      40.756804      -73.929575
# 341         50               AVE M      BMT      40.617618      -73.959399
# 342         51       KINGS HIGHWAY      BMT      40.608670      -73.957734
# 343         52               AVE U      BMT      40.599300      -73.955929
# 344         53           NECK ROAD      BMT      40.595246      -73.955161
# 345         54      SHEEPSHEAD BAY      BMT      40.586896      -73.954155
# 346         55      BRIGHTON BEACH      BMT      40.577621      -73.961376
# 347         56       OCEAN PARKWAY      BMT      40.576312      -73.968501
# 348         57     W 8 ST-AQUARIUM      BMT      40.576127      -73.975939
# 349         58       STILLWELL AVE      BMT      40.577422      -73.981233
# 350         59               9 AVE      BMT      40.646292      -73.994324
# 351          6        BEEBE-39 AVE      BMT      40.752882      -73.932755
# 352         60     FT HAMILTON PKY      BMT      40.640914      -73.994304
# 353        601               14 ST      IRT      40.737826      -74.000201
# 354        601         14 ST-6 AVE      IND      40.738228      -73.996209
# 355        601               6 AVE      BMT      40.737335      -73.996786
# 356        602      14 ST-UNION SQ      BMT      40.735736      -73.990568
# 357        602      14 ST-UNION SQ      IRT      40.734673      -73.989951
# 358        603      149 ST-GR CONC      IRT      40.818375      -73.927351
# 359        604       161 ST-YANKEE      IND      40.827905      -73.925651
# 360        604       161 ST-YANKEE      IRT      40.827994      -73.925831
# 361        605     168 ST-BROADWAY      IND      40.840719      -73.939561
# 362        605     168 ST-BROADWAY      IRT      40.840556      -73.940133
# 363        606            COURT SQ      IND      40.747846      -73.946000
# 364        606            COURT SQ      IRT      40.747023      -73.945264
# 365        606      COURT SQ-23 ST      IND      40.747846      -73.946000
# 366        607     34 ST-HERALD SQ      BMT      40.749567      -73.987950
# 367        607     34 ST-HERALD SQ      IND      40.749719      -73.987823
# 368        608               4 AVE      IND      40.670272      -73.989779
# 369        608                9 ST      BMT      40.670847      -73.988302
# 370        609     42 ST-BRYANT PK      IND      40.754222      -73.984569
# 371        609     5 AVE-BRYANT PK      IRT      40.753821      -73.981963
# 372         61               50 ST      BMT      40.636260      -73.994791
# 373        610     42 ST-GRD CNTRL      IRT      40.751776      -73.976848
# 374        611     42 ST-PA BUS TE      IND      40.757308      -73.989735
# 375        611      42 ST-TIMES SQ      BMT      40.754672      -73.986754
# 376        611      42 ST-TIMES SQ      IRT      40.755290      -73.987495
# 377        612               51 ST      IRT      40.757107      -73.971920
# 378        613               59 ST      IRT      40.762526      -73.967967
# 379        613       LEXINGTON AVE      BMT      40.762660      -73.967258
# 380        614      59 ST-COLUMBUS      IND      40.768296      -73.981736
# 381        614      59 ST-COLUMBUS      IRT      40.768247      -73.981929
# 382        615     NEW UTRECHT AVE      BMT      40.626472      -73.996895
# 383        616      74 ST-BROADWAY      IRT      40.746848      -73.891394
# 384        616       ROOSEVELT AVE      IND      40.746644      -73.891338
# 385        617        ATLANTIC AVE      IRT      40.684359      -73.977666
# 386        617          PACIFIC ST      BMT      40.683666      -73.978810
# 387        618               14 ST      IND      40.740893      -74.001690
# 388        618               8 AVE      BMT      40.739777      -74.002578
# 389        619         BLEECKER ST      IRT      40.725915      -73.994659
# 390        619      BROADWAY/LAFAY      IND      40.725297      -73.996204
# 391         62               55 ST      BMT      40.631435      -73.995476
# 392        620     BOROUGH HALL/CT      BMT      40.694100      -73.991777
# 393        620     BOROUGH HALL/CT      IRT      40.693219      -73.989998
# 394        621        BROADWAY-ENY      IND      40.678334      -73.905316
# 395        622     BROOKLYN BRIDGE      IRT      40.713065      -74.004131
# 396        622         CHAMBERS ST      BMT      40.713243      -74.003401
# 397        623            CANAL ST      BMT      40.719527      -74.001775
# 398        623     MURRAY ST-B'WAY      BMT      40.719527      -74.001775
# 399        624         CHAMBERS ST      IND      40.714111      -74.008585
# 400        624        CORTLANDT ST      BMT      40.710668      -74.011029
# 401        624          PARK PLACE      IRT      40.713051      -74.008811
# 402        624     WORLD TRADE CTR      IND      40.714111      -74.008585
# 403        625         DELANCEY ST      IND      40.718611      -73.988114
# 404        625            ESSEX ST      BMT      40.718315      -73.987437
# 405        626      BOTANIC GARDEN      BMT      40.670343      -73.959245
# 406        627        FRANKLIN AVE      IND      40.681380      -73.956848
# 407        628           FULTON ST      IND      40.710197      -74.007691
# 408        628           FULTON ST      IRT      40.709416      -74.006571
# 409        629          LORIMER ST      BMT      40.714063      -73.950275
# 410        629     METROPOLITAN AV      IND      40.712792      -73.951418
# 411        630          MYRTLE AVE      BMT      40.699430      -73.912385
# 412        635        WHITEHALL ST      BMT      40.703087      -74.012994
# 413        636     JAY ST-METROTEC      BMT      40.692180      -73.985942
# 414        636     JAY ST-METROTEC      IND      40.692338      -73.987342
# 415         64               71 ST      BMT      40.619589      -73.998864
# 416         65               79 ST      BMT      40.613501      -74.000610
# 417         66              18 AVE      BMT      40.607954      -74.001736
# 418         67              20 AVE      BMT      40.604556      -73.998168
# 419         68         BAY PARKWAY      BMT      40.601875      -73.993728
# 420         69              25 AVE      BMT      40.597704      -73.986829
# 421         70           BAY 50 ST      BMT      40.588841      -73.983765
# 422         71               8 AVE      BMT      40.635064      -74.011719
# 423         72     FT HAMILTON PKY      BMT      40.631386      -74.005351
# 424         74              18 AVE      BMT      40.620671      -73.990414
# 425         75              20 AVE      BMT      40.617410      -73.985026
# 426         76      BAY PKY-22 AVE      BMT      40.611815      -73.981848
# 427         77       KINGS HIGHWAY      BMT      40.603923      -73.980353
# 428         78               AVE U      BMT      40.597473      -73.979137
# 429         79               86 ST      BMT      40.592721      -73.978230
# 430          8         49 ST-7 AVE      BMT      40.764811      -73.973347
# 431          8         5 AVE-59 ST      BMT      40.764811      -73.973347
# 432         80              121 ST      BMT      40.700492      -73.828294
# 433         81              111 ST      BMT      40.697418      -73.836345
# 434         82              104 ST      BMT      40.695178      -73.844330
# 435         83      WOODHAVEN BLVD      BMT      40.693879      -73.851576
# 436         84      FOREST PARKWAY      BMT      40.692435      -73.860010
# 437         85        ELDERTS LANE      BMT      40.691324      -73.867139
# 438         86       CYPRESS HILLS      BMT      40.689941      -73.872550
# 439         87         CRESCENT ST      BMT      40.683194      -73.873785
# 440         88         NORWOOD AVE      BMT      40.681410      -73.880039
# 441         89        CLEVELAND ST      BMT      40.679947      -73.884639
# 442          9         57 ST-7 AVE      BMT      40.764664      -73.980658
# 443         90      VAN SICLEN AVE      BMT      40.678024      -73.891688
# 444         91         ALABAMA AVE      BMT      40.676992      -73.898654
# 445         93         CHAUNCEY ST      BMT      40.682893      -73.910456
# 446         94           HALSEY ST      BMT      40.686370      -73.916559
# 447         95           GATES AVE      BMT      40.689630      -73.922270
# 448         96       KOSCIUSZKO ST      BMT      40.693342      -73.928814
# 449         97          MYRTLE AVE      BMT      40.697207      -73.935657
# 450         98        FLUSHING AVE      BMT      40.700260      -73.941126
# 451         99          LORIMER ST      BMT      40.703869      -73.947408

# %%
# This implementation is based on the info posted here:
#  https://stackoverflow.com/questions/66144427/how-do-i-get-zipcodes-from-longitude-and-latitude-on-python

# geo = geopy.Nominatim(user_agent="check_1")

def get_zipcode(df):
    geo = geopy.Nominatim(user_agent="check_1")
    try:
        return geo.reverse('{}, {}'.format(df['GTFS_LATITUDE'], df['GTFS_LONGITUDE'])) \
                                   .raw['address']['postcode']
    except:
        return np.nan

locations['ZIPCODE'] = locations.apply(get_zipcode, axis=1)
    
# locations['ZIPCODE'] = locations.apply(lambda x: geo.reverse('{}, {}'
#                                 .format(x['GTFS_LATITUDE'], x['GTFS_LONGITUDE'])) \
#                                 .raw['address']['postcode'], axis=1)

# geo.reverse("{}, {}".format(40.641362, -74.017881)).raw['address']['neighbourhood']

# %%
print(locations.shape)
display(locations[locations['ZIPCODE'].isna()])
# Out:
# (452, 6)
#     COMPLEX_ID STATION_x DIVISION  GTFS_LATITUDE  GTFS_LONGITUDE ZIPCODE
# 188        313     72 ST      IRT      40.778453       -73.98197     NaN

# %%
# Not sure why the coordinates above failed in Geopy; manual lookup reveals the ZIPCODE to be 10023

locations.loc[188, 'ZIPCODE'] = 10023
display(locations[locations['ZIPCODE'].isna()])
# Out:
# Empty DataFrame
# Columns: [COMPLEX_ID, STATION_x, DIVISION, GTFS_LATITUDE, GTFS_LONGITUDE, ZIPCODE]
# Index: []

# %% [markdown]
# #### Strip off the -xxxx extension present in some of the ZIPCODEs

# %%
locations['ZIPCODE'] = locations['ZIPCODE'].apply(lambda x: str(x).split(sep = '-')[0])

locations[locations['ZIPCODE'].map(len) > 5]
# Out:
#     COMPLEX_ID        STATION_x DIVISION  GTFS_LATITUDE  GTFS_LONGITUDE  \
# 316        448  METS-WILLETS PT      IRT      40.754622      -73.845625
#
#     ZIPCODE
# 316  111354

# %%
# Geopy fails again: Manual lookup of the coordinates above reveals ZIPCODE to be 11368

locations.loc[316, 'ZIPCODE'] = 11368
locations.loc[316, 'ZIPCODE']
# Out:
# 11368

# %%
# Another known error (don't worry, Geopy - I still like you better than the GoogleMaps API)

locations[locations['ZIPCODE'] == '11227']
# Out:
#     COMPLEX_ID  STATION_x DIVISION  GTFS_LATITUDE  GTFS_LONGITUDE ZIPCODE
# 207        337  NEVINS ST      IRT      40.688246      -73.980492   11227

# %%
# 11227 is not a valid ZIPCODE; manual lookup of the coordinates above reveals ZIPCODE to be 11217

locations.loc[207, 'ZIPCODE'] = 11217
locations.loc[207, 'ZIPCODE']
# Out:
# 11217

# %%
locations.head()
# Out:
#   COMPLEX_ID        STATION_x DIVISION  GTFS_LATITUDE  GTFS_LONGITUDE ZIPCODE
# 0          1  DITMARS BL-31 S      BMT      40.775036      -73.912034   11101
# 1         10      49 ST-7 AVE      BMT      40.759901      -73.984139   10019
# 2        100         HEWES ST      BMT      40.706870      -73.953431   11211
# 3        101        MARCY AVE      BMT      40.708359      -73.957757   11211
# 4        103           BOWERY      BMT      40.720280      -73.993915   10002

# %% [markdown]
# #### Add ZIPCODE column to daily_per_station datasets for both years

# %%
print(daily_per_station_2019.shape)
daily_per_station_2019 =daily_per_station_2019.merge(right=locations, 
                                                     how='left', 
                                                     on=['COMPLEX_ID', 'STATION_x', 'DIVISION',
                                                         'GTFS_LATITUDE', 'GTFS_LONGITUDE'])
print(daily_per_station_2019.shape)
# Out:
# (27512, 19)
# (27512, 20)

# %%
daily_per_station_2019.sample(10)
# Out:
#       COMPLEX_ID        STATION_x DIVISION        DATE  \
# 26227          8      49 ST-7 AVE      BMT  2019-05-20
# 2527         152           135 ST      IND  2019-06-05
# 9079         272            36 ST      IND  2019-06-30
# 13418        350  PENNSYLVANIA AV      IRT  2019-05-10
# 14412        365  CASTLE HILL AVE      IRT  2019-05-28
# 3027          16   8 ST-B'WAY NYU      BMT  2019-06-17
# 12783         34            53 ST      BMT  2019-06-14
# 10151        292        FULTON ST      IND  2019-06-04
# 7658         249            AVE P      IND  2019-06-12
# 1438         130       WILSON AVE      BMT  2019-06-11
#
#        NET_DAILY_STATION_ENTRIES        STATION_y        STOP_NAME  \
# 26227                      11960            49 ST       5 Av/59 St
# 2527                        5703           135 ST           135 St
# 9079                         349            36 ST            36 St
# 13418                       4661  PENNSYLVANIA AV  Pennsylvania Av
# 14412                       6104   CASTLE HILL AV   Castle Hill Av
# 3027                       12618         8 ST-NYU       8 St - NYU
# 12783                       8979            53 ST            53 St
# 10151                       3790        FULTON ST        Fulton St
# 7658                        2591         AVENUE P         Avenue P
# 1438                        4126        WILSON AV        Wilson Av
#
#       LINE_NAME_x LINE_NAME_y BOROUGH  WEEKDAY     DESC  GTFS_LATITUDE  \
# 26227         NQR        NQRW       M        1  REGULAR      40.764811
# 2527           BC          BC       M        1  REGULAR      40.817894
# 9079           MR          MR       Q        0  REGULAR      40.752039
# 13418           3           3      Bk        1  REGULAR      40.664635
# 14412           6           6      Bx        1  REGULAR      40.834255
# 3027           NR         NRW       M        1  REGULAR      40.730328
# 12783           R           R      Bk        1  REGULAR      40.645069
# 10151           G           G      Bk        1  REGULAR      40.687119
# 7658            F           F      Bk        1  REGULAR      40.608944
# 1438            L           L      Bk        1  REGULAR      40.688764
#
#        GTFS_LONGITUDE                 LINE REMOTE BOOTH       SCP  \
# 26227      -73.973347              Astoria   R081  A015  00-00-00
# 2527       -73.947649   8th Av - Fulton St   R332  N024  00-00-00
# 9079       -73.928781          Queens Blvd   R339  N312  00-00-00
# 13418      -73.894895          Eastern Pky   R067  R632  00-00-00
# 14412      -73.851222               Pelham   R106  R418  00-00-00
# 3027       -73.992629  Broadway - Brighton   R085  A038  00-00-00
# 12783      -74.014034               4th Av   R233  C020  00-00-00
# 10151      -73.975375            Crosstown   R318  N422  00-00-00
# 7658       -73.973022      6th Av - Culver   R424  N556  00-00-00
# 1438       -73.904046             Canarsie   R295  H032  00-00-00
#
#                            ID ZIPCODE
# 26227  A015 - R081 - 00-00-00   10019
# 2527   N024 - R332 - 00-00-00   10040
# 9079   N312 - R339 - 00-00-00   11101
# 13418  R632 - R067 - 00-00-00   11207
# 14412  R418 - R106 - 00-00-00   10461
# 3027   A038 - R085 - 00-00-00   10003
# 12783  C020 - R233 - 00-00-00   11220
# 10151  N422 - R318 - 00-00-00   11221
# 7658   N556 - R424 - 00-00-00   11223
# 1438   H032 - R295 - 00-00-00   11207

# %% [markdown]
# #### Double check for NaNs, then save daily_per_station_2019 to file (can reload below and avoid running all of above in future)

# %%
daily_per_station_2019[daily_per_station_2019.isna().any(axis=1)].shape[0]
# Out:
# 0

# %%
# Okay, write this dataframe to file and then we don't have to run any of the above again!

daily_per_station_2019.to_csv('daily_per_station_2019.csv', index=False)

# %% [markdown]
# ##### Repeat the above steps for the 2021 data

# %%
# Add ZIPCODE column

print(daily_per_station_2021.shape)
daily_per_station_2021 =daily_per_station_2021.merge(right=locations, 
                                                     how='left', 
                                                     on=['COMPLEX_ID', 'STATION_x', 'DIVISION',
                                                         'GTFS_LATITUDE', 'GTFS_LONGITUDE'])
print(daily_per_station_2021.shape)
# Out:
# (27567, 19)
# (27567, 20)

# %%
daily_per_station_2021.sample(10)
# Out:
#       COMPLEX_ID       STATION_x DIVISION        DATE  \
# 11662        318  34 ST-PENN STA      IRT  2021-05-12
# 1291         129       HALSEY ST      BMT  2021-05-11
# 6416         222    ROOSEVELT IS      IND  2021-05-12
# 18464        436    148 ST-LENOX      IRT  2021-06-13
# 16337        395          103 ST      IRT  2021-06-21
# 24229        623        CANAL ST      BMT  2021-05-14
# 5717         210  NORWOOD-205 ST      IND  2021-06-14
# 21097         54  SHEEPSHEAD BAY      BMT  2021-06-23
# 18337        433     JACKSON AVE      IRT  2021-06-08
# 20693         49           AVE J      BMT  2021-05-16
#
#        NET_DAILY_STATION_ENTRIES        STATION_y             STOP_NAME  \
# 11662                       6626   34 ST-PENN STA  34 St - Penn Station
# 1291                        2924        HALSEY ST             Halsey St
# 6416                        2585  ROOSEVELT ISLND      Roosevelt Island
# 18464                        769    HARLEM 148 ST       Harlem - 148 St
# 16337                       5233           103 ST                103 St
# 24229                      36759         CANAL ST              Canal St
# 5717                        3572   NORWOOD 205 ST      Norwood - 205 St
# 21097                       5878   SHEEPSHEAD BAY        Sheepshead Bay
# 18337                       1758       JACKSON AV            Jackson Av
# 20693                       1572         AVENUE J              Avenue J
#
#       LINE_NAME_x LINE_NAME_y BOROUGH  WEEKDAY     DESC  GTFS_LATITUDE  \
# 11662         123         123       M        1  REGULAR      40.750373
# 1291            L           L       Q        1  REGULAR      40.695602
# 6416            F           F       M        1  REGULAR      40.759145
# 18464           3           3       M        0  REGULAR      40.823880
# 16337           6           6       M        1  REGULAR      40.790600
# 24229      JNQRZ6     JNQRZ6W       M        1  REGULAR      40.719527
# 5717            D           D      Bx        1  REGULAR      40.874811
# 21097          BQ          BQ      Bk        1  REGULAR      40.586896
# 18337          25          25      Bx        1  REGULAR      40.816490
# 20693          BQ          BQ      Bk        0  REGULAR      40.625039
#
#        GTFS_LONGITUDE                     LINE REMOTE BOOTH       SCP  \
# 11662      -73.991057           Broadway - 7Av   R031  R141  00-00-00
# 1291       -73.904084                 Canarsie   R266  H028  00-00-00
# 6416       -73.953260                  63rd St   R259  N602  00-00-00
# 18464      -73.936470  Lenox - White Plains Rd   R345  R309  00-00-00
# 16337      -73.947478             Lexington Av   R180  R252  00-00-00
# 24229      -74.001775                 Broadway   R118  A066  00-00-00
# 5717       -73.878855                Concourse   R157  N224  00-00-00
# 21097      -73.954155      Broadway - Brighton   R136  B027  00-00-00
# 18337      -73.907807  Lenox - White Plains Rd   R405  R312  00-00-00
# 20693      -73.960803      Broadway - Brighton   R228  B021  00-00-00
#
#                            ID ZIPCODE
# 11662  R141 - R031 - 00-00-00   10001
# 1291   H028 - R266 - 00-00-00   11385
# 6416   N602 - R259 - 00-00-00   10044
# 18464  R309 - R345 - 00-00-00   10039
# 16337  R252 - R180 - 00-00-00   10037
# 24229  A066 - R118 - 00-00-00   10003
# 5717   N224 - R157 - 00-00-00   10467
# 21097  B027 - R136 - 00-00-00   11235
# 18337  R312 - R405 - 00-00-00   10459
# 20693  B021 - R228 - 00-00-00   11234

# %% [markdown]
# #### Double check for NaNs, then save daily_per_station_2021 to file (can reload below and avoid running all of above in future)

# %%
daily_per_station_2021[daily_per_station_2021.isna().any(axis=1)].shape[0]
# Out:
# 0

# %%
# Okay, write this dataframe to file and then we don't have to run any of the above again!

daily_per_station_2021.to_csv('daily_per_station_2021.csv', index=False)

# %% [markdown]
# ## Move to Project_Notebook_Visualizations & start by loading in the 2 datasets just saved!
