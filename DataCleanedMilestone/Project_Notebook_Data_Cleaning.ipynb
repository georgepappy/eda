# %%
import pandas as pd
import numpy as np

from sqlalchemy import create_engine

import geopy

import matplotlib.pyplot as plt
import seaborn as sns

# Configure image format to be ‘svg’
# %config InlineBackend.figure_format = 'svg'

# allow visuals to render within notebook
# %matplotlib inline

# %%
# Make some room to see stuff (i.e. drop display limits on Pandas rows & cols - be careful w/ big df's!)

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # 1. Import MTA Data From SQLite Database

# %%
engine = create_engine('sqlite:///../_PROJECT/mta_data.db')

engine.table_names()
# Out:
# /var/folders/16/my2sdbrn4hvfl3_91fx0wj9c0000gn/T/ipykernel_16139/152434287.py:3: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ['mta_data']

# %%
# Check for any NULL values

pd.read_sql('''
            SELECT *
            FROM mta_data
            WHERE unit IS NULL 
               OR scp IS NULL
               OR station IS NULL
               OR linename IS NULL
               OR date IS NULL
               OR time IS NULL
               OR desc IS NULL
               OR entries IS NULL
               OR exits IS NULL;
            ''', con=engine)
# Out:
# Empty DataFrame
# Columns: [C/A, UNIT, SCP, STATION, LINENAME, DIVISION, DATE, TIME, DESC, ENTRIES, EXITS]
# Index: []

# %%
# Bring in just the data for May-June 2019 (order by ascending 'DATE'; don't bother importing 'EXITS' col)

# df_2019 = pd.read_sql('''
#                       SELECT (STATION || ' - ' || LINENAME || ' - ' || DIVISION) AS STATION_ID,
#                          STATION AS STATION_NAME, [C/A], UNIT, SCP,  DATE, TIME, DESC, ENTRIES
#                       FROM mta_data
#                       WHERE DATE = '04/30/2019' OR DATE LIKE '05%19' OR DATE LIKE '06%19'
#                       ORDER BY DATE ASC;
#                       ''', con=engine)

df_2019 = pd.read_sql('''
                      SELECT *
                      FROM mta_data
                      WHERE DATE = '04/30/2019' OR DATE LIKE '05%19' OR DATE LIKE '06%19'
                      ORDER BY DATE ASC;
                      ''', con=engine)

# %%
# Add a 'DATETIME' column (and drop 'DATE' & 'TIME' - can get either of these from 'DATETIME' if needed)

df_2019['DATETIME'] = pd.to_datetime(df_2019['DATE'] + ' ' + df_2019['TIME'])

# Make 'DATE' column a proper date format
df_2019['DATE'] = df_2019['DATETIME'].dt.date

df_2019.drop(columns=['TIME', 'EXITS'], inplace=True)

# %%
print(df_2019.shape)
display(df_2019.head())
display(df_2019.tail())
# Out:
# (3639340, 10)
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE     DESC  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  2019-04-30  REGULAR
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  2019-04-30  REGULAR
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  2019-04-30  REGULAR
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  2019-04-30  REGULAR
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  2019-04-30  REGULAR
#
#    ENTRIES            DATETIME
# 0  7038242 2019-04-30 00:00:00
# 1  7038261 2019-04-30 04:00:00
# 2  7038308 2019-04-30 08:00:00
# 3  7038474 2019-04-30 12:00:00
# 4  7038775 2019-04-30 16:00:00
#            C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 3639335  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  2019-06-30
# 3639336  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  2019-06-30
# 3639337  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  2019-06-30
# 3639338  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  2019-06-30
# 3639339  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  2019-06-30
#
#             DESC  ENTRIES            DATETIME
# 3639335  REGULAR     5554 2019-06-30 05:00:00
# 3639336  REGULAR     5554 2019-06-30 09:00:00
# 3639337  REGULAR     5554 2019-06-30 13:00:00
# 3639338  REGULAR     5554 2019-06-30 17:00:00
# 3639339  REGULAR     5554 2019-06-30 21:00:00

# %%
# Bring in just the data for May-June 2021 (order by ascending 'DATE'; don't bother importing 'EXITS' col)

# df_2021 = pd.read_sql('''
#                       SELECT (STATION || ' - ' || LINENAME || ' - ' || DIVISION) AS STATION_ID,
#                          STATION AS STATION_NAME, [C/A], UNIT, SCP,  DATE, TIME, DESC, ENTRIES
#                       FROM mta_data
#                       WHERE DATE = '04/30/2021' OR DATE LIKE '05%21' OR DATE LIKE '06%21'
#                       ORDER BY DATE ASC;
#                       ''', con=engine)

df_2021 = pd.read_sql('''
                      SELECT *
                      FROM mta_data
                      WHERE DATE = '04/30/2021' OR DATE LIKE '05%21' OR DATE LIKE '06%21'
                      ORDER BY DATE ASC;
                      ''', con=engine)

# %%
# Add a 'DATETIME' column (and drop 'DATE' & 'TIME' - can get either of these from 'DATETIME' if needed)

df_2021['DATETIME'] = pd.to_datetime(df_2021['DATE'] + ' ' + df_2021['TIME'])

# Make 'DATE' column a proper date format
df_2021['DATE'] = df_2021['DATETIME'].dt.date

df_2021.drop(columns=['TIME', 'EXITS'], inplace=True)

# %%
print(df_2021.shape)
display(df_2021.head())
display(df_2021.tail())
# Out:
# (3706606, 10)
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE     DESC  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  2021-04-30  REGULAR
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  2021-04-30  REGULAR
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  2021-04-30  REGULAR
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  2021-04-30  REGULAR
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  2021-04-30  REGULAR
#
#    ENTRIES            DATETIME
# 0  7564048 2021-04-30 00:00:00
# 1  7564059 2021-04-30 04:00:00
# 2  7564073 2021-04-30 08:00:00
# 3  7564118 2021-04-30 12:00:00
# 4  7564286 2021-04-30 16:00:00
#            C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 3706601  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  2021-06-30
# 3706602  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  2021-06-30
# 3706603  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  2021-06-30
# 3706604  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  2021-06-30
# 3706605  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  2021-06-30
#
#             DESC  ENTRIES            DATETIME
# 3706601  REGULAR     5554 2021-06-30 05:00:00
# 3706602  REGULAR     5554 2021-06-30 09:00:00
# 3706603  REGULAR     5554 2021-06-30 13:00:00
# 3706604  REGULAR     5554 2021-06-30 17:00:00
# 3706605  REGULAR     5554 2021-06-30 21:00:00

# %% [markdown]
# # 2. Basic Cleaning

# %% [markdown]
# ### 2a) Check for Duplicates
# #### A single turnstile somwhere in the system is uniquely identified by C/A (Booth) + UNIT (Station) + SCP (Turnstile)
# #### Add a new column 'ID' that creates a unique identifier for grouping on these three

# %%
df_2019['ID'] = df_2019['C/A'] + ' - ' + df_2019['UNIT'] + ' - ' + df_2019['SCP']
df_2019.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE     DESC  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  2019-04-30  REGULAR
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  2019-04-30  REGULAR
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  2019-04-30  REGULAR
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  2019-04-30  REGULAR
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  2019-04-30  REGULAR
#
#    ENTRIES            DATETIME                      ID
# 0  7038242 2019-04-30 00:00:00  A002 - R051 - 02-00-00
# 1  7038261 2019-04-30 04:00:00  A002 - R051 - 02-00-00
# 2  7038308 2019-04-30 08:00:00  A002 - R051 - 02-00-00
# 3  7038474 2019-04-30 12:00:00  A002 - R051 - 02-00-00
# 4  7038775 2019-04-30 16:00:00  A002 - R051 - 02-00-00

# %%
df_2021['ID'] = df_2021['C/A'] + ' - ' + df_2021['UNIT'] + ' - ' + df_2021['SCP']
df_2021.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE     DESC  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  2021-04-30  REGULAR
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  2021-04-30  REGULAR
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  2021-04-30  REGULAR
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  2021-04-30  REGULAR
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  2021-04-30  REGULAR
#
#    ENTRIES            DATETIME                      ID
# 0  7564048 2021-04-30 00:00:00  A002 - R051 - 02-00-00
# 1  7564059 2021-04-30 04:00:00  A002 - R051 - 02-00-00
# 2  7564073 2021-04-30 08:00:00  A002 - R051 - 02-00-00
# 3  7564118 2021-04-30 12:00:00  A002 - R051 - 02-00-00
# 4  7564286 2021-04-30 16:00:00  A002 - R051 - 02-00-00

# %% [markdown]
# #### Now check for duplicates (Start with df_2019):

# %%
check = df_2019.groupby(['ID', 'DATETIME'])['ENTRIES'] \
                        .count().sort_values(ascending=False)
check.reset_index().head()
# Out:
#                        ID            DATETIME  ENTRIES
# 0  R249 - R179 - 01-05-00 2019-06-27 00:00:00        4
# 1  N045 - R187 - 01-06-00 2019-06-02 17:00:00        4
# 2  R174 - R034 - 00-00-03 2019-06-08 00:00:00        4
# 3  N045 - R187 - 01-00-00 2019-06-02 17:00:00        4
# 4  R174 - R034 - 00-00-02 2019-06-08 00:00:00        4

# %%
for i in range(0, 6):
    display(df_2019[(df_2019['ID'] == check.reset_index().iloc[i, 0:1].values[0]) & 
                    (df_2019['DATETIME'] == check.reset_index().iloc[i, 1:2].values[0])])
# Out:
#           C/A  UNIT       SCP STATION LINENAME DIVISION        DATE  \
# 3427686  R249  R179  01-05-00   86 ST      456      IRT  2019-06-27
# 3427687  R249  R179  01-05-00   86 ST      456      IRT  2019-06-27
# 3457150  R249  R179  01-05-00   86 ST      456      IRT  2019-06-27
# 3457151  R249  R179  01-05-00   86 ST      456      IRT  2019-06-27
#
#                DESC  ENTRIES   DATETIME                      ID
# 3427686     REGULAR        6 2019-06-27  R249 - R179 - 01-05-00
# 3427687  RECOVR AUD       11 2019-06-27  R249 - R179 - 01-05-00
# 3457150     REGULAR        6 2019-06-27  R249 - R179 - 01-05-00
# 3457151  RECOVR AUD       11 2019-06-27  R249 - R179 - 01-05-00
#           C/A  UNIT       SCP       STATION LINENAME DIVISION        DATE  \
# 1940800  N045  R187  01-06-00  81 ST-MUSEUM       BC      IND  2019-06-02
# 1940801  N045  R187  01-06-00  81 ST-MUSEUM       BC      IND  2019-06-02
# 1969768  N045  R187  01-06-00  81 ST-MUSEUM       BC      IND  2019-06-02
# 1969769  N045  R187  01-06-00  81 ST-MUSEUM       BC      IND  2019-06-02
#
#                DESC  ENTRIES            DATETIME                      ID
# 1940800     REGULAR  2254050 2019-06-02 17:00:00  N045 - R187 - 01-06-00
# 1940801  RECOVR AUD  2254049 2019-06-02 17:00:00  N045 - R187 - 01-06-00
# 1969768     REGULAR  2254050 2019-06-02 17:00:00  N045 - R187 - 01-06-00
# 1969769  RECOVR AUD  2254049 2019-06-02 17:00:00  N045 - R187 - 01-06-00
#           C/A  UNIT       SCP STATION LINENAME DIVISION        DATE  \
# 2306436  R174  R034  00-00-03  125 ST        1      IRT  2019-06-08
# 2306437  R174  R034  00-00-03  125 ST        1      IRT  2019-06-08
# 2335466  R174  R034  00-00-03  125 ST        1      IRT  2019-06-08
# 2335467  R174  R034  00-00-03  125 ST        1      IRT  2019-06-08
#
#                DESC  ENTRIES   DATETIME                      ID
# 2306436     REGULAR  3828801 2019-06-08  R174 - R034 - 00-00-03
# 2306437  RECOVR AUD  3828804 2019-06-08  R174 - R034 - 00-00-03
# 2335466     REGULAR  3828801 2019-06-08  R174 - R034 - 00-00-03
# 2335467  RECOVR AUD  3828804 2019-06-08  R174 - R034 - 00-00-03
#           C/A  UNIT       SCP       STATION LINENAME DIVISION        DATE  \
# 1940782  N045  R187  01-00-00  81 ST-MUSEUM       BC      IND  2019-06-02
# 1940783  N045  R187  01-00-00  81 ST-MUSEUM       BC      IND  2019-06-02
# 1969750  N045  R187  01-00-00  81 ST-MUSEUM       BC      IND  2019-06-02
# 1969751  N045  R187  01-00-00  81 ST-MUSEUM       BC      IND  2019-06-02
#
#                DESC  ENTRIES            DATETIME                      ID
# 1940782     REGULAR  5254570 2019-06-02 17:00:00  N045 - R187 - 01-00-00
# 1940783  RECOVR AUD  5254568 2019-06-02 17:00:00  N045 - R187 - 01-00-00
# 1969750     REGULAR  5254570 2019-06-02 17:00:00  N045 - R187 - 01-00-00
# 1969751  RECOVR AUD  5254568 2019-06-02 17:00:00  N045 - R187 - 01-00-00
#           C/A  UNIT       SCP STATION LINENAME DIVISION        DATE  \
# 2306430  R174  R034  00-00-02  125 ST        1      IRT  2019-06-08
# 2306431  R174  R034  00-00-02  125 ST        1      IRT  2019-06-08
# 2335460  R174  R034  00-00-02  125 ST        1      IRT  2019-06-08
# 2335461  R174  R034  00-00-02  125 ST        1      IRT  2019-06-08
#
#                DESC  ENTRIES   DATETIME                      ID
# 2306430     REGULAR  6091547 2019-06-08  R174 - R034 - 00-00-02
# 2306431  RECOVR AUD  6091548 2019-06-08  R174 - R034 - 00-00-02
# 2335460     REGULAR  6091547 2019-06-08  R174 - R034 - 00-00-02
# 2335461  RECOVR AUD  6091548 2019-06-08  R174 - R034 - 00-00-02
#           C/A  UNIT       SCP       STATION LINENAME DIVISION        DATE  \
# 2467844  N045  R187  01-06-00  81 ST-MUSEUM       BC      IND  2019-06-11
# 2467845  N045  R187  01-06-00  81 ST-MUSEUM       BC      IND  2019-06-11
# 2496957  N045  R187  01-06-00  81 ST-MUSEUM       BC      IND  2019-06-11
# 2496958  N045  R187  01-06-00  81 ST-MUSEUM       BC      IND  2019-06-11
#
#                DESC  ENTRIES            DATETIME                      ID
# 2467844     REGULAR  2258033 2019-06-11 21:00:00  N045 - R187 - 01-06-00
# 2467845  RECOVR AUD  2258031 2019-06-11 21:00:00  N045 - R187 - 01-06-00
# 2496957     REGULAR  2258033 2019-06-11 21:00:00  N045 - R187 - 01-06-00
# 2496958  RECOVR AUD  2258031 2019-06-11 21:00:00  N045 - R187 - 01-06-00

# %% [markdown]
# #### Looks like accidental data duplication and some RECOV AUDs virtually identical to REGULARs; will just drop all the duplicates

# %%
print(df_2019.shape)

df_2019 = df_2019.sort_values(by=['ID', 'DATETIME'], 
                              ascending=False) \
                             .drop_duplicates(subset=['ID', 'DATETIME'])

df_2019.reset_index(drop=True, inplace=True)
print(df_2019.shape)
# Out:
# (3639340, 11)
# (1819646, 11)

# %%
# Re-check for duplicates

check = df_2019.groupby(['ID', 'DATETIME'])['ENTRIES'] \
                        .count().sort_values(ascending=False)
check.reset_index().head()
# Out:
#                        ID            DATETIME  ENTRIES
# 0  A002 - R051 - 02-00-00 2019-04-30 00:00:00        1
# 1  R142 - R293 - 01-00-01 2019-05-12 18:00:00        1
# 2  R142 - R293 - 01-00-01 2019-05-14 06:00:00        1
# 3  R142 - R293 - 01-00-01 2019-05-14 02:00:00        1
# 4  R142 - R293 - 01-00-01 2019-05-13 22:00:00        1

# %% [markdown]
# #### Now deal with duplicates in df_2021:

# %%
check = df_2021.groupby(['ID', 'DATETIME'])['ENTRIES'] \
                         .count().sort_values(ascending=False)
check.reset_index().head()
# Out:
#                        ID            DATETIME  ENTRIES
# 0  B024 - R211 - 00-05-00 2021-05-02 12:00:00        4
# 1  B024 - R211 - 00-05-00 2021-05-05 12:00:00        4
# 2  N329 - R201 - 00-03-02 2021-05-08 05:00:00        4
# 3  N329 - R201 - 00-03-02 2021-05-08 01:00:00        4
# 4  N335 - R158 - 01-00-03 2021-06-20 18:30:00        4

# %%
for i in range(0, 6):
    display(df_2021[(df_2021['ID'] == check.reset_index().iloc[i, 0:1].values[0]) & 
                    (df_2021['DATETIME'] == check.reset_index().iloc[i, 1:2].values[0])])
# Out:
#          C/A  UNIT       SCP    STATION LINENAME DIVISION        DATE  \
# 121785  B024  R211  00-05-00  KINGS HWY       BQ      BMT  2021-05-02
# 121786  B024  R211  00-05-00  KINGS HWY       BQ      BMT  2021-05-02
# 151574  B024  R211  00-05-00  KINGS HWY       BQ      BMT  2021-05-02
# 151575  B024  R211  00-05-00  KINGS HWY       BQ      BMT  2021-05-02
#
#               DESC  ENTRIES            DATETIME                      ID
# 121785     REGULAR   262152 2021-05-02 12:00:00  B024 - R211 - 00-05-00
# 121786  RECOVR AUD       13 2021-05-02 12:00:00  B024 - R211 - 00-05-00
# 151574     REGULAR   262152 2021-05-02 12:00:00  B024 - R211 - 00-05-00
# 151575  RECOVR AUD       13 2021-05-02 12:00:00  B024 - R211 - 00-05-00
#          C/A  UNIT       SCP    STATION LINENAME DIVISION        DATE  \
# 301051  B024  R211  00-05-00  KINGS HWY       BQ      BMT  2021-05-05
# 301052  B024  R211  00-05-00  KINGS HWY       BQ      BMT  2021-05-05
# 330870  B024  R211  00-05-00  KINGS HWY       BQ      BMT  2021-05-05
# 330871  B024  R211  00-05-00  KINGS HWY       BQ      BMT  2021-05-05
#
#               DESC  ENTRIES            DATETIME                      ID
# 301051     REGULAR   262152 2021-05-05 12:00:00  B024 - R211 - 00-05-00
# 301052  RECOVR AUD       21 2021-05-05 12:00:00  B024 - R211 - 00-05-00
# 330870     REGULAR   262152 2021-05-05 12:00:00  B024 - R211 - 00-05-00
# 330871  RECOVR AUD       21 2021-05-05 12:00:00  B024 - R211 - 00-05-00
#          C/A  UNIT       SCP         STATION LINENAME DIVISION        DATE  \
# 490387  N329  R201  00-03-02  WOODHAVEN BLVD       MR      IND  2021-05-08
# 490388  N329  R201  00-03-02  WOODHAVEN BLVD       MR      IND  2021-05-08
# 520213  N329  R201  00-03-02  WOODHAVEN BLVD       MR      IND  2021-05-08
# 520214  N329  R201  00-03-02  WOODHAVEN BLVD       MR      IND  2021-05-08
#
#               DESC   ENTRIES            DATETIME                      ID
# 490387     REGULAR   4825280 2021-05-08 05:00:00  N329 - R201 - 00-03-02
# 490388  RECOVR AUD  12538860 2021-05-08 05:00:00  N329 - R201 - 00-03-02
# 520213     REGULAR   4825280 2021-05-08 05:00:00  N329 - R201 - 00-03-02
# 520214  RECOVR AUD  12538860 2021-05-08 05:00:00  N329 - R201 - 00-03-02
#          C/A  UNIT       SCP         STATION LINENAME DIVISION        DATE  \
# 490385  N329  R201  00-03-02  WOODHAVEN BLVD       MR      IND  2021-05-08
# 490386  N329  R201  00-03-02  WOODHAVEN BLVD       MR      IND  2021-05-08
# 520211  N329  R201  00-03-02  WOODHAVEN BLVD       MR      IND  2021-05-08
# 520212  N329  R201  00-03-02  WOODHAVEN BLVD       MR      IND  2021-05-08
#
#               DESC   ENTRIES            DATETIME                      ID
# 490385     REGULAR   4825276 2021-05-08 01:00:00  N329 - R201 - 00-03-02
# 490386  RECOVR AUD  12538859 2021-05-08 01:00:00  N329 - R201 - 00-03-02
# 520211     REGULAR   4825276 2021-05-08 01:00:00  N329 - R201 - 00-03-02
# 520212  RECOVR AUD  12538859 2021-05-08 01:00:00  N329 - R201 - 00-03-02
#           C/A  UNIT       SCP      STATION LINENAME DIVISION        DATE  \
# 3061698  N335  R158  01-00-03  KEW GARDENS       EF      IND  2021-06-20
# 3061699  N335  R158  01-00-03  KEW GARDENS       EF      IND  2021-06-20
# 3091640  N335  R158  01-00-03  KEW GARDENS       EF      IND  2021-06-20
# 3091641  N335  R158  01-00-03  KEW GARDENS       EF      IND  2021-06-20
#
#                DESC  ENTRIES            DATETIME                      ID
# 3061698     REGULAR  5201958 2021-06-20 18:30:00  N335 - R158 - 01-00-03
# 3061699  RECOVR AUD  5201960 2021-06-20 18:30:00  N335 - R158 - 01-00-03
# 3091640     REGULAR  5201958 2021-06-20 18:30:00  N335 - R158 - 01-00-03
# 3091641  RECOVR AUD  5201960 2021-06-20 18:30:00  N335 - R158 - 01-00-03
#          C/A  UNIT       SCP    STATION LINENAME DIVISION        DATE  \
# 181380  B024  R211  00-05-00  KINGS HWY       BQ      BMT  2021-05-03
# 181381  B024  R211  00-05-00  KINGS HWY       BQ      BMT  2021-05-03
# 211194  B024  R211  00-05-00  KINGS HWY       BQ      BMT  2021-05-03
# 211195  B024  R211  00-05-00  KINGS HWY       BQ      BMT  2021-05-03
#
#               DESC  ENTRIES            DATETIME                      ID
# 181380     REGULAR   262152 2021-05-03 20:00:00  B024 - R211 - 00-05-00
# 181381  RECOVR AUD       16 2021-05-03 20:00:00  B024 - R211 - 00-05-00
# 211194     REGULAR   262152 2021-05-03 20:00:00  B024 - R211 - 00-05-00
# 211195  RECOVR AUD       16 2021-05-03 20:00:00  B024 - R211 - 00-05-00

# %% [markdown]
# #### Looks like a similar situation as with df_2019; some RECOVR AUDs look like trivial tests of some sort; will just drop the duplicates

# %%
print(df_2021.shape)

df_2021 = df_2021.sort_values(by=['ID', 'DATETIME'], 
                              ascending=False) \
                             .drop_duplicates(subset=['ID', 'DATETIME'])

df_2021.reset_index(drop=True, inplace=True)
print(df_2021.shape)
# Out:
# (3706606, 11)
# (1853257, 11)

# %%
# Re-check for duplicates

check = df_2021.groupby(['ID', 'DATETIME'])['ENTRIES'] \
                         .count().sort_values(ascending=False)
check.reset_index().head()
# Out:
#                        ID            DATETIME  ENTRIES
# 0  A002 - R051 - 02-00-00 2021-04-30 00:00:00        1
# 1  R138 - R293 - 00-03-04 2021-05-08 22:00:00        1
# 2  R138 - R293 - 00-03-04 2021-05-13 06:00:00        1
# 3  R138 - R293 - 00-03-04 2021-05-13 02:00:00        1
# 4  R138 - R293 - 00-03-04 2021-05-12 22:00:00        1

# %% [markdown]
# ### 2b) Find common set of Stations in 2019 and 2021 datasets (Station roughly equates to the 'UNIT' column)

# %%
print(df_2019['UNIT'].unique().shape)
print(df_2021['UNIT'].unique().shape)

print(np.setdiff1d(df_2019['UNIT'].unique(), df_2021['UNIT'].unique()))
print(np.setdiff1d(df_2021['UNIT'].unique(), df_2019['UNIT'].unique()))
# Out:
# (469,)
# (469,)
# ['R260']
# ['R094']

# %% [markdown]
# #### Each year's data has one station not present in the other - will find the common set between the two years

# %%
common_units = np.intersect1d(df_2019['UNIT'].unique(), df_2021['UNIT'].unique())
common_units.shape
# Out:
# (468,)

# %% [markdown]
# #### Now limit both year's datasets down to these common stations (UNITs)

# %%
print(df_2019.shape)
df_2019 = df_2019[df_2019['UNIT'].isin(common_units)]
df_2019.reset_index(drop=True, inplace=True)
print(df_2019.shape)
# Out:
# (1819646, 11)
# (1817754, 11)

# %%
print(df_2021.shape)
df_2021 = df_2021[df_2021['UNIT'].isin(common_units)]
df_2021.reset_index(drop=True, inplace=True)
print(df_2021.shape)
# Out:
# (1853257, 11)
# (1848056, 11)

# %% [markdown]
# ### 2c) Find NET_DAILY_ENTRIES per unique turnstile ('ID')

# %% [markdown]
# #### Assumption 1: Some turnstiles count backwards, accounting for the negatives; just take absolute value of everything
# #### Assumption 2: Even considering rush hr., >180 entries/hr ON AVERAGE over the full day (24 hours) is unlikely, so daily entries count > 24*180 = 4320 is probably due to counter rollover or other asynchronous counter reset -> just set these values to 0

# %%
daily_per_turnstile_2019 = df_2019.groupby(['ID', 'DATE']).first().reset_index().drop(columns='ENTRIES')

daily_per_turnstile_2019['NET_DAILY_ENTRIES'] = np.abs(df_2019.groupby(['ID', 'DATE'])['ENTRIES'].first() - 
                                                       df_2019.groupby(['ID', 'DATE'])['ENTRIES'].last()) \
                                                        .values

daily_per_turnstile_2019['NET_DAILY_ENTRIES'] = daily_per_turnstile_2019['NET_DAILY_ENTRIES'] \
                                                        .apply(lambda x: 0 if x > 180*24 else x)

daily_per_turnstile_2019.head()
# Out:
#                        ID        DATE   C/A  UNIT       SCP STATION LINENAME  \
# 0  A002 - R051 - 02-00-00  2019-04-30  A002  R051  02-00-00   59 ST  NQR456W
# 1  A002 - R051 - 02-00-00  2019-05-01  A002  R051  02-00-00   59 ST  NQR456W
# 2  A002 - R051 - 02-00-00  2019-05-02  A002  R051  02-00-00   59 ST  NQR456W
# 3  A002 - R051 - 02-00-00  2019-05-03  A002  R051  02-00-00   59 ST  NQR456W
# 4  A002 - R051 - 02-00-00  2019-05-04  A002  R051  02-00-00   59 ST  NQR456W
#
#   DIVISION     DESC            DATETIME  NET_DAILY_ENTRIES
# 0      BMT  REGULAR 2019-04-30 20:00:00               1278
# 1      BMT  REGULAR 2019-05-01 20:00:00               1346
# 2      BMT  REGULAR 2019-05-02 20:00:00               1327
# 3      BMT  REGULAR 2019-05-03 20:00:00               1326
# 4      BMT  REGULAR 2019-05-04 20:00:00                560

# %%
# This looks reasonable:

daily_per_turnstile_2019['NET_DAILY_ENTRIES'].describe()
# Out:
# count    300165.000000
# mean        915.348638
# std         851.082939
# min           0.000000
# 25%         222.000000
# 50%         704.000000
# 75%        1394.000000
# max        4320.000000
# Name: NET_DAILY_ENTRIES, dtype: float64

# %% [markdown]
# #### Repeat this whole process for df_2021

# %%
daily_per_turnstile_2021 = df_2021.groupby(['ID', 'DATE']).first().reset_index().drop(columns='ENTRIES')

daily_per_turnstile_2021['NET_DAILY_ENTRIES'] = np.abs(df_2021.groupby(['ID', 'DATE'])['ENTRIES'].first() - 
                                                       df_2021.groupby(['ID', 'DATE'])['ENTRIES'].last()) \
                                                        .values

daily_per_turnstile_2021['NET_DAILY_ENTRIES'] = daily_per_turnstile_2021['NET_DAILY_ENTRIES'] \
                                                        .apply(lambda x: 0 if x > 180*24 else x)

daily_per_turnstile_2021.head()
# Out:
#                        ID        DATE   C/A  UNIT       SCP STATION LINENAME  \
# 0  A002 - R051 - 02-00-00  2021-04-30  A002  R051  02-00-00   59 ST  NQR456W
# 1  A002 - R051 - 02-00-00  2021-05-01  A002  R051  02-00-00   59 ST  NQR456W
# 2  A002 - R051 - 02-00-00  2021-05-02  A002  R051  02-00-00   59 ST  NQR456W
# 3  A002 - R051 - 02-00-00  2021-05-03  A002  R051  02-00-00   59 ST  NQR456W
# 4  A002 - R051 - 02-00-00  2021-05-04  A002  R051  02-00-00   59 ST  NQR456W
#
#   DIVISION     DESC            DATETIME  NET_DAILY_ENTRIES
# 0      BMT  REGULAR 2021-04-30 20:00:00                469
# 1      BMT  REGULAR 2021-05-01 20:00:00                361
# 2      BMT  REGULAR 2021-05-02 20:00:00                250
# 3      BMT  REGULAR 2021-05-03 20:00:00                472
# 4      BMT  REGULAR 2021-05-04 20:00:00                501

# %%
# This looks reasonable:

daily_per_turnstile_2021['NET_DAILY_ENTRIES'].describe()
# Out:
# count    308646.000000
# mean        320.566260
# std         327.177385
# min           0.000000
# 25%          73.000000
# 50%         233.000000
# 75%         466.000000
# max        3808.000000
# Name: NET_DAILY_ENTRIES, dtype: float64

# %% [markdown]
# #### While we're here, let's add a WEEKDAY column (1 for M-F, 0 for Sat or Sun)

# %%
# pd.Series.dt.weekday: 0 = Mon, 6 = Sun

daily_per_turnstile_2019['WEEKDAY'] = pd.to_datetime(daily_per_turnstile_2019['DATE']) \
                                                        .dt.weekday.apply(lambda x: 1 if x < 5 else 0)
display(daily_per_turnstile_2019.sample(10))
# Out:
#                              ID        DATE    C/A  UNIT       SCP  \
# 162848   N607 - R025 - 01-00-00  2019-05-16   N607  R025  01-00-00
# 173495  PTH06 - R546 - 00-00-04  2019-06-07  PTH06  R546  00-00-04
# 66544    N023 - R332 - 01-00-00  2019-06-27   N023  R332  01-00-00
# 58354    J037 - R009 - 00-00-01  2019-05-12   J037  R009  00-00-01
# 279916   R533 - R055 - 00-03-05  2019-05-16   R533  R055  00-03-05
# 49159    H026 - R137 - 00-03-02  2019-05-06   H026  R137  00-03-02
# 103382   N192 - R336 - 00-00-00  2019-06-02   N192  R336  00-00-00
# 195370   R122 - R290 - 02-05-01  2019-06-10   R122  R290  02-05-01
# 89186    N098 - R028 - 00-00-03  2019-05-28   N098  R028  00-00-03
# 101829   N184 - R416 - 00-00-00  2019-05-29   N184  R416  00-00-00
#
#                 STATION  LINENAME DIVISION     DESC            DATETIME  \
# 162848   JAMAICA CENTER       EJZ      IND  REGULAR 2019-05-16 20:00:00
# 173495  PAVONIA/NEWPORT         1      PTH  REGULAR 2019-06-07 19:59:53
# 66544            135 ST        BC      IND  REGULAR 2019-06-27 21:00:00
# 58354            121 ST        JZ      BMT  REGULAR 2019-05-12 20:00:00
# 279916    FLUSHING-MAIN         7      IRT  REGULAR 2019-05-16 20:00:00
# 49159    MYRTLE-WYCKOFF        LM      BMT  REGULAR 2019-05-06 20:00:00
# 103382      BEACH 60 ST         A      IND  REGULAR 2019-06-02 20:00:00
# 195370       HOUSTON ST         1      IRT  REGULAR 2019-06-10 21:00:00
# 89186         FULTON ST  2345ACJZ      IND  REGULAR 2019-05-28 23:00:00
# 101829      BEACH 90 ST        AS      IND  REGULAR 2019-05-29 21:00:00
#
#         NET_DAILY_ENTRIES  WEEKDAY
# 162848                322        1
# 173495               1179        1
# 66544                  88        1
# 58354                   0        0
# 279916               2533        1
# 49159                2492        1
# 103382                347        0
# 195370                  0        1
# 89186                1238        1
# 101829                369        1

# %%
daily_per_turnstile_2021['WEEKDAY'] = pd.to_datetime(daily_per_turnstile_2021['DATE']) \
                                                        .dt.weekday.apply(lambda x: 1 if x < 5 else 0)
display(daily_per_turnstile_2021.sample(10))
# Out:
#                              ID        DATE    C/A  UNIT       SCP  \
# 100701  N120A - R153 - 01-00-03  2021-06-23  N120A  R153  01-00-03
# 70319    N017 - R331 - 00-00-03  2021-06-03   N017  R331  00-00-03
# 60031    J016 - R381 - 00-00-01  2021-06-23   J016  R381  00-00-01
# 216898   R169 - R168 - 01-00-03  2021-05-07   R169  R168  01-00-03
# 305026   R727 - R430 - 00-00-02  2021-06-07   R727  R430  00-00-02
# 292565   R606 - R225 - 00-00-01  2021-05-28   R606  R225  00-00-01
# 120959   N307 - R359 - 00-05-01  2021-06-14   N307  R359  00-05-01
# 188183  PTH19 - R549 - 02-01-03  2021-05-13  PTH19  R549  02-01-03
# 214814  R161B - R452 - 00-05-03  2021-05-31  R161B  R452  00-05-03
# 100696  N120A - R153 - 01-00-03  2021-06-18  N120A  R153  01-00-03
#
#                STATION LINENAME DIVISION     DESC            DATETIME  \
# 100701        UTICA AV       AC      IND  REGULAR 2021-06-23 21:00:00
# 70319           155 ST        C      IND  REGULAR 2021-06-03 21:00:00
# 60031        HALSEY ST        J      BMT  REGULAR 2021-06-23 21:00:00
# 216898           96 ST      123      IRT  REGULAR 2021-05-07 21:00:00
# 305026     PELHAM PKWY        5      IRT  REGULAR 2021-06-07 21:00:00
# 292565         HOYT ST       23      IRT  REGULAR 2021-05-28 20:00:00
# 120959  COURT SQ-23 ST      EMG      IND  REGULAR 2021-06-14 20:00:00
# 188183        NEWARK C        1      PTH  REGULAR 2021-05-13 20:41:05
# 214814           72 ST      123      IRT  REGULAR 2021-05-31 21:00:00
# 100696        UTICA AV       AC      IND  REGULAR 2021-06-18 21:00:00
#
#         NET_DAILY_ENTRIES  WEEKDAY
# 100701                318        1
# 70319                 197        1
# 60031                 545        1
# 216898                295        1
# 305026                424        1
# 292565                357        1
# 120959                  0        1
# 188183                 77        1
# 214814                  0        1
# 100696                334        1

# %% [markdown]
# #### Drop the April 30th Data

# %%
print(daily_per_turnstile_2019.shape)
daily_per_turnstile_2019 = daily_per_turnstile_2019[ \
                                pd.to_datetime(daily_per_turnstile_2019['DATE']) != pd.to_datetime('2019-04-30')]
daily_per_turnstile_2019.reset_index(drop=True, inplace=True)
print(daily_per_turnstile_2019.shape)
display(daily_per_turnstile_2019.head())
display(daily_per_turnstile_2019.tail())
# Out:
# (300165, 12)
# (295338, 12)
#                        ID        DATE   C/A  UNIT       SCP STATION LINENAME  \
# 0  A002 - R051 - 02-00-00  2019-05-01  A002  R051  02-00-00   59 ST  NQR456W
# 1  A002 - R051 - 02-00-00  2019-05-02  A002  R051  02-00-00   59 ST  NQR456W
# 2  A002 - R051 - 02-00-00  2019-05-03  A002  R051  02-00-00   59 ST  NQR456W
# 3  A002 - R051 - 02-00-00  2019-05-04  A002  R051  02-00-00   59 ST  NQR456W
# 4  A002 - R051 - 02-00-00  2019-05-05  A002  R051  02-00-00   59 ST  NQR456W
#
#   DIVISION     DESC            DATETIME  NET_DAILY_ENTRIES  WEEKDAY
# 0      BMT  REGULAR 2019-05-01 20:00:00               1346        1
# 1      BMT  REGULAR 2019-05-02 20:00:00               1327        1
# 2      BMT  REGULAR 2019-05-03 20:00:00               1326        1
# 3      BMT  REGULAR 2019-05-04 20:00:00                560        0
# 4      BMT  REGULAR 2019-05-05 20:00:00                449        0
#                              ID        DATE    C/A  UNIT       SCP  \
# 295333  TRAM2 - R469 - 00-05-01  2019-06-26  TRAM2  R469  00-05-01
# 295334  TRAM2 - R469 - 00-05-01  2019-06-27  TRAM2  R469  00-05-01
# 295335  TRAM2 - R469 - 00-05-01  2019-06-28  TRAM2  R469  00-05-01
# 295336  TRAM2 - R469 - 00-05-01  2019-06-29  TRAM2  R469  00-05-01
# 295337  TRAM2 - R469 - 00-05-01  2019-06-30  TRAM2  R469  00-05-01
#
#               STATION LINENAME DIVISION     DESC            DATETIME  \
# 295333  RIT-ROOSEVELT        R      RIT  REGULAR 2019-06-26 21:00:00
# 295334  RIT-ROOSEVELT        R      RIT  REGULAR 2019-06-27 21:00:00
# 295335  RIT-ROOSEVELT        R      RIT  REGULAR 2019-06-28 21:00:00
# 295336  RIT-ROOSEVELT        R      RIT  REGULAR 2019-06-29 21:00:00
# 295337  RIT-ROOSEVELT        R      RIT  REGULAR 2019-06-30 21:00:00
#
#         NET_DAILY_ENTRIES  WEEKDAY
# 295333                  0        1
# 295334                  0        1
# 295335                  0        1
# 295336                  0        0
# 295337                  0        0

# %%
# Drop the 4/30/2021 rows

print(daily_per_turnstile_2021.shape)
daily_per_turnstile_2021 = daily_per_turnstile_2021[ \
                                pd.to_datetime(daily_per_turnstile_2021['DATE']) != pd.to_datetime('2021-04-30')]
daily_per_turnstile_2019.reset_index(drop=True, inplace=True)
print(daily_per_turnstile_2021.shape)
display(daily_per_turnstile_2021.head())
display(daily_per_turnstile_2021.tail())
# Out:
# (308646, 12)
# (303670, 12)
#                        ID        DATE   C/A  UNIT       SCP STATION LINENAME  \
# 1  A002 - R051 - 02-00-00  2021-05-01  A002  R051  02-00-00   59 ST  NQR456W
# 2  A002 - R051 - 02-00-00  2021-05-02  A002  R051  02-00-00   59 ST  NQR456W
# 3  A002 - R051 - 02-00-00  2021-05-03  A002  R051  02-00-00   59 ST  NQR456W
# 4  A002 - R051 - 02-00-00  2021-05-04  A002  R051  02-00-00   59 ST  NQR456W
# 5  A002 - R051 - 02-00-00  2021-05-05  A002  R051  02-00-00   59 ST  NQR456W
#
#   DIVISION     DESC            DATETIME  NET_DAILY_ENTRIES  WEEKDAY
# 1      BMT  REGULAR 2021-05-01 20:00:00                361        0
# 2      BMT  REGULAR 2021-05-02 20:00:00                250        0
# 3      BMT  REGULAR 2021-05-03 20:00:00                472        1
# 4      BMT  REGULAR 2021-05-04 20:00:00                501        1
# 5      BMT  REGULAR 2021-05-05 20:00:00                522        1
#                              ID        DATE    C/A  UNIT       SCP  \
# 308641  TRAM2 - R469 - 00-05-01  2021-06-26  TRAM2  R469  00-05-01
# 308642  TRAM2 - R469 - 00-05-01  2021-06-27  TRAM2  R469  00-05-01
# 308643  TRAM2 - R469 - 00-05-01  2021-06-28  TRAM2  R469  00-05-01
# 308644  TRAM2 - R469 - 00-05-01  2021-06-29  TRAM2  R469  00-05-01
# 308645  TRAM2 - R469 - 00-05-01  2021-06-30  TRAM2  R469  00-05-01
#
#               STATION LINENAME DIVISION     DESC            DATETIME  \
# 308641  RIT-ROOSEVELT        R      RIT  REGULAR 2021-06-26 21:00:00
# 308642  RIT-ROOSEVELT        R      RIT  REGULAR 2021-06-27 21:00:00
# 308643  RIT-ROOSEVELT        R      RIT  REGULAR 2021-06-28 21:00:00
# 308644  RIT-ROOSEVELT        R      RIT  REGULAR 2021-06-29 21:00:00
# 308645  RIT-ROOSEVELT        R      RIT  REGULAR 2021-06-30 21:00:00
#
#         NET_DAILY_ENTRIES  WEEKDAY
# 308641                  0        0
# 308642                  0        0
# 308643                  0        1
# 308644                  0        1
# 308645                  0        1

# %% [markdown]
# ### 2e) Figure out which turnstiles all belong to the same station and sum up station-level NET_DAILY_ENTRIES

# %% [markdown]
# #### While UNIT ("Remote Unit") generally denotes a station, certain stations actually have several UNITs associated with them; the term "Complex" describes the physical location where a Remote Unit resides.

# %% [markdown]
# Import MTA Complex List Dataset (based on MTA-provided data & augmented slightly by Chris Whong); found at the following link:

# %% [markdown]
# https://qri.cloud/nyc-transit-data/remote_complex_lookup

# %%
# NOTE: The 'remote' column in this dataset refers to the same entity as 'UNIT' in the turnstile data
#         (the full name is technically 'Remote Unit'); Also, 'booth' below refers to the same entity
#         as 'C/A' in the turnstile data

complex_list = pd.read_csv('nyc_transit_data_remote_complex_lookup.csv')

print(complex_list.shape)
complex_list
# Out:
# (776, 6)
#     remote  booth  complex_id             station    line_name division
# 0     R001   A060       635.0        WHITEHALL ST           R1      BMT
# 1     R001   A058       635.0        WHITEHALL ST           R1      BMT
# 2     R001  R101S       635.0         SOUTH FERRY           R1      IRT
# 3     R002   A077       628.0           FULTON ST     ACJZ2345      BMT
# 4     R002   A081       628.0           FULTON ST     ACJZ2345      BMT
# 5     R002   A082       628.0           FULTON ST     ACJZ2345      BMT
# 6     R003   J025        86.0       CYPRESS HILLS            J      BMT
# 7     R004   J028        85.0        ELDERTS LANE           JZ      BMT
# 8     R005   J030        84.0      FOREST PARKWAY            J      BMT
# 9     R006   J031        83.0      WOODHAVEN BLVD           JZ      BMT
# 10    R006   J032        83.0      WOODHAVEN BLVD           JZ      BMT
# 11    R007   J034        82.0              104 ST           JZ      BMT
# 12    R008   J035        81.0              111 ST            J      BMT
# 13    R009   J037        80.0              121 ST           JZ      BMT
# 14    R010  N062A       611.0     42 ST-PA BUS TE  ACENQRS1237      IND
# 15    R010   N060       611.0     42 ST-PA BUS TE  ACENQRS1237      IND
# 16    R011  N063A       611.0     42 ST-PA BUS TE  ACENQRS1237      IND
# 17    R011   N062       611.0     42 ST-PA BUS TE  ACENQRS1237      IND
# 18    R011   N063       611.0     42 ST-PA BUS TE  ACENQRS1237      IND
# 19    R012   N067       164.0      34 ST-PENN STA          ACE      IND
# 20    R012   N065       164.0      34 ST-PENN STA          ACE      IND
# 21    R012   N068       164.0      34 ST-PENN STA          ACE      IND
# 22    R012   N070       164.0      34 ST-PENN STA          ACE      IND
# 23    R012   N072       164.0      34 ST-PENN STA          ACE      IND
# 24    R013   N071       164.0      34 ST-PENN STA          ACE      IND
# 25    R013   N069       164.0      34 ST-PENN STA          ACE      IND
# 26    R013   N073       164.0      34 ST-PENN STA          ACE      IND
# 27    R014   N095       628.0           FULTON ST     ACJZ2345      IND
# 28    R014   R205       628.0           FULTON ST     ACJZ2345      IRT
# 29    R014   R206       628.0           FULTON ST     2345ACJZ      IRT
# 30    R014   R208       628.0           FULTON ST     2345ACJZ      IRT
# 31    R014  R205A       628.0           FULTON ST     2345ACJZ      IRT
# 32    R015   N303       276.0         5 AVE-53 ST           EM      IND
# 33    R015   N304       276.0         5 AVE-53 ST           EM      IND
# 34    R016  N305A       613.0     LEXINGTON-53 ST          EM6      IND
# 35    R017   N306       613.0     LEXINGTON-53 ST          EM6      IND
# 36    R017   N305       613.0     LEXINGTON-53 ST          EM6      IND
# 37    R018   N324       616.0       ROOSEVELT AVE        EFMR7      IND
# 38    R018   N323       616.0       ROOSEVELT AVE        EFMR7      IND
# 39    R018   R525       616.0      74 ST-BROADWAY        EFMR7      IRT
# 40    R019   N343       254.0      JAMAICA-179 ST            F      IND
# 41    R019   N342       254.0      JAMAICA-179 ST            F      IND
# 42    R020   N500       225.0       47-50 ST-ROCK         BDFM      IND
# 43    R020   N501       225.0       47-50 ST-ROCK         BDFM      IND
# 44    R020  N501A       225.0       47-50 ST-ROCK         BDFM      IND
# 45    R021   N503       609.0     42 ST-BRYANT PK        BDFM7      IND
# 46    R021   N502       609.0     42 ST-BRYANT PK        BDFM7      IND
# 47    R021   N504       609.0     42 ST-BRYANT PK        BDFM7      IND
# 48    R022   N506       607.0     34 ST-HERALD SQ      BDFMNQR      IND
# 49    R022   A022       607.0     34 ST-HERALD SQ      BDFMNQR      BMT
# 50    R022   N505       607.0     34 ST-HERALD SQ      BDFMNQR      IND
# 51    R023   N507       607.0     34 ST-HERALD SQ      BDFMNQR      IND
# 52    R023   A025       607.0     34 ST-HERALD SQ      BDFMNQR      BMT
# 53    R024   N605       279.0        SUTPHIN BLVD          EJZ      IND
# 54    R025   N606       278.0      JAMAICA CENTER          EJZ      IND
# 55    R025   N607       278.0      JAMAICA CENTER          EJZ      IND
# 56    R027   R111       333.0             WALL ST           23      IRT
# 57    R027   R110       333.0             WALL ST           23      IRT
# 58    R027   R112       333.0             WALL ST           23      IRT
# 59    R027  R112A       333.0             WALL ST           23      IRT
# 60    R028  R113A       628.0           FULTON ST     2345ACJZ      IRT
# 61    R028   R113       628.0           FULTON ST     2345ACJZ      IRT
# 62    R028   R114       628.0           FULTON ST     2345ACJZ      IRT
# 63    R029   R115       624.0          PARK PLACE        23ACE      IRT
# 64    R029   N094       624.0     WORLD TRADE CTR        23ACE      IND
# 65    R029   N091       624.0         CHAMBERS ST        ACE23      IND
# 66    R029   N092       624.0         CHAMBERS ST        ACE23      IND
# 67    R030   R116       327.0         CHAMBERS ST          123      IRT
# 68    R031   R141       318.0      34 ST-PENN STA          123      IRT
# 69    R031   R135       318.0      34 ST-PENN STA          123      IRT
# 70    R031   R137       318.0      34 ST-PENN STA          123      IRT
# 71    R031   R139       318.0      34 ST-PENN STA          123      IRT
# 72    R032   R145       611.0      42 ST-TIMES SQ  1237ACENQRS      IRT
# 73    R032   A021       611.0      42 ST-TIMES SQ  1237ACENQRS      BMT
# 74    R032   R143       611.0      42 ST-TIMES SQ  ACENQRS1237      IRT
# 75    R032   R146       611.0      42 ST-TIMES SQ  1237ACENQRS      IRT
# 76    R033   R151       611.0      42 ST-TIMES SQ  1237ACENQRS      IRT
# 77    R033   R148       611.0      42 ST-TIMES SQ  1237ACENQRS      IRT
# 78    R033   R150       611.0      42 ST-TIMES SQ  1237ACENQRS      IRT
# 79    R033   R153       611.0      42 ST-TIMES SQ  1237ACENQRS      IRT
# 80    R033   R147       611.0      42 ST-TIMES SQ  1237ACENQRS      IRT
# 81    R034   R174       306.0              125 ST            1      IRT
# 82    R035   R182       605.0     168 ST-BROADWAY          1AC      IRT
# 83    R035   N012       605.0     168 ST-BROADWAY          1AC      IND
# 84    R035   N013       605.0     168 ST-BROADWAY          AC1      IND
# 85    R036   R186       299.0          DYCKMAN ST            1      IRT
# 86    R037   R188       298.0              207 ST            1      IRT
# 87    R038   R190       297.0              215 ST            1      IRT
# 88    R039   R192       296.0     MARBLE HILL-225            1      IRT
# 89    R040   R194       295.0              231 ST            1      IRT
# 90    R041   R201       414.0       BOWLING GREEN           45      IRT
# 91    R041  R200A       414.0       BOWLING GREEN           45      IRT
# 92    R042   R202       414.0       BOWLING GREEN           45      IRT
# 93    R043   R203       413.0             WALL ST           45      IRT
# 94    R043  R203A       413.0             WALL ST           45      IRT
# 95    R043   R204       413.0             WALL ST           45      IRT
# 96    R043  R204A       413.0             WALL ST           45      IRT
# 97    R044   R210       622.0     BROOKLYN BRIDGE        456JZ      IRT
# 98    R044   A069       622.0         CHAMBERS ST        456JZ      BMT
# 99    R044   A071       622.0         CHAMBERS ST        JZ456      BMT
# 100   R044  R210A       622.0     BROOKLYN BRIDGE        JZ456      IRT
# 101   R045   R236       610.0     42 ST-GRD CNTRL        4567S      IRT
# 102   R045   R233       610.0     42 ST-GRD CNTRL        4567S      IRT
# 103   R046   R238       610.0     42 ST-GRD CNTRL        4567S      IRT
# 104   R046   R237       610.0     42 ST-GRD CNTRL        4567S      IRT
# 105   R046  R238A       610.0     42 ST-GRD CNTRL        4567S      IRT
# 106   R047   R240       610.0     42 ST-GRD CNTRL        4567S      IRT
# 107   R047  R237B       610.0     42 ST-GRD CNTRL        4567S      IRT
# 108   R048  R241A       610.0     42 ST-GRD CNTRL        4567S      IRT
# 109   R049   R243       612.0               51 ST            6      IRT
# 110   R049   R242       612.0               51 ST            6      IRT
# 111   R049  R242A       612.0               51 ST            6      IRT
# 112   R050   R244       613.0               59 ST       456NQR      IRT
# 113   R050  R244A       613.0               59 ST       456NQR      IRT
# 114   R050   A004       613.0       LEXINGTON AVE       456NQR      BMT
# 115   R051   R245       613.0               59 ST       456NQR      IRT
# 116   R051  R245A       613.0               59 ST       456NQR      IRT
# 117   R051   A002       613.0       LEXINGTON AVE       456NQR      BMT
# 118   R052   R294       378.0       WOODLAWN ROAD            4      IRT
# 119   R053   R311       434.0        149 ST-3 AVE           25      IRT
# 120   R053   R310       434.0        149 ST-3 AVE           25      IRT
# 121   R054   R501       609.0     5 AVE-BRYANT PK        7BDFM      IRT
# 122   R054   R500       609.0     5 AVE-BRYANT PK        7BDFM      IRT
# 123   R055   R533       447.0             MAIN ST            7      IRT
# 124   R055   R534       447.0             MAIN ST            7      IRT
# 125   R056   R608       337.0           NEVINS ST         2345      IRT
# 126   R056   R609       337.0           NEVINS ST         2345      IRT
# 127   R057   R610       617.0        ATLANTIC AVE    2345BDNQR      IRT
# 128   R057   B001       617.0        ATLANTIC AVE    2345BDNQR      BMT
# 129   R057   B002       617.0        ATLANTIC AVE    BDNQR2345      BMT
# 130   R057   C009       617.0          PACIFIC ST    BDNQR2345      BMT
# 131   R058   R617       339.0           BERGEN ST           23      IRT
# 132   R058   R618       339.0           BERGEN ST           23      IRT
# 133   R059   R619       340.0     GRAND ARMY PLAZ           23      IRT
# 134   R060   R621       341.0        EASTERN PKWY           23      IRT
# 135   R061   R623       343.0        NOSTRAND AVE            3      IRT
# 136   R062   R626       345.0     CROWN HTS-UTICA           34      IRT
# 137   R062   R625       345.0     CROWN HTS-UTICA           34      IRT
# 138   R063   R627       346.0          SUTTER AVE            3      IRT
# 139   R064   R628       347.0        SARATOGA AVE            3      IRT
# 140   R065   R629       348.0        ROCKAWAY AVE            3      IRT
# 141   R066   R630       349.0           JUNIUS ST            3      IRT
# 142   R067   R632       350.0     PENNSYLVANIA AV            3      IRT
# 143   R068   R633       351.0      VAN SICLEN AVE            3      IRT
# 144   R069   R634       352.0        NEW LOTS AVE            3      IRT
# 145   R070   S101       501.0          ST. GEORGE            1      SRT
# 146   R070  S101A       501.0          ST. GEORGE            1      SRT
# 147   R072   R550       471.0      34 ST - 11 AVE            7      IRT
# 148   R072   R551       471.0      34 ST - 11 AVE            7      IRT
# 149   R076  MCC07         NaN     2 BDWY CUST SRV           45      IRT
# 150   R079   A006         8.0         5 AVE-59 ST          NQR      BMT
# 151   R079   A007         8.0         5 AVE-59 ST          NQR      BMT
# 152   R080   A010         9.0         57 ST-7 AVE          NQR      BMT
# 153   R080   A011         9.0         57 ST-7 AVE          NQR      BMT
# 154   R081   A015         8.0         49 ST-7 AVE          NQR      BMT
# 155   R081   A013        10.0         49 ST-7 AVE          NQR      BMT
# 156   R081   A014         8.0         49 ST-7 AVE          NQR      BMT
# 157   R081   A016         8.0         49 ST-7 AVE          NQR      BMT
# 158   R082   A029        13.0      28 ST-BROADWAY           NR      BMT
# 159   R082   A027        13.0      28 ST-BROADWAY           NR      BMT
# 160   R083   A031        14.0         23 ST-5 AVE           NR      BMT
# 161   R083   A030        14.0         23 ST-5 AVE           NR      BMT
# 162   R084   R158       614.0      59 ST-COLUMBUS        1ABCD      IRT
# 163   R084   N049       614.0      59 ST-COLUMBUS        1ABCD      IND
# 164   R084   N051       614.0      59 ST-COLUMBUS        ABCD1      IND
# 165   R085   A038        16.0      8 ST-B'WAY NYU           NR      BMT
# 166   R085   A039        16.0      8 ST-B'WAY NYU           NR      BMT
# 167   R086   A041        17.0     PRINCE ST-B'WAY           NR      BMT
# 168   R086   A042        17.0     PRINCE ST-B'WAY           NR      BMT
# 169   R087   A047       623.0     MURRAY ST-B'WAY            R      BMT
# 170   R088   A050       624.0        CORTLANDT ST            R      BMT
# 171   R088   A052       624.0        CORTLANDT ST            R      BMT
# 172   R088   A051       624.0        CORTLANDT ST            R      BMT
# 173   R088   A053       624.0        CORTLANDT ST            R      BMT
# 174   R089   C003       636.0     JAY ST-METROTEC            R      BMT
# 175   R089   C004       636.0     JAY ST-METROTEC            R      BMT
# 176   R090   R510         6.0        BEEBE-39 AVE           NQ      BMT
# 177   R091   R511         5.0     WASHINGTON-36 A           NQ      BMT
# 178   R092   R512         4.0      BROADWAY-31 ST           NQ      BMT
# 179   R093   R513         3.0        GRAND-30 AVE           NQ      BMT
# 180   R094   R514         2.0     HOYT ST-ASTORIA           NQ      BMT
# 181   R095   R515         1.0     DITMARS BL-31 S           NQ      BMT
# 182   R096   R526       453.0     82 ST-JACKSON H            7      IRT
# 183   R097   R528       451.0       JUNCTION BLVD            7      IRT
# 184   R098   B016        44.0          CHURCH AVE           BQ      BMT
# 185   R098   B015        44.0          CHURCH AVE           BQ      BMT
# 186   R099   C008        26.0          DEKALB AVE        BDNQR      BMT
# 187   R100   K026       108.0     METROPOLITAN AV            M      BMT
# 188   R101   N020       151.0              145 ST         ABCD      IND
# 189   R101   N019       151.0              145 ST         ABCD      IND
# 190   R102   N026       153.0              125 ST         ACBD      IND
# 191   R102   N025       153.0              125 ST         ACBD      IND
# 192   R103   N124       621.0        BROADWAY-ENY        ACJLZ      IND
# 193   R104   N207       218.0              167 ST           BD      IND
# 194   R104   N206       218.0              167 ST           BD      IND
# 195   R105   R127       601.0               14 ST       123FLM      IRT
# 196   R105   R128       601.0               14 ST       123FLM      IRT
# 197   R106   R418       365.0     CASTLE HILL AVE            6      IRT
# 198   R107   R420       363.0      WESTCHESTER SQ            6      IRT
# 199   R108   R602       620.0     BOROUGH HALL/CT        2345R      IRT
# 200   R108   C001       620.0     BOROUGH HALL/CT        2345R      BMT
# 201   R108  R601A       620.0     BOROUGH HALL/CT        R2345      IRT
# 202   R108   R604       620.0     BOROUGH HALL/CT        2345R      IRT
# 203   R109   R639       356.0          CHURCH AVE           25      IRT
# 204   R110   R645       359.0        FLATBUSH AVE           25      IRT
# 205   R110   R646       359.0        FLATBUSH AVE           25      IRT
# 206   R110   R647       359.0        FLATBUSH AVE           25      IRT
# 207   R111   N076       165.0               23 ST           CE      IND
# 208   R111   N075       165.0               23 ST           CE      IND
# 209   R111   N077       165.0               23 ST           CE      IND
# 210   R112   N217       213.0        FORDHAM ROAD           BD      IND
# 211   R112   N218       213.0        FORDHAM ROAD           BD      IND
# 212   R113   N301       277.0         7 AVE-53 ST          BDE      IND
# 213   R113   N300       277.0         7 AVE-53 ST          BDE      IND
# 214   R114  N339A       256.0        PARSONS BLVD            F      IND
# 215   R114   N339       256.0        PARSONS BLVD            F      IND
# 216   R115   N340       255.0              169 ST            F      IND
# 217   R115  N340A       255.0              169 ST            F      IND
# 218   R116   R154       316.0               50 ST            1      IRT
# 219   R116   R155       316.0               50 ST            1      IRT
# 220   R117   R197       293.0              242 ST            1      IRT
# 221   R118   A066       623.0            CANAL ST       JNQRZ6      BMT
# 222   R119   R289       382.0        FORDHAM ROAD            4      IRT
# 223   R120   R415       368.0        MORRISON AVE            6      IRT
# 224   R121   R509       461.0      QUEENSBORO PLZ          7NQ      IRT
# 225   R122   R527       452.0      90 ST-ELMHURST            7      IRT
# 226   R123   R622       627.0        FRANKLIN AVE        2345S      IRT
# 227   R124   R624       344.0        KINGSTON AVE            3      IRT
# 228   R125   A083       107.0            BROAD ST           JZ      BMT
# 229   R125   A084       107.0            BROAD ST           JZ      BMT
# 230   R125   A085       107.0            BROAD ST           JZ      BMT
# 231   R126   N010       147.0              175 ST            A      IND
# 232   R126   N011       147.0              175 ST            A      IND
# 233   R127   N103       636.0     JAY ST-METROTEC          ACF      IND
# 234   R127   N102       636.0     JAY ST-METROTEC          ACF      IND
# 235   R128  N338B       257.0        SUTPHIN BLVD            F      IND
# 236   R128   N338       257.0        SUTPHIN BLVD            F      IND
# 237   R129   N532       236.0           BERGEN ST           FG      IND
# 238   R129   N531       236.0           BERGEN ST           FG      IND
# 239   R129   N533       236.0           BERGEN ST           FG      IND
# 240   R130   N557       250.0       KINGS HIGHWAY            F      IND
# 241   R130   N558       250.0       KINGS HIGHWAY            F      IND
# 242   R131   R227       405.0               23 ST            6      IRT
# 243   R131  R227A       405.0               23 ST            6      IRT
# 244   R131   R226       405.0               23 ST            6      IRT
# 245   R131  R226A       405.0               23 ST            6      IRT
# 246   R132   R258       392.0              125 ST          456      IRT
# 247   R133   R293       379.0     MOSHOLU PARKWAY            4      IRT
# 248   R134   R507       463.0      HUNTERS PT AVE            7      IRT
# 249   R135   R643       358.0         NEWKIRK AVE           25      IRT
# 250   R135   R644       358.0         NEWKIRK AVE           25      IRT
# 251   R136   B027        54.0      SHEEPSHEAD BAY           BQ      BMT
# 252   R136   B028        54.0      SHEEPSHEAD BAY           BQ      BMT
# 253   R137   H026       630.0          MYRTLE AVE           LM      BMT
# 254   R137   H027       630.0          MYRTLE AVE           LM      BMT
# 255   R138   N080       167.0      W 4 ST-WASH SQ      ABCDEFM      IND
# 256   R138   N083       167.0      W 4 ST-WASH SQ      ABCDEFM      IND
# 257   R139   N089       169.0            CANAL ST          ACE      IND
# 258   R139   N090       169.0            CANAL ST          ACE      IND
# 259   R140  N309A       273.0        QUEENS PLAZA          EMR      IND
# 260   R140   N310       273.0        QUEENS PLAZA          EMR      IND
# 261   R141  N333A       261.0     FOREST HILLS-71         EFMR      IND
# 262   R141   N333       261.0     FOREST HILLS-71         EFMR      IND
# 263   R141  N333B       261.0     FOREST HILLS-71         EFMR      IND
# 264   R142   A061       625.0            ESSEX ST         FJMZ      BMT
# 265   R142   N525       625.0         DELANCEY ST         FJMZ      IND
# 266   R142   N526       625.0         DELANCEY ST         FJMZ      IND
# 267   R143   R228       404.0               28 ST            6      IRT
# 268   R143   R229       404.0               28 ST            6      IRT
# 269   R143   R230       404.0               28 ST            6      IRT
# 270   R144   R251       396.0               96 ST            6      IRT
# 271   R145   R336       416.0       WAKEFIELD-241            2      IRT
# 272   R146   R412       371.0     HUNTS POINT AVE            6      IRT
# 273   R147   R523       456.0      61 ST/WOODSIDE            7      IRT
# 274   R148   B014        43.0        PARKSIDE AVE           BQ      BMT
# 275   R149   B019        47.0         NEWKIRK AVE           BQ      BMT
# 276   R150   B025        52.0               AVE U           BQ      BMT
# 277   R151   G001        58.0       STILLWELL AVE         DFNQ      BMT
# 278   R151   G009        58.0       STILLWELL AVE         DFNQ      BMT
# 279   R152   H041       138.0        ROCKAWAY PKY            L      BMT
# 280   R153   N120       181.0           UTICA AVE           AC      IND
# 281   R153  N120A       181.0           UTICA AVE           AC      IND
# 282   R154   N213       215.0         TREMONT AVE           BD      IND
# 283   R154   N214       215.0         TREMONT AVE           BD      IND
# 284   R155   N221       212.0      KINGSBRIDGE RD           BD      IND
# 285   R155   N220       212.0      KINGSBRIDGE RD           BD      IND
# 286   R156   N222       211.0     BEDFORD PARK BL           BD      IND
# 287   R156   N223       211.0     BEDFORD PARK BL           BD      IND
# 288   R157   N224       210.0      NORWOOD-205 ST            D      IND
# 289   R157   N225       210.0      NORWOOD-205 ST            D      IND
# 290   R158   N336       259.0     UNION TPK-KEW G           EF      IND
# 291   R158   N335       259.0     UNION TPK-KEW G           EF      IND
# 292   R159   R173       307.0     116 ST-COLUMBIA            1      IRT
# 293   R160   R219       407.0         ASTOR PLACE            6      IRT
# 294   R160   R220       407.0         ASTOR PLACE            6      IRT
# 295   R161   R290       381.0      KINGSBRIDGE RD            4      IRT
# 296   R162   R414       369.0           ELDER AVE            6      IRT
# 297   R163   N512       601.0         14 ST-6 AVE       FLM123      IND
# 298   R163   H003       601.0               6 AVE       FLM123      BMT
# 299   R163   N510       601.0         14 ST-6 AVE       FLM123      IND
# 300   R163   N511       601.0         14 ST-6 AVE       FLM123      IND
# 301   R163   N513       601.0         14 ST-6 AVE       FLM123      IND
# 302   R164  R160A       314.0       66 ST-LINCOLN            1      IRT
# 303   R164   R159       314.0       66 ST-LINCOLN            1      IRT
# 304   R164   R160       314.0       66 ST-LINCOLN            1      IRT
# 305   R165   S102       502.0       TOMPKINSVILLE            1      SRT
# 306   R166   R162       312.0               79 ST            1      IRT
# 307   R166   R163       312.0               79 ST            1      IRT
# 308   R167   R164       311.0               86 ST            1      IRT
# 309   R167   R165       311.0               86 ST            1      IRT
# 310   R167   R166       311.0               86 ST            1      IRT
# 311   R168  R168A       310.0               96 ST          123      IRT
# 312   R168   R168       310.0               96 ST          123      IRT
# 313   R169   R176       305.0     137 ST-CITY COL            1      IRT
# 314   R169   R175       305.0     137 ST-CITY COL            1      IRT
# 315   R170   A035       602.0      14 ST-UNION SQ      LNQR456      BMT
# 316   R170   R221       602.0      14 ST-UNION SQ      LNQR456      IRT
# 317   R170   A033       602.0      14 ST-UNION SQ      456LNQR      BMT
# 318   R170   A034       602.0      14 ST-UNION SQ      LNQR456      BMT
# 319   R170   A036       602.0      14 ST-UNION SQ      LNQR456      BMT
# 320   R170   A037       602.0      14 ST-UNION SQ      LNRQ456      BMT
# 321   R171   B004        41.0               7 AVE           BQ      BMT
# 322   R172   B029        55.0      BRIGHTON BEACH           BQ      BMT
# 323   R172   B031        55.0      BRIGHTON BEACH           BQ      BMT
# 324   R173  N002A       143.0       INWOOD-207 ST            A      IND
# 325   R173   N001       143.0       INWOOD-207 ST            A      IND
# 326   R174  N007A       146.0              181 ST            A      IND
# 327   R174   N009       146.0              181 ST            A      IND
# 328   R175   H001       618.0               8 AVE         ACEL      BMT
# 329   R175   N078       618.0               14 ST         ACEL      IND
# 330   R176   R231       403.0               33 ST            6      IRT
# 331   R176  R231A       403.0               33 ST            6      IRT
# 332   R176   R232       403.0               33 ST            6      IRT
# 333   R176  R232A       403.0               33 ST            6      IRT
# 334   R177   R246       399.0     68ST-HUNTER COL            6      IRT
# 335   R178   R248       398.0               77 ST            6      IRT
# 336   R178   R247       398.0               77 ST            6      IRT
# 337   R179   R250       397.0               86 ST          456      IRT
# 338   R179   R249       397.0               86 ST          456      IRT
# 339   R180   R252       395.0              103 ST            6      IRT
# 340   R181   R253       394.0              110 ST            6      IRT
# 341   R181   R254       394.0              110 ST            6      IRT
# 342   R182   R256       393.0              116 ST            6      IRT
# 343   R182   R257       393.0              116 ST            6      IRT
# 344   R183   R291       380.0     BEDFORD PARK BL            4      IRT
# 345   R184   B018        46.0      CORTELYOU ROAD           BQ      BMT
# 346   R185   N003       144.0      DYCKMAN-200 ST            A      IND
# 347   R186   N043       158.0               86 ST           BC      IND
# 348   R186   N042       158.0               86 ST           BC      IND
# 349   R187   N044       159.0        81 ST-MUSEUM           BC      IND
# 350   R187   N045       159.0        81 ST-MUSEUM           BC      IND
# 351   R188   N057       162.0               50 ST           CE      IND
# 352   R188   N056       162.0               50 ST           CE      IND
# 353   R189   R125       323.0      CHRISTOPHER ST            1      IRT
# 354   R189   R126       323.0      CHRISTOPHER ST            1      IRT
# 355   R190   R131       320.0               23 ST            1      IRT
# 356   R190   R132       320.0               23 ST            1      IRT
# 357   R191   R170       309.0              103 ST            1      IRT
# 358   R192   R172       308.0     110 ST-CATHEDRL            1      IRT
# 359   R192   R171       308.0     110 ST-CATHEDRL            1      IRT
# 360   R193   R180       303.0              157 ST            1      IRT
# 361   R193   R179       303.0              157 ST            1      IRT
# 362   R194  R217A       619.0         BLEECKER ST          6DF      IRT
# 363   R195   N203       604.0       161 ST-YANKEE          BD4      IND
# 364   R195   N204       604.0       161 ST-YANKEE          BD4      IND
# 365   R195   N205       604.0       161 ST-YANKEE          BD4      IND
# 366   R195   R262       604.0       161 ST-YANKEE          BD4      IRT
# 367   R195  R262A       604.0       161 ST-YANKEE          4BD      IRT
# 368   R195  R262B       604.0       161 ST-YANKEE          4BD      IRT
# 369   R196   B012        42.0       PROSPECT PARK          BQS      BMT
# 370   R196   B013        42.0       PROSPECT PARK          BQS      BMT
# 371   R197   C018        32.0               36 ST          DNR      BMT
# 372   R198   N116       179.0        NOSTRAND AVE           AC      IND
# 373   R198   N117       179.0        NOSTRAND AVE           AC      IND
# 374   R199   N119       180.0     KINGSTON-THROOP            C      IND
# 375   R199   N118       180.0     KINGSTON-THROOP            C      IND
# 376   R200   N128       188.0          EUCLID AVE           AC      IND
# 377   R201   N329       264.0      WOODHAVEN BLVD           MR      IND
# 378   R201  N329A       264.0      WOODHAVEN BLVD           MR      IND
# 379   R202  N330B       263.0     63 DR-REGO PARK           MR      IND
# 380   R202  N330C       263.0     63 DR-REGO PARK           MR      IND
# 381   R203   N509       228.0         23 ST-6 AVE           FM      IND
# 382   R204   N546       243.0          CHURCH AVE           FG      IND
# 383   R204   N545       243.0          CHURCH AVE           FG      IND
# 384   R205   R260       439.0      149 ST-GR CONC          245      IRT
# 385   R205   R261       603.0      149 ST-GR CONC          245      IRT
# 386   R206   R304       439.0              125 ST           23      IRT
# 387   R206   R305       439.0              125 ST           23      IRT
# 388   R207   R306       438.0              135 ST           23      IRT
# 389   R207   R307       438.0              135 ST           23      IRT
# 390   R208   R529       450.0       103 ST-CORONA            7      IRT
# 391   R209   R636       354.0         STERLING ST           25      IRT
# 392   R210   R641       357.0        BEVERLY ROAD           25      IRT
# 393   R211   B024        51.0       KINGS HIGHWAY           BQ      BMT
# 394   R211   B023        51.0       KINGS HIGHWAY           BQ      BMT
# 395   R211  B024A        51.0       KINGS HIGHWAY           BQ      BMT
# 396   R212   C021        35.0               59 ST           NR      BMT
# 397   R212   C022        35.0               59 ST           NR      BMT
# 398   R213   C023        36.0       BAY RIDGE AVE            R      BMT
# 399   R214   C024        37.0               77 ST            R      BMT
# 400   R215   C025        38.0               86 ST            R      BMT
# 401   R215   C026        38.0               86 ST            R      BMT
# 402   R216   C027        39.0     BAY RIDGE-95 ST            R      BMT
# 403   R216   C028        39.0     BAY RIDGE-95 ST            R      BMT
# 404   R217   N108       175.0       HOYT/SCHERMER          ACG      IND
# 405   R218  N325A       266.0        ELMHURST AVE           MR      IND
# 406   R219   N331       262.0              67 AVE           MR      IND
# 407   R219   N332       262.0              67 AVE           MR      IND
# 408   R220   N535       237.0          CARROLL ST           FG      IND
# 409   R220   N534       237.0          CARROLL ST           FG      IND
# 410   R221   R283       388.0              167 ST            4      IRT
# 411   R222   R417       366.0     E 177 ST-PARKCH            6      IRT
# 412   R223   R519       458.0      46 ST-BLISS ST            7      IRT
# 413   R223   R520       458.0      46 ST-BLISS ST            7      IRT
# 414   R224   R600       334.0            CLARK ST           23      IRT
# 415   R225   R606       336.0             HOYT ST           23      IRT
# 416   R226   R728       444.0       GUN HILL ROAD            5      IRT
# 417   R227   A055        22.0           RECTOR ST            R      BMT
# 418   R227   A054        22.0           RECTOR ST            R      BMT
# 419   R228   B021        49.0               AVE J           BQ      BMT
# 420   R229   B022        50.0               AVE M           BQ      BMT
# 421   R230   B026        53.0           NECK ROAD           BQ      BMT
# 422   R231   C010        28.0            UNION ST            R      BMT
# 423   R231   C011        28.0            UNION ST            R      BMT
# 424   R232   C019        33.0               45 ST            R      BMT
# 425   R233   C020        34.0               53 ST            R      BMT
# 426   R234   E004        61.0               50 ST            D      BMT
# 427   R235   H009       120.0         BEDFORD AVE            L      BMT
# 428   R236   H023       127.0          DEKALB AVE            L      BMT
# 429   R237   N215       214.0          182-183 ST           BD      IND
# 430   R238   N315       271.0         STEINWAY ST           MR      IND
# 431   R238   N314       271.0         STEINWAY ST           MR      IND
# 432   R239   N405       283.0      GREENPOINT AVE            G      IND
# 433   R239   N403       283.0      GREENPOINT AVE            G      IND
# 434   R240   N520       231.0            GRAND ST           BD      IND
# 435   R241   N542       241.0      15 ST-PROSPECT           FG      IND
# 436   R241   N541       241.0      15 ST-PROSPECT           FG      IND
# 437   R242   N549       245.0              18 AVE            F      IND
# 438   R242   N550       245.0              18 AVE            F      IND
# 439   R243   R284       387.0              170 ST            4      IRT
# 440   R244   R287       384.0        BURNSIDE AVE            4      IRT
# 441   R245   R416       367.0     ST LAWRENCE AVE            6      IRT
# 442   R246   C014        30.0        PROSPECT AVE            R      BMT
# 443   R247   E005        62.0               55 ST            D      BMT
# 444   R248   H007       119.0               1 AVE            L      BMT
# 445   R248   H008       119.0               1 AVE            L      BMT
# 446   R249   H014       122.0          GRAHAM AVE            L      BMT
# 447   R249   H013       122.0          GRAHAM AVE            L      BMT
# 448   R250   H016       123.0            GRAND ST            L      BMT
# 449   R250   H015       123.0            GRAND ST            L      BMT
# 450   R251   N040       157.0               96 ST           BC      IND
# 451   R251   N039       157.0               96 ST           BC      IND
# 452   R252   N100       173.0             HIGH ST           AC      IND
# 453   R252   N101       173.0             HIGH ST           AC      IND
# 454   R253   N210       216.0          174-175 ST           BD      IND
# 455   R253   N212       216.0          174-175 ST           BD      IND
# 456   R254   N327       265.0     GRAND AV-NEWTON           MR      IND
# 457   R255   N337       258.0       VAN WYCK BLVD           EF      IND
# 458   R256  N408A       284.0           NASSAU AV            G      IND
# 459   R257   N529       234.0       EAST BROADWAY            F      IND
# 460   R257   N528       234.0       EAST BROADWAY            F      IND
# 461   R258   N537       608.0               4 AVE       DFGMNR      IND
# 462   R258   C012       608.0                9 ST       DFGMNR      BMT
# 463   R259   N602       222.0        ROOSEVELT IS            F      IND
# 464   R260   R183       301.0              181 ST            1      IRT
# 465   R261   R518       459.0     40 ST-LOWERY ST            7      IRT
# 466   R262   B017        45.0       BEVERLEY ROAD           BQ      BMT
# 467   R263   B020        48.0               AVE H           BQ      BMT
# 468   R264   B032        56.0       OCEAN PARKWAY            Q      BMT
# 469   R264   B034        56.0       OCEAN PARKWAY            Q      BMT
# 470   R265   H017       124.0        MONTROSE AVE            L      BMT
# 471   R266   H028       129.0           HALSEY ST            L      BMT
# 472   R266   H030       129.0           HALSEY ST            L      BMT
# 473   R267   N316       270.0               46 ST           MR      IND
# 474   R267  N316A       270.0               46 ST           MR      IND
# 475   R267   N317       270.0               46 ST           MR      IND
# 476   R268   N409       629.0     METROPOLITAN AV           GL      IND
# 477   R268   H012       629.0          LORIMER ST           GL      BMT
# 478   R269   N417       289.0     BEDFORD/NOSTRAN            G      IND
# 479   R269   N418       289.0     BEDFORD/NOSTRAN            G      IND
# 480   R270   N536       238.0          SMITH-9 ST           FG      IND
# 481   R271   N561       252.0               AVE X            F      IND
# 482   R272   R133       319.0               28 ST            1      IRT
# 483   R272   R134       319.0               28 ST            1      IRT
# 484   R273   R178       304.0              145 ST            1      IRT
# 485   R273   R177       304.0              145 ST            1      IRT
# 486   R274   R185       300.0              191 ST            1      IRT
# 487   R275   R288       383.0              183 ST            4      IRT
# 488   R276   R504       464.0      VERNON/JACKSON            7      IRT
# 489   R276   R503       464.0      VERNON/JACKSON            7      IRT
# 490   R276   R506       464.0      VERNON/JACKSON            7      IRT
# 491   R277   R635       353.0        PRESIDENT ST           25      IRT
# 492   R278   C016        31.0               25 ST            R      BMT
# 493   R279   H022       126.0        JEFFERSON ST            L      BMT
# 494   R280  N006A       145.0              190 ST            A      IND
# 495   R281   N046       160.0               72 ST           BC      IND
# 496   R282   N086       168.0           SPRING ST           CE      IND
# 497   R282   N087       168.0           SPRING ST           CE      IND
# 498   R283   N110       176.0       LAFAYETTE AVE            C      IND
# 499   R284   N111       177.0     CLINTON-WASH AV            C      IND
# 500   R284  N112A       177.0     CLINTON-WASH AV            C      IND
# 501   R285   N196       209.0        FAR ROCKAWAY            A      IND
# 502   R286   N415       288.0     MYRTLE-WILLOUGH            G      IND
# 503   R286   N416       288.0     MYRTLE-WILLOUGH            G      IND
# 504   R287   N419       290.0         CLASSON AVE            G      IND
# 505   R288  N539A       240.0     7 AV-PARK SLOPE           FG      IND
# 506   R289   N543       242.0     FT HAMILTON PKY           FG      IND
# 507   R289   N544       242.0     FT HAMILTON PKY           FG      IND
# 508   R290   R123       324.0          HOUSTON ST            1      IRT
# 509   R290   R121       324.0          HOUSTON ST            1      IRT
# 510   R290   R122       324.0          HOUSTON ST            1      IRT
# 511   R290   R124       324.0          HOUSTON ST            1      IRT
# 512   R291   R516       460.0     33 ST/RAWSON ST            7      IRT
# 513   R291   R517       460.0     33 ST/RAWSON ST            7      IRT
# 514   R292   R729       443.0      BAYCHESTER AVE            5      IRT
# 515   R293   R138       164.0      34 ST-PENN STA       123ACE      IRT
# 516   R293   R142       164.0      34 ST-PENN STA       123ACE      IRT
# 517   R294   H019       125.0          MORGAN AVE            L      BMT
# 518   R295   H032       130.0          WILSON AVE            L      BMT
# 519   R296  N016A       149.0     163 ST-AMSTERDM            C      IND
# 520   R297   N113       627.0        FRANKLIN AVE          ACS      IND
# 521   R297   N114       627.0        FRANKLIN AVE          ACS      IND
# 522   R298   N318       269.0       NORTHERN BLVD           MR      IND
# 523   R298   N319       269.0       NORTHERN BLVD           MR      IND
# 524   R299   N412       286.0            BROADWAY            G      IND
# 525   R300   N523       232.0               2 AVE            F      IND
# 526   R300   N521       232.0               2 AVE            F      IND
# 527   R301   N530       235.0             YORK ST            F      IND
# 528   R302   N600       224.0               57 ST            F      IND
# 529   R303   N603       221.0               21 ST            F      IND
# 530   R304   R103       329.0           RECTOR ST            1      IRT
# 531   R304   R102       329.0           RECTOR ST            1      IRT
# 532   R305   R107       328.0        CORTLANDT ST            1      IRT
# 533   R305   R106       328.0        CORTLANDT ST            1      IRT
# 534   R305   R108       328.0        CORTLANDT ST            1      IRT
# 535   R305   R109       328.0        CORTLANDT ST            1      IRT
# 536   R306   R196       294.0              238 ST            1      IRT
# 537   R307   R259       391.0      138 ST-GR CONC           45      IRT
# 538   R308   R285       386.0         MT EDEN AVE            4      IRT
# 539   R309   R286       385.0              176 ST            4      IRT
# 540   R310   R530       449.0              111 ST            7      IRT
# 541   R311   A064       103.0              BOWERY           JZ      BMT
# 542   R312   G011        57.0     W 8 ST-AQUARIUM           FQ      BMT
# 543   R312   G015        57.0     W 8 ST-AQUARIUM           FQ      BMT
# 544   R313   H033       131.0        BUSHWICK AVE            L      BMT
# 545   R314   N037       156.0              103 ST           BC      IND
# 546   R315   N202       220.0              155 ST           BD      IND
# 547   R316   N414       287.0        FLUSHING AVE            G      IND
# 548   R316  N414A       287.0        FLUSHING AVE            G      IND
# 549   R317  N420B       291.0     CLINTON-WASH AV            G      IND
# 550   R318   N422       292.0           FULTON ST            G      IND
# 551   R319   N601       223.0       LEXINGTON AVE            F      IND
# 552   R320   R119       325.0            CANAL ST            1      IRT
# 553   R320   R120       325.0            CANAL ST            1      IRT
# 554   R321   R129       321.0               18 ST            1      IRT
# 555   R321   R130       321.0               18 ST            1      IRT
# 556   R322   R215       409.0           SPRING ST            6      IRT
# 557   R322   R216       409.0           SPRING ST            6      IRT
# 558   R323   R301       441.0          110 ST-CPN           23      IRT
# 559   R324   R303       440.0              116 ST           23      IRT
# 560   R324   R302       440.0              116 ST           23      IRT
# 561   R325   R413       370.0        WHITLOCK AVE            6      IRT
# 562   R326   R419       364.0          ZEREGA AVE            6      IRT
# 563   R327   R521       457.0       52 ST-LINCOLN            7      IRT
# 564   R328   R532       448.0     METS-WILLETS PT            7      IRT
# 565   R328  R532G       448.0     METS-WILLETS PT            7      IRT
# 566   R328  R532H       448.0     METS-WILLETS PT            7      IRT
# 567   R329   R726       446.0         MORRIS PARK            5      IRT
# 568   R330   H005       118.0               3 AVE            L      BMT
# 569   R330   H006       118.0               3 AVE            L      BMT
# 570   R331   N017       150.0              155 ST            C      IND
# 571   R332   N024       152.0              135 ST           BC      IND
# 572   R332   N023       152.0              135 ST           BC      IND
# 573   R332   N022       152.0              135 ST           BC      IND
# 574   R333   N030       154.0              116 ST           BC      IND
# 575   R333   N029       154.0              116 ST           BC      IND
# 576   R334   N035       155.0     CATHEDRL-110 ST           BC      IND
# 577   R334   N034       155.0     CATHEDRL-110 ST           BC      IND
# 578   R335   N191       204.0         BEACH 67 ST            A      IND
# 579   R336   N192       205.0         BEACH 60 ST            A      IND
# 580   R337   N193       206.0         BEACH 44 ST            A      IND
# 581   R338   N194       207.0         BEACH 36 ST            A      IND
# 582   R339   N312       272.0               36 ST           MR      IND
# 583   R339   N311       272.0               36 ST           MR      IND
# 584   R340   N322       268.0               65 ST           MR      IND
# 585   R341  N334B       260.0              75 AVE           EF      IND
# 586   R342   N604       280.0     JAMAICA-VAN WYC            E      IND
# 587   R343   R117       326.0         FRANKLIN ST            1      IRT
# 588   R343   R118       326.0         FRANKLIN ST            1      IRT
# 589   R344   R308       437.0              145 ST            3      IRT
# 590   R345   R309       436.0        148 ST-LENOX            3      IRT
# 591   R346   R508       606.0            COURT SQ            7      IRT
# 592   R347   R524       455.0      69 ST-FISK AVE            7      IRT
# 593   R348   H035       133.0        ATLANTIC AVE            L      BMT
# 594   R349   H037       134.0          SUTTER AVE            L      BMT
# 595   R350   H038       135.0         LIVONIA AVE            L      BMT
# 596   R352   J003       100.0            HEWES ST           JM      BMT
# 597   R353   J005        99.0          LORIMER ST           JM      BMT
# 598   R354   N137       193.0       OXFORD-104 ST            A      IND
# 599   R355   N139       194.0       GREENWOOD-111            A      IND
# 600   R355   N138       194.0       GREENWOOD-111            A      IND
# 601   R356   N141       195.0       LEFFERTS BLVD            A      IND
# 602   R357   N181       197.0     AQUEDUCT-N CNDT            A      IND
# 603   R358   N195       208.0         BEACH 25 ST            A      IND
# 604   R359   N307       606.0      COURT SQ-23 ST          EMG      IND
# 605   R359   N400       606.0            COURT SQ          EMG      IND
# 606   R359  N400A       606.0            COURT SQ          EMG      IND
# 607   R360   N401       282.0     VAN ALSTON-21ST            G      IND
# 608   R361   R328       424.0      PELHAM PARKWAY           25      IRT
# 609   R361   R327       424.0      PELHAM PARKWAY           25      IRT
# 610   R362   R329       423.0        ALLERTON AVE           25      IRT
# 611   R363   R330       422.0           BURKE AVE           25      IRT
# 612   R364   R331       421.0       GUN HILL ROAD           25      IRT
# 613   R365   R332       420.0              219 ST           25      IRT
# 614   R366   R333       419.0              225 ST           25      IRT
# 615   R367   R334       418.0              233 ST           25      IRT
# 616   R368   E001        59.0               9 AVE            D      BMT
# 617   R369   E003        60.0     FT HAMILTON PKY            D      BMT
# 618   R370   E009        64.0               71 ST            D      BMT
# 619   R371   E011        65.0               79 ST            D      BMT
# 620   R372   E012        66.0              18 AVE            D      BMT
# 621   R373   E013        67.0              20 AVE            D      BMT
# 622   R374   E014        68.0         BAY PARKWAY            D      BMT
# 623   R375   H039       136.0        NEW LOTS AVE            L      BMT
# 624   R376   H040       137.0         EAST 105 ST            L      BMT
# 625   R377   J007        98.0        FLUSHING AVE           JM      BMT
# 626   R378   J009        97.0          MYRTLE AVE          JMZ      BMT
# 627   R379   J012        96.0       KOSCIUSZKO ST            J      BMT
# 628   R380   J013        95.0           GATES AVE           JZ      BMT
# 629   R381   J016        94.0           HALSEY ST            J      BMT
# 630   R382   N129       189.0           GRANT AVE            A      IND
# 631   R383   N131       190.0        HUDSON-80 ST            A      IND
# 632   R383   N130       190.0        HUDSON-80 ST            A      IND
# 633   R384   N133       191.0          BOYD-88 ST            A      IND
# 634   R385   N134       192.0       ROCKAWAY BLVD            A      IND
# 635   R385   N135       192.0       ROCKAWAY BLVD            A      IND
# 636   R386   R322       428.0              174 ST           25      IRT
# 637   R386   R321       428.0              174 ST           25      IRT
# 638   R387   R323       427.0       E TREMONT AVE           25      IRT
# 639   R387  R323A       427.0       E TREMONT AVE           25      IRT
# 640   R388   R325       426.0            E 180 ST           25      IRT
# 641   R389   R326       425.0     BRONX PARK EAST           25      IRT
# 642   R390   D002        71.0               8 AVE            N      BMT
# 643   R391   D003        72.0     FT HAMILTON PKY            N      BMT
# 644   R391   D004        72.0     FT HAMILTON PKY            N      BMT
# 645   R392   D008        74.0              18 AVE            N      BMT
# 646   R393   D009        75.0              20 AVE            N      BMT
# 647   R394   D010        76.0      BAY PKY-22 AVE            N      BMT
# 648   R394   D011        76.0      BAY PKY-22 AVE            N      BMT
# 649   R395   D012        77.0       KINGS HIGHWAY            N      BMT
# 650   R396   D015        78.0               AVE U            N      BMT
# 651   R397   D016        79.0               86 ST            N      BMT
# 652   R398   D005       615.0     NEW UTRECHT AVE           ND      BMT
# 653   R398   D006       615.0     NEW UTRECHT AVE           ND      BMT
# 654   R399   E015        69.0              25 AVE            D      BMT
# 655   R400   E016        70.0           BAY 50 ST            D      BMT
# 656   R401   K017       114.0         CENTRAL AVE            M      BMT
# 657   R402   K022       111.0          SENECA AVE            M      BMT
# 658   R403   K024       110.0          FOREST AVE            M      BMT
# 659   R404   K025       109.0     FRESH POND ROAD            M      BMT
# 660   R405   R312       433.0         JACKSON AVE           25      IRT
# 661   R406   R314       432.0        PROSPECT AVE           25      IRT
# 662   R406   R315       432.0        PROSPECT AVE           25      IRT
# 663   R407   R316       431.0       INTERVALE-163           25      IRT
# 664   R408   R318       430.0          SIMPSON ST           25      IRT
# 665   R408   R317       430.0          SIMPSON ST           25      IRT
# 666   R409   R320       429.0          FREEMAN ST           25      IRT
# 667   R409   R319       429.0          FREEMAN ST           25      IRT
# 668   R410   X001         NaN     NYC & CO - 7 AV            1      IRT
# 669   R411   B009       141.0          PARK PLACE            S      BMT
# 670   R412   B010       626.0      BOTANIC GARDEN        S2345      BMT
# 671   R413   K019       113.0       KNICKERBOCKER            M      BMT
# 672   R414   N182       198.0      HOWARD BCH-JFK            A      IND
# 673   R414  N182A       198.0      HOWARD BCH-JFK            A      IND
# 674   R415   N183       199.0       BROAD CHANNEL           AS      IND
# 675   R416   N184       200.0         BEACH 90 ST           AS      IND
# 676   R417   N185       201.0         BEACH 98 ST           AS      IND
# 677   R418   N186       202.0        BEACH 105 ST           AS      IND
# 678   R419   N187       203.0     ROCKAWAY PK 116           AS      IND
# 679   R420   N548       244.0          DITMAS AVE            F      IND
# 680   R420   N547       244.0          DITMAS AVE            F      IND
# 681   R421   N551       246.0               AVE I            F      IND
# 682   R422   N553       247.0      22 AVE-BAY PKY            F      IND
# 683   R423   N555       248.0               AVE N            F      IND
# 684   R423   N554       248.0               AVE N            F      IND
# 685   R424   N556       249.0               AVE P            F      IND
# 686   R425   N559       251.0               AVE U            F      IND
# 687   R426   N562       253.0         NEPTUNE AVE            F      IND
# 688   R427   R421       362.0     MIDDLETOWN ROAD            6      IRT
# 689   R428   R422       361.0           BUHRE AVE            6      IRT
# 690   R429   R423       360.0     PELHAM BAY PARK            6      IRT
# 691   R430   R727       445.0      PELHAM PARKWAY            5      IRT
# 692   R431   R730       442.0            DYRE AVE            5      IRT
# 693   R432   J017        93.0         CHAUNCEY ST           JZ      BMT
# 694   R433   J020        91.0         ALABAMA AVE            J      BMT
# 695   R434   J021        90.0      VAN SICLEN AVE           JZ      BMT
# 696   R435   J022        89.0        CLEVELAND ST            J      BMT
# 697   R436   J023        88.0         NORWOOD AVE           JZ      BMT
# 698   R437   J024        87.0         CRESCENT ST           JZ      BMT
# 699   R438  N121B       182.0           RALPH AVE            C      IND
# 700   R439   N122       183.0        ROCKAWAY AVE            C      IND
# 701   R439  N123B       183.0        ROCKAWAY AVE            C      IND
# 702   R440   N125       185.0         LIBERTY AVE            C      IND
# 703   R441   N126       186.0      VAN SICLEN AVE            C      IND
# 704   R442   N127       187.0        SHEPHERD AVE            C      IND
# 705   R443   N209       217.0              170 ST           BD      IND
# 706   R443   N208       217.0              170 ST           BD      IND
# 707   R444   R335       417.0          NEREID AVE           25      IRT
# 708   R445   R401       377.0        138 ST-3 AVE            6      IRT
# 709   R446   R402       376.0           BROOK AVE            6      IRT
# 710   R446   R403       376.0           BROOK AVE            6      IRT
# 711   R447   R404       375.0         CYPRESS AVE            6      IRT
# 712   R447   R405       375.0         CYPRESS AVE            6      IRT
# 713   R448   R406       374.0            E 143 ST            6      IRT
# 714   R448   R407       374.0            E 143 ST            6      IRT
# 715   R449   R408       373.0            E 149 ST            6      IRT
# 716   R449   R409       373.0            E 149 ST            6      IRT
# 717   R450   R410       372.0        LONGWOOD AVE            6      IRT
# 718   R450   R411       372.0        LONGWOOD AVE            6      IRT
# 719   R451   R637       355.0         WINTHROP ST           25      IRT
# 720   R452  R161B       313.0               72 ST          123      IRT
# 721   R452  R161A       313.0               72 ST          123      IRT
# 722   R453   N508       228.0         23 ST-6 AVE           FM      IND
# 723   R454   C015        30.0        PROSPECT AVE            R      BMT
# 724   R455   C017        31.0               25 ST            R      BMT
# 725   R456   R605       336.0             HOYT ST           23      IRT
# 726   R457   MCB1         NaN     METROCARD BUS 1           23      BMT
# 727   R458   MCB2         NaN     METROCARD BUS 2           23      BMT
# 728   R459   OB01         NaN       ORCHARD BEACH            6      IND
# 729   R460   J002       101.0           MARCY AVE          JMZ      BMT
# 730   R460   J001       101.0           MARCY AVE          JMZ      BMT
# 731   R461   N519       619.0      BROADWAY/LAFAY        BDFQ6      IND
# 732   R461  N519A       619.0      BROADWAY/LAFAY        BDFQ6      IND
# 733   R462   A043       623.0            CANAL ST       JNQRZ6      BMT
# 734   R462   A044       623.0            CANAL ST       JNQRZ6      BMT
# 735   R463   A046       623.0            CANAL ST       JNQRZ6      BMT
# 736   R463   R214       623.0            CANAL ST       JNQRZ6      IRT
# 737   R464  N181A       196.0      AQUEDUCT TRACK            A      IND
# 738   R465   MCV1         NaN     METROCARD VAN-1            1      BMT
# 739   R466   MCV2         NaN     METROCARD VAN-2            1      BMT
# 740   R467   MCV3         NaN     METROCARD VAN-3            1      BMT
# 741   R468  TRAM1         NaN       RIT-MANHATTAN            R      RIT
# 742   R469  TRAM2         NaN       RIT-ROOSEVELT            R      RIT
# 743   R470   X002       514.0      ELTINGVILLE PK            Z      SRT
# 744   R526  LI001         NaN       LIB-HEMPSTEAD            F      LIB
# 745   R532  WCCTR         NaN     WEST COUNTY CTR            5      BEE
# 746   R535  JFK01       198.0      JFK HOWARD BCH            A      IND
# 747   R535  JFK02       198.0      JFK HOWARD BCH            A      IND
# 748   R536  JFK03       278.0     JFK JAMAICA CT1            E      IND
# 749   R537  JFK04       278.0     JFK JAMAICA CT2            E      IND
# 750   R538  LGA01         NaN     LGA AIRPORT CTB            7      IRT
# 751   R540  PTH08         NaN            PATH WTC            1      PTH
# 752   R540  PTH21         NaN          PATH WTC 2            1      PTH
# 753   R541  PTH13         NaN           THIRTY ST            1      PTH
# 754   R541  PTH17         NaN     THIRTY THIRD ST            1      PTH
# 755   R542  PTH12         NaN     TWENTY THIRD ST            1      PTH
# 756   R543  PTH05         NaN      EXCHANGE PLACE            1      PTH
# 757   R544  PTH02         NaN            HARRISON            1      PTH
# 758   R545  PTH11         NaN         14TH STREET            1      PTH
# 759   R546  PTH06         NaN     PAVONIA/NEWPORT            1      PTH
# 760   R547  PTH10         NaN          9TH STREET            1      PTH
# 761   R548  PTH09         NaN      CHRISTOPHER ST            1      PTH
# 762   R549  PTH01         NaN     NEWARK HW BMEBE            1      PTH
# 763   R549  PTH18         NaN        NEWARK BM BW            1      PTH
# 764   R549  PTH19         NaN            NEWARK C            1      PTH
# 765   R549  PTH20         NaN        NEWARK HM HE            1      PTH
# 766   R550  PTH07         NaN          CITY / BUS            1      PTH
# 767   R550  PTH16         NaN          LACKAWANNA            1      PTH
# 768   R551  PTH04         NaN        GROVE STREET            1      PTH
# 769   R552  PTH03         NaN      JOURNAL SQUARE            1      PTH
# 770   R570   N700       477.0  72 ST - SECOND AVE            Q      IND
# 771   R570  N700A       477.0  72 ST - SECOND AVE            Q      IND
# 772   R571   N701       476.0  86 ST - SECOND AVE            Q      IND
# 773   R571  N701A       476.0  86 ST - SECOND AVE            Q      IND
# 774   R572   N702       475.0  96 ST - SECOND AVE            Q      IND
# 775   R572  N702A       475.0  96 ST - SECOND AVE            Q      IND

# %% [markdown]
# Now import the dataset that maps complex_id to physical location of each "Complex" (MTA-provided data but again slightly modified by Chris Whong). Can be found at the following link:

# %% [markdown]
# https://qri.cloud/nyc-transit-data/turnstiles_station_list

# %%
station_locations = pd.read_csv('nyc_transit_turnstiles_station_list.csv')

print(station_locations.shape)
station_locations
# Out:
# (511, 14)
#      ogc_fid  station_id complex_id gtfs_stop_id division  \
# 0          1         1.0          1          R01      BMT
# 1          2         2.0          2          R03      BMT
# 2          3         3.0          3          R04      BMT
# 3          4         4.0          4          R05      BMT
# 4          5         5.0          5          R06      BMT
# 5          6         6.0          6          R08      BMT
# 6          7         7.0        613          R11      BMT
# 7          8         8.0          8          R13      BMT
# 8          9         9.0          9          R14      BMT
# 9         10        10.0         10          R15      BMT
# 10        11        11.0        611          R16      BMT
# 11        12        12.0        607          R17      BMT
# 12        13        13.0         13          R18      BMT
# 13        14        14.0         14          R19      BMT
# 14        15        15.0        602          R20      BMT
# 15        16        16.0         16          R21      BMT
# 16        17        17.0         17          R22      BMT
# 17        18        18.0        623          R23      BMT
# 18        19        19.0        623          Q01      BMT
# 19        20        20.0         20          R24      BMT
# 20        21        21.0        624          R25      BMT
# 21        22        22.0         22          R26      BMT
# 22        23        23.0        635          R27      BMT
# 23        24        24.0        620          R28      BMT
# 24        25        25.0        636          R29      BMT
# 25        26        26.0         26          R30      BMT
# 26        27        27.0        617          R31      BMT
# 27        28        28.0         28          R32      BMT
# 28        29        29.0        608          R33      BMT
# 29        30        30.0         30          R34      BMT
# 30        31        31.0         31          R35      BMT
# 31        32        32.0         32          R36      BMT
# 32        33        33.0         33          R39      BMT
# 33        34        34.0         34          R40      BMT
# 34        35        35.0         35          R41      BMT
# 35        36        36.0         36          R42      BMT
# 36        37        37.0         37          R43      BMT
# 37        38        38.0         38          R44      BMT
# 38        39        39.0         39          R45      BMT
# 39        40        40.0        617          D24      BMT
# 40        41        41.0         41          D25      BMT
# 41        42        42.0         42          D26      BMT
# 42        43        43.0         43          D27      BMT
# 43        44        44.0         44          D28      BMT
# 44        45        45.0         45          D29      BMT
# 45        46        46.0         46          D30      BMT
# 46        47        47.0         47          D31      BMT
# 47        48        48.0         48          D32      BMT
# 48        49        49.0         49          D33      BMT
# 49        50        50.0         50          D34      BMT
# 50        51        51.0         51          D35      BMT
# 51        52        52.0         52          D37      BMT
# 52        53        53.0         53          D38      BMT
# 53        54        54.0         54          D39      BMT
# 54        55        55.0         55          D40      BMT
# 55        56        56.0         56          D41      BMT
# 56        57        57.0         57          D42      BMT
# 57        58        58.0         58          D43      BMT
# 58        59        59.0         59          B12      BMT
# 59        60        60.0         60          B13      BMT
# 60        61        61.0         61          B14      BMT
# 61        62        62.0         62          B15      BMT
# 62        63        63.0        615          B16      BMT
# 63        64        64.0         64          B17      BMT
# 64        65        65.0         65          B18      BMT
# 65        66        66.0         66          B19      BMT
# 66        67        67.0         67          B20      BMT
# 67        68        68.0         68          B21      BMT
# 68        69        69.0         69          B22      BMT
# 69        70        70.0         70          B23      BMT
# 70        71        71.0         71          N02      BMT
# 71        72        72.0         72          N03      BMT
# 72        73        73.0        615          N04      BMT
# 73        74        74.0         74          N05      BMT
# 74        75        75.0         75          N06      BMT
# 75        76        76.0         76          N07      BMT
# 76        77        77.0         77          N08      BMT
# 77        78        78.0         78          N09      BMT
# 78        79        79.0         79          N10      BMT
# 79        80        80.0         80          J12      BMT
# 80        81        81.0         81          J13      BMT
# 81        82        82.0         82          J14      BMT
# 82        83        83.0         83          J15      BMT
# 83        84        84.0         84          J16      BMT
# 84        85        85.0         85          J17      BMT
# 85        86        86.0         86          J19      BMT
# 86        87        87.0         87          J20      BMT
# 87        88        88.0         88          J21      BMT
# 88        89        89.0         89          J22      BMT
# 89        90        90.0         90          J23      BMT
# 90        91        91.0         91          J24      BMT
# 91        92        92.0        621          J27      BMT
# 92        93        93.0         93          J28      BMT
# 93        94        94.0         94          J29      BMT
# 94        95        95.0         95          J30      BMT
# 95        96        96.0         96          J31      BMT
# 96        97        97.0         97          M11      BMT
# 97        98        98.0         98          M12      BMT
# 98        99        99.0         99          M13      BMT
# 99       100       100.0        100          M14      BMT
# 100      101       101.0        101          M16      BMT
# 101      102       102.0        625          M18      BMT
# 102      103       103.0        103          M19      BMT
# 103      104       104.0        623          M20      BMT
# 104      105       105.0        622          M21      BMT
# 105      106       106.0        628          M22      BMT
# 106      107       107.0        107          M23      BMT
# 107      108       108.0        108          M01      BMT
# 108      109       109.0        109          M04      BMT
# 109      110       110.0        110          M05      BMT
# 110      111       111.0        111          M06      BMT
# 111      112       112.0        630          M08      BMT
# 112      113       113.0        113          M09      BMT
# 113      114       114.0        114          M10      BMT
# 114      115       115.0        618          L01      BMT
# 115      116       116.0        601          L02      BMT
# 116      117       117.0        602          L03      BMT
# 117      118       118.0        118          L05      BMT
# 118      119       119.0        119          L06      BMT
# 119      120       120.0        120          L08      BMT
# 120      121       121.0        629          L10      BMT
# 121      122       122.0        122          L11      BMT
# 122      123       123.0        123          L12      BMT
# 123      124       124.0        124          L13      BMT
# 124      125       125.0        125          L14      BMT
# 125      126       126.0        126          L15      BMT
# 126      127       127.0        127          L16      BMT
# 127      128       128.0        630          L17      BMT
# 128      129       129.0        129          L19      BMT
# 129      130       130.0        130          L20      BMT
# 130      131       131.0        131          L21      BMT
# 131      132       132.0        621          L22      BMT
# 132      133       133.0        133          L24      BMT
# 133      134       134.0        134          L25      BMT
# 134      135       135.0        135          L26      BMT
# 135      136       136.0        136          L27      BMT
# 136      137       137.0        137          L28      BMT
# 137      138       138.0        138          L29      BMT
# 138      139       139.0        627          S01      BMT
# 139      140       141.0        141          S03      BMT
# 140      141       142.0        626          S04      BMT
# 141      142       143.0        143          A02      IND
# 142      143       144.0        144          A03      IND
# 143      144       145.0        145          A05      IND
# 144      145       146.0        146          A06      IND
# 145      146       147.0        147          A07      IND
# 146      147       148.0        605          A09      IND
# 147      148       149.0        149          A10      IND
# 148      149       150.0        150          A11      IND
# 149      150       151.0        151          A12      IND
# 150      151       151.0        151          D13      IND
# 151      152       152.0        152          A14      IND
# 152      153       153.0        153          A15      IND
# 153      154       154.0        154          A16      IND
# 154      155       155.0        155          A17      IND
# 155      156       156.0        156          A18      IND
# 156      157       157.0        157          A19      IND
# 157      158       158.0        158          A20      IND
# 158      159       159.0        159          A21      IND
# 159      160       160.0        160          A22      IND
# 160      161       161.0        614          A24      IND
# 161      162       162.0        162          A25      IND
# 162      163       163.0        611          A27      IND
# 163      164       164.0        164          A28      IND
# 164      165       165.0        165          A30      IND
# 165      166       166.0        618          A31      IND
# 166      167       167.0        167          A32      IND
# 167      168       167.0        167          D20      IND
# 168      169       168.0        168          A33      IND
# 169      170       169.0        169          A34      IND
# 170      171       170.0        624          A36      IND
# 171      172       171.0        624          E01      IND
# 172      173       172.0        628          A38      IND
# 173      174       173.0        173          A40      IND
# 174      175       174.0        636          A41      IND
# 175      176       175.0        175          A42      IND
# 176      177       176.0        176          A43      IND
# 177      178       177.0        177          A44      IND
# 178      179       178.0        627          A45      IND
# 179      180       179.0        179          A46      IND
# 180      181       180.0        180          A47      IND
# 181      182       181.0        181          A48      IND
# 182      183       182.0        182          A49      IND
# 183      184       183.0        183          A50      IND
# 184      185       184.0        621          A51      IND
# 185      186       185.0        185          A52      IND
# 186      187       186.0        186          A53      IND
# 187      188       187.0        187          A54      IND
# 188      189       188.0        188          A55      IND
# 189      190       189.0        189          A57      IND
# 190      191       190.0        190          A59      IND
# 191      192       191.0        191          A60      IND
# 192      193       192.0        192          A61      IND
# 193      194       193.0        193          A63      IND
# 194      195       194.0        194          A64      IND
# 195      196       195.0        195          A65      IND
# 196      197       196.0        196          H01      IND
# 197      198       197.0        197          H02      IND
# 198      199       198.0        198          H03      IND
# 199      200       199.0        199          H04      IND
# 200      201       200.0        200          H12      IND
# 201      202       201.0        201          H13      IND
# 202      203       202.0        202          H14      IND
# 203      204       203.0        203          H15      IND
# 204      205       204.0        204          H06      IND
# 205      206       205.0        205          H07      IND
# 206      207       206.0        206          H08      IND
# 207      208       207.0        207          H09      IND
# 208      209       208.0        208          H10      IND
# 209      210       209.0        209          H11      IND
# 210      211       210.0        210          D01      IND
# 211      212       211.0        211          D03      IND
# 212      213       212.0        212          D04      IND
# 213      214       213.0        213          D05      IND
# 214      215       214.0        214          D06      IND
# 215      216       215.0        215          D07      IND
# 216      217       216.0        216          D08      IND
# 217      218       217.0        217          D09      IND
# 218      219       218.0        218          D10      IND
# 219      220       219.0        604          D11      IND
# 220      221       220.0        220          D12      IND
# 221      222       221.0        221          B04      IND
# 222      223       222.0        222          B06      IND
# 223      224       223.0        223          B08      IND
# 224      225       224.0        224          B10      IND
# 225      226       225.0        225          D15      IND
# 226      227       226.0        609          D16      IND
# 227      228       227.0        607          D17      IND
# 228      229       228.0        228          D18      IND
# 229      230       229.0        601          D19      IND
# 230      231       230.0        619          D21      IND
# 231      232       231.0        231          D22      IND
# 232      233       232.0        232          F14      IND
# 233      234       233.0        625          F15      IND
# 234      235       234.0        234          F16      IND
# 235      236       235.0        235          F18      IND
# 236      237       236.0        236          F20      IND
# 237      238       237.0        237          F21      IND
# 238      239       238.0        238          F22      IND
# 239      240       239.0        608          F23      IND
# 240      241       240.0        240          F24      IND
# 241      242       241.0        241          F25      IND
# 242      243       242.0        242          F26      IND
# 243      244       243.0        243          F27      IND
# 244      245       244.0        244          F29      IND
# 245      246       245.0        245          F30      IND
# 246      247       246.0        246          F31      IND
# 247      248       247.0        247          F32      IND
# 248      249       248.0        248          F33      IND
# 249      250       249.0        249          F34      IND
# 250      251       250.0        250          F35      IND
# 251      252       251.0        251          F36      IND
# 252      253       252.0        252          F38      IND
# 253      254       253.0        253          F39      IND
# 254      255       254.0        254          F01      IND
# 255      256       255.0        255          F02      IND
# 256      257       256.0        256          F03      IND
# 257      258       257.0        257          F04      IND
# 258      259       258.0        258          F05      IND
# 259      260       259.0        259          F06      IND
# 260      261       260.0        260          F07      IND
# 261      262       261.0        261          G08      IND
# 262      263       262.0        262          G09      IND
# 263      264       263.0        263          G10      IND
# 264      265       264.0        264          G11      IND
# 265      266       265.0        265          G12      IND
# 266      267       266.0        266          G13      IND
# 267      268       267.0        616          G14      IND
# 268      269       268.0        268          G15      IND
# 269      270       269.0        269          G16      IND
# 270      271       270.0        270          G18      IND
# 271      272       271.0        271          G19      IND
# 272      273       272.0        272          G20      IND
# 273      274       273.0        273          G21      IND
# 274      275       274.0        606          F09      IND
# 275      276       275.0        612          F11      IND
# 276      277       276.0        276          F12      IND
# 277      278       277.0        277          D14      IND
# 278      279       278.0        278          G05      IND
# 279      280       279.0        279          G06      IND
# 280      281       280.0        280          G07      IND
# 281      282       281.0        606          G22      IND
# 282      283       282.0        282          G24      IND
# 283      284       283.0        283          G26      IND
# 284      285       284.0        284          G28      IND
# 285      286       285.0        629          G29      IND
# 286      287       286.0        286          G30      IND
# 287      288       287.0        287          G31      IND
# 288      289       288.0        288          G32      IND
# 289      290       289.0        289          G33      IND
# 290      291       290.0        290          G34      IND
# 291      292       291.0        291          G35      IND
# 292      293       292.0        292          G36      IND
# 293      294       293.0        293          101      IRT
# 294      295       294.0        294          103      IRT
# 295      296       295.0        295          104      IRT
# 296      297       296.0        296          106      IRT
# 297      298       297.0        297          107      IRT
# 298      299       298.0        298          108      IRT
# 299      300       299.0        299          109      IRT
# 300      301       300.0        300          110      IRT
# 301      302       301.0        301          111      IRT
# 302      303       302.0        605          112      IRT
# 303      304       303.0        303          113      IRT
# 304      305       304.0        304          114      IRT
# 305      306       305.0        305          115      IRT
# 306      307       306.0        306          116      IRT
# 307      308       307.0        307          117      IRT
# 308      309       308.0        308          118      IRT
# 309      310       309.0        309          119      IRT
# 310      311       310.0        310          120      IRT
# 311      312       311.0        311          121      IRT
# 312      313       312.0        312          122      IRT
# 313      314       313.0        313          123      IRT
# 314      315       314.0        314          124      IRT
# 315      316       315.0        614          125      IRT
# 316      317       316.0        316          126      IRT
# 317      318       317.0        611          127      IRT
# 318      319       318.0        318          128      IRT
# 319      320       319.0        319          129      IRT
# 320      321       320.0        320          130      IRT
# 321      322       321.0        321          131      IRT
# 322      323       322.0        601          132      IRT
# 323      324       323.0        323          133      IRT
# 324      325       324.0        324          134      IRT
# 325      326       325.0        325          135      IRT
# 326      327       326.0        326          136      IRT
# 327      328       327.0        327          137      IRT
# 328      329       328.0        328          138      IRT
# 329      330       329.0        329          139      IRT
# 330      331       330.0        635          142      IRT
# 331      332       331.0        624          228      IRT
# 332      333       332.0        628          229      IRT
# 333      334       333.0        333          230      IRT
# 334      335       334.0        334          231      IRT
# 335      336       335.0        620          232      IRT
# 336      337       336.0        336          233      IRT
# 337      338       337.0        337          234      IRT
# 338      339       338.0        617          235      IRT
# 339      340       339.0        339          236      IRT
# 340      341       340.0        340          237      IRT
# 341      342       341.0        341          238      IRT
# 342      343       342.0        626          239      IRT
# 343      344       343.0        343          248      IRT
# 344      345       344.0        344          249      IRT
# 345      346       345.0        345          250      IRT
# 346      347       346.0        346          251      IRT
# 347      348       347.0        347          252      IRT
# 348      349       348.0        348          253      IRT
# 349      350       349.0        349          254      IRT
# 350      351       350.0        350          255      IRT
# 351      352       351.0        351          256      IRT
# 352      353       352.0        352          257      IRT
# 353      354       353.0        353          241      IRT
# 354      355       354.0        354          242      IRT
# 355      356       355.0        355          243      IRT
# 356      357       356.0        356          244      IRT
# 357      358       357.0        357          245      IRT
# 358      359       358.0        358          246      IRT
# 359      360       359.0        359          247      IRT
# 360      361       360.0        360          601      IRT
# 361      362       361.0        361          602      IRT
# 362      363       362.0        362          603      IRT
# 363      364       363.0        363          604      IRT
# 364      365       364.0        364          606      IRT
# 365      366       365.0        365          607      IRT
# 366      367       366.0        366          608      IRT
# 367      368       367.0        367          609      IRT
# 368      369       368.0        368          610      IRT
# 369      370       369.0        369          611      IRT
# 370      371       370.0        370          612      IRT
# 371      372       371.0        371          613      IRT
# 372      373       372.0        372          614      IRT
# 373      374       373.0        373          615      IRT
# 374      375       374.0        374          616      IRT
# 375      376       375.0        375          617      IRT
# 376      377       376.0        376          618      IRT
# 377      378       377.0        377          619      IRT
# 378      379       378.0        378          401      IRT
# 379      380       379.0        379          402      IRT
# 380      381       380.0        380          405      IRT
# 381      382       381.0        381          406      IRT
# 382      383       382.0        382          407      IRT
# 383      384       383.0        383          408      IRT
# 384      385       384.0        384          409      IRT
# 385      386       385.0        385          410      IRT
# 386      387       386.0        386          411      IRT
# 387      388       387.0        387          412      IRT
# 388      389       388.0        388          413      IRT
# 389      390       389.0        604          414      IRT
# 390      391       390.0        603          415      IRT
# 391      392       391.0        391          416      IRT
# 392      393       392.0        392          621      IRT
# 393      394       393.0        393          622      IRT
# 394      395       394.0        394          623      IRT
# 395      396       395.0        395          624      IRT
# 396      397       396.0        396          625      IRT
# 397      398       397.0        397          626      IRT
# 398      399       398.0        398          627      IRT
# 399      400       399.0        399          628      IRT
# 400      401       400.0        613          629      IRT
# 401      402       401.0        612          630      IRT
# 402      403       402.0        610          631      IRT
# 403      404       403.0        403          632      IRT
# 404      405       404.0        404          633      IRT
# 405      406       405.0        405          634      IRT
# 406      407       406.0        602          635      IRT
# 407      408       407.0        407          636      IRT
# 408      409       408.0        619          637      IRT
# 409      410       409.0        409          638      IRT
# 410      411       410.0        623          639      IRT
# 411      412       411.0        622          640      IRT
# 412      413       412.0        628          418      IRT
# 413      414       413.0        413          419      IRT
# 414      415       414.0        414          420      IRT
# 415      416       415.0        620          423      IRT
# 416      417       416.0        416          201      IRT
# 417      418       417.0        417          204      IRT
# 418      419       418.0        418          205      IRT
# 419      420       419.0        419          206      IRT
# 420      421       420.0        420          207      IRT
# 421      422       421.0        421          208      IRT
# 422      423       422.0        422          209      IRT
# 423      424       423.0        423          210      IRT
# 424      425       424.0        424          211      IRT
# 425      426       425.0        425          212      IRT
# 426      427       426.0        426          213      IRT
# 427      428       427.0        427          214      IRT
# 428      429       428.0        428          215      IRT
# 429      430       429.0        429          216      IRT
# 430      431       430.0        430          217      IRT
# 431      432       431.0        431          218      IRT
# 432      433       432.0        432          219      IRT
# 433      434       433.0        433          220      IRT
# 434      435       434.0        434          221      IRT
# 435      436       435.0        603          222      IRT
# 436      437       436.0        436          301      IRT
# 437      438       437.0        437          302      IRT
# 438      439       438.0        438          224      IRT
# 439      440       439.0        439          225      IRT
# 440      441       440.0        440          226      IRT
# 441      442       441.0        441          227      IRT
# 442      443       442.0        442          501      IRT
# 443      444       443.0        443          502      IRT
# 444      445       444.0        444          503      IRT
# 445      446       445.0        445          504      IRT
# 446      447       446.0        446          505      IRT
# 447      448       447.0        447          701      IRT
# 448      449       448.0        448          702      IRT
# 449      450       449.0        449          705      IRT
# 450      451       450.0        450          706      IRT
# 451      452       451.0        451          707      IRT
# 452      453       452.0        452          708      IRT
# 453      454       453.0        453          709      IRT
# 454      455       454.0        616          710      IRT
# 455      456       455.0        455          711      IRT
# 456      457       456.0        456          712      IRT
# 457      458       457.0        457          713      IRT
# 458      459       458.0        458          714      IRT
# 459      460       459.0        459          715      IRT
# 460      461       460.0        460          716      IRT
# 461      462       461.0        461          718      IRT
# 462      463       461.0        461          R09      BMT
# 463      464       462.0        606          719      IRT
# 464      465       463.0        463          720      IRT
# 465      466       464.0        464          721      IRT
# 466      467       465.0        610          723      IRT
# 467      468       466.0        609          724      IRT
# 468      469       467.0        611          725      IRT
# 469      470       468.0        611          902      IRT
# 470      471       469.0        610          901      IRT
# 471      472       471.0        471          726      IRT
# 472      473       475.0        475          Q05      IND
# 473      474       476.0        476          Q04      IND
# 474      475       477.0        477          Q03      IND
# 475      476       501.0        501          S31      SIR
# 476      477       502.0        502          S30      SIR
# 477      478       503.0        503          S29      SIR
# 478      479       504.0        504          S28      SIR
# 479      480       505.0        505          S27      SIR
# 480      481       506.0        506          S26      SIR
# 481      482       507.0        507          S25      SIR
# 482      483       508.0        508          S24      SIR
# 483      484       509.0        509          S23      SIR
# 484      485       510.0        510          S22      SIR
# 485      486       511.0        511          S21      SIR
# 486      487       512.0        512          S20      SIR
# 487      488       513.0        513          S19      SIR
# 488      489       514.0        514          S18      SIR
# 489      490       515.0        515          S17      SIR
# 490      491       516.0        516          S16      SIR
# 491      492       517.0        517          S15      SIR
# 492      493       518.0        518          S14      SIR
# 493      494       519.0        519          S13      SIR
# 494      495       522.0        522          S09      SIR
# 495      496       523.0        523          S11      SIR
# 496      497         NaN       R468          NaN      RIT
# 497      498         NaN       R469          NaN      RIT
# 498      499         NaN       R540          NaN      PTH
# 499      500         NaN       R541          NaN      PTH
# 500      501         NaN       R542          NaN      PTH
# 501      502         NaN       R543          NaN      PTH
# 502      503         NaN       R544          NaN      PTH
# 503      504         NaN       R545          NaN      PTH
# 504      505         NaN       R546          NaN      PTH
# 505      506         NaN       R547          NaN      PTH
# 506      507         NaN       R548          NaN      PTH
# 507      508         NaN       R549          NaN      PTH
# 508      509         NaN       R550          NaN      PTH
# 509      510         NaN       R551          NaN      PTH
# 510      511         NaN       R552          NaN      PTH
#
#                                          line  \
# 0                                     Astoria
# 1                                     Astoria
# 2                                     Astoria
# 3                                     Astoria
# 4                                     Astoria
# 5                                     Astoria
# 6                                     Astoria
# 7                                     Astoria
# 8                         Broadway - Brighton
# 9                         Broadway - Brighton
# 10                        Broadway - Brighton
# 11                        Broadway - Brighton
# 12                        Broadway - Brighton
# 13                        Broadway - Brighton
# 14                        Broadway - Brighton
# 15                        Broadway - Brighton
# 16                        Broadway - Brighton
# 17                                   Broadway
# 18                           Manhattan Bridge
# 19                                   Broadway
# 20                                   Broadway
# 21                                   Broadway
# 22                                   Broadway
# 23                                   Broadway
# 24                                   Broadway
# 25                        Broadway - Brighton
# 26                                     4th Av
# 27                                     4th Av
# 28                                     4th Av
# 29                                     4th Av
# 30                                     4th Av
# 31                                     4th Av
# 32                                     4th Av
# 33                                     4th Av
# 34                                     4th Av
# 35                                     4th Av
# 36                                     4th Av
# 37                                     4th Av
# 38                                     4th Av
# 39                        Broadway - Brighton
# 40                        Broadway - Brighton
# 41                        Broadway - Brighton
# 42                        Broadway - Brighton
# 43                        Broadway - Brighton
# 44                        Broadway - Brighton
# 45                        Broadway - Brighton
# 46                        Broadway - Brighton
# 47                        Broadway - Brighton
# 48                        Broadway - Brighton
# 49                        Broadway - Brighton
# 50                        Broadway - Brighton
# 51                        Broadway - Brighton
# 52                        Broadway - Brighton
# 53                        Broadway - Brighton
# 54                        Broadway - Brighton
# 55                        Broadway - Brighton
# 56                        Broadway - Brighton
# 57   Sea Beach / West End / Culver / Brighton
# 58                                   West End
# 59                                   West End
# 60                                   West End
# 61                                   West End
# 62                                   West End
# 63                                   West End
# 64                                   West End
# 65                                   West End
# 66                                   West End
# 67                                   West End
# 68                                   West End
# 69                                   West End
# 70                                  Sea Beach
# 71                                  Sea Beach
# 72                                  Sea Beach
# 73                                  Sea Beach
# 74                                  Sea Beach
# 75                                  Sea Beach
# 76                                  Sea Beach
# 77                                  Sea Beach
# 78                                  Sea Beach
# 79                                    Jamaica
# 80                                    Jamaica
# 81                                    Jamaica
# 82                                    Jamaica
# 83                                    Jamaica
# 84                                    Jamaica
# 85                                    Jamaica
# 86                                    Jamaica
# 87                                    Jamaica
# 88                                    Jamaica
# 89                                    Jamaica
# 90                                    Jamaica
# 91                                    Jamaica
# 92                                    Jamaica
# 93                                    Jamaica
# 94                                    Jamaica
# 95                                    Jamaica
# 96                                    Jamaica
# 97                                    Jamaica
# 98                                    Jamaica
# 99                                    Jamaica
# 100                                   Jamaica
# 101                                   Jamaica
# 102                                   Jamaica
# 103                                   Jamaica
# 104                                   Jamaica
# 105                                   Jamaica
# 106                                   Jamaica
# 107                                 Myrtle Av
# 108                                 Myrtle Av
# 109                                 Myrtle Av
# 110                                 Myrtle Av
# 111                                 Myrtle Av
# 112                                 Myrtle Av
# 113                                 Myrtle Av
# 114                                  Canarsie
# 115                                  Canarsie
# 116                                  Canarsie
# 117                                  Canarsie
# 118                                  Canarsie
# 119                                  Canarsie
# 120                                  Canarsie
# 121                                  Canarsie
# 122                                  Canarsie
# 123                                  Canarsie
# 124                                  Canarsie
# 125                                  Canarsie
# 126                                  Canarsie
# 127                                  Canarsie
# 128                                  Canarsie
# 129                                  Canarsie
# 130                                  Canarsie
# 131                                  Canarsie
# 132                                  Canarsie
# 133                                  Canarsie
# 134                                  Canarsie
# 135                                  Canarsie
# 136                                  Canarsie
# 137                                  Canarsie
# 138                          Franklin Shuttle
# 139                          Franklin Shuttle
# 140                          Franklin Shuttle
# 141                        8th Av - Fulton St
# 142                        8th Av - Fulton St
# 143                        8th Av - Fulton St
# 144                        8th Av - Fulton St
# 145                        8th Av - Fulton St
# 146                        8th Av - Fulton St
# 147                        8th Av - Fulton St
# 148                        8th Av - Fulton St
# 149                        8th Av - Fulton St
# 150                                 Concourse
# 151                        8th Av - Fulton St
# 152                        8th Av - Fulton St
# 153                        8th Av - Fulton St
# 154                        8th Av - Fulton St
# 155                        8th Av - Fulton St
# 156                        8th Av - Fulton St
# 157                        8th Av - Fulton St
# 158                        8th Av - Fulton St
# 159                        8th Av - Fulton St
# 160                        8th Av - Fulton St
# 161                        8th Av - Fulton St
# 162                        8th Av - Fulton St
# 163                        8th Av - Fulton St
# 164                        8th Av - Fulton St
# 165                        8th Av - Fulton St
# 166                        8th Av - Fulton St
# 167                           6th Av - Culver
# 168                        8th Av - Fulton St
# 169                        8th Av - Fulton St
# 170                        8th Av - Fulton St
# 171                        8th Av - Fulton St
# 172                        8th Av - Fulton St
# 173                        8th Av - Fulton St
# 174                        8th Av - Fulton St
# 175                        8th Av - Fulton St
# 176                        8th Av - Fulton St
# 177                        8th Av - Fulton St
# 178                        8th Av - Fulton St
# 179                        8th Av - Fulton St
# 180                        8th Av - Fulton St
# 181                        8th Av - Fulton St
# 182                        8th Av - Fulton St
# 183                        8th Av - Fulton St
# 184                        8th Av - Fulton St
# 185                        8th Av - Fulton St
# 186                        8th Av - Fulton St
# 187                        8th Av - Fulton St
# 188                        8th Av - Fulton St
# 189                                Liberty Av
# 190                                Liberty Av
# 191                                Liberty Av
# 192                                Liberty Av
# 193                                Liberty Av
# 194                                Liberty Av
# 195                                Liberty Av
# 196                                  Rockaway
# 197                                  Rockaway
# 198                                  Rockaway
# 199                                  Rockaway
# 200                                  Rockaway
# 201                                  Rockaway
# 202                                  Rockaway
# 203                                  Rockaway
# 204                                  Rockaway
# 205                                  Rockaway
# 206                                  Rockaway
# 207                                  Rockaway
# 208                                  Rockaway
# 209                                  Rockaway
# 210                                 Concourse
# 211                                 Concourse
# 212                                 Concourse
# 213                                 Concourse
# 214                                 Concourse
# 215                                 Concourse
# 216                                 Concourse
# 217                                 Concourse
# 218                                 Concourse
# 219                                 Concourse
# 220                                 Concourse
# 221                                   63rd St
# 222                                   63rd St
# 223                                   63rd St
# 224                           6th Av - Culver
# 225                           6th Av - Culver
# 226                           6th Av - Culver
# 227                           6th Av - Culver
# 228                           6th Av - Culver
# 229                           6th Av - Culver
# 230                           6th Av - Culver
# 231                           6th Av - Culver
# 232                           6th Av - Culver
# 233                           6th Av - Culver
# 234                           6th Av - Culver
# 235                           6th Av - Culver
# 236                           6th Av - Culver
# 237                           6th Av - Culver
# 238                           6th Av - Culver
# 239                           6th Av - Culver
# 240                           6th Av - Culver
# 241                           6th Av - Culver
# 242                           6th Av - Culver
# 243                           6th Av - Culver
# 244                           6th Av - Culver
# 245                           6th Av - Culver
# 246                           6th Av - Culver
# 247                           6th Av - Culver
# 248                           6th Av - Culver
# 249                           6th Av - Culver
# 250                           6th Av - Culver
# 251                           6th Av - Culver
# 252                           6th Av - Culver
# 253                           6th Av - Culver
# 254                               Queens Blvd
# 255                               Queens Blvd
# 256                               Queens Blvd
# 257                               Queens Blvd
# 258                               Queens Blvd
# 259                               Queens Blvd
# 260                               Queens Blvd
# 261                               Queens Blvd
# 262                               Queens Blvd
# 263                               Queens Blvd
# 264                               Queens Blvd
# 265                               Queens Blvd
# 266                               Queens Blvd
# 267                               Queens Blvd
# 268                               Queens Blvd
# 269                               Queens Blvd
# 270                               Queens Blvd
# 271                               Queens Blvd
# 272                               Queens Blvd
# 273                               Queens Blvd
# 274                               Queens Blvd
# 275                               Queens Blvd
# 276                               Queens Blvd
# 277                               Queens Blvd
# 278                           Queens - Archer
# 279                           Queens - Archer
# 280                           Queens - Archer
# 281                                 Crosstown
# 282                                 Crosstown
# 283                                 Crosstown
# 284                                 Crosstown
# 285                                 Crosstown
# 286                                 Crosstown
# 287                                 Crosstown
# 288                                 Crosstown
# 289                                 Crosstown
# 290                                 Crosstown
# 291                                 Crosstown
# 292                                 Crosstown
# 293                            Broadway - 7Av
# 294                            Broadway - 7Av
# 295                            Broadway - 7Av
# 296                            Broadway - 7Av
# 297                            Broadway - 7Av
# 298                            Broadway - 7Av
# 299                            Broadway - 7Av
# 300                            Broadway - 7Av
# 301                            Broadway - 7Av
# 302                            Broadway - 7Av
# 303                            Broadway - 7Av
# 304                            Broadway - 7Av
# 305                            Broadway - 7Av
# 306                            Broadway - 7Av
# 307                            Broadway - 7Av
# 308                            Broadway - 7Av
# 309                            Broadway - 7Av
# 310                            Broadway - 7Av
# 311                            Broadway - 7Av
# 312                            Broadway - 7Av
# 313                            Broadway - 7Av
# 314                            Broadway - 7Av
# 315                            Broadway - 7Av
# 316                            Broadway - 7Av
# 317                            Broadway - 7Av
# 318                            Broadway - 7Av
# 319                            Broadway - 7Av
# 320                            Broadway - 7Av
# 321                            Broadway - 7Av
# 322                            Broadway - 7Av
# 323                            Broadway - 7Av
# 324                            Broadway - 7Av
# 325                            Broadway - 7Av
# 326                            Broadway - 7Av
# 327                            Broadway - 7Av
# 328                            Broadway - 7Av
# 329                            Broadway - 7Av
# 330                            Broadway - 7Av
# 331                                  Clark St
# 332                                  Clark St
# 333                                  Clark St
# 334                                  Clark St
# 335                                  Clark St
# 336                               Eastern Pky
# 337                               Eastern Pky
# 338                               Eastern Pky
# 339                               Eastern Pky
# ...
# 204                                  Far Rockaway
# 205                                  Far Rockaway
# 206                                  Far Rockaway
# 207                                  Far Rockaway
# 208                                  Far Rockaway
# 209                                           NaN
# 210                                     Manhattan
# 211                                     Manhattan
# 212                                     Manhattan
# 213                                     Manhattan
# 214                                     Manhattan
# 215                                     Manhattan
# 216                                     Manhattan
# 217                                     Manhattan
# 218                                     Manhattan
# 219                                     Manhattan
# 220                           Downtown & Brooklyn
# 221                                     Manhattan
# 222                                     Manhattan
# 223                           Downtown & Brooklyn
# 224                           Downtown & Brooklyn
# 225                           Downtown & Brooklyn
# 226                           Downtown & Brooklyn
# 227                           Downtown & Brooklyn
# 228                           Downtown & Brooklyn
# 229                           Downtown & Brooklyn
# 230                           Downtown & Brooklyn
# 231                                      Brooklyn
# 232                           Downtown & Brooklyn
# 233                           Downtown & Brooklyn
# 234                                      Brooklyn
# 235                                  Coney Island
# 236                      Church Av - Coney Island
# 237                      Church Av - Coney Island
# 238                      Church Av - Coney Island
# 239                      Church Av - Coney Island
# 240                      Church Av - Coney Island
# 241                      Church Av - Coney Island
# 242                      Church Av - Coney Island
# 243                                  Coney Island
# 244                                  Coney Island
# 245                                  Coney Island
# 246                                  Coney Island
# 247                                  Coney Island
# 248                                  Coney Island
# 249                                  Coney Island
# 250                                  Coney Island
# 251                                  Coney Island
# 252                                  Coney Island
# 253                                  Stillwell Av
# 254                                     Manhattan
# 255                                     Manhattan
# 256                                     Manhattan
# 257                                     Manhattan
# 258                                     Manhattan
# 259                                     Manhattan
# 260                                     Manhattan
# 261                                     Manhattan
# 262                                     Manhattan
# 263                                     Manhattan
# 264                                     Manhattan
# 265                                     Manhattan
# 266                                     Manhattan
# 267                                     Manhattan
# 268                                     Manhattan
# 269                                     Manhattan
# 270                                     Manhattan
# 271                                     Manhattan
# 272                                     Manhattan
# 273                                     Manhattan
# 274                                     Manhattan
# 275                           Downtown & Brooklyn
# 276                           Downtown & Brooklyn
# 277                           Downtown & Brooklyn
# 278                                     Manhattan
# 279                                     Manhattan
# 280                                     Manhattan
# 281                                      Brooklyn
# 282                                      Brooklyn
# 283                                     Church Av
# 284                                     Church Av
# 285                                     Church Av
# 286                                     Church Av
# 287                                     Church Av
# 288                                     Church Av
# 289                                     Church Av
# 290                                     Church Av
# 291                                     Church Av
# 292                                     Church Av
# 293                                     Manhattan
# 294                                     Manhattan
# 295                                     Manhattan
# 296                                      Downtown
# 297                                      Downtown
# 298                                      Downtown
# 299                                      Downtown
# 300                                      Downtown
# 301                                      Downtown
# 302                                      Downtown
# 303                                      Downtown
# 304                                      Downtown
# 305                                      Downtown
# 306                                      Downtown
# 307                                      Downtown
# 308                                      Downtown
# 309                                      Downtown
# 310                           Downtown & Brooklyn
# 311                                      Downtown
# 312                                      Downtown
# 313                           Downtown & Brooklyn
# 314                                      Downtown
# 315                                      Downtown
# 316                                      Downtown
# 317                           Downtown & Brooklyn
# 318                           Downtown & Brooklyn
# 319                                      Downtown
# 320                                      Downtown
# 321                                      Downtown
# 322                           Downtown & Brooklyn
# 323                                      Downtown
# 324                                      Downtown
# 325                                      Downtown
# 326                                      Downtown
# 327                           Downtown & Brooklyn
# 328                                      Downtown
# 329                                      Downtown
# 330                                           NaN
# 331                           Downtown & Brooklyn
# 332                           Downtown & Brooklyn
# 333                                      Brooklyn
# 334                           Flatbush - New Lots
# 335                           Flatbush - New Lots
# 336                           Flatbush - New Lots
# 337                   Flatbush - Utica - New Lots
# 338                           Flatbush - New Lots
# 339                           Flatbush - New Lots
# 340                           Flatbush - New Lots
# 341                           Flatbush - New Lots
# 342                   Flatbush - Utica - New Lots
# 343                                      New Lots
# 344                                      New Lots
# 345                                      New Lots
# 346                                      New Lots
# 347                                      New Lots
# 348                                      New Lots
# 349                                      New Lots
# 350                                      New Lots
# 351                                      New Lots
# 352                                           NaN
# 353                                      Flatbush
# 354                                      Flatbush
# 355                                      Flatbush
# 356                                      Flatbush
# 357                                      Flatbush
# 358                                      Flatbush
# 359                                           NaN
# 360                                     Manhattan
# 361                                     Manhattan
# 362                                     Manhattan
# 363                                     Manhattan
# 364                                     Manhattan
# 365                                     Manhattan
# 366                                     Manhattan
# 367                                     Manhattan
# 368                                     Manhattan
# 369                                     Manhattan
# 370                                     Manhattan
# 371                                     Manhattan
# 372                                     Manhattan
# 373                                     Manhattan
# 374                                     Manhattan
# 375                                     Manhattan
# 376                                     Manhattan
# 377                                     Manhattan
# 378                                     Manhattan
# 379                                     Manhattan
# 380                                     Manhattan
# 381                                     Manhattan
# 382                                     Manhattan
# 383                                     Manhattan
# 384                                     Manhattan
# 385                                     Manhattan
# 386                                     Manhattan
# 387                                     Manhattan
# 388                                     Manhattan
# 389                                     Manhattan
# 390                                     Manhattan
# 391                                     Manhattan
# 392                           Downtown & Brooklyn
# 393                                      Downtown
# 394                                      Downtown
# 395                                      Downtown
# 396                                      Downtown
# 397                           Downtown & Brooklyn
# 398                                      Downtown
# 399                                      Downtown
# 400                           Downtown & Brooklyn
# 401                                      Downtown
# 402                           Downtown & Brooklyn
# 403                                      Downtown
# 404                                      Downtown
# 405                                      Downtown
# 406                           Downtown & Brooklyn
# 407                                      Downtown
# 408                                      Downtown
# 409                                      Downtown
# 410                                      Downtown
# 411                           Downtown & Brooklyn
# 412                           Downtown & Brooklyn
# 413                           Downtown & Brooklyn
# 414                                      Brooklyn
# 415                              Flatbush - Utica
# 416                                     Manhattan
# 417                                     Manhattan
# 418                                     Manhattan
# 419                                     Manhattan
# 420                                     Manhattan
# 421                                     Manhattan
# 422                                     Manhattan
# 423                                     Manhattan
# 424                                     Manhattan
# 425                                     Manhattan
# 426                                     Manhattan
# 427                                     Manhattan
# 428                                     Manhattan
# 429                                     Manhattan
# 430                                     Manhattan
# 431                                     Manhattan
# 432                                     Manhattan
# 433                                     Manhattan
# 434                                     Manhattan
# 435                                     Manhattan
# 436                           Downtown & Brooklyn
# 437                           Downtown & Brooklyn
# 438                           Downtown & Brooklyn
# 439                           Downtown & Brooklyn
# 440                           Downtown & Brooklyn
# 441                           Downtown & Brooklyn
# 442                                     Manhattan
# 443                                     Manhattan
# 444                                     Manhattan
# 445                                     Manhattan
# 446                                     Manhattan
# 447                                     Manhattan
# 448                                     Manhattan
# 449                                     Manhattan
# 450                                     Manhattan
# 451                                     Manhattan
# 452                                     Manhattan
# 453                                     Manhattan
# 454                                     Manhattan
# 455                                     Manhattan
# 456                                     Manhattan
# 457                                     Manhattan
# 458                                     Manhattan
# 459                                     Manhattan
# 460                                     Manhattan
# 461                                     Manhattan
# 462                                     Manhattan
# 463                                     Manhattan
# 464                                     Manhattan
# 465                                     Manhattan
# 466                          34 St - Hudson Yards
# 467                          34 St - Hudson Yards
# 468                          34 St - Hudson Yards
# 469                                 Grand Central
# 470                                           NaN
# 471                                           NaN
# 472                           Downtown & Brooklyn
# 473                           Downtown & Brooklyn
# 474                           Downtown & Brooklyn
# 475                                   Tottenville
# 476                                   Tottenville
# 477                                   Tottenville
# 478                                   Tottenville
# 479                                   Tottenville
# 480                                   Tottenville
# 481                                   Tottenville
# 482                                   Tottenville
# 483                                   Tottenville
# 484                                   Tottenville
# 485                                   Tottenville
# 486                                   Tottenville
# 487                                   Tottenville
# 488                                   Tottenville
# 489                                   Tottenville
# 490                                   Tottenville
# 491                                   Tottenville
# 492                                   Tottenville
# 493                                   Tottenville
# 494                                           NaN
# 495                                   Tottenville
# 496                                           NaN
# 497                                           NaN
# 498                                           NaN
# 499                                           NaN
# 500                                           NaN
# 501                                           NaN
# 502                                           NaN
# 503                                           NaN
# 504                                           NaN
# 505                                           NaN
# 506                                           NaN
# 507                                           NaN
# 508                                           NaN
# 509                                           NaN
# 510                                           NaN

# %%
# Let's drop some unnecessary columns from station_locations

station_locations = station_locations[['complex_id', 'division', 'line', 'stop_name', 
                                       'borough', 'gtfs_latitude', 'gtfs_longitude']]
station_locations.head()
# Out:
#   complex_id division     line               stop_name borough  gtfs_latitude  \
# 0          1      BMT  Astoria  Astoria - Ditmars Blvd       Q      40.775036
# 1          2      BMT  Astoria            Astoria Blvd       Q      40.770258
# 2          3      BMT  Astoria                   30 Av       Q      40.766779
# 3          4      BMT  Astoria                Broadway       Q      40.761820
# 4          5      BMT  Astoria                   36 Av       Q      40.756804
#
#    gtfs_longitude
# 0      -73.912034
# 1      -73.917843
# 2      -73.921479
# 3      -73.925508
# 4      -73.929575

# %% [markdown]
# #### Now merge complex_list with station_locations

# %%
station_locations['complex_id'].dtype
# Out:
# dtype('O')

# %%
# Need to convert 'complex_id' in complex_list to same format

print(complex_list['complex_id'].dtype)

complex_list['complex_id'] = complex_list['complex_id'].apply(lambda x: str(x).replace('.0','')).astype('str')
print(complex_list['complex_id'].dtype)
# Out:
# float64
# object

# %%
complex_locations = complex_list.merge(right=station_locations, 
                                       how='inner', 
                                       on=['complex_id', 'division'])

# %%
print(complex_locations.shape)
complex_locations.head(20)
# Out:
# (809, 11)
#    remote  booth complex_id          station    line_name division  \
# 0    R001   A060        635     WHITEHALL ST           R1      BMT
# 1    R001   A058        635     WHITEHALL ST           R1      BMT
# 2    R001  R101S        635      SOUTH FERRY           R1      IRT
# 3    R002   A077        628        FULTON ST     ACJZ2345      BMT
# 4    R002   A081        628        FULTON ST     ACJZ2345      BMT
# 5    R002   A082        628        FULTON ST     ACJZ2345      BMT
# 6    R003   J025         86    CYPRESS HILLS            J      BMT
# 7    R004   J028         85     ELDERTS LANE           JZ      BMT
# 8    R005   J030         84   FOREST PARKWAY            J      BMT
# 9    R006   J031         83   WOODHAVEN BLVD           JZ      BMT
# 10   R006   J032         83   WOODHAVEN BLVD           JZ      BMT
# 11   R007   J034         82           104 ST           JZ      BMT
# 12   R008   J035         81           111 ST            J      BMT
# 13   R009   J037         80           121 ST           JZ      BMT
# 14   R010  N062A        611  42 ST-PA BUS TE  ACENQRS1237      IND
# 15   R010   N060        611  42 ST-PA BUS TE  ACENQRS1237      IND
# 16   R011  N063A        611  42 ST-PA BUS TE  ACENQRS1237      IND
# 17   R011   N062        611  42 ST-PA BUS TE  ACENQRS1237      IND
# 18   R011   N063        611  42 ST-PA BUS TE  ACENQRS1237      IND
# 19   R012   N067        164   34 ST-PENN STA          ACE      IND
#
#                   line                            stop_name borough  \
# 0             Broadway                         Whitehall St       M
# 1             Broadway                         Whitehall St       M
# 2       Broadway - 7Av                          South Ferry       M
# 3              Jamaica                            Fulton St       M
# 4              Jamaica                            Fulton St       M
# 5              Jamaica                            Fulton St       M
# 6              Jamaica                        Cypress Hills      Bk
# 7              Jamaica                                75 St       Q
# 8              Jamaica                  85 St - Forest Pkwy       Q
# 9              Jamaica                       Woodhaven Blvd       Q
# 10             Jamaica                       Woodhaven Blvd       Q
# 11             Jamaica                               104 St       Q
# 12             Jamaica                               111 St       Q
# 13             Jamaica                               121 St       Q
# 14  8th Av - Fulton St  42 St - Port Authority Bus Terminal       M
# 15  8th Av - Fulton St  42 St - Port Authority Bus Terminal       M
# 16  8th Av - Fulton St  42 St - Port Authority Bus Terminal       M
# 17  8th Av - Fulton St  42 St - Port Authority Bus Terminal       M
# 18  8th Av - Fulton St  42 St - Port Authority Bus Terminal       M
# 19  8th Av - Fulton St                 34 St - Penn Station       M
#
#     gtfs_latitude  gtfs_longitude
# 0       40.703087      -74.012994
# 1       40.703087      -74.012994
# 2       40.702068      -74.013664
# 3       40.710374      -74.007582
# 4       40.710374      -74.007582
# 5       40.710374      -74.007582
# 6       40.689941      -73.872550
# 7       40.691324      -73.867139
# 8       40.692435      -73.860010
# 9       40.693879      -73.851576
# 10      40.693879      -73.851576
# 11      40.695178      -73.844330
# 12      40.697418      -73.836345
# 13      40.700492      -73.828294
# 14      40.757308      -73.989735
# 15      40.757308      -73.989735
# 16      40.757308      -73.989735
# 17      40.757308      -73.989735
# 18      40.757308      -73.989735
# 19      40.752287      -73.993391

# %% [markdown]
# #### Now we can merge complex_locations with the daily_per_turnstile datasets for 2019 & 2021

# %%
complex_locations.columns = [col.upper() for col in complex_locations.columns]
complex_locations.head()
# Out:
#   REMOTE  BOOTH COMPLEX_ID       STATION LINE_NAME DIVISION            LINE  \
# 0   R001   A060        635  WHITEHALL ST        R1      BMT        Broadway
# 1   R001   A058        635  WHITEHALL ST        R1      BMT        Broadway
# 2   R001  R101S        635   SOUTH FERRY        R1      IRT  Broadway - 7Av
# 3   R002   A077        628     FULTON ST  ACJZ2345      BMT         Jamaica
# 4   R002   A081        628     FULTON ST  ACJZ2345      BMT         Jamaica
#
#       STOP_NAME BOROUGH  GTFS_LATITUDE  GTFS_LONGITUDE
# 0  Whitehall St       M      40.703087      -74.012994
# 1  Whitehall St       M      40.703087      -74.012994
# 2   South Ferry       M      40.702068      -74.013664
# 3     Fulton St       M      40.710374      -74.007582
# 4     Fulton St       M      40.710374      -74.007582

# %%
temp = complex_locations.groupby(['COMPLEX_ID', 'GTFS_LATITUDE', 'GTFS_LONGITUDE'])\
                                                                    .count().reset_index() \
                                                                    .sort_values(by=['STATION', 'COMPLEX_ID'],
                                                                                 ascending=False) \
                                                                    .drop(columns=['REMOTE', 'BOOTH', 'STATION',
                                                                                   'LINE_NAME', 'DIVISION', 'LINE',
                                                                                   'STOP_NAME', 'BOROUGH'])

temp['COMPLEX_ID'].value_counts()
# Out:
# 611    5
# 628    4
# 623    4
# 624    4
# 601    3
# 617    3
# 620    3
# 610    3
# 606    3
# 602    3
# 629    2
# 605    2
# 607    2
# 615    2
# 616    2
# 619    2
# 622    2
# 625    2
# 630    2
# 635    2
# 636    2
# 603    2
# 608    2
# 604    2
# 614    2
# 618    2
# 609    2
# 613    2
# 383    1
# 369    1
# 37     1
# 370    1
# 371    1
# 377    1
# 378    1
# 379    1
# 380    1
# 381    1
# 382    1
# 384    1
# 367    1
# 385    1
# 386    1
# 387    1
# 388    1
# 391    1
# 392    1
# 395    1
# 396    1
# 399    1
# 368    1
# 366    1
# 41     1
# 365    1
# 341    1
# 343    1
# 344    1
# 346    1
# 347    1
# 348    1
# 349    1
# 350    1
# 351    1
# 352    1
# 353    1
# 354    1
# 355    1
# 356    1
# 357    1
# 36     1
# 360    1
# 361    1
# 362    1
# 363    1
# 364    1
# 4      1
# 416    1
# 127    1
# 417    1
# 453    1
# 455    1
# 456    1
# 457    1
# 459    1
# 46     1
# 461    1
# 463    1
# 47     1
# 48     1
# 103    1
# 49     1
# 5      1
# 50     1
# 52     1
# 53     1
# 59     1
# 6      1
# 60     1
# 100    1
# 10     1
# 452    1
# 451    1
# 450    1
# 431    1
# 418    1
# 419    1
# 420    1
# 421    1
# 422    1
# 423    1
# 425    1
# 426    1
# 43     1
# 433    1
# 45     1
# 436    1
# 437    1
# 441    1
# 442    1
# 443    1
# 444    1
# 445    1
# 446    1
# 449    1
# 340    1
# 34     1
# 334    1
# 187    1
# 114    1
# 113    1
# 111    1
# 110    1
# 109    1
# 108    1
# 188    1
# 189    1
# 191    1
# 193    1
# 195    1
# 196    1
# 197    1
# 199    1
# 2      1
# 200    1
# 201    1
# 202    1
# 203    1
# 204    1
# 205    1
# 120    1
# 124    1
# 33     1
# 125    1
# 130    1
# 131    1
# 133    1
# 134    1
# 135    1
# 136    1
# 137    1
# 138    1
# 141    1
# 144    1
# 145    1
# 149    1
# 150    1
# 156    1
# 160    1
# 175    1
# 176    1
# 182    1
# 185    1
# 186    1
# 126    1
# 206    1
# 207    1
# 208    1
# 209    1
# 282    1
# 284    1
# 286    1
# 290    1
# 291    1
# 292    1
# 293    1
# 294    1
# 295    1
# 296    1
# 61     1
# 298    1
# 299    1
# 3      1
# 300    1
# 301    1
# 306    1
# 307    1
# 309    1
# 32     1
# 327    1
# 280    1
# 279    1
# 268    1
# 240    1
# 214    1
# 220    1
# 221    1
# 222    1
# 223    1
# 224    1
# 231    1
# 235    1
# 238    1
# 246    1
# 266    1
# 247    1
# 249    1
# 251    1
# 252    1
# 253    1
# 258    1
# 26     1
# 260    1
# 265    1
# 297    1
# 71     1
# 62     1
# 35     1
# 372    1
# 373    1
# 374    1
# 375    1
# 376    1
# 38     1
# 39     1
# 393    1
# 394    1
# 397    1
# 398    1
# 407    1
# 409    1
# 42     1
# 424    1
# 427    1
# 428    1
# 429    1
# 430    1
# 432    1
# 434    1
# 358    1
# 345    1
# 44     1
# 339    1
# 288    1
# 289    1
# 30     1
# 303    1
# 304    1
# 305    1
# 308    1
# 31     1
# 310    1
# 312    1
# 313    1
# 316    1
# 319    1
# 320    1
# 321    1
# 323    1
# 325    1
# 326    1
# 329    1
# 336    1
# 337    1
# 438    1
# 440    1
# 621    1
# 311    1
# 359    1
# 404    1
# 414    1
# 439    1
# 448    1
# 464    1
# 51     1
# 612    1
# 151    1
# 167    1
# 198    1
# 278    1
# 318    1
# 324    1
# 328    1
# 333    1
# 403    1
# 405    1
# 413    1
# 8      1
# 164    1
# 314    1
# 270    1
# 447    1
# 261    1
# 458    1
# 460    1
# 471    1
# 475    1
# 476    1
# 477    1
# 54     1
# 55     1
# 56     1
# 57     1
# 58     1
# 627    1
# 72     1
# 76     1
# 83     1
# 9      1
# 107    1
# 152    1
# 165    1
# 225    1
# 236    1
# 287    1
# 283    1
# 28     1
# 91     1
# 94     1
# 95     1
# 96     1
# 97     1
# 98     1
# 99     1
# 101    1
# 118    1
# 119    1
# 122    1
# 123    1
# 129    1
# 13     1
# 14     1
# 143    1
# 146    1
# 147    1
# 153    1
# 154    1
# 155    1
# 157    1
# 93     1
# 90     1
# 277    1
# 89     1
# 626    1
# 64     1
# 65     1
# 66     1
# 67     1
# 68     1
# 69     1
# 70     1
# 74     1
# 75     1
# 77     1
# 78     1
# 79     1
# 80     1
# 81     1
# 82     1
# 84     1
# 85     1
# 86     1
# 87     1
# 88     1
# 158    1
# 159    1
# 16     1
# 162    1
# 237    1
# 241    1
# 242    1
# 243    1
# 244    1
# 245    1
# 248    1
# 250    1
# 254    1
# 255    1
# 256    1
# 257    1
# 259    1
# 262    1
# 263    1
# 264    1
# 269    1
# 271    1
# 272    1
# 273    1
# 276    1
# 234    1
# 232    1
# 228    1
# 190    1
# 168    1
# 169    1
# 17     1
# 173    1
# 177    1
# 179    1
# 180    1
# 181    1
# 183    1
# 192    1
# 22     1
# 194    1
# 210    1
# 211    1
# 212    1
# 213    1
# 215    1
# 216    1
# 217    1
# 218    1
# 1      1
# Name: COMPLEX_ID, dtype: int64

# %%
complex_locations[complex_locations['COMPLEX_ID'] == '611']
# Out:
#     REMOTE  BOOTH COMPLEX_ID          STATION    LINE_NAME DIVISION  \
# 14    R010  N062A        611  42 ST-PA BUS TE  ACENQRS1237      IND
# 15    R010   N060        611  42 ST-PA BUS TE  ACENQRS1237      IND
# 16    R011  N063A        611  42 ST-PA BUS TE  ACENQRS1237      IND
# 17    R011   N062        611  42 ST-PA BUS TE  ACENQRS1237      IND
# 18    R011   N063        611  42 ST-PA BUS TE  ACENQRS1237      IND
# 81    R032   R145        611   42 ST-TIMES SQ  1237ACENQRS      IRT
# 82    R032   R145        611   42 ST-TIMES SQ  1237ACENQRS      IRT
# 83    R032   R145        611   42 ST-TIMES SQ  1237ACENQRS      IRT
# 84    R032   R143        611   42 ST-TIMES SQ  ACENQRS1237      IRT
# 85    R032   R143        611   42 ST-TIMES SQ  ACENQRS1237      IRT
# 86    R032   R143        611   42 ST-TIMES SQ  ACENQRS1237      IRT
# 87    R032   R146        611   42 ST-TIMES SQ  1237ACENQRS      IRT
# 88    R032   R146        611   42 ST-TIMES SQ  1237ACENQRS      IRT
# 89    R032   R146        611   42 ST-TIMES SQ  1237ACENQRS      IRT
# 90    R033   R151        611   42 ST-TIMES SQ  1237ACENQRS      IRT
# 91    R033   R151        611   42 ST-TIMES SQ  1237ACENQRS      IRT
# 92    R033   R151        611   42 ST-TIMES SQ  1237ACENQRS      IRT
# 93    R033   R148        611   42 ST-TIMES SQ  1237ACENQRS      IRT
# 94    R033   R148        611   42 ST-TIMES SQ  1237ACENQRS      IRT
# 95    R033   R148        611   42 ST-TIMES SQ  1237ACENQRS      IRT
# 96    R033   R150        611   42 ST-TIMES SQ  1237ACENQRS      IRT
# 97    R033   R150        611   42 ST-TIMES SQ  1237ACENQRS      IRT
# 98    R033   R150        611   42 ST-TIMES SQ  1237ACENQRS      IRT
# 99    R033   R153        611   42 ST-TIMES SQ  1237ACENQRS      IRT
# 100   R033   R153        611   42 ST-TIMES SQ  1237ACENQRS      IRT
# 101   R033   R153        611   42 ST-TIMES SQ  1237ACENQRS      IRT
# 102   R033   R147        611   42 ST-TIMES SQ  1237ACENQRS      IRT
# 103   R033   R147        611   42 ST-TIMES SQ  1237ACENQRS      IRT
# 104   R033   R147        611   42 ST-TIMES SQ  1237ACENQRS      IRT
# 105   R032   A021        611   42 ST-TIMES SQ  1237ACENQRS      BMT
#
#                     LINE                            STOP_NAME BOROUGH  \
# 14    8th Av - Fulton St  42 St - Port Authority Bus Terminal       M
# 15    8th Av - Fulton St  42 St - Port Authority Bus Terminal       M
# 16    8th Av - Fulton St  42 St - Port Authority Bus Terminal       M
# 17    8th Av - Fulton St  42 St - Port Authority Bus Terminal       M
# 18    8th Av - Fulton St  42 St - Port Authority Bus Terminal       M
# 81        Broadway - 7Av                     Times Sq - 42 St       M
# 82              Flushing                     Times Sq - 42 St       M
# 83   Lexington - Shuttle                     Times Sq - 42 St       M
# 84        Broadway - 7Av                     Times Sq - 42 St       M
# 85              Flushing                     Times Sq - 42 St       M
# 86   Lexington - Shuttle                     Times Sq - 42 St       M
# 87        Broadway - 7Av                     Times Sq - 42 St       M
# 88              Flushing                     Times Sq - 42 St       M
# 89   Lexington - Shuttle                     Times Sq - 42 St       M
# 90        Broadway - 7Av                     Times Sq - 42 St       M
# 91              Flushing                     Times Sq - 42 St       M
# 92   Lexington - Shuttle                     Times Sq - 42 St       M
# 93        Broadway - 7Av                     Times Sq - 42 St       M
# 94              Flushing                     Times Sq - 42 St       M
# 95   Lexington - Shuttle                     Times Sq - 42 St       M
# 96        Broadway - 7Av                     Times Sq - 42 St       M
# 97              Flushing                     Times Sq - 42 St       M
# 98   Lexington - Shuttle                     Times Sq - 42 St       M
# 99        Broadway - 7Av                     Times Sq - 42 St       M
# 100             Flushing                     Times Sq - 42 St       M
# 101  Lexington - Shuttle                     Times Sq - 42 St       M
# 102       Broadway - 7Av                     Times Sq - 42 St       M
# 103             Flushing                     Times Sq - 42 St       M
# 104  Lexington - Shuttle                     Times Sq - 42 St       M
# 105  Broadway - Brighton                     Times Sq - 42 St       M
#
#      GTFS_LATITUDE  GTFS_LONGITUDE
# 14       40.757308      -73.989735
# 15       40.757308      -73.989735
# 16       40.757308      -73.989735
# 17       40.757308      -73.989735
# 18       40.757308      -73.989735
# 81       40.755290      -73.987495
# 82       40.755477      -73.987691
# 83       40.755983      -73.986229
# 84       40.755290      -73.987495
# 85       40.755477      -73.987691
# 86       40.755983      -73.986229
# 87       40.755290      -73.987495
# 88       40.755477      -73.987691
# 89       40.755983      -73.986229
# 90       40.755290      -73.987495
# 91       40.755477      -73.987691
# 92       40.755983      -73.986229
# 93       40.755290      -73.987495
# 94       40.755477      -73.987691
# 95       40.755983      -73.986229
# 96       40.755290      -73.987495
# 97       40.755477      -73.987691
# 98       40.755983      -73.986229
# 99       40.755290      -73.987495
# 100      40.755477      -73.987691
# 101      40.755983      -73.986229
# 102      40.755290      -73.987495
# 103      40.755477      -73.987691
# 104      40.755983      -73.986229
# 105      40.754672      -73.986754

# %%
# Drop unnecessary column
daily_per_turnstile_2019.drop(columns=['DATETIME'], inplace=True)

# Get consistent column names between the two dataframes to be merged

daily_per_turnstile_2019.columns = ['ID', 'DATE', 'BOOTH', 'REMOTE', 'SCP', 'STATION', 
                                    'LINE_NAME', 'DIVISION', 'DESC', 'NET_DAILY_ENTRIES', 'WEEKDAY']
daily_per_turnstile_2019.head()
# Out:
#                        ID        DATE BOOTH REMOTE       SCP STATION  \
# 0  A002 - R051 - 02-00-00  2019-05-01  A002   R051  02-00-00   59 ST
# 1  A002 - R051 - 02-00-00  2019-05-02  A002   R051  02-00-00   59 ST
# 2  A002 - R051 - 02-00-00  2019-05-03  A002   R051  02-00-00   59 ST
# 3  A002 - R051 - 02-00-00  2019-05-04  A002   R051  02-00-00   59 ST
# 4  A002 - R051 - 02-00-00  2019-05-05  A002   R051  02-00-00   59 ST
#
#   LINE_NAME DIVISION     DESC  NET_DAILY_ENTRIES  WEEKDAY
# 0   NQR456W      BMT  REGULAR               1346        1
# 1   NQR456W      BMT  REGULAR               1327        1
# 2   NQR456W      BMT  REGULAR               1326        1
# 3   NQR456W      BMT  REGULAR                560        0
# 4   NQR456W      BMT  REGULAR                449        0

# %%
daily_per_turnstile_2019[(daily_per_turnstile_2019['REMOTE'] == 'R032') & 
                         (daily_per_turnstile_2019['BOOTH'] == 'R145')].head()
# Out:
#                             ID        DATE BOOTH REMOTE       SCP  \
# 198821  R145 - R032 - 00-00-00  2019-05-01  R145   R032  00-00-00
# 198822  R145 - R032 - 00-00-00  2019-05-02  R145   R032  00-00-00
# 198823  R145 - R032 - 00-00-00  2019-05-03  R145   R032  00-00-00
# 198824  R145 - R032 - 00-00-00  2019-05-04  R145   R032  00-00-00
# 198825  R145 - R032 - 00-00-00  2019-05-05  R145   R032  00-00-00
#
#                STATION     LINE_NAME DIVISION     DESC  NET_DAILY_ENTRIES  \
# 198821  TIMES SQ-42 ST  1237ACENQRSW      IRT  REGULAR                854
# 198822  TIMES SQ-42 ST  1237ACENQRSW      IRT  REGULAR                884
# 198823  TIMES SQ-42 ST  1237ACENQRSW      IRT  REGULAR                780
# 198824  TIMES SQ-42 ST  1237ACENQRSW      IRT  REGULAR                495
# 198825  TIMES SQ-42 ST  1237ACENQRSW      IRT  REGULAR                386
#
#         WEEKDAY
# 198821        1
# 198822        1
# 198823        1
# 198824        0
# 198825        0

# %%
daily_per_turnstile_loc_2019 = complex_locations.merge(right=daily_per_turnstile_2019, 
                                                       how='inner',
                                                       on=['BOOTH', 'REMOTE', 'DIVISION'])

# %%
# Didn't even lose 5000 rows here - pretty good!

print(daily_per_turnstile_2019.shape)
daily_per_turnstile_loc_2019.shape
# Out:
# (295338, 11)
# (290643, 19)

# %%
# Check for NaNs

daily_per_turnstile_loc_2019[daily_per_turnstile_loc_2019.isna().any(axis=1)].shape[0]
# Out:
# 0

# %%
# STATION_x and STATION_y seem to match up well! (LINE_NAME_x and LINE_NAME_y, too!)

daily_per_turnstile_loc_2019.sample(n=20)
# Out:
#        REMOTE BOOTH COMPLEX_ID           STATION_x  LINE_NAME_x DIVISION  \
# 80893    R068  R633        351      VAN SICLEN AVE            3      IRT
# 121383   R120  R415        368        MORRISON AVE            6      IRT
# 211895   R259  N602        222        ROOSEVELT IS            F      IND
# 160283   R170  A033        602      14 ST-UNION SQ      456LNQR      BMT
# 123646   R126  N010        147              175 ST            A      IND
# 58007    R046  R238        610     42 ST-GRD CNTRL        4567S      IRT
# 215713   R268  N409        629     METROPOLITAN AV           GL      IND
# 36165    R030  R116        327         CHAMBERS ST          123      IRT
# 58847    R046  R238        610     42 ST-GRD CNTRL        4567S      IRT
# 147537   R153  N120        181           UTICA AVE           AC      IND
# 78300    R062  R626        345     CROWN HTS-UTICA           34      IRT
# 94892    R462  A043        623            CANAL ST       JNQRZ6      BMT
# 285392   R460  J002        101           MARCY AVE          JMZ      BMT
# 278390   R431  R730        442            DYRE AVE            5      IRT
# 270885   R408  R317        430          SIMPSON ST           25      IRT
# 276220   R425  N559        251               AVE U            F      IND
# 87660    R084  R158        614      59 ST-COLUMBUS        1ABCD      IRT
# 40537    R033  R151        611      42 ST-TIMES SQ  1237ACENQRS      IRT
# 289868   R572  N702        475  96 ST - SECOND AVE            Q      IND
# 31270    R029  N094        624     WORLD TRADE CTR        23ACE      IND
#
#                            LINE                STOP_NAME BOROUGH  \
# 80893               Eastern Pky            Van Siclen Av      Bk
# 121383                   Pelham  Morrison Av- Sound View      Bx
# 211895                  63rd St         Roosevelt Island       M
# 160283                 Canarsie         Union Sq - 14 St       M
# 123646       8th Av - Fulton St                   175 St       M
# 58007                  Flushing    Grand Central - 42 St       M
# 215713                Crosstown          Metropolitan Av      Bk
# 36165            Broadway - 7Av              Chambers St       M
# 58847       Lexington - Shuttle    Grand Central - 42 St       M
# 147537       8th Av - Fulton St                 Utica Av      Bk
# 78300               Eastern Pky     Crown Hts - Utica Av      Bk
# 94892                   Jamaica                 Canal St       M
# 285392                  Jamaica                 Marcy Av      Bk
# 278390                  Dyre Av    Eastchester - Dyre Av      Bx
# 270885  Lenox - White Plains Rd               Simpson St      Bx
# 276220          6th Av - Culver                 Avenue U      Bk
# 87660            Broadway - 7Av  59 St - Columbus Circle       M
# 40537            Broadway - 7Av         Times Sq - 42 St       M
# 289868                Second Av                    96 St       M
# 31270        8th Av - Fulton St       World Trade Center       M
#
#         GTFS_LATITUDE  GTFS_LONGITUDE                      ID        DATE  \
# 80893       40.665449      -73.889395  R633 - R068 - 00-00-02  2019-06-19
# 121383      40.829521      -73.874516  R415 - R120 - 00-00-01  2019-06-15
# 211895      40.759145      -73.953260  N602 - R259 - 00-05-01  2019-06-24
# 160283      40.734789      -73.990730  A033 - R170 - 02-00-03  2019-05-24
# 123646      40.847391      -73.939704  N010 - R126 - 00-00-02  2019-06-21
# 58007       40.751431      -73.976041  R238 - R046 - 00-00-07  2019-05-28
# 215713      40.712792      -73.951418  N409 - R268 - 00-00-05  2019-06-03
# 36165       40.715478      -74.009266  R116 - R030 - 00-06-01  2019-06-09
# 58847       40.752769      -73.979189  R238 - R046 - 00-00-03  2019-05-14
# 147537      40.679364      -73.930729  N120 - R153 - 00-00-01  2019-05-12
# 78300       40.668897      -73.932942  R626 - R062 - 00-00-03  2019-05-19
# 94892       40.718092      -73.999892  A043 - R462 - 00-00-01  2019-05-21
# 285392      40.708359      -73.957757  J002 - R460 - 00-03-01  2019-06-12
# 278390      40.888300      -73.830834  R730 - R431 - 00-00-03  2019-06-06
# 270885      40.824073      -73.893064  R317 - R408 - 01-00-01  2019-06-03
# 276220      40.596063      -73.973357  N559 - R425 - 00-00-00  2019-05-02
# 87660       40.768247      -73.981929  R158 - R084 - 00-02-00  2019-06-15
# 40537       40.755290      -73.987495  R151 - R033 - 00-00-00  2019-06-11
# 289868      40.784318      -73.947152  N702 - R572 - 00-00-03  2019-05-19
# 31270       40.712582      -74.009781  N094 - R029 - 01-00-01  2019-05-05
#
#              SCP        STATION_y   LINE_NAME_y     DESC  NET_DAILY_ENTRIES  \
# 80893   00-00-02    VAN SICLEN AV             3  REGULAR                607
# 121383  00-00-01  MORISN AV/SNDVW             6  REGULAR                918
# 211895  00-05-01  ROOSEVELT ISLND             F  REGULAR                  0
# 160283  02-00-03   14 ST-UNION SQ      LNQR456W  REGULAR               2977
# 123646  00-00-02           175 ST             A  REGULAR               2233
# 58007   00-00-07  GRD CNTRL-42 ST         4567S  REGULAR                275
# 215713  00-00-05  METROPOLITAN AV            GL  REGULAR                664
# 36165   00-06-01      CHAMBERS ST           123  REGULAR                354
# 58847   00-00-03  GRD CNTRL-42 ST         4567S  REGULAR                225
# 147537  00-00-01         UTICA AV            AC  REGULAR                786
# 78300   00-00-03  CROWN HTS-UTICA            34  REGULAR                795
# 94892   00-00-01         CANAL ST       JNQRZ6W  REGULAR               1826
# 285392  00-03-01         MARCY AV           JMZ  REGULAR                760
# 278390  00-00-03  EASTCHSTER/DYRE             5  REGULAR               1211
# 270885  01-00-01       SIMPSON ST            25  REGULAR                794
# 276220  00-00-00         AVENUE U             F  REGULAR                544
# 87660   00-02-00   59 ST COLUMBUS         1ABCD  REGULAR                377
# 40537   00-00-00   TIMES SQ-42 ST  1237ACENQRSW  REGULAR                 82
# 289868  00-00-03      96 ST-2 AVE             Q  REGULAR               1370
# 31270   01-00-01  WORLD TRADE CTR         ACE23  REGULAR                339
#
#         WEEKDAY
# 80893         1
# 121383        0
# 211895        1
# 160283        1
# 123646        1
# 58007         1
# 215713        1
# 36165         0
# 58847         1
# 147537        0
# 78300         0
# 94892         1
# 285392        1
# 278390        1
# 270885        1
# 276220        1
# 87660         0
# 40537         1
# 289868        0
# 31270         0

# %% [markdown]
# #### Reorder the columns for more readability (might be useful not to drop any for future troubleshooting)

# %%
daily_per_turnstile_loc_2019 = daily_per_turnstile_loc_2019[['STATION_x', 'STATION_y', 'STOP_NAME', 
                                                             'LINE_NAME_x', 'LINE_NAME_y', 'DIVISION', 
                                                             'BOROUGH', 'DATE', 'NET_DAILY_ENTRIES', 'WEEKDAY', 
                                                             'DESC', 'GTFS_LATITUDE', 'GTFS_LONGITUDE', 'LINE', 
                                                             'REMOTE', 'BOOTH', 'SCP', 'COMPLEX_ID', 'ID']]
print(daily_per_turnstile_loc_2019.shape)
daily_per_turnstile_loc_2019.head()
# Out:
# (290643, 19)
#       STATION_x        STATION_y     STOP_NAME LINE_NAME_x LINE_NAME_y  \
# 0  WHITEHALL ST  WHITEHALL S-FRY  Whitehall St          R1         R1W
# 1  WHITEHALL ST  WHITEHALL S-FRY  Whitehall St          R1         R1W
# 2  WHITEHALL ST  WHITEHALL S-FRY  Whitehall St          R1         R1W
# 3  WHITEHALL ST  WHITEHALL S-FRY  Whitehall St          R1         R1W
# 4  WHITEHALL ST  WHITEHALL S-FRY  Whitehall St          R1         R1W
#
#   DIVISION BOROUGH        DATE  NET_DAILY_ENTRIES  WEEKDAY     DESC  \
# 0      BMT       M  2019-05-01               2604        1  REGULAR
# 1      BMT       M  2019-05-02               2676        1  REGULAR
# 2      BMT       M  2019-05-03               2768        1  REGULAR
# 3      BMT       M  2019-05-04               1717        0  REGULAR
# 4      BMT       M  2019-05-05               1184        0  REGULAR
#
#    GTFS_LATITUDE  GTFS_LONGITUDE      LINE REMOTE BOOTH       SCP COMPLEX_ID  \
# 0      40.703087      -74.012994  Broadway   R001  A060  00-00-00        635
# 1      40.703087      -74.012994  Broadway   R001  A060  00-00-00        635
# 2      40.703087      -74.012994  Broadway   R001  A060  00-00-00        635
# 3      40.703087      -74.012994  Broadway   R001  A060  00-00-00        635
# 4      40.703087      -74.012994  Broadway   R001  A060  00-00-00        635
#
#                        ID
# 0  A060 - R001 - 00-00-00
# 1  A060 - R001 - 00-00-00
# 2  A060 - R001 - 00-00-00
# 3  A060 - R001 - 00-00-00
# 4  A060 - R001 - 00-00-00

# %% [markdown]
# ##### Repeat all of the above steps for the 2021 data

# %%
# Drop unnecessary column
daily_per_turnstile_2021.drop(columns=['DATETIME'], inplace=True)

# Get consistent column names between the two dataframes to be merged

daily_per_turnstile_2021.columns = ['ID', 'DATE', 'BOOTH', 'REMOTE', 'SCP', 'STATION', 
                                    'LINE_NAME', 'DIVISION', 'DESC', 'NET_DAILY_ENTRIES', 'WEEKDAY']
daily_per_turnstile_2021.head()
# Out:
#                        ID        DATE BOOTH REMOTE       SCP STATION  \
# 1  A002 - R051 - 02-00-00  2021-05-01  A002   R051  02-00-00   59 ST
# 2  A002 - R051 - 02-00-00  2021-05-02  A002   R051  02-00-00   59 ST
# 3  A002 - R051 - 02-00-00  2021-05-03  A002   R051  02-00-00   59 ST
# 4  A002 - R051 - 02-00-00  2021-05-04  A002   R051  02-00-00   59 ST
# 5  A002 - R051 - 02-00-00  2021-05-05  A002   R051  02-00-00   59 ST
#
#   LINE_NAME DIVISION     DESC  NET_DAILY_ENTRIES  WEEKDAY
# 1   NQR456W      BMT  REGULAR                361        0
# 2   NQR456W      BMT  REGULAR                250        0
# 3   NQR456W      BMT  REGULAR                472        1
# 4   NQR456W      BMT  REGULAR                501        1
# 5   NQR456W      BMT  REGULAR                522        1

# %%
daily_per_turnstile_loc_2021 = complex_locations.merge(right=daily_per_turnstile_2021, 
                                                       how='inner',
                                                       on=['BOOTH', 'REMOTE', 'DIVISION'])

# %%
# Again, only lost ~5000 rows here - pretty good!

print(daily_per_turnstile_2021.shape)
daily_per_turnstile_loc_2021.shape
# Out:
# (303670, 11)
# (298140, 19)

# %%
# Check for NaNs

daily_per_turnstile_loc_2021[daily_per_turnstile_loc_2021.isna().any(axis=1)].shape[0]
# Out:
# 0

# %%
# Again, STATION_x and STATION_y seem to match up well! (LINE_NAME_x and LINE_NAME_y, too!)

daily_per_turnstile_loc_2021.sample(n=20)
# Out:
#        REMOTE  BOOTH COMPLEX_ID        STATION_x  LINE_NAME_x DIVISION  \
# 250385   R336   N192        205      BEACH 60 ST            A      IND
# 92760    R085   A039         16   8 ST-B'WAY NYU           NR      BMT
# 12244    R014   R208        628        FULTON ST     2345ACJZ      IRT
# 219781   R267  N316A        270            46 ST           MR      IND
# 232834   R297   N114        627     FRANKLIN AVE          ACS      IND
# 41216    R033   R151        611   42 ST-TIMES SQ  1237ACENQRS      IRT
# 171843   R177   R246        399  68ST-HUNTER COL            6      IRT
# 260590   R359  N400A        606         COURT SQ          EMG      IND
# 39174    R032   R145        611   42 ST-TIMES SQ  1237ACENQRS      IRT
# 52068    R044  R210A        622  BROOKLYN BRIDGE        JZ456      IRT
# 159023   R164   R159        314    66 ST-LINCOLN            1      IRT
# 181417   R195   N203        604    161 ST-YANKEE          BD4      IND
# 210997   R249   H013        122       GRAHAM AVE            L      BMT
# 26425    R024   N605        279     SUTPHIN BLVD          EJZ      IND
# 237504   R305   R108        328     CORTLANDT ST            1      IRT
# 46950    R038   R190        297           215 ST            1      IRT
# 115576   R108   R604        620  BOROUGH HALL/CT        2345R      IRT
# 128771   R128  N338B        257     SUTPHIN BLVD            F      IND
# 79927    R062   R626        345  CROWN HTS-UTICA           34      IRT
# 228705   R286   N416        288  MYRTLE-WILLOUGH            G      IND
#
#                        LINE                               STOP_NAME BOROUGH  \
# 250385             Rockaway                             Beach 60 St       Q
# 92760   Broadway - Brighton                              8 St - NYU       M
# 12244          Lexington Av                               Fulton St       M
# 219781          Queens Blvd                                   46 St       Q
# 232834   8th Av - Fulton St                             Franklin Av      Bk
# 41216        Broadway - 7Av                        Times Sq - 42 St       M
# 171843         Lexington Av                  68 St - Hunter College       M
# 260590            Crosstown                                Court Sq       Q
# 39174   Lexington - Shuttle                        Times Sq - 42 St       M
# 52068          Lexington Av             Brooklyn Bridge - City Hall       M
# 159023       Broadway - 7Av                  66 St - Lincoln Center       M
# 181417            Concourse                 161 St - Yankee Stadium      Bx
# 210997             Canarsie                               Graham Av      Bk
# 26425       Queens - Archer  Sutphin Blvd - Archer Av - JFK Airport       Q
# 237504       Broadway - 7Av                           WTC Cortlandt       M
# 46950        Broadway - 7Av                                  215 St       M
# 115576             Clark St                            Borough Hall      Bk
# 128771          Queens Blvd                            Sutphin Blvd       Q
# 79927           Eastern Pky                    Crown Hts - Utica Av      Bk
# 228705            Crosstown                 Myrtle - Willoughby Avs      Bk
#
#         GTFS_LATITUDE  GTFS_LONGITUDE                       ID        DATE  \
# 250385      40.592374      -73.788522   N192 - R336 - 00-00-01  2021-06-19
# 92760       40.730328      -73.992629   A039 - R085 - 01-00-00  2021-05-04
# 12244       40.710368      -74.009509   R208 - R014 - 03-03-00  2021-05-03
# 219781      40.756312      -73.913333  N316A - R267 - 01-00-02  2021-06-16
# 232834      40.681380      -73.956848   N114 - R297 - 01-05-00  2021-05-03
# 41216       40.755290      -73.987495   R151 - R033 - 00-00-08  2021-06-20
# 171843      40.768141      -73.963870   R246 - R177 - 00-03-01  2021-05-30
# 260590      40.746554      -73.943832  N400A - R359 - 02-00-01  2021-06-05
# 39174       40.755983      -73.986229   R145 - R032 - 00-06-02  2021-05-22
# 52068       40.713065      -74.004131  R210A - R044 - 03-03-00  2021-05-19
# 159023      40.773440      -73.982209   R159 - R164 - 01-06-00  2021-05-20
# 181417      40.827905      -73.925651   N203 - R195 - 00-00-02  2021-05-29
# 210997      40.714565      -73.944053   H013 - R249 - 01-00-02  2021-05-01
# 26425       40.700486      -73.807969   N605 - R024 - 00-00-06  2021-06-01
# 237504      40.711835      -74.012188   R108 - R305 - 02-00-03  2021-06-05
# 46950       40.869444      -73.915279   R190 - R038 - 00-06-00  2021-06-24
# 115576      40.693219      -73.989998   R604 - R108 - 03-00-03  2021-05-16
# 128771      40.705460      -73.810708  N338B - R128 - 00-00-03  2021-06-05
# 79927       40.668897      -73.932942   R626 - R062 - 00-00-03  2021-06-08
# 228705      40.694568      -73.949046   N416 - R286 - 01-06-00  2021-05-17
#
#              SCP        STATION_y   LINE_NAME_y     DESC  NET_DAILY_ENTRIES  \
# 250385  00-00-01      BEACH 60 ST             A  REGULAR                166
# 92760   01-00-00         8 ST-NYU           NRW  REGULAR                144
# 12244   03-03-00        FULTON ST      2345ACJZ  REGULAR                  9
# 219781  01-00-02            46 ST            MR  REGULAR                 77
# 232834  01-05-00      FRANKLIN AV           ACS  REGULAR                  1
# 41216   00-00-08   TIMES SQ-42 ST  1237ACENQRSW  REGULAR                476
# 171843  00-03-01   68ST-HUNTER CO             6  REGULAR                 37
# 260590  02-00-01         COURT SQ           EMG  REGULAR                 34
# 39174   00-06-02   TIMES SQ-42 ST  1237ACENQRSW  REGULAR                133
# 52068   03-03-00  BROOKLYN BRIDGE         456JZ  REGULAR                239
# 159023  01-06-00    66 ST-LINCOLN             1  REGULAR                 15
# 181417  00-00-02  161/YANKEE STAD           BD4  REGULAR                519
# 210997  01-00-02        GRAHAM AV             L  REGULAR                587
# 26425   00-00-06   SUTPHIN-ARCHER           EJZ  REGULAR                512
# 237504  02-00-03    WTC-CORTLANDT             1  REGULAR                107
# 46950   00-06-00           215 ST             1  REGULAR                100
# 115576  03-00-03     BOROUGH HALL         2345R  REGULAR                 47
# 128771  00-00-03     SUTPHIN BLVD             F  REGULAR                 90
# 79927   00-00-03  CROWN HTS-UTICA            34  REGULAR                662
# 228705  01-06-00  MYRTLE-WILLOUGH             G  REGULAR                302
#
#         WEEKDAY
# 250385        0
# 92760         1
# 12244         1
# 219781        1
# 232834        1
# 41216         0
# 171843        0
# 260590        0
# 39174         0
# 52068         1
# 159023        1
# 181417        0
# 210997        0
# 26425         1
# 237504        0
# 46950         1
# 115576        0
# 128771        0
# 79927         1
# 228705        1

# %% [markdown]
# #### Reorder the columns for more readability (might be useful not to drop any for future troubleshooting)

# %%
daily_per_turnstile_loc_2021 = daily_per_turnstile_loc_2021[['STATION_x', 'STATION_y', 'STOP_NAME', 
                                                             'LINE_NAME_x', 'LINE_NAME_y', 'DIVISION', 
                                                             'BOROUGH', 'DATE', 'NET_DAILY_ENTRIES', 'WEEKDAY', 
                                                             'DESC', 'GTFS_LATITUDE', 'GTFS_LONGITUDE', 'LINE', 
                                                             'REMOTE', 'BOOTH', 'SCP', 'COMPLEX_ID', 'ID']]
print(daily_per_turnstile_loc_2021.shape)
daily_per_turnstile_loc_2021.head()
# Out:
# (298140, 19)
#       STATION_x        STATION_y     STOP_NAME LINE_NAME_x LINE_NAME_y  \
# 0  WHITEHALL ST  WHITEHALL S-FRY  Whitehall St          R1         R1W
# 1  WHITEHALL ST  WHITEHALL S-FRY  Whitehall St          R1         R1W
# 2  WHITEHALL ST  WHITEHALL S-FRY  Whitehall St          R1         R1W
# 3  WHITEHALL ST  WHITEHALL S-FRY  Whitehall St          R1         R1W
# 4  WHITEHALL ST  WHITEHALL S-FRY  Whitehall St          R1         R1W
#
#   DIVISION BOROUGH        DATE  NET_DAILY_ENTRIES  WEEKDAY     DESC  \
# 0      BMT       M  2021-05-01                692        0  REGULAR
# 1      BMT       M  2021-05-02                578        0  REGULAR
# 2      BMT       M  2021-05-03                895        1  REGULAR
# 3      BMT       M  2021-05-04                947        1  REGULAR
# 4      BMT       M  2021-05-05                905        1  REGULAR
#
#    GTFS_LATITUDE  GTFS_LONGITUDE      LINE REMOTE BOOTH       SCP COMPLEX_ID  \
# 0      40.703087      -74.012994  Broadway   R001  A060  00-00-00        635
# 1      40.703087      -74.012994  Broadway   R001  A060  00-00-00        635
# 2      40.703087      -74.012994  Broadway   R001  A060  00-00-00        635
# 3      40.703087      -74.012994  Broadway   R001  A060  00-00-00        635
# 4      40.703087      -74.012994  Broadway   R001  A060  00-00-00        635
#
#                        ID
# 0  A060 - R001 - 00-00-00
# 1  A060 - R001 - 00-00-00
# 2  A060 - R001 - 00-00-00
# 3  A060 - R001 - 00-00-00
# 4  A060 - R001 - 00-00-00

# %% [markdown]
# ### 2f) Now generate NET_DAILY_STATION_ENTRIES (i.e. aggregate from per-turnstile to per-station basis)

# %% [markdown]
# #### (Recall from previous section that 'COMPLEX_ID' is the unifying element that identifies all turnstiles residing "under one roof")

# %%
daily_per_complex_2019 = daily_per_turnstile_loc_2019.groupby(['COMPLEX_ID', 'DATE'])['NET_DAILY_ENTRIES'] \
                                                     .sum().reset_index()

daily_per_complex_2019.columns = ['COMPLEX_ID', 'DATE', 'NET_DAILY_STATION_ENTRIES']
print(daily_per_complex_2019.shape)
display(daily_per_complex_2019.head())
display(daily_per_complex_2019.tail())
# Out:
# (25567, 3)
#   COMPLEX_ID        DATE  NET_DAILY_STATION_ENTRIES
# 0          1  2019-05-01                      18999
# 1          1  2019-05-02                      19257
# 2          1  2019-05-03                      18661
# 3          1  2019-05-04                       9577
# 4          1  2019-05-05                       6630
#       COMPLEX_ID        DATE  NET_DAILY_STATION_ENTRIES
# 25562         99  2019-06-26                       5117
# 25563         99  2019-06-27                       5155
# 25564         99  2019-06-28                       4908
# 25565         99  2019-06-29                       3587
# 25566         99  2019-06-30                       3284

# %% [markdown]
# #### Now merge in the other desired columns

# %%
daily_per_complex_2019 = daily_per_complex_2019.merge(right=daily_per_turnstile_loc_2019
                                                      .groupby(['COMPLEX_ID', 'DATE'])
                                                      .first().reset_index(),
                                                      how='inner',
                                                      on=['COMPLEX_ID', 'DATE']) \
                                                      .drop(columns='NET_DAILY_ENTRIES')

# %%
print(daily_per_complex_2019.shape)
display(daily_per_complex_2019.head(10))
display(daily_per_complex_2019.tail(10))
# Out:
# (25567, 19)
#   COMPLEX_ID        DATE  NET_DAILY_STATION_ENTRIES        STATION_x  \
# 0          1  2019-05-01                      18999  DITMARS BL-31 S
# 1          1  2019-05-02                      19257  DITMARS BL-31 S
# 2          1  2019-05-03                      18661  DITMARS BL-31 S
# 3          1  2019-05-04                       9577  DITMARS BL-31 S
# 4          1  2019-05-05                       6630  DITMARS BL-31 S
# 5          1  2019-05-06                      18272  DITMARS BL-31 S
# 6          1  2019-05-07                      19146  DITMARS BL-31 S
# 7          1  2019-05-08                      19359  DITMARS BL-31 S
# 8          1  2019-05-09                      19073  DITMARS BL-31 S
# 9          1  2019-05-10                      18527  DITMARS BL-31 S
#
#          STATION_y               STOP_NAME LINE_NAME_x LINE_NAME_y DIVISION  \
# 0  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW      BMT
# 1  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW      BMT
# 2  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW      BMT
# 3  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW      BMT
# 4  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW      BMT
# 5  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW      BMT
# 6  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW      BMT
# 7  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW      BMT
# 8  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW      BMT
# 9  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW      BMT
#
#   BOROUGH  WEEKDAY     DESC  GTFS_LATITUDE  GTFS_LONGITUDE     LINE REMOTE  \
# 0       Q        1  REGULAR      40.775036      -73.912034  Astoria   R095
# 1       Q        1  REGULAR      40.775036      -73.912034  Astoria   R095
# 2       Q        1  REGULAR      40.775036      -73.912034  Astoria   R095
# 3       Q        0  REGULAR      40.775036      -73.912034  Astoria   R095
# 4       Q        0  REGULAR      40.775036      -73.912034  Astoria   R095
# 5       Q        1  REGULAR      40.775036      -73.912034  Astoria   R095
# 6       Q        1  REGULAR      40.775036      -73.912034  Astoria   R095
# 7       Q        1  REGULAR      40.775036      -73.912034  Astoria   R095
# 8       Q        1  REGULAR      40.775036      -73.912034  Astoria   R095
# 9       Q        1  REGULAR      40.775036      -73.912034  Astoria   R095
#
#   BOOTH       SCP                      ID
# 0  R515  00-00-00  R515 - R095 - 00-00-00
# 1  R515  00-00-00  R515 - R095 - 00-00-00
# 2  R515  00-00-00  R515 - R095 - 00-00-00
# 3  R515  00-00-00  R515 - R095 - 00-00-00
# 4  R515  00-00-00  R515 - R095 - 00-00-00
# 5  R515  00-00-00  R515 - R095 - 00-00-00
# 6  R515  00-00-00  R515 - R095 - 00-00-00
# 7  R515  00-00-00  R515 - R095 - 00-00-00
# 8  R515  00-00-00  R515 - R095 - 00-00-00
# 9  R515  00-00-00  R515 - R095 - 00-00-00
#       COMPLEX_ID        DATE  NET_DAILY_STATION_ENTRIES   STATION_x  \
# 25557         99  2019-06-21                       5253  LORIMER ST
# 25558         99  2019-06-22                       4194  LORIMER ST
# 25559         99  2019-06-23                       3647  LORIMER ST
# 25560         99  2019-06-24                       5175  LORIMER ST
# 25561         99  2019-06-25                       5099  LORIMER ST
# 25562         99  2019-06-26                       5117  LORIMER ST
# 25563         99  2019-06-27                       5155  LORIMER ST
# 25564         99  2019-06-28                       4908  LORIMER ST
# 25565         99  2019-06-29                       3587  LORIMER ST
# 25566         99  2019-06-30                       3284  LORIMER ST
#
#         STATION_y   STOP_NAME LINE_NAME_x LINE_NAME_y DIVISION BOROUGH  \
# 25557  LORIMER ST  Lorimer St          JM          JM      BMT      Bk
# 25558  LORIMER ST  Lorimer St          JM          JM      BMT      Bk
# 25559  LORIMER ST  Lorimer St          JM          JM      BMT      Bk
# 25560  LORIMER ST  Lorimer St          JM          JM      BMT      Bk
# 25561  LORIMER ST  Lorimer St          JM          JM      BMT      Bk
# 25562  LORIMER ST  Lorimer St          JM          JM      BMT      Bk
# 25563  LORIMER ST  Lorimer St          JM          JM      BMT      Bk
# 25564  LORIMER ST  Lorimer St          JM          JM      BMT      Bk
# 25565  LORIMER ST  Lorimer St          JM          JM      BMT      Bk
# 25566  LORIMER ST  Lorimer St          JM          JM      BMT      Bk
#
#        WEEKDAY        DESC  GTFS_LATITUDE  GTFS_LONGITUDE     LINE REMOTE  \
# 25557        1     REGULAR      40.703869      -73.947408  Jamaica   R353
# 25558        0  RECOVR AUD      40.703869      -73.947408  Jamaica   R353
# 25559        0     REGULAR      40.703869      -73.947408  Jamaica   R353
# 25560        1     REGULAR      40.703869      -73.947408  Jamaica   R353
# 25561        1     REGULAR      40.703869      -73.947408  Jamaica   R353
# 25562        1     REGULAR      40.703869      -73.947408  Jamaica   R353
# 25563        1     REGULAR      40.703869      -73.947408  Jamaica   R353
# 25564        1     REGULAR      40.703869      -73.947408  Jamaica   R353
# 25565        0     REGULAR      40.703869      -73.947408  Jamaica   R353
# 25566        0     REGULAR      40.703869      -73.947408  Jamaica   R353
#
#       BOOTH       SCP                      ID
# 25557  J005  00-00-00  J005 - R353 - 00-00-00
# 25558  J005  00-00-00  J005 - R353 - 00-00-00
# 25559  J005  00-00-00  J005 - R353 - 00-00-00
# 25560  J005  00-00-00  J005 - R353 - 00-00-00
# 25561  J005  00-00-00  J005 - R353 - 00-00-00
# 25562  J005  00-00-00  J005 - R353 - 00-00-00
# 25563  J005  00-00-00  J005 - R353 - 00-00-00
# 25564  J005  00-00-00  J005 - R353 - 00-00-00
# 25565  J005  00-00-00  J005 - R353 - 00-00-00
# 25566  J005  00-00-00  J005 - R353 - 00-00-00

# %% [markdown]
# ##### Do the same for 2021 data

# %%
daily_per_complex_2021 = daily_per_turnstile_loc_2021.groupby(['COMPLEX_ID', 'DATE'])['NET_DAILY_ENTRIES'] \
                                                     .sum().reset_index()

daily_per_complex_2021.columns = ['COMPLEX_ID', 'DATE', 'NET_DAILY_STATION_ENTRIES']
print(daily_per_complex_2021.shape)
display(daily_per_complex_2021.head())
display(daily_per_complex_2021.tail())
# Out:
# (25615, 3)
#   COMPLEX_ID        DATE  NET_DAILY_STATION_ENTRIES
# 0          1  2021-05-01                       3485
# 1          1  2021-05-02                       2378
# 2          1  2021-05-03                       4990
# 3          1  2021-05-04                       5290
# 4          1  2021-05-05                       5196
#       COMPLEX_ID        DATE  NET_DAILY_STATION_ENTRIES
# 25610         99  2021-06-26                       1132
# 25611         99  2021-06-27                        981
# 25612         99  2021-06-28                       1663
# 25613         99  2021-06-29                       1542
# 25614         99  2021-06-30                       1669

# %% [markdown]
# #### Now merge in the other desired columns

# %%
daily_per_complex_2021 = daily_per_complex_2021.merge(right=daily_per_turnstile_loc_2021
                                                      .groupby(['COMPLEX_ID', 'DATE'])
                                                      .first().reset_index(),
                                                      how='inner',
                                                      on=['COMPLEX_ID', 'DATE']) \
                                                      .drop(columns='NET_DAILY_ENTRIES')

# %%
print(daily_per_complex_2021.shape)
display(daily_per_complex_2021.head(10))
display(daily_per_complex_2021.tail(10))
# Out:
# (25615, 19)
#   COMPLEX_ID        DATE  NET_DAILY_STATION_ENTRIES        STATION_x  \
# 0          1  2021-05-01                       3485  DITMARS BL-31 S
# 1          1  2021-05-02                       2378  DITMARS BL-31 S
# 2          1  2021-05-03                       4990  DITMARS BL-31 S
# 3          1  2021-05-04                       5290  DITMARS BL-31 S
# 4          1  2021-05-05                       5196  DITMARS BL-31 S
# 5          1  2021-05-06                       5470  DITMARS BL-31 S
# 6          1  2021-05-07                       5448  DITMARS BL-31 S
# 7          1  2021-05-08                       3192  DITMARS BL-31 S
# 8          1  2021-05-09                       2362  DITMARS BL-31 S
# 9          1  2021-05-10                       4986  DITMARS BL-31 S
#
#          STATION_y               STOP_NAME LINE_NAME_x LINE_NAME_y DIVISION  \
# 0  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW      BMT
# 1  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW      BMT
# 2  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW      BMT
# 3  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW      BMT
# 4  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW      BMT
# 5  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW      BMT
# 6  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW      BMT
# 7  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW      BMT
# 8  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW      BMT
# 9  ASTORIA DITMARS  Astoria - Ditmars Blvd          NQ         NQW      BMT
#
#   BOROUGH  WEEKDAY     DESC  GTFS_LATITUDE  GTFS_LONGITUDE     LINE REMOTE  \
# 0       Q        0  REGULAR      40.775036      -73.912034  Astoria   R095
# 1       Q        0  REGULAR      40.775036      -73.912034  Astoria   R095
# 2       Q        1  REGULAR      40.775036      -73.912034  Astoria   R095
# 3       Q        1  REGULAR      40.775036      -73.912034  Astoria   R095
# 4       Q        1  REGULAR      40.775036      -73.912034  Astoria   R095
# 5       Q        1  REGULAR      40.775036      -73.912034  Astoria   R095
# 6       Q        1  REGULAR      40.775036      -73.912034  Astoria   R095
# 7       Q        0  REGULAR      40.775036      -73.912034  Astoria   R095
# 8       Q        0  REGULAR      40.775036      -73.912034  Astoria   R095
# 9       Q        1  REGULAR      40.775036      -73.912034  Astoria   R095
#
#   BOOTH       SCP                      ID
# 0  R515  00-00-00  R515 - R095 - 00-00-00
# 1  R515  00-00-00  R515 - R095 - 00-00-00
# 2  R515  00-00-00  R515 - R095 - 00-00-00
# 3  R515  00-00-00  R515 - R095 - 00-00-00
# 4  R515  00-00-00  R515 - R095 - 00-00-00
# 5  R515  00-00-00  R515 - R095 - 00-00-00
# 6  R515  00-00-00  R515 - R095 - 00-00-00
# 7  R515  00-00-00  R515 - R095 - 00-00-00
# 8  R515  00-00-00  R515 - R095 - 00-00-00
# 9  R515  00-00-00  R515 - R095 - 00-00-00
#       COMPLEX_ID        DATE  NET_DAILY_STATION_ENTRIES   STATION_x  \
# 25605         99  2021-06-21                       1711  LORIMER ST
# 25606         99  2021-06-22                       1705  LORIMER ST
# 25607         99  2021-06-23                       1909  LORIMER ST
# 25608         99  2021-06-24                       1836  LORIMER ST
# 25609         99  2021-06-25                       1868  LORIMER ST
# 25610         99  2021-06-26                       1132  LORIMER ST
# 25611         99  2021-06-27                        981  LORIMER ST
# 25612         99  2021-06-28                       1663  LORIMER ST
# 25613         99  2021-06-29                       1542  LORIMER ST
# 25614         99  2021-06-30                       1669  LORIMER ST
#
#         STATION_y   STOP_NAME LINE_NAME_x LINE_NAME_y DIVISION BOROUGH  \
# 25605  LORIMER ST  Lorimer St          JM          JM      BMT      Bk
# 25606  LORIMER ST  Lorimer St          JM          JM      BMT      Bk
# 25607  LORIMER ST  Lorimer St          JM          JM      BMT      Bk
# 25608  LORIMER ST  Lorimer St          JM          JM      BMT      Bk
# 25609  LORIMER ST  Lorimer St          JM          JM      BMT      Bk
# 25610  LORIMER ST  Lorimer St          JM          JM      BMT      Bk
# 25611  LORIMER ST  Lorimer St          JM          JM      BMT      Bk
# 25612  LORIMER ST  Lorimer St          JM          JM      BMT      Bk
# 25613  LORIMER ST  Lorimer St          JM          JM      BMT      Bk
# 25614  LORIMER ST  Lorimer St          JM          JM      BMT      Bk
#
#        WEEKDAY     DESC  GTFS_LATITUDE  GTFS_LONGITUDE     LINE REMOTE BOOTH  \
# 25605        1  REGULAR      40.703869      -73.947408  Jamaica   R353  J005
# 25606        1  REGULAR      40.703869      -73.947408  Jamaica   R353  J005
# 25607        1  REGULAR      40.703869      -73.947408  Jamaica   R353  J005
# 25608        1  REGULAR      40.703869      -73.947408  Jamaica   R353  J005
# 25609        1  REGULAR      40.703869      -73.947408  Jamaica   R353  J005
# 25610        0  REGULAR      40.703869      -73.947408  Jamaica   R353  J005
# 25611        0  REGULAR      40.703869      -73.947408  Jamaica   R353  J005
# 25612        1  REGULAR      40.703869      -73.947408  Jamaica   R353  J005
# 25613        1  REGULAR      40.703869      -73.947408  Jamaica   R353  J005
# 25614        1  REGULAR      40.703869      -73.947408  Jamaica   R353  J005
#
#             SCP                      ID
# 25605  00-00-00  J005 - R353 - 00-00-00
# 25606  00-00-00  J005 - R353 - 00-00-00
# 25607  00-00-00  J005 - R353 - 00-00-00
# 25608  00-00-00  J005 - R353 - 00-00-00
# 25609  00-00-00  J005 - R353 - 00-00-00
# 25610  00-00-00  J005 - R353 - 00-00-00
# 25611  00-00-00  J005 - R353 - 00-00-00
# 25612  00-00-00  J005 - R353 - 00-00-00
# 25613  00-00-00  J005 - R353 - 00-00-00
# 25614  00-00-00  J005 - R353 - 00-00-00

# %% [markdown]
# #### Verify that we've still got a common set of stations (COMPLEX_IDs) between the two years

# %%
print(daily_per_complex_2019['COMPLEX_ID'].unique().shape)
print(daily_per_complex_2021['COMPLEX_ID'].unique().shape)
print(np.setdiff1d(daily_per_complex_2019['COMPLEX_ID'].unique(), daily_per_complex_2021['COMPLEX_ID'].unique()))
print(np.setdiff1d(daily_per_complex_2021['COMPLEX_ID'].unique(), daily_per_complex_2019['COMPLEX_ID'].unique()))
# Out:
# (420,)
# (420,)
# []
# []

# %% [markdown]
# ### 2g) Now add ZIPCODEs corresponding to the latitude/longitude information

# %%
# Just using WEEKDAY column as a placeholder during grouping; will drop immediately

locations = daily_per_complex_2019.groupby(['COMPLEX_ID', 'GTFS_LATITUDE', 'GTFS_LONGITUDE']) \
                                  ['WEEKDAY'].first().reset_index()

locations.drop(columns='WEEKDAY', inplace=True)
print(locations.shape)
locations
# Out:
# (421, 3)
#     COMPLEX_ID  GTFS_LATITUDE  GTFS_LONGITUDE
# 0            1      40.775036      -73.912034
# 1           10      40.759901      -73.984139
# 2          100      40.706870      -73.953431
# 3          101      40.708359      -73.957757
# 4          103      40.720280      -73.993915
# 5          107      40.706476      -74.011056
# 6          108      40.711396      -73.889601
# 7          109      40.706186      -73.895877
# 8          110      40.704423      -73.903077
# 9          111      40.702762      -73.907740
# 10         113      40.698664      -73.919711
# 11         114      40.697857      -73.927397
# 12         118      40.732849      -73.986122
# 13         119      40.730953      -73.981628
# 14         120      40.717304      -73.956872
# 15         122      40.714565      -73.944053
# 16         123      40.711926      -73.940670
# 17         124      40.707739      -73.939850
# 18         125      40.706152      -73.933147
# 19         126      40.706607      -73.922913
# 20         127      40.703811      -73.918425
# 21         129      40.695602      -73.904084
# 22          13      40.745494      -73.988691
# 23         130      40.688764      -73.904046
# 24         131      40.682829      -73.905249
# 25         133      40.675345      -73.903097
# 26         134      40.669367      -73.901975
# 27         135      40.664038      -73.900571
# 28         136      40.658733      -73.899232
# 29         137      40.650573      -73.899485
# 30         138      40.646654      -73.901850
# 31          14      40.741303      -73.989344
# 32         141      40.674772      -73.957624
# 33         143      40.868072      -73.919899
# 34         144      40.865491      -73.927271
# 35         145      40.859022      -73.934180
# 36         146      40.851695      -73.937969
# 37         147      40.847391      -73.939704
# 38         149      40.836013      -73.939892
# 39         150      40.830518      -73.941514
# 40         151      40.824783      -73.944216
# 41         152      40.817894      -73.947649
# 42         153      40.811109      -73.952343
# 43         154      40.805085      -73.954882
# 44         155      40.800603      -73.958161
# 45         156      40.796092      -73.961454
# 46         157      40.791642      -73.964696
# 47         158      40.785868      -73.968916
# 48         159      40.781433      -73.972143
# 49          16      40.730328      -73.992629
# 50         160      40.775594      -73.976410
# 51         162      40.762456      -73.985984
# 52         164      40.752287      -73.993391
# 53         165      40.745906      -73.998041
# 54         167      40.732338      -74.000495
# 55         168      40.726227      -74.003739
# 56         169      40.720824      -74.005229
# 57          17      40.724329      -73.997702
# 58         173      40.699337      -73.990531
# 59         175      40.688484      -73.985001
# 60         176      40.686113      -73.973946
# 61         177      40.683263      -73.965838
# 62         179      40.680438      -73.950426
# 63         180      40.679921      -73.940858
# 64         181      40.679364      -73.930729
# 65         182      40.678822      -73.920786
# 66         183      40.678340      -73.911946
# 67         185      40.674542      -73.896548
# 68         186      40.672710      -73.890358
# 69         187      40.674130      -73.880750
# 70         188      40.675377      -73.872106
# 71         189      40.677044      -73.865050
# 72         190      40.679371      -73.858992
# 73         191      40.679843      -73.851470
# 74         192      40.680429      -73.843853
# 75         193      40.681711      -73.837683
# 76         194      40.684331      -73.832163
# 77         195      40.685951      -73.825798
# 78         196      40.672097      -73.835919
# 79         197      40.668234      -73.834058
# 80         198      40.660476      -73.830301
# 81         199      40.608382      -73.815925
# 82         200      40.588034      -73.813641
# 83         201      40.585307      -73.820558
# 84         202      40.583209      -73.827559
# 85         203      40.580903      -73.835592
# 86         204      40.590927      -73.796924
# 87         205      40.592374      -73.788522
# 88         206      40.592943      -73.776013
# 89         207      40.595398      -73.768175
# 90         208      40.600066      -73.761353
# 91         209      40.603995      -73.755405
# 92         210      40.874811      -73.878855
# 93         211      40.873244      -73.887138
# 94         212      40.866978      -73.893509
# 95         213      40.861296      -73.897749
# 96         214      40.856093      -73.900741
# 97         215      40.850410      -73.905227
# 98         216      40.845900      -73.910136
# 99         217      40.839306      -73.913400
# 100        218      40.833771      -73.918440
# 101         22      40.707220      -74.013342
# 102        220      40.830135      -73.938209
# 103        221      40.754203      -73.942836
# 104        222      40.759145      -73.953260
# 105        223      40.764629      -73.966113
# 106        224      40.763972      -73.977450
# 107        225      40.758663      -73.981329
# 108        228      40.742878      -73.992821
# 109        231      40.718267      -73.993753
# 110        232      40.723402      -73.989938
# 111        234      40.713715      -73.990173
# 112        235      40.701397      -73.986751
# 113        236      40.686145      -73.990862
# 114        237      40.680303      -73.995048
# 115        238      40.673580      -73.995959
# 116        241      40.660365      -73.979493
# 117        242      40.650782      -73.975776
# 118        243      40.644041      -73.979678
# 119        244      40.636119      -73.978172
# 120        245      40.629755      -73.976971
# 121        246      40.625322      -73.976127
# 122        247      40.620769      -73.975264
# 123        248      40.615140      -73.974197
# 124        249      40.608944      -73.973022
# 125        250      40.603217      -73.972361
# 126        251      40.596063      -73.973357
# 127        252      40.589620      -73.974250
# 128        253      40.581011      -73.974574
# 129        254      40.712646      -73.783817
# 130        255      40.710470      -73.793604
# 131        256      40.707564      -73.803326
# 132        257      40.705460      -73.810708
# 133        258      40.709179      -73.820574
# 134        259      40.714441      -73.831008
# 135         26      40.690635      -73.981824
# 136        260      40.718331      -73.837324
# 137        261      40.721691      -73.844521
# 138        262      40.726523      -73.852719
# 139        263      40.729846      -73.861604
# 140        264      40.733106      -73.869229
# 141        265      40.737015      -73.877223
# 142        266      40.742454      -73.882017
# 143        268      40.749669      -73.898453
# 144        269      40.752885      -73.906006
# 145        270      40.756312      -73.913333
# 146        271      40.756879      -73.920740
# 147        272      40.752039      -73.928781
# 148        273      40.748973      -73.937243
# 149        276      40.760167      -73.975224
# 150        277      40.762862      -73.981637
# 151        278      40.702147      -73.801109
# 152        279      40.700486      -73.807969
# 153         28      40.677316      -73.983110
# 154        280      40.702566      -73.816859
# 155        282      40.744065      -73.949724
# 156        283      40.731352      -73.954449
# 157        284      40.724635      -73.951277
# 158        286      40.706092      -73.950308
# 159        287      40.700377      -73.950234
# 160        288      40.694568      -73.949046
# 161        289      40.689627      -73.953522
# 162        290      40.688873      -73.960070
# 163        291      40.688089      -73.966839
# 164        292      40.687119      -73.975375
# 165        293      40.889248      -73.898583
# 166        294      40.884667      -73.900870
# 167        295      40.878856      -73.904834
# 168        296      40.874561      -73.909831
# 169        297      40.869444      -73.915279
# 170        298      40.864621      -73.918822
# 171        299      40.860531      -73.925536
# 172          3      40.766779      -73.921479
# 173         30      40.665414      -73.992872
# 174        300      40.855225      -73.929412
# 175        303      40.834041      -73.944890
# 176        304      40.826551      -73.950360
# 177        305      40.822008      -73.953676
# 178        306      40.815581      -73.958372
# 179        307      40.807722      -73.964110
# 180        308      40.803967      -73.966847
# 181        309      40.799446      -73.968379
# 182         31      40.660397      -73.998091
# 183        310      40.793919      -73.972323
# 184        311      40.788644      -73.976218
# 185        312      40.783934      -73.979917
# 186        313      40.778453      -73.981970
# 187        314      40.773440      -73.982209
# 188        316      40.761728      -73.983849
# 189        318      40.750373      -73.991057
# 190        319      40.747215      -73.993365
# 191         32      40.655144      -74.003549
# 192        320      40.744081      -73.995657
# 193        321      40.741040      -73.997871
# 194        323      40.733422      -74.002906
# 195        324      40.728251      -74.005367
# 196        325      40.722854      -74.006277
# 197        326      40.719318      -74.006886
# 198        327      40.715478      -74.009266
# 199        328      40.711835      -74.012188
# 200        329      40.707513      -74.013783
# 201         33      40.648939      -74.010006
# 202        333      40.706821      -74.009100
# 203        334      40.697466      -73.993086
# 204        336      40.690545      -73.985065
# 205        337      40.688246      -73.980492
# 206        339      40.680829      -73.975098
# 207         34      40.645069      -74.014034
# 208        340      40.675235      -73.971046
# 209        341      40.671987      -73.964375
# 210        343      40.669847      -73.950466
# 211        344      40.669399      -73.942161
# 212        345      40.668897      -73.932942
# 213        346      40.664717      -73.922610
# 214        347      40.661453      -73.916327
# 215        348      40.662549      -73.908946
# 216        349      40.663515      -73.902447
# 217         35      40.641362      -74.017881
# 218        350      40.664635      -73.894895
# 219        351      40.665449      -73.889395
# 220        352      40.666235      -73.884079
# 221        353      40.667883      -73.950683
# 222        354      40.662742      -73.950850
# 223        355      40.656652      -73.950200
# 224        356      40.650843      -73.949575
# 225        357      40.645098      -73.948959
# 226        358      40.639967      -73.948411
# 227        359      40.632836      -73.947642
# 228         36      40.634967      -74.023377
# 229        360      40.852462      -73.828121
# 230        361      40.846810      -73.832569
# 231        362      40.843863      -73.836322
# 232        363      40.839892      -73.842952
# 233        364      40.836488      -73.847036
# 234        365      40.834255      -73.851222
# 235        366      40.833226      -73.860816
# 236        367      40.831509      -73.867618
# 237        368      40.829521      -73.874516
# 238        369      40.828584      -73.879159
# 239         37      40.629742      -74.025510
# 240        370      40.826525      -73.886283
# 241        371      40.820948      -73.890549
# 242        372      40.816104      -73.896435
# 243        373      40.812118      -73.904098
# 244        374      40.808719      -73.907657
# 245        375      40.805368      -73.914042
# 246        376      40.807566      -73.919240
# 247        377      40.810476      -73.926138
# 248        378      40.886037      -73.878751
# 249        379      40.879750      -73.884655
# 250         38      40.622687      -74.028398
# 251        380      40.873412      -73.890064
# 252        381      40.867760      -73.897174
# 253        382      40.862803      -73.901034
# 254        383      40.858407      -73.903879
# 255        384      40.853453      -73.907684
# 256        385      40.848480      -73.911794
# 257        386      40.844434      -73.914685
# 258        387      40.840075      -73.917791
# 259        388      40.835537      -73.921400
# 260         39      40.616622      -74.030876
# 261        391      40.813224      -73.929849
# 262        392      40.804138      -73.937594
# 263        393      40.798629      -73.941617
# 264        394      40.795020      -73.944250
# 265        395      40.790600      -73.947478
# 266        396      40.785672      -73.951070
# 267        397      40.779492      -73.955589
# 268        398      40.773620      -73.959874
# 269        399      40.768141      -73.963870
# 270          4      40.761820      -73.925508
# 271        403      40.746081      -73.982076
# 272        404      40.743070      -73.984264
# 273        405      40.739864      -73.986599
# 274        407      40.730054      -73.991070
# 275        409      40.722301      -73.997141
# 276         41      40.677050      -73.972367
# 277        413      40.707557      -74.011862
# 278        414      40.704817      -74.014065
# 279        416      40.903125      -73.850620
# 280        417      40.898379      -73.854376
# 281        418      40.893193      -73.857473
# 282        419      40.888022      -73.860341
# 283         42      40.661614      -73.962246
# 284        420      40.883895      -73.862633
# 285        421      40.877850      -73.866256
# 286        422      40.871356      -73.867164
# 287        423      40.865462      -73.867352
# 288        424      40.857192      -73.867615
# 289        425      40.848828      -73.868457
# 290        426      40.841894      -73.873488
# 291        427      40.840295      -73.880049
# 292        428      40.837288      -73.887734
# 293        429      40.829993      -73.891865
# 294         43      40.655292      -73.961495
# 295        430      40.824073      -73.893064
# 296        431      40.822181      -73.896736
# 297        432      40.819585      -73.901770
# 298        433      40.816490      -73.907807
# 299        434      40.816109      -73.917757
# 300        436      40.823880      -73.936470
# 301        437      40.820421      -73.936245
# 302        438      40.814229      -73.940770
# 303        439      40.807754      -73.945495
# 304         44      40.650527      -73.962982
# 305        440      40.802098      -73.949625
# 306        441      40.799075      -73.951822
# 307        442      40.888300      -73.830834
# 308        443      40.878663      -73.838591
# 309        444      40.869526      -73.846384
# 310        445      40.858985      -73.855359
# 311        446      40.854364      -73.860495
# 312        447      40.759600      -73.830030
# 313        448      40.754622      -73.845625
# 314        449      40.751730      -73.855334
# 315         45      40.644031      -73.964492
# 316        450      40.749865      -73.862700
# 317        451      40.749145      -73.869527
# 318        452      40.748408      -73.876613
# 319        453      40.747659      -73.883697
# 320        455      40.746325      -73.896403
# 321        456      40.745630      -73.902984
# 322        457      40.744149      -73.912549
# 323        458      40.743132      -73.918435
# 324        459      40.743781      -73.924016
# 325         46      40.640927      -73.963891
# 326        460      40.744587      -73.930997
# 327        461      40.750582      -73.940202
# 328        463      40.742216      -73.948916
# 329        464      40.742626      -73.953581
# 330         47      40.635082      -73.962793
# 331        471      40.755882      -74.001910
# 332        475      40.784318      -73.947152
# 333        476      40.777891      -73.951787
# 334        477      40.768799      -73.958424
# 335         48      40.629270      -73.961639
# 336         49      40.625039      -73.960803
# 337          5      40.756804      -73.929575
# 338         50      40.617618      -73.959399
# 339         51      40.608670      -73.957734
# 340         52      40.599300      -73.955929
# 341         53      40.595246      -73.955161
# 342         54      40.586896      -73.954155
# 343         55      40.577621      -73.961376
# 344         56      40.576312      -73.968501
# 345         57      40.576127      -73.975939
# 346         58      40.577422      -73.981233
# 347         59      40.646292      -73.994324
# 348          6      40.752882      -73.932755
# 349         60      40.640914      -73.994304
# 350        601      40.737826      -74.000201
# 351        602      40.735736      -73.990568
# 352        603      40.818375      -73.927351
# 353        604      40.827905      -73.925651
# 354        605      40.840556      -73.940133
# 355        606      40.747023      -73.945264
# 356        607      40.749719      -73.987823
# 357        608      40.670272      -73.989779
# 358        609      40.753821      -73.981963
# 359        609      40.754222      -73.984569
# 360         61      40.636260      -73.994791
# 361        610      40.751776      -73.976848
# 362        611      40.757308      -73.989735
# 363        612      40.757107      -73.971920
# 364        613      40.762526      -73.967967
# 365        614      40.768247      -73.981929
# 366        615      40.626472      -73.996895
# 367        616      40.746644      -73.891338
# 368        617      40.684359      -73.977666
# 369        618      40.739777      -74.002578
# 370        619      40.725915      -73.994659
# 371         62      40.631435      -73.995476
# 372        620      40.693219      -73.989998
# 373        621      40.678334      -73.905316
# 374        622      40.713065      -74.004131
# 375        623      40.719527      -74.001775
# 376        624      40.713051      -74.008811
# 377        625      40.718315      -73.987437
# 378        626      40.670343      -73.959245
# 379        627      40.681380      -73.956848
# 380        628      40.710197      -74.007691
# 381        629      40.712792      -73.951418
# 382        630      40.699430      -73.912385
# 383        635      40.703087      -74.012994
# 384        636      40.692180      -73.985942
# 385         64      40.619589      -73.998864
# 386         65      40.613501      -74.000610
# 387         66      40.607954      -74.001736
# 388         67      40.604556      -73.998168
# 389         68      40.601875      -73.993728
# 390         69      40.597704      -73.986829
# 391         70      40.588841      -73.983765
# 392         71      40.635064      -74.011719
# 393         72      40.631386      -74.005351
# 394         74      40.620671      -73.990414
# 395         75      40.617410      -73.985026
# 396         76      40.611815      -73.981848
# 397         77      40.603923      -73.980353
# 398         78      40.597473      -73.979137
# 399         79      40.592721      -73.978230
# 400          8      40.764811      -73.973347
# 401         80      40.700492      -73.828294
# 402         81      40.697418      -73.836345
# 403         82      40.695178      -73.844330
# 404         83      40.693879      -73.851576
# 405         84      40.692435      -73.860010
# 406         85      40.691324      -73.867139
# 407         86      40.689941      -73.872550
# 408         87      40.683194      -73.873785
# 409         88      40.681410      -73.880039
# 410         89      40.679947      -73.884639
# 411          9      40.764664      -73.980658
# 412         90      40.678024      -73.891688
# 413         91      40.676992      -73.898654
# 414         93      40.682893      -73.910456
# 415         94      40.686370      -73.916559
# 416         95      40.689630      -73.922270
# 417         96      40.693342      -73.928814
# 418         97      40.697207      -73.935657
# 419         98      40.700260      -73.941126
# 420         99      40.703869      -73.947408

# %%
# This implementation is based on the info posted here:
#  https://stackoverflow.com/questions/66144427/how-do-i-get-zipcodes-from-longitude-and-latitude-on-python

# geo = geopy.Nominatim(user_agent="check_1")

def get_zipcode(df):
    geo = geopy.Nominatim(user_agent="check_1")
    try:
        return geo.reverse('{}, {}'.format(df['GTFS_LATITUDE'], df['GTFS_LONGITUDE'])) \
                                   .raw['address']['postcode']
    except:
        return np.nan

locations['ZIPCODE'] = locations.apply(get_zipcode, axis=1)
    
# locations['ZIPCODE'] = locations.apply(lambda x: geo.reverse('{}, {}'
#                                 .format(x['GTFS_LATITUDE'], x['GTFS_LONGITUDE'])) \
#                                 .raw['address']['postcode'], axis=1)

# geo.reverse("{}, {}".format(40.641362, -74.017881)).raw['address']['neighbourhood']

# %%
print(locations.shape)
display(locations[locations['ZIPCODE'].isna()])
# Out:
# (421, 4)
#     COMPLEX_ID  GTFS_LATITUDE  GTFS_LONGITUDE ZIPCODE
# 186        313      40.778453       -73.98197     NaN

# %%
# Not sure why the coordinates above failed in Geopy; manual lookup reveals the ZIPCODE to be 10023

locations.loc[186, 'ZIPCODE'] = 10023
display(locations[locations['ZIPCODE'].isna()])
# Out:
# Empty DataFrame
# Columns: [COMPLEX_ID, GTFS_LATITUDE, GTFS_LONGITUDE, ZIPCODE]
# Index: []

# %% [markdown]
# #### Strip off the -xxxx extension present in some of the ZIPCODEs

# %%
locations['ZIPCODE'] = locations['ZIPCODE'].apply(lambda x: str(x).split(sep = '-')[0])

locations[locations['ZIPCODE'].map(len) > 5]
# Out:
#     COMPLEX_ID  GTFS_LATITUDE  GTFS_LONGITUDE ZIPCODE
# 313        448      40.754622      -73.845625  111354

# %%
# Geopy fails again: Manual lookup of the coordinates above reveals ZIPCODE to be 11368

locations.loc[313, 'ZIPCODE'] = 11368
locations.loc[313, 'ZIPCODE']
# Out:
# 11368

# %%
# Another known error (don't worry, Geopy - I still like you better than the GoogleMaps API)

locations[locations['ZIPCODE'] == '11227']
# Out:
#     COMPLEX_ID  GTFS_LATITUDE  GTFS_LONGITUDE ZIPCODE
# 205        337      40.688246      -73.980492   11227

# %%
# 11227 is not a valid ZIPCODE; manual lookup of the coordinates above reveals ZIPCODE to be 11217

locations.loc[205, 'ZIPCODE'] = 11217
locations.loc[205, 'ZIPCODE']
# Out:
# 11217

# %% [markdown]
# #### Add ZIPCODE column to daily_per_complex datasets for both years

# %%
print(daily_per_complex_2019.shape)
daily_per_complex_2019 =daily_per_complex_2019.merge(right=locations, 
                                                     how='left', 
                                                     on=['COMPLEX_ID', 'GTFS_LATITUDE', 'GTFS_LONGITUDE'])
print(daily_per_complex_2019.shape)
# Out:
# (25567, 19)
# (25567, 20)

# %%
daily_per_complex_2019.sample(10)
# Out:
#       COMPLEX_ID        DATE  NET_DAILY_STATION_ENTRIES        STATION_x  \
# 23585         66  2019-06-22                       3915           18 AVE
# 21236          6  2019-05-22                       2724     BEEBE-39 AVE
# 20551          5  2019-05-08                       6216  WASHINGTON-36 A
# 25559         99  2019-06-23                       3647       LORIMER ST
# 6720         232  2019-05-20                      13551            2 AVE
# 18215        433  2019-06-18                       5163      JACKSON AVE
# 1959         141  2019-05-15                       1667       PARK PLACE
# 9690         287  2019-05-01                       1741     FLUSHING AVE
# 10185        295  2019-05-08                       9869           231 ST
# 10295        296  2019-06-26                       4900  MARBLE HILL-225
#
#              STATION_y             STOP_NAME LINE_NAME_x LINE_NAME_y DIVISION  \
# 23585            18 AV                 18 Av           D           D      BMT
# 21236            39 AV                 39 Av          NQ         NQW      BMT
# 20551            36 AV                 36 Av          NQ         NQW      BMT
# 25559       LORIMER ST            Lorimer St          JM          JM      BMT
# 6720              2 AV                  2 Av           F           F      IND
# 18215       JACKSON AV            Jackson Av          25          25      IRT
# 1959        PARK PLACE               Park Pl           S           S      BMT
# 9690       FLUSHING AV           Flushing Av           G           G      IND
# 10185           231 ST                231 St           1           1      IRT
# 10295  MARBLE HILL-225  Marble Hill - 225 St           1           1      IRT
#
#       BOROUGH  WEEKDAY     DESC  GTFS_LATITUDE  GTFS_LONGITUDE  \
# 23585      Bk        0  REGULAR      40.607954      -74.001736
# 21236       Q        1  REGULAR      40.752882      -73.932755
# 20551       Q        1  REGULAR      40.756804      -73.929575
# 25559      Bk        0  REGULAR      40.703869      -73.947408
# 6720        M        1  REGULAR      40.723402      -73.989938
# 18215      Bx        1  REGULAR      40.816490      -73.907807
# 1959       Bk        1  REGULAR      40.674772      -73.957624
# 9690       Bk        1  REGULAR      40.700377      -73.950234
# 10185      Bx        1  REGULAR      40.878856      -73.904834
# 10295       M        1  REGULAR      40.874561      -73.909831
#
#                           LINE REMOTE BOOTH       SCP                      ID  \
# 23585                 West End   R372  E012  00-00-00  E012 - R372 - 00-00-00
# 21236                  Astoria   R090  R510  00-00-00  R510 - R090 - 00-00-00
# 20551                  Astoria   R091  R511  00-00-00  R511 - R091 - 00-00-00
# 25559                  Jamaica   R353  J005  00-00-00  J005 - R353 - 00-00-00
# 6720           6th Av - Culver   R300  N523  00-00-00  N523 - R300 - 00-00-00
# 18215  Lenox - White Plains Rd   R405  R312  00-00-00  R312 - R405 - 00-00-00
# 1959          Franklin Shuttle   R411  B009  00-00-00  B009 - R411 - 00-00-00
# 9690                 Crosstown   R316  N414  00-00-00  N414 - R316 - 00-00-00
# 10185           Broadway - 7Av   R040  R194  00-00-00  R194 - R040 - 00-00-00
# 10295           Broadway - 7Av   R039  R192  00-00-00  R192 - R039 - 00-00-00
#
#       ZIPCODE
# 23585   11214
# 21236   11101
# 20551   11106
# 25559   11207
# 6720    10003
# 18215   10459
# 1959    11233
# 9690    11211
# 10185   10463
# 10295   10463

# %% [markdown]
# #### Double check for NaNs, then save daily_per_complex_2019 to file (can reload below and avoid running all of above in future)

# %%
daily_per_complex_2019[daily_per_complex_2019.isna().any(axis=1)].shape[0]
# Out:
# 0

# %%
# Okay, write this dataframe to file and then we don't have to run any of the above again!

daily_per_complex_2019.to_csv('daily_per_complex_2019.csv', index=False)

# %% [markdown]
# ##### Repeat the above steps for the 2021 data

# %%
# Add ZIPCODE column

print(daily_per_complex_2021.shape)
daily_per_complex_2021 =daily_per_complex_2021.merge(right=locations, 
                                                     how='left', 
                                                     on=['COMPLEX_ID', 'GTFS_LATITUDE', 'GTFS_LONGITUDE'])
print(daily_per_complex_2021.shape)
# Out:
# (25615, 19)
# (25615, 20)

# %%
daily_per_complex_2021.sample(10)
# Out:
#       COMPLEX_ID        DATE  NET_DAILY_STATION_ENTRIES       STATION_x  \
# 17469        422  2021-05-25                       1305       BURKE AVE
# 18483        439  2021-05-02                       3657  149 ST-GR CONC
# 21128         58  2021-05-24                       5847   STILLWELL AVE
# 7644         250  2021-05-20                       1713   KINGS HIGHWAY
# 18425        438  2021-05-05                       4865          135 ST
# 20092        464  2021-05-25                       4869  VERNON/JACKSON
# 13501        353  2021-05-21                       1424    PRESIDENT ST
# 24429         80  2021-05-31                        619          121 ST
# 3223         164  2021-06-21                      22448  34 ST-PENN STA
# 4915         198  2021-06-05                        917  HOWARD BCH-JFK
#
#              STATION_y                    STOP_NAME LINE_NAME_x LINE_NAME_y  \
# 17469         BURKE AV                     Burke Av          25          25
# 18483   149/GRAND CONC                       125 St         245         245
# 21128  CONEY IS-STILLW  Coney Island - Stillwell Av        DFNQ        DFNQ
# 7644         KINGS HWY                    Kings Hwy           F           F
# 18425           135 ST                       135 St          23          23
# 20092   VERNON-JACKSON     Vernon Blvd - Jackson Av           7           7
# 13501     PRESIDENT ST                 President St          25          25
# 24429           121 ST                       121 St          JZ          JZ
# 3223    34 ST-PENN STA         34 St - Penn Station         ACE         ACE
# 4915    HOWARD BCH JFK   Howard Beach - JFK Airport           A           A
#
#       DIVISION BOROUGH  WEEKDAY     DESC  GTFS_LATITUDE  GTFS_LONGITUDE  \
# 17469      IRT      Bx        1  REGULAR      40.871356      -73.867164
# 18483      IRT       M        0  REGULAR      40.807754      -73.945495
# 21128      BMT      Bk        1  REGULAR      40.577422      -73.981233
# 7644       IND      Bk        1  REGULAR      40.603217      -73.972361
# 18425      IRT       M        1  REGULAR      40.814229      -73.940770
# 20092      IRT       Q        1  REGULAR      40.742626      -73.953581
# 13501      IRT      Bk        1  REGULAR      40.667883      -73.950683
# 24429      BMT       Q        1  REGULAR      40.700492      -73.828294
# 3223       IND       M        1  REGULAR      40.752287      -73.993391
# 4915       IND       Q        0  REGULAR      40.660476      -73.830301
#
#                                            LINE REMOTE BOOTH       SCP  \
# 17469                   Lenox - White Plains Rd   R363  R330  00-00-00
# 18483                   Lenox - White Plains Rd   R205  R260  01-05-00
# 21128  Sea Beach / West End / Culver / Brighton   R151  G001  00-00-00
# 7644                            6th Av - Culver   R130  N557  00-00-00
# 18425                   Lenox - White Plains Rd   R207  R306  00-00-00
# 20092                                  Flushing   R276  R504  00-00-00
# 13501                                  Nostrand   R277  R635  00-00-00
# 24429                                   Jamaica   R009  J037  00-00-00
# 3223                         8th Av - Fulton St   R012  N067  00-00-00
# 4915                                   Rockaway   R414  N182  00-00-00
#
#                            ID ZIPCODE
# 17469  R330 - R363 - 00-00-00   10467
# 18483  R260 - R205 - 01-05-00   10027
# 21128  G001 - R151 - 00-00-00   11224
# 7644   N557 - R130 - 00-00-00   11223
# 18425  R306 - R207 - 00-00-00   10030
# 20092  R504 - R276 - 00-00-00   11101
# 13501  R635 - R277 - 00-00-00   11225
# 24429  J037 - R009 - 00-00-00   11418
# 3223   N067 - R012 - 00-00-00   10001
# 4915   N182 - R414 - 00-00-00   11414

# %% [markdown]
# #### Double check for NaNs, then save daily_per_complex_2021 to file (can reload below and avoid running all of above in future)

# %%
daily_per_complex_2021[daily_per_complex_2021.isna().any(axis=1)].shape[0]
# Out:
# 0

# %%
# Okay, write this dataframe to file and then we don't have to run any of the above again!

daily_per_complex_2021.to_csv('daily_per_complex_2021.csv', index=False)

# %% [markdown]
# ## Move to Project_Notebook_Visualizations & start by loading in the 2 datasets just saved!
